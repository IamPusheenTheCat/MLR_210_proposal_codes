# %%
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from rdkit.Chem import AllChem, MolFromSmiles
from rdkit.Chem.SaltRemover import SaltRemover
from rdkit.Chem import DataStructs
from rdkit import Chem
from rxnfp.tokenization import get_default_tokenizer, SmilesTokenizer
from rdkit.Chem import rdChemReactions
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
def combnfeats_MLR_evaby_crossval_metric(feats, df_x, df_y, n_fold, model, metric, score):
    print('----------Linear regression of n features evaby crossval starts----------')
    """_Screen and select Well behalved features from of a list of 3 features_
    Evaluated by sum of 5-fold cross validation.
    This is because just taking consideration of one result from one MLR can cause lost of important features due to randomness.
    If the displaied R^2 is also high, there's a higher chance that these features are of high predictive value.
    If the displaied R^2 is 0/-/unexplainable, it can be due to accident, and further cross-validation can verify their importance.
    """
    # Create a list to store features with high, medium, or low score
    List_cvd_3 = [] 
    List_cvd_2 = [] 
    List_cvd_0 = [] 
    # for r2 and explained variance the closer to 1 the better
    if metric == 'r2' or metric == 'explained_variance':
        sum_score = [score*1,score*0.8,score*0.5]
    # for nmae, nrmse and max error, the closer to 0 the better, therefore we need to readjust the rank
    elif metric == 'neg_mean_absolute_error' or metric == 'neg_root_mean_squared_error' or metric == 'max_error':
        sum_score = [score/1,score/0.8,score/0.5]
    
    # Three different ranks for high, medium and low, based on the score we imputed
    rank_score = sorted(sum_score,reverse=True)
    score_1 = rank_score[0]
    score_2 = rank_score[1]
    score_3 = rank_score[2]
    
    for m in feats:
        fts = feats.index(m)
        df_repeated_cv_x = df_x
        df_repeated_cv_y = df_y
        sum_cvd = 0
        for k in range(0,n_fold):
            # Shuffle the data
            df_repeated_cv_x = df_repeated_cv_x.sample(frac=1,random_state=k)
            df_nf = df_repeated_cv_x[list(feats[fts])]
            df_repeated_cv_y = df_repeated_cv_y.sample(frac=1,random_state=k)
            cvd_scores = cross_val_score(model, df_nf, df_repeated_cv_y, cv=5,scoring= metric)
            sum_cvd += sum(cvd_scores)
        # Calculate average R^2
        avg_cvd = sum_cvd/n_fold/5
        if avg_cvd >= score_1: 
            print('Significant!')
            print(f'For features {feats[fts]} with {metric} = {avg_cvd}')
            List_cvd_3.append(feats[fts]) 
        elif avg_cvd >=score_2:
            List_cvd_2.append(feats[fts])
        elif avg_cvd >=score_3:
            List_cvd_0.append(feats[fts])
        #print(f'For features {feats[fts]} with {metric} = {avg_cvd}'+'cvd_scores = ',cvd_scores,sum_cvd,avg_cvd)   
    return List_cvd_3,List_cvd_2,List_cvd_0

# %%
# Data processing
df_origin = pd.read_excel('Afterscreen.xlsx', sheet_name='Result2')
df_origin = df_origin.sample(frac=1,random_state=42)
# Reindex the data
df_origin = df_origin.set_index('ID')


df_x = df_origin.drop(columns = ['Yield-avg','ligand','buch','Unnamed: 0','SMILES'])
df_y = df_origin[['Yield-avg']]
# standardize
scaler = StandardScaler()
df_x=pd.DataFrame(scaler.fit_transform(df_x),index=df_x.index, columns=df_x.columns)
df_std_origin = df_x
zero_std_cols = df_x.columns[df_x.std() == 0]
df_x=df_x[df_x.columns.difference(zero_std_cols)]
print (f"Dropping {len(zero_std_cols)} zero-variance features {zero_std_cols}")
# Out:
# Dropping 4 zero-variance features Index(['x119', 'x122', 'x144', 'x147'], dtype='object')

# %%
high_corr_feats = []
selected_feats = ['x1', 'x14', 'x46', 'x56','x100', 'x184']
# For i in selected_feats, find the features with high correlation coefficient (>0.7) 
# from high_corr (corr matrix from earlier), and add them to the list
corr = df_origin.corr(method='pearson')
"""
# select 5 top features corr to Yield-avg
corr = corr.sort_values('Yield-avg',ascending=False)
corr_yield = corr['Yield-avg']
corr1 = corr_yield[:5]
corr2 = corr_yield[-5:]
list_corr_yield1 = corr1.index.tolist()
list_corr_yield2 = corr2.index.tolist()
# combine lists
list_corr_yield =   list_corr_yield1 + list_corr_yield2
print(list_corr_yield)
"""

corr = df_origin.corr(method='pearson')
# Iterate over selected features
for selected_feat in selected_feats:
    # Check if the selected feature is in the DataFrame
    if selected_feat in corr.columns:
        # Get all features with correlation > 0.7 with the selected feature
        correlated_feats = corr.index[abs(corr[selected_feat]) > 0.7].tolist()
        # Remove the selected feature from the list
        correlated_feats.remove(selected_feat)
        # Extend the high_corr_feats list
        high_corr_feats.extend(correlated_feats)

# Remove duplicates
high_corr_feats = list(set(high_corr_feats))

print(len(high_corr_feats))
# Out:
# 45

# %%
# export to txt
with open('high_corr_feats.txt', 'w') as f:
    for item in high_corr_feats:
        f.write("%s\n" % item)

# %%
combined_feats = selected_feats + high_corr_feats
df_x = df_x[combined_feats]

# %% [markdown]
# # Combination of 3 features - after adding back correlated feats

# %%
print('Shape of input:',df_x.shape,'\nShape of output:' ,df_y.shape)
df_x = df_x.astype(float)
df_y = df_y.astype(float)
# Out:
# Shape of input: (35, 51)
# Shape of output: (35, 1)

# %%
from itertools import combinations
feats = list(combinations(high_corr_feats, 3))
len(feats)
# Out:
# 14190

# %%
model = LinearRegression()
#Screening of features, report significant when score of 5-fold crossval is greater than 0
List_cvd_3_r2,List_cvd_2_r2,List_cvd_0_r2 = combnfeats_MLR_evaby_crossval_metric(feats,df_x,df_y,5,model,'r2',0.1)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x49', 'x27') with r2 = 0.14367466522539252
# Significant!
# For features ('x186', 'x49', 'x23') with r2 = 0.23145111964257464
# Significant!
# For features ('x186', 'x32', 'x23') with r2 = 0.3349289341776286
# Significant!
# For features ('x186', 'x8', 'x27') with r2 = 0.15062580358028313
# Significant!
# For features ('x186', 'x8', 'x23') with r2 = 0.28708936585492706
# Significant!
# For features ('x186', 'x2', 'x23') with r2 = 0.1989431688803517
# Significant!
# For features ('x186', 'x2', 'x33') with r2 = 0.24650188993020605
# Significant!
# For features ('x186', 'x2', 'x102') with r2 = 0.14142741498596006
# Significant!
# For features ('x186', 'x2', 'x159') with r2 = 0.101802269653949
# Significant!
# For features ('x186', 'x4', 'x23') with r2 = 0.2320386972402802
# Significant!
# For features ('x186', 'x27', 'x99') with r2 = 0.17074327166445993
# Significant!
# For features ('x186', 'x27', 'x50') with r2 = 0.16513601925610252
# Significant!
# For features ('x186', 'x27', 'x188') with r2 = 0.12381937678855995
# Significant!
# For features ('x186', 'x27', 'x45') with r2 = 0.1300552854224229
# Significant!
# For features ('x186', 'x27', 'x42') with r2 = 0.13114294676673652
# Significant!
# For features ('x186', 'x27', 'x193') with r2 = 0.11552578177412094
# Significant!
# For features ('x186', 'x27', 'x23') with r2 = 0.1750718922106912
# Significant!
# For features ('x186', 'x27', 'x149') with r2 = 0.13721654062077754
# Significant!
# For features ('x186', 'x27', 'x5') with r2 = 0.12349992470549061
# Significant!
# For features ('x186', 'x27', 'x39') with r2 = 0.11660233200727496
# Significant!
# For features ('x186', 'x27', 'x41') with r2 = 0.11923995193932121
# Significant!
# For features ('x186', 'x27', 'x33') with r2 = 0.15527248076622685
# Significant!
# For features ('x186', 'x27', 'x148') with r2 = 0.12183521169280484
# Significant!
# For features ('x186', 'x27', 'x194') with r2 = 0.10984372451299707
# Significant!
# For features ('x186', 'x27', 'x102') with r2 = 0.22013007568686774
# Significant!
# For features ('x186', 'x27', 'x150') with r2 = 0.13349150107680927
# Significant!
# For features ('x186', 'x27', 'x98') with r2 = 0.18098346364786216
# Significant!
# For features ('x186', 'x27', 'x162') with r2 = 0.10513961133443708
# Significant!
# For features ('x186', 'x27', 'x159') with r2 = 0.15024363628928689
# Significant!
# For features ('x186', 'x27', 'x195') with r2 = 0.12603692845220157
# Significant!
# For features ('x186', 'x27', 'x152') with r2 = 0.13624088293832173
# Significant!
# For features ('x186', 'x27', 'x158') with r2 = 0.15526764166207968
# Significant!
# For features ('x186', 'x27', 'x160') with r2 = 0.12222290602426492
# Significant!
# For features ('x186', 'x27', 'x213') with r2 = 0.12390382371667541
# Significant!
# For features ('x186', 'x27', 'x3') with r2 = 0.1304088118877209
# Significant!
# For features ('x186', 'x27', 'x48') with r2 = 0.12793349105794224
# Significant!
# For features ('x186', 'x99', 'x23') with r2 = 0.3543929206383005
# Significant!
# For features ('x186', 'x50', 'x23') with r2 = 0.2834044332150131
# Significant!
# For features ('x186', 'x188', 'x23') with r2 = 0.22051891573893587
# Significant!
# For features ('x186', 'x45', 'x23') with r2 = 0.2664882286123808
# Significant!
# For features ('x186', 'x42', 'x23') with r2 = 0.22451320960181181
# Significant!
# For features ('x186', 'x193', 'x23') with r2 = 0.21438733932423099
# Significant!
# For features ('x186', 'x71', 'x23') with r2 = 0.13162228737956966
# Significant!
# For features ('x186', 'x23', 'x149') with r2 = 0.2450545169352593
# Significant!
# For features ('x186', 'x23', 'x6') with r2 = 0.13628628609385962
# Significant!
# For features ('x186', 'x23', 'x5') with r2 = 0.25441811024239447
# Significant!
# For features ('x186', 'x23', 'x39') with r2 = 0.25334351860450555
# Significant!
# For features ('x186', 'x23', 'x175') with r2 = 0.2081122435553957
# Significant!
# For features ('x186', 'x23', 'x67') with r2 = 0.1525112398230179
# Significant!
# For features ('x186', 'x23', 'x41') with r2 = 0.14220305260055183
# Significant!
# For features ('x186', 'x23', 'x33') with r2 = 0.4210853744966691
# Significant!
# For features ('x186', 'x23', 'x148') with r2 = 0.22776890245633313
# Significant!
# For features ('x186', 'x23', 'x194') with r2 = 0.20976697967169705
# Significant!
# For features ('x186', 'x23', 'x102') with r2 = 0.4208526094565722
# Significant!
# For features ('x186', 'x23', 'x150') with r2 = 0.22837869983267858
# Significant!
# For features ('x186', 'x23', 'x98') with r2 = 0.3727184311216502
# Significant!
# For features ('x186', 'x23', 'x162') with r2 = 0.33125116368269747
# Significant!
# For features ('x186', 'x23', 'x159') with r2 = 0.36175478776445813
# Significant!
# For features ('x186', 'x23', 'x195') with r2 = 0.22167225693186848
# Significant!
# For features ('x186', 'x23', 'x58') with r2 = 0.1577456005138703
# Significant!
# For features ('x186', 'x23', 'x9') with r2 = 0.17129217016042658
# Significant!
# For features ('x186', 'x23', 'x152') with r2 = 0.2319622698974671
# Significant!
# For features ('x186', 'x23', 'x43') with r2 = 0.23699673302435195
# Significant!
# For features ('x186', 'x23', 'x173') with r2 = 0.2858175221688084
# Significant!
# For features ('x186', 'x23', 'x158') with r2 = 0.2925495726807194
# Significant!
# For features ('x186', 'x23', 'x177') with r2 = 0.26986236168171224
# Significant!
# For features ('x186', 'x23', 'x63') with r2 = 0.157872298098944
# Significant!
# For features ('x186', 'x23', 'x160') with r2 = 0.2434825741196359
# Significant!
# For features ('x186', 'x23', 'x213') with r2 = 0.21885718870953702
# Significant!
# For features ('x186', 'x23', 'x3') with r2 = 0.17869056453282944
# Significant!
# For features ('x186', 'x23', 'x7') with r2 = 0.2541838592292204
# Significant!
# For features ('x186', 'x23', 'x48') with r2 = 0.21383767928102443
# Significant!
# For features ('x49', 'x32', 'x27') with r2 = 0.10153366309385306
# Significant!
# For features ('x49', 'x32', 'x23') with r2 = 0.30629825487618045
# Significant!
# For features ('x49', 'x8', 'x27') with r2 = 0.13723205294934182
# Significant!
# For features ('x49', 'x8', 'x23') with r2 = 0.20510823539078524
# Significant!
# For features ('x49', 'x8', 'x33') with r2 = 0.18004127312130372
# Significant!
# For features ('x49', 'x2', 'x23') with r2 = 0.12254115252644174
# Significant!
# For features ('x49', 'x2', 'x33') with r2 = 0.21356655099113406
# Significant!
# For features ('x49', 'x4', 'x27') with r2 = 0.1327186582869865
# Significant!
# For features ('x49', 'x4', 'x23') with r2 = 0.18887320323955784
# Significant!
# For features ('x49', 'x27', 'x99') with r2 = 0.1858531351422789
# Significant!
# For features ('x49', 'x27', 'x50') with r2 = 0.13643360719563596
# Significant!
# For features ('x49', 'x27', 'x45') with r2 = 0.12425730686404753
# Significant!
# For features ('x49', 'x27', 'x6') with r2 = 0.13068732841094782
# Significant!
# For features ('x49', 'x27', 'x5') with r2 = 0.15452489819737636
# Significant!
# For features ('x49', 'x27', 'x39') with r2 = 0.13571396453851328
# Significant!
# For features ('x49', 'x27', 'x67') with r2 = 0.10780698498394412
# Significant!
# For features ('x49', 'x27', 'x41') with r2 = 0.1742265937799639
# Significant!
# For features ('x49', 'x27', 'x33') with r2 = 0.1331386412254168
# Significant!
# For features ('x49', 'x27', 'x102') with r2 = 0.20209884576599632
# Significant!
# For features ('x49', 'x27', 'x98') with r2 = 0.18940365167753329
# Significant!
# For features ('x49', 'x27', 'x162') with r2 = 0.11972073086781834
# Significant!
# For features ('x49', 'x27', 'x159') with r2 = 0.1650497639239445
# Significant!
# For features ('x49', 'x27', 'x58') with r2 = 0.10229871374747428
# Significant!
# For features ('x49', 'x27', 'x9') with r2 = 0.13290406149081985
# Significant!
# For features ('x49', 'x27', 'x152') with r2 = 0.11796305797814732
# Significant!
# For features ('x49', 'x27', 'x158') with r2 = 0.16668440407026133
# Significant!
# For features ('x49', 'x27', 'x63') with r2 = 0.10134973639106133
# Significant!
# For features ('x49', 'x27', 'x160') with r2 = 0.1374238422326029
# Significant!
# For features ('x49', 'x27', 'x3') with r2 = 0.14017171642363474
# Significant!
# For features ('x49', 'x27', 'x7') with r2 = 0.13930261385470544
# Significant!
# For features ('x49', 'x27', 'x48') with r2 = 0.1252683395109295
# Significant!
# For features ('x49', 'x99', 'x23') with r2 = 0.30761778018182917
# Significant!
# For features ('x49', 'x45', 'x23') with r2 = 0.18150358677487585
# Significant!
# For features ('x49', 'x45', 'x33') with r2 = 0.1979672444470783
# Significant!
# For features ('x49', 'x23', 'x6') with r2 = 0.1582842959490515
# Significant!
# For features ('x49', 'x23', 'x5') with r2 = 0.15037328366274702
# Significant!
# For features ('x49', 'x23', 'x39') with r2 = 0.20038494698768322
# Significant!
# For features ('x49', 'x23', 'x33') with r2 = 0.41509684418670856
# Significant!
# For features ('x49', 'x23', 'x148') with r2 = 0.11729586861589106
# Significant!
# For features ('x49', 'x23', 'x194') with r2 = 0.10451297911398268
# Significant!
# For features ('x49', 'x23', 'x102') with r2 = 0.32830597677294465
# Significant!
# For features ('x49', 'x23', 'x98') with r2 = 0.2875010216727666
# Significant!
# For features ('x49', 'x23', 'x162') with r2 = 0.2623145607829469
# Significant!
# For features ('x49', 'x23', 'x159') with r2 = 0.342177622987739
# Significant!
# For features ('x49', 'x23', 'x173') with r2 = 0.17723402189761678
# Significant!
# For features ('x49', 'x23', 'x158') with r2 = 0.1581783636950777
# Significant!
# For features ('x49', 'x23', 'x177') with r2 = 0.19738864817052124
# Significant!
# For features ('x49', 'x23', 'x63') with r2 = 0.10327557977288478
# Significant!
# For features ('x49', 'x23', 'x7') with r2 = 0.1478857719647361
# Significant!
# For features ('x49', 'x39', 'x33') with r2 = 0.13801292078549482
# Significant!
# For features ('x32', 'x8', 'x50') with r2 = 0.18031674625403812
# Significant!
# For features ('x32', 'x8', 'x23') with r2 = 0.31232452465817895
# Significant!
# For features ('x32', 'x8', 'x158') with r2 = 0.23013824851084336
# Significant!
# For features ('x32', 'x8', 'x160') with r2 = 0.18550174106507916
# Significant!
# For features ('x32', 'x2', 'x99') with r2 = 0.20854140291434287
# Significant!
# For features ('x32', 'x2', 'x50') with r2 = 0.1649517669104613
# Significant!
# For features ('x32', 'x2', 'x23') with r2 = 0.32059492807484935
# Significant!
# For features ('x32', 'x2', 'x33') with r2 = 0.21306702314557935
# Significant!
# For features ('x32', 'x2', 'x102') with r2 = 0.2605246725428806
# Significant!
# For features ('x32', 'x2', 'x98') with r2 = 0.20797151785618792
# Significant!
# For features ('x32', 'x2', 'x162') with r2 = 0.1504660266119662
# Significant!
# For features ('x32', 'x2', 'x159') with r2 = 0.20451239208294042
# Significant!
# For features ('x32', 'x2', 'x173') with r2 = 0.15001607992452512
# Significant!
# For features ('x32', 'x2', 'x158') with r2 = 0.25062615954719025
# Significant!
# For features ('x32', 'x2', 'x160') with r2 = 0.19185315327350025
# Significant!
# For features ('x32', 'x4', 'x23') with r2 = 0.26100007310051077
# Significant!
# For features ('x32', 'x4', 'x158') with r2 = 0.11596929243135892
# Significant!
# For features ('x32', 'x27', 'x50') with r2 = 0.136606179383806
# Significant!
# For features ('x32', 'x27', 'x71') with r2 = 0.12553293935966314
# Significant!
# For features ('x32', 'x27', 'x23') with r2 = 0.2634981947673759
# Significant!
# For features ('x32', 'x27', 'x6') with r2 = 0.10694332614456967
# Significant!
# For features ('x32', 'x27', 'x41') with r2 = 0.25084287104675385
# Significant!
# For features ('x32', 'x27', 'x102') with r2 = 0.1575277018015499
# Significant!
# For features ('x32', 'x27', 'x158') with r2 = 0.16946013056874532
# Significant!
# For features ('x32', 'x27', 'x160') with r2 = 0.1832582887560949
# Significant!
# For features ('x32', 'x99', 'x23') with r2 = 0.5007975111479162
# Significant!
# For features ('x32', 'x50', 'x23') with r2 = 0.39262609403416293
# Significant!
# For features ('x32', 'x50', 'x39') with r2 = 0.12082687008527446
# Significant!
# For features ('x32', 'x188', 'x23') with r2 = 0.2853365088936329
# Significant!
# For features ('x32', 'x188', 'x48') with r2 = 0.1564906308046218
# Significant!
# For features ('x32', 'x45', 'x23') with r2 = 0.3444903736828883
# Significant!
# For features ('x32', 'x42', 'x23') with r2 = 0.29095637137777997
# Significant!
# For features ('x32', 'x193', 'x23') with r2 = 0.2826108271491545
# Significant!
# For features ('x32', 'x193', 'x48') with r2 = 0.11790966989869692
# Significant!
# For features ('x32', 'x71', 'x23') with r2 = 0.28880070302393507
# Significant!
# For features ('x32', 'x23', 'x149') with r2 = 0.3050618997912085
# Significant!
# For features ('x32', 'x23', 'x6') with r2 = 0.25290311875756233
# Significant!
# For features ('x32', 'x23', 'x5') with r2 = 0.2828878141757225
# Significant!
# For features ('x32', 'x23', 'x39') with r2 = 0.2793555898323007
# Significant!
# For features ('x32', 'x23', 'x175') with r2 = 0.3459881285053869
# Significant!
# For features ('x32', 'x23', 'x67') with r2 = 0.27209547375332876
# Significant!
# For features ('x32', 'x23', 'x41') with r2 = 0.29315526764266675
# Significant!
# For features ('x32', 'x23', 'x33') with r2 = 0.4162811513024759
# Significant!
# For features ('x32', 'x23', 'x148') with r2 = 0.29469431203011553
# Significant!
# For features ('x32', 'x23', 'x194') with r2 = 0.27816032939917484
# Significant!
# For features ('x32', 'x23', 'x102') with r2 = 0.5299796711071997
# Significant!
# For features ('x32', 'x23', 'x150') with r2 = 0.294957374164587
# Significant!
# For features ('x32', 'x23', 'x98') with r2 = 0.4938143506743552
# Significant!
# For features ('x32', 'x23', 'x162') with r2 = 0.4262564751611263
# Significant!
# For features ('x32', 'x23', 'x159') with r2 = 0.49313951340814316
# Significant!
# For features ('x32', 'x23', 'x195') with r2 = 0.285154081332486
# Significant!
# For features ('x32', 'x23', 'x61') with r2 = 0.2682002147019653
# Significant!
# For features ('x32', 'x23', 'x58') with r2 = 0.285681783620001
# Significant!
# For features ('x32', 'x23', 'x9') with r2 = 0.27356294193364056
# Significant!
# For features ('x32', 'x23', 'x152') with r2 = 0.29807986111884127
# Significant!
# For features ('x32', 'x23', 'x43') with r2 = 0.29192554284049815
# Significant!
# For features ('x32', 'x23', 'x173') with r2 = 0.43639656306277785
# Significant!
# For features ('x32', 'x23', 'x158') with r2 = 0.533068705097729
# Significant!
# For features ('x32', 'x23', 'x177') with r2 = 0.33970002211253686
# Significant!
# For features ('x32', 'x23', 'x63') with r2 = 0.28574448548048687
# Significant!
# For features ('x32', 'x23', 'x160') with r2 = 0.4717008877987846
# Significant!
# For features ('x32', 'x23', 'x213') with r2 = 0.28842803803400124
# Significant!
# For features ('x32', 'x23', 'x3') with r2 = 0.27463928975917656
# Significant!
# For features ('x32', 'x23', 'x7') with r2 = 0.27120221526925226
# Significant!
# For features ('x32', 'x23', 'x48') with r2 = 0.28449145070821447
# Significant!
# For features ('x32', 'x39', 'x158') with r2 = 0.1915186363678886
# Significant!
# For features ('x32', 'x39', 'x160') with r2 = 0.13286064385979812
# Significant!
# For features ('x32', 'x102', 'x7') with r2 = 0.12255052571098073
# Significant!
# For features ('x32', 'x43', 'x160') with r2 = 0.13553950066517417
# Significant!
# For features ('x32', 'x158', 'x7') with r2 = 0.2014766724142727
# Significant!
# For features ('x32', 'x160', 'x7') with r2 = 0.129788654903782
# Significant!
# For features ('x8', 'x2', 'x27') with r2 = 0.15768362979475622
# Significant!
# For features ('x8', 'x2', 'x23') with r2 = 0.2606438097692522
# Significant!
# For features ('x8', 'x2', 'x33') with r2 = 0.19572542226864814
# Significant!
# For features ('x8', 'x2', 'x102') with r2 = 0.11708220627805006
# Significant!
# For features ('x8', 'x4', 'x23') with r2 = 0.23268064448503784
# Significant!
# For features ('x8', 'x27', 'x99') with r2 = 0.14541663254979809
# Significant!
# For features ('x8', 'x27', 'x50') with r2 = 0.14236890714084136
# Significant!
# For features ('x8', 'x27', 'x188') with r2 = 0.1224530059526466
# Significant!
# For features ('x8', 'x27', 'x45') with r2 = 0.10864493777166877
# Significant!
# For features ('x8', 'x27', 'x42') with r2 = 0.1272355451939514
# Significant!
# For features ('x8', 'x27', 'x193') with r2 = 0.11428270900320522
# Significant!
# For features ('x8', 'x27', 'x71') with r2 = 0.1339939349817819
# Significant!
# For features ('x8', 'x27', 'x23') with r2 = 0.2859110333434655
# Significant!
# For features ('x8', 'x27', 'x149') with r2 = 0.12656985362145695
# Significant!
# For features ('x8', 'x27', 'x6') with r2 = 0.19918798549445882
# Significant!
# For features ('x8', 'x27', 'x67') with r2 = 0.12498663350978226
# Significant!
# For features ('x8', 'x27', 'x41') with r2 = 0.3261329781330277
# Significant!
# For features ('x8', 'x27', 'x148') with r2 = 0.11512122090348949
# Significant!
# For features ('x8', 'x27', 'x194') with r2 = 0.10633800969754674
# Significant!
# For features ('x8', 'x27', 'x102') with r2 = 0.19029248424697648
# Significant!
# For features ('x8', 'x27', 'x150') with r2 = 0.12736882311380238
# Significant!
# For features ('x8', 'x27', 'x98') with r2 = 0.15756367416922928
# Significant!
# For features ('x8', 'x27', 'x162') with r2 = 0.10684916258070251
# Significant!
# For features ('x8', 'x27', 'x159') with r2 = 0.1394568297262915
# Significant!
# For features ('x8', 'x27', 'x195') with r2 = 0.12290846328964447
# Significant!
# For features ('x8', 'x27', 'x58') with r2 = 0.11572977588876385
# Significant!
# For features ('x8', 'x27', 'x9') with r2 = 0.16803969267937055
# Significant!
# For features ('x8', 'x27', 'x152') with r2 = 0.1280232928706448
# Significant!
# For features ('x8', 'x27', 'x158') with r2 = 0.1723200923227699
# Significant!
# For features ('x8', 'x27', 'x177') with r2 = 0.10096992860582603
# Significant!
# For features ('x8', 'x27', 'x63') with r2 = 0.10376975393596147
# Significant!
# For features ('x8', 'x27', 'x160') with r2 = 0.1566730926173799
# Significant!
# For features ('x8', 'x27', 'x213') with r2 = 0.12048086592938163
# Significant!
# For features ('x8', 'x27', 'x3') with r2 = 0.13603877365258935
# Significant!
# For features ('x8', 'x27', 'x48') with r2 = 0.13032192756620556
# Significant!
# For features ('x8', 'x99', 'x23') with r2 = 0.3527557026675464
# Significant!
# For features ('x8', 'x50', 'x23') with r2 = 0.2185581302907429
# Significant!
# For features ('x8', 'x50', 'x33') with r2 = 0.24242125120829297
# Significant!
# For features ('x8', 'x188', 'x23') with r2 = 0.20198344478615343
# Significant!
# For features ('x8', 'x45', 'x23') with r2 = 0.20299597665956534
# Significant!
# For features ('x8', 'x42', 'x23') with r2 = 0.20386494411057923
# Significant!
# For features ('x8', 'x42', 'x33') with r2 = 0.11839702201295996
# Significant!
# For features ('x8', 'x193', 'x23') with r2 = 0.20019930511261236
# Significant!
# For features ('x8', 'x71', 'x23') with r2 = 0.23543805605607013
# Significant!
# For features ('x8', 'x23', 'x149') with r2 = 0.20963708065901182
# Significant!
# For features ('x8', 'x23', 'x6') with r2 = 0.24728309663644135
# Significant!
# For features ('x8', 'x23', 'x5') with r2 = 0.23934528480961528
# Significant!
# For features ('x8', 'x23', 'x39') with r2 = 0.23598092050692077
# Significant!
# For features ('x8', 'x23', 'x175') with r2 = 0.2058746174067958
# Significant!
# For features ('x8', 'x23', 'x67') with r2 = 0.2544344190883055
# Significant!
# For features ('x8', 'x23', 'x41') with r2 = 0.22836931491911444
# Significant!
# For features ('x8', 'x23', 'x33') with r2 = 0.34033835353788316
# Significant!
# For features ('x8', 'x23', 'x148') with r2 = 0.19484571977516524
# Significant!
# For features ('x8', 'x23', 'x194') with r2 = 0.18905370140526237
# Significant!
# For features ('x8', 'x23', 'x102') with r2 = 0.3557363464967234
# Significant!
# For features ('x8', 'x23', 'x150') with r2 = 0.20402646860762652
# Significant!
# For features ('x8', 'x23', 'x98') with r2 = 0.32836290129496687
# Significant!
# For features ('x8', 'x23', 'x162') with r2 = 0.27555151085012863
# Significant!
# For features ('x8', 'x23', 'x159') with r2 = 0.35692547681547204
# Significant!
# For features ('x8', 'x23', 'x195') with r2 = 0.20399373552082567
# Significant!
# For features ('x8', 'x23', 'x61') with r2 = 0.22684674956901268
# Significant!
# For features ('x8', 'x23', 'x58') with r2 = 0.2419677619928824
# Significant!
# For features ('x8', 'x23', 'x9') with r2 = 0.2568520839065413
# Significant!
# For features ('x8', 'x23', 'x152') with r2 = 0.20488995597450219
# Significant!
# For features ('x8', 'x23', 'x43') with r2 = 0.21344443325844517
# Significant!
# For features ('x8', 'x23', 'x173') with r2 = 0.23522168828245987
# Significant!
# For features ('x8', 'x23', 'x158') with r2 = 0.2251247317232493
# Significant!
# For features ('x8', 'x23', 'x177') with r2 = 0.2554959951606876
# Significant!
# For features ('x8', 'x23', 'x63') with r2 = 0.2472075091498631
# Significant!
# For features ('x8', 'x23', 'x160') with r2 = 0.2135741974615692
# Significant!
# For features ('x8', 'x23', 'x213') with r2 = 0.20229582662306886
# Significant!
# For features ('x8', 'x23', 'x3') with r2 = 0.2313803363766025
# Significant!
# For features ('x8', 'x23', 'x7') with r2 = 0.251601381211369
# Significant!
# For features ('x8', 'x23', 'x48') with r2 = 0.20170334705472354
# Significant!
# For features ('x8', 'x33', 'x150') with r2 = 0.1216696591037437
# Significant!
# For features ('x8', 'x33', 'x195') with r2 = 0.10550182701381543
# Significant!
# For features ('x8', 'x33', 'x152') with r2 = 0.12379967297283104
# Significant!
# For features ('x8', 'x33', 'x160') with r2 = 0.11564448900829787
# Significant!
# For features ('x8', 'x33', 'x213') with r2 = 0.1125664902895441
# Significant!
# For features ('x8', 'x33', 'x48') with r2 = 0.13507603002525417
# Significant!
# For features ('x2', 'x4', 'x23') with r2 = 0.19161560542252665
# Significant!
# For features ('x2', 'x4', 'x33') with r2 = 0.17209288692069283
# Significant!
# For features ('x2', 'x4', 'x102') with r2 = 0.13533446261130355
# Significant!
# For features ('x2', 'x27', 'x99') with r2 = 0.13315749026359042
# Significant!
# For features ('x2', 'x27', 'x50') with r2 = 0.10192365916298554
# Significant!
# For features ('x2', 'x27', 'x23') with r2 = 0.11051590470347342
# Significant!
# For features ('x2', 'x27', 'x5') with r2 = 0.12336940358245947
# Significant!
# For features ('x2', 'x27', 'x39') with r2 = 0.12187263522775624
# Significant!
# For features ('x2', 'x27', 'x33') with r2 = 0.22427035853194105
# Significant!
# For features ('x2', 'x27', 'x102') with r2 = 0.20724556109455264
# Significant!
# For features ('x2', 'x27', 'x98') with r2 = 0.14819485905164093
# Significant!
# For features ('x2', 'x99', 'x23') with r2 = 0.3159462158774641
# Significant!
# For features ('x2', 'x99', 'x6') with r2 = 0.1018320091033686
# Significant!
# For features ('x2', 'x99', 'x33') with r2 = 0.2547892542842078
# Significant!
# For features ('x2', 'x50', 'x23') with r2 = 0.15625987713655237
# Significant!
# For features ('x2', 'x50', 'x33') with r2 = 0.2193733110591313
# Significant!
# For features ('x2', 'x188', 'x23') with r2 = 0.12006546496553742
# Significant!
# For features ('x2', 'x188', 'x33') with r2 = 0.20938078022682668
# Significant!
# For features ('x2', 'x45', 'x23') with r2 = 0.18764035729763762
# Significant!
# For features ('x2', 'x45', 'x33') with r2 = 0.22008017912699257
# Significant!
# For features ('x2', 'x42', 'x23') with r2 = 0.11960764327180487
# Significant!
# For features ('x2', 'x42', 'x33') with r2 = 0.21022381946496765
# Significant!
# For features ('x2', 'x193', 'x23') with r2 = 0.11477388186735933
# Significant!
# For features ('x2', 'x193', 'x33') with r2 = 0.2081501475024929
# Significant!
# For features ('x2', 'x71', 'x33') with r2 = 0.25193979379703024
# Significant!
# For features ('x2', 'x71', 'x102') with r2 = 0.12757474742351227
# Significant!
# For features ('x2', 'x23', 'x149') with r2 = 0.20016101533644734
# Significant!
# For features ('x2', 'x23', 'x6') with r2 = 0.1343305616015394
# Significant!
# For features ('x2', 'x23', 'x5') with r2 = 0.15493091641124157
# Significant!
# For features ('x2', 'x23', 'x39') with r2 = 0.23725622608819305
# Significant!
# For features ('x2', 'x23', 'x175') with r2 = 0.10304643379154729
# Significant!
# For features ('x2', 'x23', 'x33') with r2 = 0.39692399770753745
# Significant!
# For features ('x2', 'x23', 'x148') with r2 = 0.13432949044341708
# Significant!
# For features ('x2', 'x23', 'x194') with r2 = 0.13108105861423464
# Significant!
# For features ('x2', 'x23', 'x102') with r2 = 0.3536274175464084
# Significant!
# For features ('x2', 'x23', 'x150') with r2 = 0.12313306393548493
# Significant!
# For features ('x2', 'x23', 'x98') with r2 = 0.2959635165111062
# Significant!
# For features ('x2', 'x23', 'x162') with r2 = 0.2777317183973339
# Significant!
# For features ('x2', 'x23', 'x159') with r2 = 0.34348940264748684
# Significant!
# For features ('x2', 'x23', 'x195') with r2 = 0.11869293157550806
# Significant!
# For features ('x2', 'x23', 'x9') with r2 = 0.11671854133557476
# Significant!
# For features ('x2', 'x23', 'x152') with r2 = 0.1270422827588354
# Significant!
# For features ('x2', 'x23', 'x43') with r2 = 0.16034314228135826
# Significant!
# For features ('x2', 'x23', 'x173') with r2 = 0.22357134108590176
# Significant!
# For features ('x2', 'x23', 'x158') with r2 = 0.1832604978739581
# Significant!
# For features ('x2', 'x23', 'x177') with r2 = 0.23245412850494845
# Significant!
# For features ('x2', 'x23', 'x213') with r2 = 0.11461261398955998
# Significant!
# For features ('x2', 'x23', 'x7') with r2 = 0.1561184000899922
# Significant!
# For features ('x2', 'x23', 'x48') with r2 = 0.11032124597402744
# Significant!
# For features ('x2', 'x149', 'x33') with r2 = 0.21127375177064528
# Significant!
# For features ('x2', 'x149', 'x159') with r2 = 0.10200638377685962
# Significant!
# For features ('x2', 'x6', 'x33') with r2 = 0.14635055540824418
# Significant!
# For features ('x2', 'x6', 'x102') with r2 = 0.16212848054773044
# Significant!
# For features ('x2', 'x6', 'x159') with r2 = 0.10209191502700751
# Significant!
# For features ('x2', 'x5', 'x33') with r2 = 0.16173392844568615
# Significant!
# For features ('x2', 'x39', 'x33') with r2 = 0.1840299601657967
# Significant!
# For features ('x2', 'x39', 'x102') with r2 = 0.13721720451118746
# Significant!
# For features ('x2', 'x175', 'x33') with r2 = 0.18653035237002888
# Significant!
# For features ('x2', 'x175', 'x102') with r2 = 0.18867010122010766
# Significant!
# For features ('x2', 'x67', 'x33') with r2 = 0.24106840970082102
# Significant!
# For features ('x2', 'x41', 'x33') with r2 = 0.23650880051842896
# Significant!
# For features ('x2', 'x33', 'x148') with r2 = 0.20949558234457574
# Significant!
# For features ('x2', 'x33', 'x194') with r2 = 0.206122819407026
# Significant!
# For features ('x2', 'x33', 'x102') with r2 = 0.25305642659666394
# Significant!
# For features ('x2', 'x33', 'x150') with r2 = 0.21038681725752223
# Significant!
# For features ('x2', 'x33', 'x98') with r2 = 0.2550749728164373
# Significant!
# For features ('x2', 'x33', 'x162') with r2 = 0.21500807662825258
# Significant!
# For features ('x2', 'x33', 'x159') with r2 = 0.23761031214904996
# Significant!
# For features ('x2', 'x33', 'x195') with r2 = 0.2101192807623699
# Significant!
# For features ('x2', 'x33', 'x61') with r2 = 0.23303531018825097
# Significant!
# For features ('x2', 'x33', 'x58') with r2 = 0.227569983292164
# Significant!
# For features ('x2', 'x33', 'x9') with r2 = 0.15833526306088413
# Significant!
# For features ('x2', 'x33', 'x152') with r2 = 0.21046383511412675
# Significant!
# For features ('x2', 'x33', 'x43') with r2 = 0.14468534447246764
# Significant!
# For features ('x2', 'x33', 'x173') with r2 = 0.17654602833230376
# Significant!
# For features ('x2', 'x33', 'x158') with r2 = 0.26148417790384293
# Significant!
# For features ('x2', 'x33', 'x177') with r2 = 0.24956406071139697
# Significant!
# For features ('x2', 'x33', 'x63') with r2 = 0.231324798388516
# Significant!
# For features ('x2', 'x33', 'x160') with r2 = 0.24511575821370007
# Significant!
# For features ('x2', 'x33', 'x213') with r2 = 0.2094832469461335
# Significant!
# For features ('x2', 'x33', 'x3') with r2 = 0.16241982475892205
# Significant!
# For features ('x2', 'x33', 'x7') with r2 = 0.15971479672496017
# Significant!
# For features ('x2', 'x33', 'x48') with r2 = 0.211476313013531
# Significant!
# For features ('x2', 'x102', 'x63') with r2 = 0.1129673595509526
# Significant!
# For features ('x4', 'x27', 'x50') with r2 = 0.16135059564305407
# Significant!
# For features ('x4', 'x27', 'x42') with r2 = 0.1082483346590847
# Significant!
# For features ('x4', 'x27', 'x23') with r2 = 0.2242440360787386
# Significant!
# For features ('x4', 'x27', 'x6') with r2 = 0.1352686978062964
# Significant!
# For features ('x4', 'x27', 'x5') with r2 = 0.13526872268506657
# Significant!
# For features ('x4', 'x27', 'x41') with r2 = 0.25155560880546884
# Significant!
# For features ('x4', 'x27', 'x102') with r2 = 0.18129423091836522
# Significant!
# For features ('x4', 'x27', 'x150') with r2 = 0.1100278111967461
# Significant!
# For features ('x4', 'x27', 'x98') with r2 = 0.12161794207101906
# Significant!
# For features ('x4', 'x27', 'x152') with r2 = 0.11188003321855153
# Significant!
# For features ('x4', 'x27', 'x158') with r2 = 0.16965729961818063
# Significant!
# For features ('x4', 'x27', 'x160') with r2 = 0.1590603051961404
# Significant!
# For features ('x4', 'x27', 'x3') with r2 = 0.13526870811373554
# Significant!
# For features ('x4', 'x27', 'x7') with r2 = 0.10916590886053604
# Significant!
# For features ('x4', 'x27', 'x48') with r2 = 0.11344304573781774
# Significant!
# For features ('x4', 'x99', 'x23') with r2 = 0.36866621408665406
# Significant!
# For features ('x4', 'x50', 'x23') with r2 = 0.2173723585337716
# Significant!
# For features ('x4', 'x188', 'x23') with r2 = 0.1795159674747164
# Significant!
# For features ('x4', 'x45', 'x23') with r2 = 0.20343104088862693
# Significant!
# For features ('x4', 'x42', 'x23') with r2 = 0.1792579972235235
# Significant!
# For features ('x4', 'x193', 'x23') with r2 = 0.17478633010631853
# Significant!
# For features ('x4', 'x71', 'x23') with r2 = 0.20121810574600793
# Significant!
# For features ('x4', 'x23', 'x149') with r2 = 0.21658751127374143
# Significant!
# For features ('x4', 'x23', 'x6') with r2 = 0.19505290041459855
# Significant!
# For features ('x4', 'x23', 'x5') with r2 = 0.19505290325741362
# Significant!
# For features ('x4', 'x23', 'x39') with r2 = 0.23786527419294265
# Significant!
# For features ('x4', 'x23', 'x175') with r2 = 0.19072815621193379
# Significant!
# For features ('x4', 'x23', 'x67') with r2 = 0.229465209239824
# Significant!
# For features ('x4', 'x23', 'x41') with r2 = 0.18814830401606578
# Significant!
# For features ('x4', 'x23', 'x33') with r2 = 0.3514919639286268
# Significant!
# For features ('x4', 'x23', 'x148') with r2 = 0.18213650229273964
# Significant!
# For features ('x4', 'x23', 'x194') with r2 = 0.1747872747570959
# Significant!
# For features ('x4', 'x23', 'x102') with r2 = 0.3837811112176804
# Significant!
# For features ('x4', 'x23', 'x150') with r2 = 0.18136145340340676
# Significant!
# For features ('x4', 'x23', 'x98') with r2 = 0.34763833822310786
# Significant!
# For features ('x4', 'x23', 'x162') with r2 = 0.29365470183807013
# Significant!
# For features ('x4', 'x23', 'x159') with r2 = 0.37761909792046006
# Significant!
# For features ('x4', 'x23', 'x195') with r2 = 0.17875794979017318
# Significant!
# For features ('x4', 'x23', 'x61') with r2 = 0.19439998903981243
# Significant!
# For features ('x4', 'x23', 'x58') with r2 = 0.21344110268535554
# Significant!
# For features ('x4', 'x23', 'x9') with r2 = 0.23347081204559278
# Significant!
# For features ('x4', 'x23', 'x152') with r2 = 0.18363352612830738
# Significant!
# For features ('x4', 'x23', 'x43') with r2 = 0.1960067131535713
# Significant!
# For features ('x4', 'x23', 'x173') with r2 = 0.2774968273909433
# Significant!
# For features ('x4', 'x23', 'x158') with r2 = 0.26824628323715516
# Significant!
# For features ('x4', 'x23', 'x177') with r2 = 0.2559382430284331
# Significant!
# For features ('x4', 'x23', 'x63') with r2 = 0.21231856395928217
# Significant!
# For features ('x4', 'x23', 'x160') with r2 = 0.20624533417338115
# Significant!
# For features ('x4', 'x23', 'x213') with r2 = 0.1749873111583834
# Significant!
# For features ('x4', 'x23', 'x3') with r2 = 0.19505290265478942
# Significant!
# For features ('x4', 'x23', 'x7') with r2 = 0.16467133202704615
# Significant!
# For features ('x4', 'x23', 'x48') with r2 = 0.1796270129631602
# Significant!
# For features ('x27', 'x99', 'x50') with r2 = 0.18404968300428948
# Significant!
# For features ('x27', 'x99', 'x188') with r2 = 0.17146458559963834
# Significant!
# For features ('x27', 'x99', 'x45') with r2 = 0.1573942519609515
# Significant!
# For features ('x27', 'x99', 'x42') with r2 = 0.17625889030120567
# Significant!
# For features ('x27', 'x99', 'x193') with r2 = 0.16546898776142807
# Significant!
# For features ('x27', 'x99', 'x71') with r2 = 0.10847381996025543
# Significant!
# For features ('x27', 'x99', 'x23') with r2 = 0.33319021120785286
# Significant!
# For features ('x27', 'x99', 'x149') with r2 = 0.16324963212577312
# Significant!
# For features ('x27', 'x99', 'x6') with r2 = 0.11629545984385366
# Significant!
# For features ('x27', 'x99', 'x5') with r2 = 0.118560208715219
# Significant!
# For features ('x27', 'x99', 'x39') with r2 = 0.12121856999790662
# Significant!
# For features ('x27', 'x99', 'x175') with r2 = 0.15549450952559296
# Significant!
# For features ('x27', 'x99', 'x67') with r2 = 0.1420475225796933
# Significant!
# For features ('x27', 'x99', 'x41') with r2 = 0.22634861438370488
# Significant!
# For features ('x27', 'x99', 'x148') with r2 = 0.16358119576677227
# Significant!
# For features ('x27', 'x99', 'x194') with r2 = 0.1562396167102511
# Significant!
# For features ('x27', 'x99', 'x102') with r2 = 0.15597256807035237
# Significant!
# For features ('x27', 'x99', 'x150') with r2 = 0.1760310648339648
# Significant!
# For features ('x27', 'x99', 'x98') with r2 = 0.17322437330437482
# Significant!
# For features ('x27', 'x99', 'x162') with r2 = 0.12284671942945088
# Significant!
# For features ('x27', 'x99', 'x159') with r2 = 0.11066932191408826
# Significant!
# For features ('x27', 'x99', 'x195') with r2 = 0.17240013043469246
# Significant!
# For features ('x27', 'x99', 'x58') with r2 = 0.12646677065761402
# Significant!
# For features ('x27', 'x99', 'x9') with r2 = 0.1430358159500888
# Significant!
# For features ('x27', 'x99', 'x152') with r2 = 0.1764266802117085
# Significant!
# For features ('x27', 'x99', 'x43') with r2 = 0.11031356116217068
# Significant!
# For features ('x27', 'x99', 'x173') with r2 = 0.13613003063811052
# Significant!
# For features ('x27', 'x99', 'x158') with r2 = 0.13415828984539196
# Significant!
# For features ('x27', 'x99', 'x177') with r2 = 0.1939397200190766
# Significant!
# For features ('x27', 'x99', 'x63') with r2 = 0.12199859628789396
# Significant!
# For features ('x27', 'x99', 'x160') with r2 = 0.16310100562245516
# Significant!
# For features ('x27', 'x99', 'x213') with r2 = 0.17120840589104364
# Significant!
# For features ('x27', 'x99', 'x3') with r2 = 0.17281809332697115
# Significant!
# For features ('x27', 'x99', 'x48') with r2 = 0.1800704918739895
# Significant!
# For features ('x27', 'x50', 'x188') with r2 = 0.13534450521307098
# Significant!
# For features ('x27', 'x50', 'x42') with r2 = 0.1355026342176731
# Significant!
# For features ('x27', 'x50', 'x193') with r2 = 0.12905635479751432
# Significant!
# For features ('x27', 'x50', 'x71') with r2 = 0.12287263597493739
# Significant!
# For features ('x27', 'x50', 'x23') with r2 = 0.15027403894703992
# Significant!
# For features ('x27', 'x50', 'x149') with r2 = 0.14022290554980202
# Significant!
# For features ('x27', 'x50', 'x6') with r2 = 0.15377984532176653
# Significant!
# For features ('x27', 'x50', 'x5') with r2 = 0.17875095624779244
# Significant!
# For features ('x27', 'x50', 'x39') with r2 = 0.15570389648626823
# Significant!
# For features ('x27', 'x50', 'x175') with r2 = 0.1505469067355122
# Significant!
# For features ('x27', 'x50', 'x67') with r2 = 0.14738454149946406
# Significant!
# For features ('x27', 'x50', 'x41') with r2 = 0.21521231768753438
# Significant!
# For features ('x27', 'x50', 'x148') with r2 = 0.12174697489516509
# Significant!
# For features ('x27', 'x50', 'x194') with r2 = 0.12483987959580556
# Significant!
# For features ('x27', 'x50', 'x102') with r2 = 0.2010433660734397
# Significant!
# For features ('x27', 'x50', 'x150') with r2 = 0.13439923469708043
# Significant!
# For features ('x27', 'x50', 'x98') with r2 = 0.18683047727691673
# Significant!
# For features ('x27', 'x50', 'x162') with r2 = 0.1323619072633472
# Significant!
# For features ('x27', 'x50', 'x159') with r2 = 0.16634161527316382
# Significant!
# For features ('x27', 'x50', 'x195') with r2 = 0.13425302163035302
# Significant!
# For features ('x27', 'x50', 'x58') with r2 = 0.13198329593591288
# Significant!
# For features ('x27', 'x50', 'x9') with r2 = 0.1723147700384596
# Significant!
# For features ('x27', 'x50', 'x152') with r2 = 0.1343406629980558
# Significant!
# For features ('x27', 'x50', 'x173') with r2 = 0.11264876644363775
# Significant!
# For features ('x27', 'x50', 'x158') with r2 = 0.15941160454507558
# Significant!
# For features ('x27', 'x50', 'x177') with r2 = 0.10151494445531066
# Significant!
# For features ('x27', 'x50', 'x63') with r2 = 0.12667330194467064
# Significant!
# For features ('x27', 'x50', 'x160') with r2 = 0.14182087080090755
# Significant!
# For features ('x27', 'x50', 'x213') with r2 = 0.13182127092772905
# Significant!
# For features ('x27', 'x50', 'x3') with r2 = 0.19810493299284204
# Significant!
# For features ('x27', 'x50', 'x7') with r2 = 0.16444598457978105
# Significant!
# For features ('x27', 'x50', 'x48') with r2 = 0.1352649449566054
# Significant!
# For features ('x27', 'x188', 'x45') with r2 = 0.11440016859525595
# Significant!
# For features ('x27', 'x188', 'x42') with r2 = 0.12651262282041187
# Significant!
# For features ('x27', 'x188', 'x149') with r2 = 0.10227435552450748
# Significant!
# For features ('x27', 'x188', 'x6') with r2 = 0.10731677802122146
# Significant!
# For features ('x27', 'x188', 'x5') with r2 = 0.11646180740478873
# Significant!
# For features ('x27', 'x188', 'x39') with r2 = 0.10902081228663882
# Significant!
# For features ('x27', 'x188', 'x41') with r2 = 0.1811601986835494
# Significant!
# For features ('x27', 'x188', 'x33') with r2 = 0.11456948469215544
# Significant!
# For features ('x27', 'x188', 'x102') with r2 = 0.19863670051367996
# Significant!
# For features ('x27', 'x188', 'x150') with r2 = 0.1479381219148235
# Significant!
# For features ('x27', 'x188', 'x98') with r2 = 0.1800295103764253
# Significant!
# For features ('x27', 'x188', 'x162') with r2 = 0.10249178276985074
# Significant!
# For features ('x27', 'x188', 'x159') with r2 = 0.14916097756998276
# Significant!
# For features ('x27', 'x188', 'x9') with r2 = 0.12021530971027956
# Significant!
# For features ('x27', 'x188', 'x152') with r2 = 0.17001976337046004
# Significant!
# For features ('x27', 'x188', 'x158') with r2 = 0.16716034612604402
# Significant!
# For features ('x27', 'x188', 'x160') with r2 = 0.13744092278781175
# Significant!
# For features ('x27', 'x188', 'x3') with r2 = 0.10189663872685847
# Significant!
# For features ('x27', 'x188', 'x7') with r2 = 0.1040284882002307
# Significant!
# For features ('x27', 'x45', 'x42') with r2 = 0.11729130734316247
# Significant!
# For features ('x27', 'x45', 'x193') with r2 = 0.10438172833472499
# Significant!
# For features ('x27', 'x45', 'x23') with r2 = 0.20600689251057433
# Significant!
# For features ('x27', 'x45', 'x149') with r2 = 0.13984174114497536
# Significant!
# For features ('x27', 'x45', 'x6') with r2 = 0.10646227353220913
# Significant!
# For features ('x27', 'x45', 'x175') with r2 = 0.1089190175257343
# Significant!
# For features ('x27', 'x45', 'x67') with r2 = 0.11406883693021286
# Significant!
# For features ('x27', 'x45', 'x41') with r2 = 0.2308825786294348
# Significant!
# For features ('x27', 'x45', 'x33') with r2 = 0.10330202374310005
# Significant!
# For features ('x27', 'x45', 'x102') with r2 = 0.1762648685825919
# Significant!
# For features ('x27', 'x45', 'x150') with r2 = 0.11657434989772972
# Significant!
# For features ('x27', 'x45', 'x98') with r2 = 0.17541355578480058
# Significant!
# For features ('x27', 'x45', 'x159') with r2 = 0.13522231768848486
# Significant!
# For features ('x27', 'x45', 'x195') with r2 = 0.11473081892242196
# Significant!
# For features ('x27', 'x45', 'x58') with r2 = 0.10057122435185835
# Significant!
# For features ('x27', 'x45', 'x9') with r2 = 0.11571672944771472
# Significant!
# For features ('x27', 'x45', 'x152') with r2 = 0.11793372610207431
# Significant!
# For features ('x27', 'x45', 'x173') with r2 = 0.10103702802227424
# Significant!
# For features ('x27', 'x45', 'x158') with r2 = 0.17333067083759085
# Significant!
# For features ('x27', 'x45', 'x160') with r2 = 0.1558512448971643
# Significant!
# For features ('x27', 'x45', 'x213') with r2 = 0.10829708038174654
# Significant!
# For features ('x27', 'x45', 'x48') with r2 = 0.11839746640902937
# Significant!
# For features ('x27', 'x42', 'x23') with r2 = 0.10176926620572871
# Significant!
# For features ('x27', 'x42', 'x6') with r2 = 0.1151251644938969
# Significant!
# For features ('x27', 'x42', 'x5') with r2 = 0.12831916335230206
# Significant!
# For features ('x27', 'x42', 'x39') with r2 = 0.11758093816764856
# Significant!
# For features ('x27', 'x42', 'x41') with r2 = 0.18103953821457336
# Significant!
# For features ('x27', 'x42', 'x33') with r2 = 0.1190555627998687
# Significant!
# For features ('x27', 'x42', 'x102') with r2 = 0.19981832525093482
# Significant!
# For features ('x27', 'x42', 'x150') with r2 = 0.1536947184251314
# Significant!
# For features ('x27', 'x42', 'x98') with r2 = 0.1839445077449674
# Significant!
# For features ('x27', 'x42', 'x162') with r2 = 0.10952025386567513
# Significant!
# For features ('x27', 'x42', 'x159') with r2 = 0.15477498067418902
# Significant!
# For features ('x27', 'x42', 'x9') with r2 = 0.12415341333325172
# Significant!
# For features ('x27', 'x42', 'x152') with r2 = 0.18004584723851585
# Significant!
# For features ('x27', 'x42', 'x158') with r2 = 0.1694432565655347
# Significant!
# For features ('x27', 'x42', 'x160') with r2 = 0.14034982195045048
# Significant!
# For features ('x27', 'x42', 'x3') with r2 = 0.11531343148492021
# Significant!
# For features ('x27', 'x42', 'x7') with r2 = 0.11518935935740604
# Significant!
# For features ('x27', 'x42', 'x48') with r2 = 0.10222771588746934
# Significant!
# For features ('x27', 'x193', 'x5') with r2 = 0.10812436488484607
# Significant!
# For features ('x27', 'x193', 'x41') with r2 = 0.17731452185908356
# Significant!
# For features ('x27', 'x193', 'x33') with r2 = 0.10766462336495863
# Significant!
# For features ('x27', 'x193', 'x148') with r2 = 0.12452753595373331
# Significant!
# For features ('x27', 'x193', 'x102') with r2 = 0.1949921460363028
# Significant!
# For features ('x27', 'x193', 'x150') with r2 = 0.11787176896356977
# Significant!
# For features ('x27', 'x193', 'x98') with r2 = 0.17621097003216132
# Significant!
# For features ('x27', 'x193', 'x159') with r2 = 0.14395304973828088
# Significant!
# For features ('x27', 'x193', 'x9') with r2 = 0.11038290430441933
# Significant!
# For features ('x27', 'x193', 'x152') with r2 = 0.1428823051344838
# Significant!
# For features ('x27', 'x193', 'x158') with r2 = 0.16489597777884207
# Significant!
# For features ('x27', 'x193', 'x160') with r2 = 0.13168629288297845
# Significant!
# For features ('x27', 'x193', 'x213') with r2 = 0.10108282113867488
# Significant!
# For features ('x27', 'x71', 'x149') with r2 = 0.10940563366901587
# Significant!
# For features ('x27', 'x71', 'x5') with r2 = 0.11408980772415256
# Significant!
# For features ('x27', 'x71', 'x39') with r2 = 0.12012917827397793
# Significant!
# For features ('x27', 'x71', 'x33') with r2 = 0.16512740675337526
# Significant!
# For features ('x27', 'x71', 'x102') with r2 = 0.18336586375983183
# Significant!
# For features ('x27', 'x71', 'x98') with r2 = 0.12304360409909845
# Significant!
# For features ('x27', 'x71', 'x158') with r2 = 0.11679622457251453
# Significant!
# For features ('x27', 'x71', 'x3') with r2 = 0.12122516544620443
# Significant!
# For features ('x27', 'x23', 'x149') with r2 = 0.18821682026906264
# Significant!
# For features ('x27', 'x23', 'x5') with r2 = 0.28175638243095724
# Significant!
# For features ('x27', 'x23', 'x39') with r2 = 0.2613525560877471
# Significant!
# For features ('x27', 'x23', 'x33') with r2 = 0.3756677577663959
# Significant!
# For features ('x27', 'x23', 'x148') with r2 = 0.11160490111765982
# Significant!
# For features ('x27', 'x23', 'x194') with r2 = 0.11247929802793284
# Significant!
# For features ('x27', 'x23', 'x102') with r2 = 0.347560642997521
# Significant!
# For features ('x27', 'x23', 'x150') with r2 = 0.10550967378853707
# Significant!
# For features ('x27', 'x23', 'x98') with r2 = 0.31084453876388723
# Significant!
# For features ('x27', 'x23', 'x162') with r2 = 0.2559838192246102
# Significant!
# For features ('x27', 'x23', 'x159') with r2 = 0.33937460921394447
# Significant!
# For features ('x27', 'x23', 'x152') with r2 = 0.1100727356264692
# Significant!
# For features ('x27', 'x23', 'x173') with r2 = 0.17807384389761344
# Significant!
# For features ('x27', 'x23', 'x158') with r2 = 0.153868738302003
# Significant!
# For features ('x27', 'x23', 'x177') with r2 = 0.20056552422867474
# Significant!
# For features ('x27', 'x23', 'x3') with r2 = 0.15482566315916668
# Significant!
# For features ('x27', 'x23', 'x7') with r2 = 0.28710914867858833
# Significant!
# For features ('x27', 'x149', 'x6') with r2 = 0.11809655585775833
# Significant!
# For features ('x27', 'x149', 'x39') with r2 = 0.10435908554230218
# Significant!
# For features ('x27', 'x149', 'x175') with r2 = 0.1245872759878837
# Significant!
# For features ('x27', 'x149', 'x67') with r2 = 0.11641129735058349
# Significant!
# For features ('x27', 'x149', 'x41') with r2 = 0.24493486852593188
# Significant!
# For features ('x27', 'x149', 'x33') with r2 = 0.10519797006800169
# Significant!
# For features ('x27', 'x149', 'x194') with r2 = 0.10787392920565739
# Significant!
# For features ('x27', 'x149', 'x102') with r2 = 0.18060740600020636
# Significant!
# For features ('x27', 'x149', 'x98') with r2 = 0.18042853376131904
# Significant!
# For features ('x27', 'x149', 'x162') with r2 = 0.11600784465352845
# Significant!
# For features ('x27', 'x149', 'x159') with r2 = 0.15024405573192462
# Significant!
# For features ('x27', 'x149', 'x195') with r2 = 0.10448881805367205
# Significant!
# For features ('x27', 'x149', 'x58') with r2 = 0.12136671279239786
# Significant!
# For features ('x27', 'x149', 'x9') with r2 = 0.14413530741071773
# Significant!
# For features ('x27', 'x149', 'x173') with r2 = 0.12091041532002866
# Significant!
# For features ('x27', 'x149', 'x158') with r2 = 0.18780350986084007
# Significant!
# For features ('x27', 'x149', 'x63') with r2 = 0.11455756548754778
# Significant!
# For features ('x27', 'x149', 'x160') with r2 = 0.16921736334944212
# Significant!
# For features ('x27', 'x6', 'x5') with r2 = 0.13526871127182247
# Significant!
# For features ('x27', 'x6', 'x39') with r2 = 0.2177686656047121
# Significant!
# For features ('x27', 'x6', 'x41') with r2 = 0.22416073103664771
# Significant!
# For features ('x27', 'x6', 'x148') with r2 = 0.10126913866909623
# Significant!
# For features ('x27', 'x6', 'x102') with r2 = 0.19849737885853586
# Significant!
# For features ('x27', 'x6', 'x150') with r2 = 0.11734838712566364
# Significant!
# For features ('x27', 'x6', 'x98') with r2 = 0.1400776567532034
# Significant!
# For features ('x27', 'x6', 'x195') with r2 = 0.11028239386872127
# Significant!
# For features ('x27', 'x6', 'x152') with r2 = 0.12002123726191001
# Significant!
# For features ('x27', 'x6', 'x158') with r2 = 0.15919464209952233
# Significant!
# For features ('x27', 'x6', 'x160') with r2 = 0.12213234127918651
# Significant!
# For features ('x27', 'x6', 'x213') with r2 = 0.10700447833446838
# Significant!
# For features ('x27', 'x6', 'x3') with r2 = 0.13526870804980506
# Significant!
# For features ('x27', 'x6', 'x7') with r2 = 0.1279440283244757
# Significant!
# For features ('x27', 'x6', 'x48') with r2 = 0.11322852710300288
# Significant!
# For features ('x27', 'x5', 'x67') with r2 = 0.1168580971691328
# Significant!
# For features ('x27', 'x5', 'x41') with r2 = 0.24287193312030983
# Significant!
# For features ('x27', 'x5', 'x148') with r2 = 0.10638542866553916
# Significant!
# For features ('x27', 'x5', 'x102') with r2 = 0.1933258707218848
# Significant!
# For features ('x27', 'x5', 'x150') with r2 = 0.12974241127511543
# Significant!
# For features ('x27', 'x5', 'x98') with r2 = 0.13839565260333148
# Significant!
# For features ('x27', 'x5', 'x195') with r2 = 0.11945373882749641
# Significant!
# For features ('x27', 'x5', 'x58') with r2 = 0.1008359173115974
# Significant!
# For features ('x27', 'x5', 'x152') with r2 = 0.1308368254016903
# Significant!
# For features ('x27', 'x5', 'x158') with r2 = 0.18234271061918794
# Significant!
# For features ('x27', 'x5', 'x160') with r2 = 0.18740279054670494
# Significant!
# ...
# For features ('x23', 'x41', 'x162') with r2 = 0.23746344753566398
# Significant!
# For features ('x23', 'x41', 'x159') with r2 = 0.31569150211444214
# Significant!
# For features ('x23', 'x41', 'x9') with r2 = 0.1383554550635659
# Significant!
# For features ('x23', 'x41', 'x43') with r2 = 0.10356581664637488
# Significant!
# For features ('x23', 'x41', 'x173') with r2 = 0.15272791695616855
# Significant!
# For features ('x23', 'x41', 'x158') with r2 = 0.13120943154601433
# Significant!
# For features ('x23', 'x41', 'x177') with r2 = 0.17919572891534247
# Significant!
# For features ('x23', 'x41', 'x7') with r2 = 0.11231959860389558
# Significant!
# For features ('x23', 'x33', 'x148') with r2 = 0.40826762459046195
# Significant!
# For features ('x23', 'x33', 'x194') with r2 = 0.4032960611280596
# Significant!
# For features ('x23', 'x33', 'x102') with r2 = 0.4979104095562753
# Significant!
# For features ('x23', 'x33', 'x150') with r2 = 0.4104785868362681
# Significant!
# For features ('x23', 'x33', 'x98') with r2 = 0.48268016138486997
# Significant!
# For features ('x23', 'x33', 'x162') with r2 = 0.42257040566105514
# Significant!
# For features ('x23', 'x33', 'x159') with r2 = 0.47141104958640934
# Significant!
# For features ('x23', 'x33', 'x195') with r2 = 0.407622213440734
# Significant!
# For features ('x23', 'x33', 'x61') with r2 = 0.4165736959875539
# Significant!
# For features ('x23', 'x33', 'x58') with r2 = 0.41368595325409013
# Significant!
# For features ('x23', 'x33', 'x9') with r2 = 0.38746349971164046
# Significant!
# For features ('x23', 'x33', 'x152') with r2 = 0.4111127510695688
# Significant!
# For features ('x23', 'x33', 'x43') with r2 = 0.3619177252424434
# Significant!
# For features ('x23', 'x33', 'x173') with r2 = 0.4306829402410495
# Significant!
# For features ('x23', 'x33', 'x158') with r2 = 0.508745113447382
# Significant!
# For features ('x23', 'x33', 'x177') with r2 = 0.4109406615282586
# Significant!
# For features ('x23', 'x33', 'x63') with r2 = 0.4238400954044123
# Significant!
# For features ('x23', 'x33', 'x160') with r2 = 0.47199102352026817
# Significant!
# For features ('x23', 'x33', 'x213') with r2 = 0.4071707784431842
# Significant!
# For features ('x23', 'x33', 'x3') with r2 = 0.37682495873617
# Significant!
# For features ('x23', 'x33', 'x7') with r2 = 0.3160817071778587
# Significant!
# For features ('x23', 'x33', 'x48') with r2 = 0.41275571881473444
# Significant!
# For features ('x23', 'x148', 'x102') with r2 = 0.30976997108976545
# Significant!
# For features ('x23', 'x148', 'x98') with r2 = 0.27917581462470925
# Significant!
# For features ('x23', 'x148', 'x162') with r2 = 0.2513753233976188
# Significant!
# For features ('x23', 'x148', 'x159') with r2 = 0.33906583699163007
# Significant!
# For features ('x23', 'x148', 'x195') with r2 = 0.11331118112441178
# Significant!
# For features ('x23', 'x148', 'x58') with r2 = 0.10115006195835671
# Significant!
# For features ('x23', 'x148', 'x43') with r2 = 0.11606368037629547
# Significant!
# For features ('x23', 'x148', 'x173') with r2 = 0.16828900652688425
# Significant!
# For features ('x23', 'x148', 'x158') with r2 = 0.11595054481180518
# Significant!
# For features ('x23', 'x148', 'x177') with r2 = 0.18356706699700637
# Significant!
# For features ('x23', 'x148', 'x63') with r2 = 0.11520961109874872
# Significant!
# For features ('x23', 'x148', 'x213') with r2 = 0.14638801381636538
# Significant!
# For features ('x23', 'x148', 'x7') with r2 = 0.14384143301817393
# Significant!
# For features ('x23', 'x148', 'x48') with r2 = 0.20849284039984
# Significant!
# For features ('x23', 'x194', 'x102') with r2 = 0.29620690336135225
# Significant!
# For features ('x23', 'x194', 'x150') with r2 = 0.12210725198708258
# Significant!
# For features ('x23', 'x194', 'x98') with r2 = 0.2747978194086176
# Significant!
# For features ('x23', 'x194', 'x162') with r2 = 0.24150599370288078
# Significant!
# For features ('x23', 'x194', 'x159') with r2 = 0.3374269059414152
# Significant!
# For features ('x23', 'x194', 'x195') with r2 = 0.13718364592833593
# Significant!
# For features ('x23', 'x194', 'x58') with r2 = 0.1041971101573278
# Significant!
# For features ('x23', 'x194', 'x152') with r2 = 0.11188701597107972
# Significant!
# For features ('x23', 'x194', 'x43') with r2 = 0.1053850318257119
# Significant!
# For features ('x23', 'x194', 'x173') with r2 = 0.16184350905083794
# Significant!
# For features ('x23', 'x194', 'x158') with r2 = 0.12132534507301695
# Significant!
# For features ('x23', 'x194', 'x177') with r2 = 0.1757306322609194
# Significant!
# For features ('x23', 'x194', 'x63') with r2 = 0.11691879723673966
# Significant!
# For features ('x23', 'x194', 'x213') with r2 = 0.1460151201591095
# Significant!
# For features ('x23', 'x194', 'x7') with r2 = 0.14026134014618935
# Significant!
# For features ('x23', 'x194', 'x48') with r2 = 0.1594749942126777
# Significant!
# For features ('x23', 'x102', 'x150') with r2 = 0.3242705720598029
# Significant!
# For features ('x23', 'x102', 'x98') with r2 = 0.12584362590242315
# Significant!
# For features ('x23', 'x102', 'x162') with r2 = 0.27844149193356804
# Significant!
# For features ('x23', 'x102', 'x159') with r2 = 0.3254988316138633
# Significant!
# For features ('x23', 'x102', 'x195') with r2 = 0.3202897838113193
# Significant!
# For features ('x23', 'x102', 'x61') with r2 = 0.330907629402403
# Significant!
# For features ('x23', 'x102', 'x58') with r2 = 0.3259404625356781
# Significant!
# For features ('x23', 'x102', 'x9') with r2 = 0.33809288108429236
# Significant!
# For features ('x23', 'x102', 'x152') with r2 = 0.32364361199710195
# Significant!
# For features ('x23', 'x102', 'x43') with r2 = 0.30321455227258787
# Significant!
# For features ('x23', 'x102', 'x173') with r2 = 0.3126792762651647
# Significant!
# For features ('x23', 'x102', 'x158') with r2 = 0.20974058238493942
# Significant!
# For features ('x23', 'x102', 'x177') with r2 = 0.26331158528540566
# Significant!
# For features ('x23', 'x102', 'x63') with r2 = 0.34816281330491144
# Significant!
# For features ('x23', 'x102', 'x160') with r2 = 0.32023935724914687
# Significant!
# For features ('x23', 'x102', 'x213') with r2 = 0.32405919087240037
# Significant!
# For features ('x23', 'x102', 'x3') with r2 = 0.3290768171617819
# Significant!
# For features ('x23', 'x102', 'x7') with r2 = 0.3422043815048229
# Significant!
# For features ('x23', 'x102', 'x48') with r2 = 0.3275358063403459
# Significant!
# For features ('x23', 'x150', 'x98') with r2 = 0.2844151721225535
# Significant!
# For features ('x23', 'x150', 'x162') with r2 = 0.2580981942365714
# Significant!
# For features ('x23', 'x150', 'x159') with r2 = 0.34151032779441587
# Significant!
# For features ('x23', 'x150', 'x152') with r2 = 0.22027369420070034
# Significant!
# For features ('x23', 'x150', 'x43') with r2 = 0.1111695653194048
# Significant!
# For features ('x23', 'x150', 'x173') with r2 = 0.17339124026638814
# Significant!
# For features ('x23', 'x150', 'x158') with r2 = 0.14003380614145006
# Significant!
# For features ('x23', 'x150', 'x177') with r2 = 0.191429071768284
# Significant!
# For features ('x23', 'x150', 'x63') with r2 = 0.10399285821640307
# Significant!
# For features ('x23', 'x150', 'x7') with r2 = 0.14141032226566827
# Significant!
# For features ('x23', 'x150', 'x48') with r2 = 0.1632469484281079
# Significant!
# For features ('x23', 'x98', 'x162') with r2 = 0.24432978377421763
# Significant!
# For features ('x23', 'x98', 'x159') with r2 = 0.33500386965795104
# Significant!
# For features ('x23', 'x98', 'x195') with r2 = 0.2791195512803095
# Significant!
# For features ('x23', 'x98', 'x61') with r2 = 0.26431164449932193
# Significant!
# For features ('x23', 'x98', 'x58') with r2 = 0.28639947991514975
# Significant!
# For features ('x23', 'x98', 'x9') with r2 = 0.2940125062261677
# Significant!
# For features ('x23', 'x98', 'x152') with r2 = 0.28407712152747167
# Significant!
# For features ('x23', 'x98', 'x43') with r2 = 0.25470818195299366
# Significant!
# For features ('x23', 'x98', 'x173') with r2 = 0.25145820148542847
# Significant!
# For features ('x23', 'x98', 'x158') with r2 = 0.1796461180006577
# Significant!
# For features ('x23', 'x98', 'x177') with r2 = 0.24749702723061612
# Significant!
# For features ('x23', 'x98', 'x63') with r2 = 0.30476144352561796
# Significant!
# For features ('x23', 'x98', 'x160') with r2 = 0.21151852794181042
# Significant!
# For features ('x23', 'x98', 'x213') with r2 = 0.28442506880060586
# Significant!
# For features ('x23', 'x98', 'x3') with r2 = 0.26649679209650734
# Significant!
# For features ('x23', 'x98', 'x7') with r2 = 0.3016685404839699
# Significant!
# For features ('x23', 'x98', 'x48') with r2 = 0.2886808002666371
# Significant!
# For features ('x23', 'x162', 'x159') with r2 = 0.3188535490997762
# Significant!
# For features ('x23', 'x162', 'x195') with r2 = 0.25380277831696724
# Significant!
# For features ('x23', 'x162', 'x61') with r2 = 0.2053664781799848
# Significant!
# For features ('x23', 'x162', 'x58') with r2 = 0.25239370282932233
# Significant!
# For features ('x23', 'x162', 'x9') with r2 = 0.25257000616826863
# Significant!
# For features ('x23', 'x162', 'x152') with r2 = 0.2579051400731342
# Significant!
# For features ('x23', 'x162', 'x43') with r2 = 0.2333220855692411
# Significant!
# For features ('x23', 'x162', 'x173') with r2 = 0.2677899046277068
# Significant!
# For features ('x23', 'x162', 'x177') with r2 = 0.24448139387704457
# Significant!
# For features ('x23', 'x162', 'x63') with r2 = 0.2598062787580195
# Significant!
# For features ('x23', 'x162', 'x160') with r2 = 0.21418865911657964
# Significant!
# For features ('x23', 'x162', 'x213') with r2 = 0.2575040937378184
# Significant!
# For features ('x23', 'x162', 'x3') with r2 = 0.26256414391091787
# Significant!
# For features ('x23', 'x162', 'x7') with r2 = 0.2642751897130317
# Significant!
# For features ('x23', 'x162', 'x48') with r2 = 0.2606987506914812
# Significant!
# For features ('x23', 'x159', 'x195') with r2 = 0.3406569762121362
# Significant!
# For features ('x23', 'x159', 'x61') with r2 = 0.26544341636785174
# Significant!
# For features ('x23', 'x159', 'x58') with r2 = 0.32492966315409694
# Significant!
# For features ('x23', 'x159', 'x9') with r2 = 0.3491142818361529
# Significant!
# For features ('x23', 'x159', 'x152') with r2 = 0.3417125437533232
# Significant!
# For features ('x23', 'x159', 'x43') with r2 = 0.3269791527147238
# Significant!
# For features ('x23', 'x159', 'x173') with r2 = 0.3305212786962918
# Significant!
# For features ('x23', 'x159', 'x158') with r2 = 0.3107259923411529
# Significant!
# For features ('x23', 'x159', 'x177') with r2 = 0.3139154371926343
# Significant!
# For features ('x23', 'x159', 'x63') with r2 = 0.3257864837193381
# Significant!
# For features ('x23', 'x159', 'x160') with r2 = 0.32952193004037716
# Significant!
# For features ('x23', 'x159', 'x213') with r2 = 0.34086983583096064
# Significant!
# For features ('x23', 'x159', 'x3') with r2 = 0.33644994670238276
# Significant!
# For features ('x23', 'x159', 'x7') with r2 = 0.3522742175285507
# Significant!
# For features ('x23', 'x159', 'x48') with r2 = 0.3417253197508843
# Significant!
# For features ('x23', 'x195', 'x43') with r2 = 0.11352567888980145
# Significant!
# For features ('x23', 'x195', 'x173') with r2 = 0.16826127322563686
# Significant!
# For features ('x23', 'x195', 'x158') with r2 = 0.13328384658913986
# Significant!
# For features ('x23', 'x195', 'x177') with r2 = 0.18614940763689308
# Significant!
# For features ('x23', 'x195', 'x7') with r2 = 0.1400993094901138
# Significant!
# For features ('x23', 'x61', 'x173') with r2 = 0.1484214552894982
# Significant!
# For features ('x23', 'x61', 'x158') with r2 = 0.12795437235236612
# Significant!
# For features ('x23', 'x61', 'x177') with r2 = 0.16171546820585497
# Significant!
# For features ('x23', 'x61', 'x7') with r2 = 0.14057634593953164
# Significant!
# For features ('x23', 'x58', 'x43') with r2 = 0.11885713689930714
# Significant!
# For features ('x23', 'x58', 'x173') with r2 = 0.18836315061022443
# Significant!
# For features ('x23', 'x58', 'x158') with r2 = 0.16404508295904402
# Significant!
# For features ('x23', 'x58', 'x177') with r2 = 0.20690274989378268
# Significant!
# For features ('x23', 'x58', 'x7') with r2 = 0.14822722725303739
# Significant!
# For features ('x23', 'x9', 'x173') with r2 = 0.17450300226829416
# Significant!
# For features ('x23', 'x9', 'x158') with r2 = 0.16704336128051647
# Significant!
# For features ('x23', 'x9', 'x177') with r2 = 0.18857578963615082
# Significant!
# For features ('x23', 'x9', 'x3') with r2 = 0.16882305398473527
# Significant!
# For features ('x23', 'x9', 'x7') with r2 = 0.22805144302392052
# Significant!
# For features ('x23', 'x152', 'x43') with r2 = 0.11213835392909186
# Significant!
# For features ('x23', 'x152', 'x173') with r2 = 0.1728631997759796
# Significant!
# For features ('x23', 'x152', 'x158') with r2 = 0.13906925138655923
# Significant!
# For features ('x23', 'x152', 'x177') with r2 = 0.1921055386555655
# Significant!
# For features ('x23', 'x152', 'x63') with r2 = 0.10828426513097958
# Significant!
# For features ('x23', 'x152', 'x213') with r2 = 0.1739550576160008
# Significant!
# For features ('x23', 'x152', 'x7') with r2 = 0.14392071477074897
# Significant!
# For features ('x23', 'x152', 'x48') with r2 = 0.18045013692844183
# Significant!
# For features ('x23', 'x43', 'x173') with r2 = 0.1346317304639376
# Significant!
# For features ('x23', 'x43', 'x177') with r2 = 0.17477191547125243
# Significant!
# For features ('x23', 'x43', 'x63') with r2 = 0.12229163274612775
# Significant!
# For features ('x23', 'x43', 'x213') with r2 = 0.11377146459448492
# Significant!
# For features ('x23', 'x43', 'x7') with r2 = 0.17087001768408772
# Significant!
# For features ('x23', 'x43', 'x48') with r2 = 0.11485121855891145
# Significant!
# For features ('x23', 'x173', 'x177') with r2 = 0.17057194284164648
# Significant!
# For features ('x23', 'x173', 'x63') with r2 = 0.19793891025736213
# Significant!
# For features ('x23', 'x173', 'x160') with r2 = 0.177550243109016
# Significant!
# For features ('x23', 'x173', 'x213') with r2 = 0.1724933784083839
# Significant!
# For features ('x23', 'x173', 'x3') with r2 = 0.17938786116942437
# Significant!
# For features ('x23', 'x173', 'x7') with r2 = 0.23405295535724316
# Significant!
# For features ('x23', 'x173', 'x48') with r2 = 0.17553482673125742
# Significant!
# For features ('x23', 'x158', 'x63') with r2 = 0.17948572253311618
# Significant!
# For features ('x23', 'x158', 'x160') with r2 = 0.3766090836264512
# Significant!
# For features ('x23', 'x158', 'x213') with r2 = 0.1392202961440096
# Significant!
# For features ('x23', 'x158', 'x3') with r2 = 0.13197412119825258
# Significant!
# For features ('x23', 'x158', 'x7') with r2 = 0.19485615011681062
# Significant!
# For features ('x23', 'x158', 'x48') with r2 = 0.149242116205547
# Significant!
# For features ('x23', 'x177', 'x63') with r2 = 0.21259348672058076
# Significant!
# For features ('x23', 'x177', 'x160') with r2 = 0.18322419986383764
# Significant!
# For features ('x23', 'x177', 'x213') with r2 = 0.1884026324432621
# Significant!
# For features ('x23', 'x177', 'x3') with r2 = 0.2280169242733642
# Significant!
# For features ('x23', 'x177', 'x7') with r2 = 0.2419180804678068
# Significant!
# For features ('x23', 'x177', 'x48') with r2 = 0.1923145096816097
# Significant!
# For features ('x23', 'x63', 'x7') with r2 = 0.16383546112153596
# Significant!
# For features ('x23', 'x160', 'x7') with r2 = 0.13212827339253458
# Significant!
# For features ('x23', 'x213', 'x7') with r2 = 0.13470904394031788
# Significant!
# For features ('x23', 'x213', 'x48') with r2 = 0.12518746900476213
# Significant!
# For features ('x23', 'x3', 'x7') with r2 = 0.13768387100599236
# Significant!
# For features ('x23', 'x7', 'x48') with r2 = 0.13857430183871156
# Significant!
# For features ('x5', 'x41', 'x33') with r2 = 0.10932605290446862
# Significant!
# For features ('x39', 'x41', 'x7') with r2 = 0.20806344791135026
# Significant!
# For features ('x39', 'x33', 'x48') with r2 = 0.11650533121643254
# Significant!
# For features ('x41', 'x33', 'x3') with r2 = 0.1958222773720448
# Significant!
# For features ('x41', 'x33', 'x7') with r2 = 0.15858425348472677
# Significant!
# For features ('x33', 'x148', 'x48') with r2 = 0.22212885470590585
# Significant!
# For features ('x33', 'x150', 'x48') with r2 = 0.1183937538368782
# Significant!
# For features ('x33', 'x195', 'x48') with r2 = 0.29591019392283513
# Significant!
# For features ('x33', 'x213', 'x48') with r2 = 0.23613775269932766

# %%
len(List_cvd_3_r2)
# Out:
# 1289

# %%
List3_cvd_3_r2,List3_cvd_2_r2,List3_cvd_0_r2 = combnfeats_MLR_evaby_crossval_metric(List_cvd_3_r2,df_x,df_y,20,model,'r2',0.3)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x23', 'x33') with r2 = 0.3499597523736553
# Significant!
# For features ('x186', 'x23', 'x102') with r2 = 0.3550960865791761
# Significant!
# For features ('x186', 'x23', 'x98') with r2 = 0.30982139399688974
# Significant!
# For features ('x49', 'x23', 'x33') with r2 = 0.3285730221719026
# Significant!
# For features ('x32', 'x99', 'x23') with r2 = 0.474844246198988
# Significant!
# For features ('x32', 'x50', 'x23') with r2 = 0.3385126020578181
# Significant!
# For features ('x32', 'x23', 'x175') with r2 = 0.3043744778021484
# Significant!
# For features ('x32', 'x23', 'x33') with r2 = 0.3611215848285063
# Significant!
# For features ('x32', 'x23', 'x102') with r2 = 0.4852123994481189
# Significant!
# For features ('x32', 'x23', 'x98') with r2 = 0.45497834067816656
# Significant!
# For features ('x32', 'x23', 'x162') with r2 = 0.36979143626638494
# Significant!
# For features ('x32', 'x23', 'x159') with r2 = 0.4562349443241981
# Significant!
# For features ('x32', 'x23', 'x173') with r2 = 0.37398275278171045
# Significant!
# For features ('x32', 'x23', 'x158') with r2 = 0.44791945115319026
# Significant!
# For features ('x32', 'x23', 'x160') with r2 = 0.39022974151501666
# Significant!
# For features ('x8', 'x99', 'x23') with r2 = 0.3326178968092088
# Significant!
# For features ('x8', 'x23', 'x102') with r2 = 0.3069187889080195
# Significant!
# For features ('x8', 'x23', 'x159') with r2 = 0.3305129410701676
# Significant!
# For features ('x2', 'x23', 'x33') with r2 = 0.35015891438580377
# Significant!
# For features ('x4', 'x99', 'x23') with r2 = 0.3332097422860822
# Significant!
# For features ('x4', 'x23', 'x33') with r2 = 0.34231883777444144
# Significant!
# For features ('x4', 'x23', 'x102') with r2 = 0.32395776643643853
# Significant!
# For features ('x4', 'x23', 'x98') with r2 = 0.3051969987695737
# Significant!
# For features ('x4', 'x23', 'x159') with r2 = 0.3361219433858591
# Significant!
# For features ('x27', 'x23', 'x33') with r2 = 0.3305423539690088
# Significant!
# For features ('x27', 'x23', 'x159') with r2 = 0.3011773165920103
# Significant!
# For features ('x99', 'x23', 'x6') with r2 = 0.34445537625848555
# Significant!
# For features ('x99', 'x23', 'x39') with r2 = 0.3387267945560083
# Significant!
# For features ('x99', 'x23', 'x33') with r2 = 0.4389334994595693
# Significant!
# For features ('x99', 'x23', 'x9') with r2 = 0.3114618464631733
# Significant!
# For features ('x50', 'x23', 'x33') with r2 = 0.3522515501506097
# Significant!
# For features ('x50', 'x23', 'x159') with r2 = 0.3023219346951796
# Significant!
# For features ('x188', 'x23', 'x33') with r2 = 0.31332212800852866
# Significant!
# For features ('x188', 'x33', 'x48') with r2 = 0.3625558442824128
# Significant!
# For features ('x45', 'x23', 'x33') with r2 = 0.34097592477840544
# Significant!
# For features ('x42', 'x23', 'x33') with r2 = 0.31681057167672577
# Significant!
# For features ('x193', 'x23', 'x33') with r2 = 0.3105719981181686
# Significant!
# For features ('x193', 'x33', 'x48') with r2 = 0.30286468940503436
# Significant!
# For features ('x71', 'x23', 'x33') with r2 = 0.3711819088183278
# Significant!
# For features ('x23', 'x149', 'x33') with r2 = 0.323117868914282
# Significant!
# For features ('x23', 'x6', 'x33') with r2 = 0.34735776091487847
# Significant!
# For features ('x23', 'x6', 'x102') with r2 = 0.37360047844857885
# Significant!
# For features ('x23', 'x6', 'x98') with r2 = 0.3298696930488639
# Significant!
# For features ('x23', 'x6', 'x159') with r2 = 0.33717427469230266
# Significant!
# For features ('x23', 'x5', 'x33') with r2 = 0.32699703544997216
# Significant!
# For features ('x23', 'x39', 'x33') with r2 = 0.3204339154096186
# Significant!
# For features ('x23', 'x39', 'x102') with r2 = 0.3223716077862053
# Significant!
# For features ('x23', 'x39', 'x98') with r2 = 0.30759939747565274
# Significant!
# For features ('x23', 'x39', 'x159') with r2 = 0.3376109223768434
# Significant!
# For features ('x23', 'x175', 'x33') with r2 = 0.3474836880541309
# Significant!
# For features ('x23', 'x175', 'x102') with r2 = 0.3362494440386139
# Significant!
# For features ('x23', 'x67', 'x33') with r2 = 0.37376272455604714
# Significant!
# For features ('x23', 'x41', 'x33') with r2 = 0.3527171956723108
# Significant!
# For features ('x23', 'x33', 'x148') with r2 = 0.31812154497260225
# Significant!
# For features ('x23', 'x33', 'x194') with r2 = 0.3025700425077205
# Significant!
# For features ('x23', 'x33', 'x102') with r2 = 0.44255618843632993
# Significant!
# For features ('x23', 'x33', 'x150') with r2 = 0.3193078868766438
# Significant!
# For features ('x23', 'x33', 'x98') with r2 = 0.42524257985483815
# Significant!
# For features ('x23', 'x33', 'x162') with r2 = 0.3596068622755614
# Significant!
# For features ('x23', 'x33', 'x159') with r2 = 0.4132786191469739
# Significant!
# For features ('x23', 'x33', 'x195') with r2 = 0.31263134065863746
# Significant!
# For features ('x23', 'x33', 'x61') with r2 = 0.3639791409294998
# Significant!
# For features ('x23', 'x33', 'x58') with r2 = 0.34837296295951575
# Significant!
# For features ('x23', 'x33', 'x9') with r2 = 0.325472485040603
# Significant!
# For features ('x23', 'x33', 'x152') with r2 = 0.32081060605172007
# Significant!
# For features ('x23', 'x33', 'x173') with r2 = 0.3587099915321633
# Significant!
# For features ('x23', 'x33', 'x158') with r2 = 0.42321070006129347
# Significant!
# For features ('x23', 'x33', 'x177') with r2 = 0.34373585360991055
# Significant!
# For features ('x23', 'x33', 'x63') with r2 = 0.36052902843406814
# Significant!
# For features ('x23', 'x33', 'x160') with r2 = 0.39530349440733303
# Significant!
# For features ('x23', 'x33', 'x213') with r2 = 0.31449669955768855
# Significant!
# For features ('x23', 'x33', 'x3') with r2 = 0.32335166330065873
# Significant!
# For features ('x23', 'x33', 'x7') with r2 = 0.31682083796978305
# Significant!
# For features ('x23', 'x33', 'x48') with r2 = 0.3191246729718037
# Significant!
# For features ('x23', 'x159', 'x9') with r2 = 0.32282744778515304
# Significant!
# For features ('x23', 'x159', 'x7') with r2 = 0.3005293614824217

# %%
len(List3_cvd_3_r2)
# Out:
# 76

# %%
List4_cvd_3_r2,List4_cvd_2_r2,List4_cvd_0_r2 = combnfeats_MLR_evaby_crossval_metric(List3_cvd_3_r2,df_x,df_y,20,model,'r2',0.4)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x32', 'x99', 'x23') with r2 = 0.474844246198988
# Significant!
# For features ('x32', 'x23', 'x102') with r2 = 0.4852123994481189
# Significant!
# For features ('x32', 'x23', 'x98') with r2 = 0.45497834067816656
# Significant!
# For features ('x32', 'x23', 'x159') with r2 = 0.4562349443241981
# Significant!
# For features ('x32', 'x23', 'x158') with r2 = 0.44791945115319026
# Significant!
# For features ('x99', 'x23', 'x33') with r2 = 0.4389334994595693
# Significant!
# For features ('x23', 'x33', 'x102') with r2 = 0.44255618843632993
# Significant!
# For features ('x23', 'x33', 'x98') with r2 = 0.42524257985483815
# Significant!
# For features ('x23', 'x33', 'x159') with r2 = 0.4132786191469739
# Significant!
# For features ('x23', 'x33', 'x158') with r2 = 0.42321070006129347

# %%
List5_cvd_3_r2,List5_cvd_2_r2,List5_cvd_0_r2 = combnfeats_MLR_evaby_crossval_metric(List4_cvd_3_r2,df_x,df_y,500,model,'r2',0.4)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x32', 'x99', 'x23') with r2 = 0.4668700151847758
# Significant!
# For features ('x32', 'x23', 'x102') with r2 = 0.48501430269752543
# Significant!
# For features ('x32', 'x23', 'x98') with r2 = 0.456111542422716
# Significant!
# For features ('x32', 'x23', 'x159') with r2 = 0.45159303804133105
# Significant!
# For features ('x32', 'x23', 'x158') with r2 = 0.44968125241633017
# Significant!
# For features ('x99', 'x23', 'x33') with r2 = 0.4420672881832912
# Significant!
# For features ('x23', 'x33', 'x102') with r2 = 0.45778706856396373
# Significant!
# For features ('x23', 'x33', 'x98') with r2 = 0.4395539940948253
# Significant!
# For features ('x23', 'x33', 'x159') with r2 = 0.421074102645426
# Significant!
# For features ('x23', 'x33', 'x158') with r2 = 0.4409134217578748

# %% [markdown]
# 'x32', 'x23', 'x102'

# %% [markdown]
# Negative MAE

# %%
# Scoring gave you the middle bar - the high bar is scoring *1.5, the low bar is scoring *0.5. A ranking is embedded in the function to 
# ensure that negative metric, like -RMSE, can also be ranked normally, not reversely.
List2_2cvd_3_nmae,List2_2cvd_2_nmae,List2_2cvd_0_nmae = combnfeats_MLR_evaby_crossval_metric(feats,df_x,df_y,5,model,'neg_mean_absolute_error',-19)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x49', 'x27') with neg_mean_absolute_error = -18.72571533404028
# Significant!
# For features ('x186', 'x49', 'x23') with neg_mean_absolute_error = -17.751141956222806
# Significant!
# For features ('x186', 'x32', 'x23') with neg_mean_absolute_error = -16.429187344974576
# Significant!
# For features ('x186', 'x8', 'x23') with neg_mean_absolute_error = -17.59163535893577
# Significant!
# For features ('x186', 'x2', 'x99') with neg_mean_absolute_error = -18.32687168623706
# Significant!
# For features ('x186', 'x2', 'x33') with neg_mean_absolute_error = -17.77220056760386
# Significant!
# For features ('x186', 'x2', 'x102') with neg_mean_absolute_error = -17.338450349684642
# Significant!
# For features ('x186', 'x2', 'x98') with neg_mean_absolute_error = -17.917779634968422
# Significant!
# For features ('x186', 'x2', 'x162') with neg_mean_absolute_error = -18.43405983052849
# Significant!
# For features ('x186', 'x2', 'x159') with neg_mean_absolute_error = -18.041679884784337
# Significant!
# For features ('x186', 'x4', 'x23') with neg_mean_absolute_error = -18.539953090683106
# Significant!
# For features ('x186', 'x27', 'x99') with neg_mean_absolute_error = -18.221368690938398
# Significant!
# For features ('x186', 'x27', 'x50') with neg_mean_absolute_error = -18.727083504241335
# Significant!
# For features ('x186', 'x27', 'x149') with neg_mean_absolute_error = -18.937508104565325
# Significant!
# For features ('x186', 'x27', 'x33') with neg_mean_absolute_error = -18.86782449900899
# Significant!
# For features ('x186', 'x27', 'x102') with neg_mean_absolute_error = -16.636961315502397
# Significant!
# For features ('x186', 'x27', 'x150') with neg_mean_absolute_error = -18.998637242532563
# Significant!
# For features ('x186', 'x27', 'x98') with neg_mean_absolute_error = -17.59190144713387
# Significant!
# For features ('x186', 'x27', 'x162') with neg_mean_absolute_error = -18.703372869002486
# Significant!
# For features ('x186', 'x27', 'x159') with neg_mean_absolute_error = -18.849374478145574
# Significant!
# For features ('x186', 'x27', 'x152') with neg_mean_absolute_error = -18.976115950445937
# Significant!
# For features ('x186', 'x27', 'x173') with neg_mean_absolute_error = -18.990958955424723
# Significant!
# For features ('x186', 'x27', 'x158') with neg_mean_absolute_error = -17.93710478127404
# Significant!
# For features ('x186', 'x27', 'x160') with neg_mean_absolute_error = -18.303900695348954
# Significant!
# For features ('x186', 'x99', 'x23') with neg_mean_absolute_error = -15.861610728292339
# Significant!
# For features ('x186', 'x50', 'x23') with neg_mean_absolute_error = -17.033189291270702
# Significant!
# For features ('x186', 'x188', 'x23') with neg_mean_absolute_error = -17.877816214646966
# Significant!
# For features ('x186', 'x45', 'x23') with neg_mean_absolute_error = -17.02711260454968
# Significant!
# For features ('x186', 'x42', 'x23') with neg_mean_absolute_error = -17.803379636386204
# Significant!
# For features ('x186', 'x193', 'x23') with neg_mean_absolute_error = -17.98919277126936
# Significant!
# For features ('x186', 'x23', 'x149') with neg_mean_absolute_error = -17.463473106404614
# Significant!
# For features ('x186', 'x23', 'x5') with neg_mean_absolute_error = -18.362680382276572
# Significant!
# For features ('x186', 'x23', 'x39') with neg_mean_absolute_error = -18.16829971660714
# Significant!
# For features ('x186', 'x23', 'x175') with neg_mean_absolute_error = -18.075573389823596
# Significant!
# For features ('x186', 'x23', 'x33') with neg_mean_absolute_error = -16.194786669548293
# Significant!
# For features ('x186', 'x23', 'x148') with neg_mean_absolute_error = -17.69714449147347
# Significant!
# For features ('x186', 'x23', 'x194') with neg_mean_absolute_error = -17.964978859773314
# Significant!
# For features ('x186', 'x23', 'x102') with neg_mean_absolute_error = -14.275031233242993
# Significant!
# For features ('x186', 'x23', 'x150') with neg_mean_absolute_error = -17.735268931284192
# Significant!
# For features ('x186', 'x23', 'x98') with neg_mean_absolute_error = -15.097794482659799
# Significant!
# For features ('x186', 'x23', 'x162') with neg_mean_absolute_error = -15.768968531106363
# Significant!
# For features ('x186', 'x23', 'x159') with neg_mean_absolute_error = -15.596059579376282
# Significant!
# For features ('x186', 'x23', 'x195') with neg_mean_absolute_error = -17.841796112730467
# Significant!
# For features ('x186', 'x23', 'x9') with neg_mean_absolute_error = -18.76583044917229
# Significant!
# For features ('x186', 'x23', 'x152') with neg_mean_absolute_error = -17.676199991826167
# Significant!
# For features ('x186', 'x23', 'x43') with neg_mean_absolute_error = -17.649373795820484
# Significant!
# For features ('x186', 'x23', 'x173') with neg_mean_absolute_error = -16.933568928374218
# Significant!
# For features ('x186', 'x23', 'x158') with neg_mean_absolute_error = -16.157698580597575
# Significant!
# For features ('x186', 'x23', 'x177') with neg_mean_absolute_error = -17.90321242539543
# Significant!
# For features ('x186', 'x23', 'x160') with neg_mean_absolute_error = -17.104988790967525
# Significant!
# For features ('x186', 'x23', 'x213') with neg_mean_absolute_error = -17.90581441165223
# Significant!
# For features ('x186', 'x23', 'x7') with neg_mean_absolute_error = -18.475764111813525
# Significant!
# For features ('x186', 'x23', 'x48') with neg_mean_absolute_error = -18.028361585872965
# Significant!
# For features ('x49', 'x32', 'x23') with neg_mean_absolute_error = -16.83797102018011
# Significant!
# For features ('x49', 'x8', 'x23') with neg_mean_absolute_error = -17.931188571026016
# Significant!
# For features ('x49', 'x8', 'x33') with neg_mean_absolute_error = -18.167722391522926
# Significant!
# For features ('x49', 'x2', 'x33') with neg_mean_absolute_error = -18.08506003639257
# Significant!
# For features ('x49', 'x2', 'x159') with neg_mean_absolute_error = -18.846921277436728
# Significant!
# For features ('x49', 'x4', 'x23') with neg_mean_absolute_error = -18.30771273206529
# Significant!
# For features ('x49', 'x27', 'x99') with neg_mean_absolute_error = -18.12341737953912
# Significant!
# For features ('x49', 'x27', 'x5') with neg_mean_absolute_error = -18.98350972333801
# Significant!
# For features ('x49', 'x27', 'x41') with neg_mean_absolute_error = -18.411293680576517
# Significant!
# For features ('x49', 'x27', 'x33') with neg_mean_absolute_error = -18.777551473719072
# Significant!
# For features ('x49', 'x27', 'x102') with neg_mean_absolute_error = -17.345433996693266
# Significant!
# For features ('x49', 'x27', 'x98') with neg_mean_absolute_error = -17.826056550427502
# Significant!
# For features ('x49', 'x27', 'x162') with neg_mean_absolute_error = -18.864994209144168
# Significant!
# For features ('x49', 'x27', 'x159') with neg_mean_absolute_error = -18.548195055848417
# Significant!
# For features ('x49', 'x27', 'x9') with neg_mean_absolute_error = -18.756625996617885
# Significant!
# For features ('x49', 'x27', 'x158') with neg_mean_absolute_error = -18.184633814504043
# Significant!
# For features ('x49', 'x27', 'x160') with neg_mean_absolute_error = -18.75152761797238
# Significant!
# For features ('x49', 'x27', 'x3') with neg_mean_absolute_error = -18.377396181059837
# Significant!
# For features ('x49', 'x99', 'x23') with neg_mean_absolute_error = -16.34917261208103
# Significant!
# For features ('x49', 'x188', 'x33') with neg_mean_absolute_error = -18.89054546176961
# Significant!
# For features ('x49', 'x45', 'x23') with neg_mean_absolute_error = -18.536425269229287
# Significant!
# For features ('x49', 'x45', 'x33') with neg_mean_absolute_error = -17.682199492245644
# Significant!
# For features ('x49', 'x42', 'x33') with neg_mean_absolute_error = -18.466952061675777
# Significant!
# For features ('x49', 'x193', 'x33') with neg_mean_absolute_error = -18.965482198010143
# Significant!
# For features ('x49', 'x23', 'x6') with neg_mean_absolute_error = -17.870613324181573
# Significant!
# For features ('x49', 'x23', 'x39') with neg_mean_absolute_error = -17.94925355990653
# Significant!
# For features ('x49', 'x23', 'x33') with neg_mean_absolute_error = -16.190970330046685
# Significant!
# For features ('x49', 'x23', 'x102') with neg_mean_absolute_error = -16.156944729532746
# Significant!
# For features ('x49', 'x23', 'x98') with neg_mean_absolute_error = -16.743984125213995
# Significant!
# For features ('x49', 'x23', 'x162') with neg_mean_absolute_error = -16.876201080112256
# Significant!
# For features ('x49', 'x23', 'x159') with neg_mean_absolute_error = -15.491943647347302
# Significant!
# For features ('x49', 'x23', 'x173') with neg_mean_absolute_error = -17.84903753270195
# Significant!
# For features ('x49', 'x23', 'x158') with neg_mean_absolute_error = -17.508232626475635
# Significant!
# For features ('x49', 'x23', 'x177') with neg_mean_absolute_error = -17.823256624868137
# Significant!
# For features ('x49', 'x39', 'x33') with neg_mean_absolute_error = -18.5452462711161
# Significant!
# For features ('x49', 'x33', 'x150') with neg_mean_absolute_error = -17.878615064236648
# Significant!
# For features ('x49', 'x33', 'x195') with neg_mean_absolute_error = -18.471138269201212
# Significant!
# For features ('x49', 'x33', 'x152') with neg_mean_absolute_error = -17.59835414118162
# Significant!
# For features ('x49', 'x33', 'x213') with neg_mean_absolute_error = -18.294148662929835
# Significant!
# For features ('x32', 'x8', 'x50') with neg_mean_absolute_error = -18.956571371404532
# Significant!
# For features ('x32', 'x8', 'x23') with neg_mean_absolute_error = -17.098490755548337
# Significant!
# For features ('x32', 'x8', 'x158') with neg_mean_absolute_error = -18.689528468827753
# Significant!
# For features ('x32', 'x8', 'x160') with neg_mean_absolute_error = -18.83747811273027
# Significant!
# For features ('x32', 'x2', 'x99') with neg_mean_absolute_error = -17.91036009493217
# Significant!
# For features ('x32', 'x2', 'x50') with neg_mean_absolute_error = -18.989331342259838
# Significant!
# For features ('x32', 'x2', 'x23') with neg_mean_absolute_error = -17.407798537705567
# Significant!
# For features ('x32', 'x2', 'x33') with neg_mean_absolute_error = -18.309949284517007
# Significant!
# For features ('x32', 'x2', 'x102') with neg_mean_absolute_error = -17.53981631063037
# Significant!
# For features ('x32', 'x2', 'x98') with neg_mean_absolute_error = -18.48892094569498
# Significant!
# For features ('x32', 'x2', 'x159') with neg_mean_absolute_error = -18.187052712910557
# Significant!
# For features ('x32', 'x2', 'x173') with neg_mean_absolute_error = -18.951449372837235
# Significant!
# For features ('x32', 'x2', 'x158') with neg_mean_absolute_error = -17.965092159225378
# Significant!
# For features ('x32', 'x2', 'x160') with neg_mean_absolute_error = -18.579100906732315
# Significant!
# For features ('x32', 'x4', 'x23') with neg_mean_absolute_error = -17.99835148002757
# Significant!
# For features ('x32', 'x27', 'x99') with neg_mean_absolute_error = -18.745164851111706
# Significant!
# For features ('x32', 'x27', 'x50') with neg_mean_absolute_error = -18.84903563820206
# Significant!
# For features ('x32', 'x27', 'x23') with neg_mean_absolute_error = -17.682386588552596
# Significant!
# For features ('x32', 'x27', 'x41') with neg_mean_absolute_error = -17.782605486530723
# Significant!
# For features ('x32', 'x27', 'x102') with neg_mean_absolute_error = -17.62661335909508
# Significant!
# For features ('x32', 'x27', 'x98') with neg_mean_absolute_error = -18.46380234153336
# Significant!
# For features ('x32', 'x27', 'x158') with neg_mean_absolute_error = -18.025667958587686
# Significant!
# For features ('x32', 'x27', 'x160') with neg_mean_absolute_error = -17.849683417155667
# Significant!
# For features ('x32', 'x99', 'x23') with neg_mean_absolute_error = -14.190133608840819
# Significant!
# For features ('x32', 'x50', 'x23') with neg_mean_absolute_error = -15.729901432749301
# Significant!
# For features ('x32', 'x188', 'x23') with neg_mean_absolute_error = -17.168523884095396
# Significant!
# For features ('x32', 'x45', 'x23') with neg_mean_absolute_error = -16.40268403818997
# Significant!
# For features ('x32', 'x42', 'x23') with neg_mean_absolute_error = -17.077763582179287
# Significant!
# For features ('x32', 'x193', 'x23') with neg_mean_absolute_error = -17.18571374450186
# Significant!
# For features ('x32', 'x71', 'x23') with neg_mean_absolute_error = -17.596408122738474
# Significant!
# For features ('x32', 'x23', 'x149') with neg_mean_absolute_error = -16.531117748190074
# Significant!
# For features ('x32', 'x23', 'x6') with neg_mean_absolute_error = -17.782253314857734
# Significant!
# For features ('x32', 'x23', 'x5') with neg_mean_absolute_error = -17.705298834838494
# Significant!
# For features ('x32', 'x23', 'x39') with neg_mean_absolute_error = -17.65723142051857
# Significant!
# For features ('x32', 'x23', 'x175') with neg_mean_absolute_error = -16.75177217238049
# Significant!
# For features ('x32', 'x23', 'x67') with neg_mean_absolute_error = -17.739142116918938
# Significant!
# For features ('x32', 'x23', 'x41') with neg_mean_absolute_error = -17.559829511752156
# Significant!
# For features ('x32', 'x23', 'x33') with neg_mean_absolute_error = -16.083486805295507
# Significant!
# For features ('x32', 'x23', 'x148') with neg_mean_absolute_error = -17.023545767681345
# Significant!
# For features ('x32', 'x23', 'x194') with neg_mean_absolute_error = -16.973378785999387
# Significant!
# For features ('x32', 'x23', 'x102') with neg_mean_absolute_error = -13.62055399836952
# Significant!
# For features ('x32', 'x23', 'x150') with neg_mean_absolute_error = -17.03545538154893
# Significant!
# For features ('x32', 'x23', 'x98') with neg_mean_absolute_error = -14.609007824911018
# Significant!
# For features ('x32', 'x23', 'x162') with neg_mean_absolute_error = -15.787237701579745
# Significant!
# For features ('x32', 'x23', 'x159') with neg_mean_absolute_error = -14.285732776834356
# Significant!
# For features ('x32', 'x23', 'x195') with neg_mean_absolute_error = -17.165000104729476
# Significant!
# For features ('x32', 'x23', 'x61') with neg_mean_absolute_error = -17.888530816127005
# Significant!
# For features ('x32', 'x23', 'x58') with neg_mean_absolute_error = -17.512152404727974
# Significant!
# For features ('x32', 'x23', 'x9') with neg_mean_absolute_error = -17.600450221497514
# Significant!
# For features ('x32', 'x23', 'x152') with neg_mean_absolute_error = -17.00519884139002
# Significant!
# For features ('x32', 'x23', 'x43') with neg_mean_absolute_error = -17.225978634925045
# Significant!
# For features ('x32', 'x23', 'x173') with neg_mean_absolute_error = -15.567928487528556
# Significant!
# For features ('x32', 'x23', 'x158') with neg_mean_absolute_error = -14.197111475469635
# Significant!
# For features ('x32', 'x23', 'x177') with neg_mean_absolute_error = -16.959015125821264
# Significant!
# For features ('x32', 'x23', 'x63') with neg_mean_absolute_error = -17.54937447183525
# Significant!
# For features ('x32', 'x23', 'x160') with neg_mean_absolute_error = -15.066800409421253
# Significant!
# For features ('x32', 'x23', 'x213') with neg_mean_absolute_error = -17.098642989842638
# Significant!
# For features ('x32', 'x23', 'x3') with neg_mean_absolute_error = -17.743041347682997
# Significant!
# For features ('x32', 'x23', 'x7') with neg_mean_absolute_error = -17.870198301678847
# Significant!
# For features ('x32', 'x23', 'x48') with neg_mean_absolute_error = -17.150702448923067
# Significant!
# For features ('x32', 'x5', 'x158') with neg_mean_absolute_error = -18.601233699703283
# Significant!
# For features ('x32', 'x5', 'x160') with neg_mean_absolute_error = -18.751911415426452
# Significant!
# For features ('x32', 'x39', 'x158') with neg_mean_absolute_error = -18.773292825100718
# Significant!
# For features ('x32', 'x102', 'x7') with neg_mean_absolute_error = -18.145768233911802
# Significant!
# For features ('x32', 'x98', 'x7') with neg_mean_absolute_error = -18.83109280735554
# Significant!
# For features ('x32', 'x43', 'x160') with neg_mean_absolute_error = -18.353188256625465
# Significant!
# For features ('x32', 'x158', 'x7') with neg_mean_absolute_error = -17.308675355039448
# Significant!
# For features ('x32', 'x160', 'x7') with neg_mean_absolute_error = -18.058838030679254
# Significant!
# For features ('x8', 'x2', 'x23') with neg_mean_absolute_error = -17.683190101069677
# Significant!
# For features ('x8', 'x2', 'x33') with neg_mean_absolute_error = -18.246310312708538
# Significant!
# For features ('x8', 'x4', 'x23') with neg_mean_absolute_error = -17.64813779356757
# Significant!
# For features ('x8', 'x27', 'x23') with neg_mean_absolute_error = -17.45830575649034
# Significant!
# For features ('x8', 'x27', 'x6') with neg_mean_absolute_error = -18.492495574966767
# Significant!
# For features ('x8', 'x27', 'x41') with neg_mean_absolute_error = -16.72686767538757
# Significant!
# For features ('x8', 'x27', 'x102') with neg_mean_absolute_error = -17.91825218857436
# Significant!
# For features ('x8', 'x27', 'x98') with neg_mean_absolute_error = -18.65499770276768
# Significant!
# For features ('x8', 'x27', 'x9') with neg_mean_absolute_error = -18.912967913501923
# Significant!
# For features ('x8', 'x27', 'x158') with neg_mean_absolute_error = -18.32646266273249
# Significant!
# For features ('x8', 'x27', 'x160') with neg_mean_absolute_error = -18.605233772131733
# Significant!
# For features ('x8', 'x99', 'x23') with neg_mean_absolute_error = -16.03948499274228
# Significant!
# For features ('x8', 'x50', 'x23') with neg_mean_absolute_error = -17.79447283411181
# Significant!
# For features ('x8', 'x50', 'x33') with neg_mean_absolute_error = -17.291839556359733
# Significant!
# For features ('x8', 'x188', 'x23') with neg_mean_absolute_error = -17.965674280331932
# Significant!
# For features ('x8', 'x45', 'x23') with neg_mean_absolute_error = -18.05002740543005
# Significant!
# For features ('x8', 'x42', 'x23') with neg_mean_absolute_error = -17.967776361704267
# Significant!
# For features ('x8', 'x42', 'x33') with neg_mean_absolute_error = -18.7739459946215
# Significant!
# For features ('x8', 'x193', 'x23') with neg_mean_absolute_error = -17.98490030968162
# Significant!
# For features ('x8', 'x71', 'x23') with neg_mean_absolute_error = -17.896866461464107
# Significant!
# For features ('x8', 'x23', 'x149') with neg_mean_absolute_error = -17.433887709499736
# Significant!
# For features ('x8', 'x23', 'x6') with neg_mean_absolute_error = -17.399570843095784
# Significant!
# For features ('x8', 'x23', 'x5') with neg_mean_absolute_error = -17.33527644198022
# Significant!
# For features ('x8', 'x23', 'x39') with neg_mean_absolute_error = -17.59806080448604
# Significant!
# For features ('x8', 'x23', 'x175') with neg_mean_absolute_error = -17.742513622083955
# Significant!
# For features ('x8', 'x23', 'x67') with neg_mean_absolute_error = -17.823955502121994
# Significant!
# For features ('x8', 'x23', 'x41') with neg_mean_absolute_error = -17.789192787517443
# Significant!
# For features ('x8', 'x23', 'x33') with neg_mean_absolute_error = -17.09144384888649
# Significant!
# For features ('x8', 'x23', 'x148') with neg_mean_absolute_error = -18.02766530068049
# Significant!
# For features ('x8', 'x23', 'x194') with neg_mean_absolute_error = -18.0000853016338
# Significant!
# For features ('x8', 'x23', 'x102') with neg_mean_absolute_error = -15.629849252154518
# Significant!
# For features ('x8', 'x23', 'x150') with neg_mean_absolute_error = -17.962782560756033
# Significant!
# For features ('x8', 'x23', 'x98') with neg_mean_absolute_error = -16.125141121355295
# Significant!
# For features ('x8', 'x23', 'x162') with neg_mean_absolute_error = -16.47316320077438
# Significant!
# For features ('x8', 'x23', 'x159') with neg_mean_absolute_error = -15.758160218642796
# Significant!
# For features ('x8', 'x23', 'x195') with neg_mean_absolute_error = -17.95225711647613
# Significant!
# For features ('x8', 'x23', 'x61') with neg_mean_absolute_error = -18.105437926150085
# Significant!
# For features ('x8', 'x23', 'x58') with neg_mean_absolute_error = -18.06266590548985
# Significant!
# For features ('x8', 'x23', 'x9') with neg_mean_absolute_error = -17.356830883473496
# Significant!
# For features ('x8', 'x23', 'x152') with neg_mean_absolute_error = -17.95383131993745
# Significant!
# For features ('x8', 'x23', 'x43') with neg_mean_absolute_error = -17.767991071141424
# Significant!
# For features ('x8', 'x23', 'x173') with neg_mean_absolute_error = -17.085911347113807
# Significant!
# For features ('x8', 'x23', 'x158') with neg_mean_absolute_error = -16.987522312514262
# Significant!
# For features ('x8', 'x23', 'x177') with neg_mean_absolute_error = -16.9997921345193
# Significant!
# For features ('x8', 'x23', 'x63') with neg_mean_absolute_error = -17.809805923189934
# Significant!
# For features ('x8', 'x23', 'x160') with neg_mean_absolute_error = -17.48172631224448
# Significant!
# For features ('x8', 'x23', 'x213') with neg_mean_absolute_error = -17.987890690975963
# Significant!
# For features ('x8', 'x23', 'x3') with neg_mean_absolute_error = -17.0986097895108
# Significant!
# For features ('x8', 'x23', 'x7') with neg_mean_absolute_error = -17.32601243021696
# Significant!
# For features ('x8', 'x23', 'x48') with neg_mean_absolute_error = -17.966968598392523
# Significant!
# For features ('x8', 'x149', 'x33') with neg_mean_absolute_error = -18.953679685157052
# Significant!
# For features ('x8', 'x33', 'x148') with neg_mean_absolute_error = -18.953144364704272
# Significant!
# For features ('x8', 'x33', 'x194') with neg_mean_absolute_error = -18.958598640358304
# Significant!
# For features ('x8', 'x33', 'x150') with neg_mean_absolute_error = -18.74373899222806
# Significant!
# For features ('x8', 'x33', 'x195') with neg_mean_absolute_error = -18.910039848561546
# Significant!
# For features ('x8', 'x33', 'x152') with neg_mean_absolute_error = -18.731748537982956
# Significant!
# For features ('x8', 'x33', 'x213') with neg_mean_absolute_error = -18.76086687846933
# Significant!
# For features ('x8', 'x33', 'x48') with neg_mean_absolute_error = -18.62642751113423
# Significant!
# For features ('x2', 'x4', 'x99') with neg_mean_absolute_error = -18.956394353761887
# Significant!
# For features ('x2', 'x4', 'x33') with neg_mean_absolute_error = -18.479007881500856
# Significant!
# For features ('x2', 'x4', 'x102') with neg_mean_absolute_error = -18.86817344317588
# Significant!
# For features ('x2', 'x4', 'x159') with neg_mean_absolute_error = -18.961211071682918
# Significant!
# For features ('x2', 'x27', 'x99') with neg_mean_absolute_error = -18.221346041806125
# Significant!
# For features ('x2', 'x27', 'x33') with neg_mean_absolute_error = -18.189422555795524
# Significant!
# For features ('x2', 'x27', 'x102') with neg_mean_absolute_error = -16.51437868354696
# Significant!
# For features ('x2', 'x27', 'x98') with neg_mean_absolute_error = -17.538478150657518
# Significant!
# For features ('x2', 'x27', 'x162') with neg_mean_absolute_error = -18.770999115510683
# Significant!
# For features ('x2', 'x27', 'x159') with neg_mean_absolute_error = -18.74062854468305
# Significant!
# For features ('x2', 'x27', 'x158') with neg_mean_absolute_error = -18.40226028829423
# Significant!
# For features ('x2', 'x99', 'x71') with neg_mean_absolute_error = -18.79922344680255
# Significant!
# For features ('x2', 'x99', 'x23') with neg_mean_absolute_error = -15.980712109902734
# Significant!
# For features ('x2', 'x99', 'x6') with neg_mean_absolute_error = -18.33890303869204
# Significant!
# For features ('x2', 'x99', 'x39') with neg_mean_absolute_error = -18.924538929942052
# Significant!
# For features ('x2', 'x99', 'x175') with neg_mean_absolute_error = -18.968826549675683
# Significant!
# For features ('x2', 'x99', 'x33') with neg_mean_absolute_error = -17.54597472636687
# Significant!
# For features ('x2', 'x99', 'x61') with neg_mean_absolute_error = -18.970525102888537
# Significant!
# For features ('x2', 'x99', 'x58') with neg_mean_absolute_error = -18.371964590395073
# Significant!
# For features ('x2', 'x99', 'x9') with neg_mean_absolute_error = -18.544818412044247
# Significant!
# For features ('x2', 'x99', 'x177') with neg_mean_absolute_error = -18.904570028358357
# Significant!
# For features ('x2', 'x99', 'x63') with neg_mean_absolute_error = -18.371070054296602
# Significant!
# For features ('x2', 'x50', 'x23') with neg_mean_absolute_error = -18.39984134383417
# Significant!
# For features ('x2', 'x50', 'x33') with neg_mean_absolute_error = -17.885088437575654
# Significant!
# For features ('x2', 'x188', 'x33') with neg_mean_absolute_error = -18.21983679407042
# Significant!
# For features ('x2', 'x188', 'x159') with neg_mean_absolute_error = -18.758783256486495
# Significant!
# For features ('x2', 'x45', 'x23') with neg_mean_absolute_error = -18.299391324564926
# Significant!
# For features ('x2', 'x45', 'x33') with neg_mean_absolute_error = -18.094986215815897
# Significant!
# For features ('x2', 'x45', 'x159') with neg_mean_absolute_error = -18.71111030604539
# Significant!
# For features ('x2', 'x42', 'x33') with neg_mean_absolute_error = -18.18167179478141
# Significant!
# For features ('x2', 'x42', 'x159') with neg_mean_absolute_error = -18.776585802914433
# Significant!
# For features ('x2', 'x193', 'x33') with neg_mean_absolute_error = -18.244966910561775
# Significant!
# For features ('x2', 'x193', 'x159') with neg_mean_absolute_error = -18.775931385356834
# Significant!
# For features ('x2', 'x71', 'x33') with neg_mean_absolute_error = -17.686575407535194
# Significant!
# For features ('x2', 'x71', 'x102') with neg_mean_absolute_error = -18.486091945154175
# Significant!
# For features ('x2', 'x71', 'x159') with neg_mean_absolute_error = -18.891225523880472
# Significant!
# For features ('x2', 'x23', 'x149') with neg_mean_absolute_error = -17.727230896764723
# Significant!
# For features ('x2', 'x23', 'x6') with neg_mean_absolute_error = -18.868138750859185
# Significant!
# For features ('x2', 'x23', 'x39') with neg_mean_absolute_error = -18.07045430252527
# Significant!
# For features ('x2', 'x23', 'x33') with neg_mean_absolute_error = -16.417534904874472
# Significant!
# For features ('x2', 'x23', 'x194') with neg_mean_absolute_error = -18.953309115771543
# Significant!
# For features ('x2', 'x23', 'x102') with neg_mean_absolute_error = -15.902235582962584
# Significant!
# For features ('x2', 'x23', 'x98') with neg_mean_absolute_error = -16.70594542443324
# Significant!
# For features ('x2', 'x23', 'x162') with neg_mean_absolute_error = -16.702904682461668
# Significant!
# For features ('x2', 'x23', 'x159') with neg_mean_absolute_error = -15.501397482400042
# Significant!
# For features ('x2', 'x23', 'x43') with neg_mean_absolute_error = -18.47414018071437
# Significant!
# For features ('x2', 'x23', 'x173') with neg_mean_absolute_error = -17.346601908844633
# Significant!
# For features ('x2', 'x23', 'x158') with neg_mean_absolute_error = -17.132849645805223
# Significant!
# For features ('x2', 'x23', 'x177') with neg_mean_absolute_error = -17.663481437792292
# Significant!
# For features ('x2', 'x23', 'x160') with neg_mean_absolute_error = -18.599238935279352
# Significant!
# For features ('x2', 'x149', 'x33') with neg_mean_absolute_error = -18.207265274356715
# Significant!
# For features ('x2', 'x149', 'x159') with neg_mean_absolute_error = -18.753852675455228
# Significant!
# For features ('x2', 'x6', 'x33') with neg_mean_absolute_error = -18.47455945580968
# Significant!
# For features ('x2', 'x6', 'x102') with neg_mean_absolute_error = -17.566553004964867
# Significant!
# For features ('x2', 'x6', 'x98') with neg_mean_absolute_error = -18.436659905906282
# Significant!
# For features ('x2', 'x6', 'x159') with neg_mean_absolute_error = -18.63754432026304
# Significant!
# For features ('x2', 'x5', 'x33') with neg_mean_absolute_error = -18.696921102520854
# Significant!
# For features ('x2', 'x39', 'x33') with neg_mean_absolute_error = -18.342501168303574
# Significant!
# For features ('x2', 'x39', 'x159') with neg_mean_absolute_error = -18.85139993583821
# Significant!
# For features ('x2', 'x175', 'x33') with neg_mean_absolute_error = -18.287294926670388
# Significant!
# For features ('x2', 'x175', 'x102') with neg_mean_absolute_error = -18.00061781983781
# Significant!
# For features ('x2', 'x175', 'x162') with neg_mean_absolute_error = -18.395916743848254
# Significant!
# For features ('x2', 'x175', 'x159') with neg_mean_absolute_error = -18.701725855656345
# Significant!
# For features ('x2', 'x67', 'x33') with neg_mean_absolute_error = -17.902383441025876
# Significant!
# For features ('x2', 'x67', 'x159') with neg_mean_absolute_error = -18.68905503449148
# Significant!
# For features ('x2', 'x41', 'x33') with neg_mean_absolute_error = -17.640088008462687
# Significant!
# For features ('x2', 'x41', 'x159') with neg_mean_absolute_error = -18.970163324347197
# Significant!
# For features ('x2', 'x33', 'x148') with neg_mean_absolute_error = -18.242511036531575
# Significant!
# For features ('x2', 'x33', 'x194') with neg_mean_absolute_error = -18.29533913210699
# Significant!
# For features ('x2', 'x33', 'x102') with neg_mean_absolute_error = -17.274135767967646
# Significant!
# For features ('x2', 'x33', 'x150') with neg_mean_absolute_error = -18.17932778759295
# Significant!
# For features ('x2', 'x33', 'x98') with neg_mean_absolute_error = -17.556858747316717
# Significant!
# For features ('x2', 'x33', 'x162') with neg_mean_absolute_error = -18.05912426430885
# Significant!
# For features ('x2', 'x33', 'x159') with neg_mean_absolute_error = -17.797242601526115
# Significant!
# For features ('x2', 'x33', 'x195') with neg_mean_absolute_error = -18.206011479383783
# Significant!
# For features ('x2', 'x33', 'x61') with neg_mean_absolute_error = -18.050868263124762
# Significant!
# For features ('x2', 'x33', 'x58') with neg_mean_absolute_error = -18.007794812806132
# Significant!
# For features ('x2', 'x33', 'x9') with neg_mean_absolute_error = -18.62460826661632
# Significant!
# For features ('x2', 'x33', 'x152') with neg_mean_absolute_error = -18.181344655928573
# Significant!
# For features ('x2', 'x33', 'x43') with neg_mean_absolute_error = -18.662718153805503
# Significant!
# For features ('x2', 'x33', 'x173') with neg_mean_absolute_error = -18.330270528298065
# Significant!
# For features ('x2', 'x33', 'x158') with neg_mean_absolute_error = -17.431996928132033
# Significant!
# For features ('x2', 'x33', 'x177') with neg_mean_absolute_error = -17.68827426864772
# Significant!
# For features ('x2', 'x33', 'x63') with neg_mean_absolute_error = -18.078301747623037
# Significant!
# For features ('x2', 'x33', 'x160') with neg_mean_absolute_error = -17.67667677617596
# Significant!
# For features ('x2', 'x33', 'x213') with neg_mean_absolute_error = -18.20197801551549
# Significant!
# For features ('x2', 'x33', 'x3') with neg_mean_absolute_error = -18.51114815646405
# Significant!
# For features ('x2', 'x33', 'x7') with neg_mean_absolute_error = -18.48548685718955
# Significant!
# For features ('x2', 'x33', 'x48') with neg_mean_absolute_error = -18.15466408945831
# Significant!
# For features ('x2', 'x148', 'x159') with neg_mean_absolute_error = -18.770398530692948
# Significant!
# For features ('x2', 'x194', 'x159') with neg_mean_absolute_error = -18.869793396841338
# Significant!
# For features ('x2', 'x102', 'x61') with neg_mean_absolute_error = -18.946467756881088
# Significant!
# For features ('x2', 'x102', 'x58') with neg_mean_absolute_error = -18.889281817457082
# Significant!
# For features ('x2', 'x102', 'x9') with neg_mean_absolute_error = -18.71885138255387
# Significant!
# For features ('x2', 'x102', 'x63') with neg_mean_absolute_error = -18.691871270253756
# Significant!
# For features ('x2', 'x102', 'x160') with neg_mean_absolute_error = -18.992864965600205
# Significant!
# For features ('x2', 'x150', 'x159') with neg_mean_absolute_error = -18.774659182419974
# Significant!
# For features ('x2', 'x98', 'x159') with neg_mean_absolute_error = -18.541525101964975
# Significant!
# For features ('x2', 'x162', 'x159') with neg_mean_absolute_error = -18.843947950747655
# Significant!
# For features ('x2', 'x159', 'x195') with neg_mean_absolute_error = -18.781312215745597
# Significant!
# For features ('x2', 'x159', 'x58') with neg_mean_absolute_error = -18.53821283058975
# Significant!
# For features ('x2', 'x159', 'x9') with neg_mean_absolute_error = -18.26276712767997
# Significant!
# For features ('x2', 'x159', 'x152') with neg_mean_absolute_error = -18.778217096450803
# Significant!
# For features ('x2', 'x159', 'x43') with neg_mean_absolute_error = -18.950359806944853
# Significant!
# For features ('x2', 'x159', 'x173') with neg_mean_absolute_error = -18.661243721854504
# Significant!
# For features ('x2', 'x159', 'x177') with neg_mean_absolute_error = -18.77872910746202
# Significant!
# For features ('x2', 'x159', 'x63') with neg_mean_absolute_error = -18.692463667125473
# Significant!
# For features ('x2', 'x159', 'x160') with neg_mean_absolute_error = -18.71377321846834
# Significant!
# For features ('x2', 'x159', 'x213') with neg_mean_absolute_error = -18.786301430613495
# Significant!
# For features ('x2', 'x159', 'x48') with neg_mean_absolute_error = -18.774976579419757
# Significant!
# For features ('x4', 'x27', 'x50') with neg_mean_absolute_error = -18.894084124552645
# Significant!
# For features ('x4', 'x27', 'x23') with neg_mean_absolute_error = -18.675599088825702
# Significant!
# For features ('x4', 'x27', 'x41') with neg_mean_absolute_error = -18.058487110352463
# Significant!
# For features ('x4', 'x27', 'x102') with neg_mean_absolute_error = -17.549648599006535
# Significant!
# For features ('x4', 'x27', 'x98') with neg_mean_absolute_error = -18.615382011452674
# Significant!
# For features ('x4', 'x27', 'x158') with neg_mean_absolute_error = -17.99077862869895
# Significant!
# For features ('x4', 'x27', 'x160') with neg_mean_absolute_error = -18.153734516175795
# Significant!
# For features ('x4', 'x99', 'x23') with neg_mean_absolute_error = -15.887777910949586
# Significant!
# For features ('x4', 'x50', 'x23') with neg_mean_absolute_error = -17.935005019489132
# Significant!
# For features ('x4', 'x188', 'x23') with neg_mean_absolute_error = -18.40971204478654
# Significant!
# For features ('x4', 'x45', 'x23') with neg_mean_absolute_error = -17.96858301222705
# Significant!
# For features ('x4', 'x42', 'x23') with neg_mean_absolute_error = -18.416713677113055
# Significant!
# For features ('x4', 'x193', 'x23') with neg_mean_absolute_error = -18.450400553533484
# Significant!
# For features ('x4', 'x23', 'x149') with neg_mean_absolute_error = -17.461606345103945
# Significant!
# For features ('x4', 'x23', 'x6') with neg_mean_absolute_error = -18.470104447052375
# Significant!
# For features ('x4', 'x23', 'x5') with neg_mean_absolute_error = -18.470104515380303
# Significant!
# For features ('x4', 'x23', 'x39') with neg_mean_absolute_error = -17.610843188831602
# Significant!
# For features ('x4', 'x23', 'x175') with neg_mean_absolute_error = -18.086493074727127
# Significant!
# For features ('x4', 'x23', 'x67') with neg_mean_absolute_error = -18.88158923049319
# Significant!
# For features ('x4', 'x23', 'x41') with neg_mean_absolute_error = -18.979467432010043
# Significant!
# For features ('x4', 'x23', 'x33') with neg_mean_absolute_error = -16.803129127908377
# Significant!
# For features ('x4', 'x23', 'x148') with neg_mean_absolute_error = -18.26195739671383
# Significant!
# For features ('x4', 'x23', 'x194') with neg_mean_absolute_error = -18.06944727592677
# Significant!
# For features ('x4', 'x23', 'x102') with neg_mean_absolute_error = -15.235947112780746
# Significant!
# For features ('x4', 'x23', 'x150') with neg_mean_absolute_error = -18.38468963980696
# Significant!
# For features ('x4', 'x23', 'x98') with neg_mean_absolute_error = -15.910578227469381
# Significant!
# For features ('x4', 'x23', 'x162') with neg_mean_absolute_error = -16.35000072029059
# Significant!
# For features ('x4', 'x23', 'x159') with neg_mean_absolute_error = -15.540411444386049
# Significant!
# For features ('x4', 'x23', 'x195') with neg_mean_absolute_error = -18.433700938555408
# Significant!
# For features ('x4', 'x23', 'x58') with neg_mean_absolute_error = -18.935236715055616
# Significant!
# For features ('x4', 'x23', 'x9') with neg_mean_absolute_error = -17.773190539271667
# Significant!
# For features ('x4', 'x23', 'x152') with neg_mean_absolute_error = -18.35207423845606
# Significant!
# For features ('x4', 'x23', 'x43') with neg_mean_absolute_error = -18.031206550492964
# Significant!
# For features ('x4', 'x23', 'x173') with neg_mean_absolute_error = -16.95845432323296
# Significant!
# For features ('x4', 'x23', 'x158') with neg_mean_absolute_error = -16.72447112440681
# Significant!
# For features ('x4', 'x23', 'x177') with neg_mean_absolute_error = -17.734981395986683
# Significant!
# For features ('x4', 'x23', 'x63') with neg_mean_absolute_error = -18.8374428165106
# Significant!
# For features ('x4', 'x23', 'x160') with neg_mean_absolute_error = -17.679300205048104
# Significant!
# For features ('x4', 'x23', 'x213') with neg_mean_absolute_error = -18.460601521927124
# Significant!
# For features ('x4', 'x23', 'x3') with neg_mean_absolute_error = -18.470104463425873
# Significant!
# For features ('x4', 'x23', 'x48') with neg_mean_absolute_error = -18.45368202970927
# Significant!
# For features ('x4', 'x102', 'x7') with neg_mean_absolute_error = -18.04823817989854
# Significant!
# For features ('x27', 'x99', 'x50') with neg_mean_absolute_error = -18.259873785494456
# Significant!
# For features ('x27', 'x99', 'x188') with neg_mean_absolute_error = -18.48763323885987
# Significant!
# For features ('x27', 'x99', 'x45') with neg_mean_absolute_error = -18.711049636847893
# Significant!
# For features ('x27', 'x99', 'x42') with neg_mean_absolute_error = -18.363864368356595
# Significant!
# For features ('x27', 'x99', 'x193') with neg_mean_absolute_error = -18.524517802259385
# Significant!
# For features ('x27', 'x99', 'x71') with neg_mean_absolute_error = -18.89563033441974
# Significant!
# For features ('x27', 'x99', 'x23') with neg_mean_absolute_error = -15.777168848341947
# Significant!
# For features ('x27', 'x99', 'x149') with neg_mean_absolute_error = -18.654624879305903
# Significant!
# For features ('x27', 'x99', 'x6') with neg_mean_absolute_error = -18.935436608733472
# Significant!
# For features ('x27', 'x99', 'x5') with neg_mean_absolute_error = -18.951222686413423
# Significant!
# For features ('x27', 'x99', 'x175') with neg_mean_absolute_error = -18.27047953329125
# Significant!
# For features ('x27', 'x99', 'x67') with neg_mean_absolute_error = -18.627207726435177
# Significant!
# For features ('x27', 'x99', 'x41') with neg_mean_absolute_error = -17.339083196646353
# Significant!
# For features ('x27', 'x99', 'x148') with neg_mean_absolute_error = -18.49634738331749
# Significant!
# For features ('x27', 'x99', 'x194') with neg_mean_absolute_error = -18.69101751006361
# Significant!
# For features ('x27', 'x99', 'x102') with neg_mean_absolute_error = -17.465646070395618
# Significant!
# For features ('x27', 'x99', 'x150') with neg_mean_absolute_error = -18.35379999134303
# Significant!
# For features ('x27', 'x99', 'x98') with neg_mean_absolute_error = -17.509805604591257
# Significant!
# For features ('x27', 'x99', 'x162') with neg_mean_absolute_error = -18.678156853630462
# Significant!
# For features ('x27', 'x99', 'x195') with neg_mean_absolute_error = -18.465798413778096
# Significant!
# For features ('x27', 'x99', 'x58') with neg_mean_absolute_error = -18.674522515138115
# Significant!
# For features ('x27', 'x99', 'x9') with neg_mean_absolute_error = -18.57992872967763
# Significant!
# For features ('x27', 'x99', 'x152') with neg_mean_absolute_error = -18.35661947456395
# Significant!
# For features ('x27', 'x99', 'x43') with neg_mean_absolute_error = -18.900638686384905
# Significant!
# For features ('x27', 'x99', 'x173') with neg_mean_absolute_error = -18.434726637577747
# Significant!
# For features ('x27', 'x99', 'x158') with neg_mean_absolute_error = -18.3047271488376
# Significant!
# For features ('x27', 'x99', 'x177') with neg_mean_absolute_error = -18.1299400511423
# Significant!
# For features ('x27', 'x99', 'x63') with neg_mean_absolute_error = -18.815258183458628
# Significant!
# For features ('x27', 'x99', 'x160') with neg_mean_absolute_error = -17.74601851740344
# Significant!
# For features ('x27', 'x99', 'x213') with neg_mean_absolute_error = -18.400285546418765
# Significant!
# For features ('x27', 'x99', 'x3') with neg_mean_absolute_error = -18.044267509789837
# Significant!
# For features ('x27', 'x99', 'x48') with neg_mean_absolute_error = -18.254211697680013
# Significant!
# For features ('x27', 'x50', 'x23') with neg_mean_absolute_error = -18.790752499660567
# Significant!
# For features ('x27', 'x50', 'x149') with neg_mean_absolute_error = -18.847760182149692
# Significant!
# For features ('x27', 'x50', 'x6') with neg_mean_absolute_error = -18.95695098339514
# Significant!
# For features ('x27', 'x50', 'x5') with neg_mean_absolute_error = -18.704383612230117
# Significant!
# For features ('x27', 'x50', 'x175') with neg_mean_absolute_error = -18.96713505605926
# Significant!
# For features ('x27', 'x50', 'x41') with neg_mean_absolute_error = -17.653525595385936
# Significant!
# For features ('x27', 'x50', 'x33') with neg_mean_absolute_error = -18.9883810799222
# Significant!
# For features ('x27', 'x50', 'x102') with neg_mean_absolute_error = -17.534188243552492
# Significant!
# For features ('x27', 'x50', 'x98') with neg_mean_absolute_error = -17.897277675366727
# Significant!
# For features ('x27', 'x50', 'x159') with neg_mean_absolute_error = -18.641657637985865
# Significant!
# For features ('x27', 'x50', 'x9') with neg_mean_absolute_error = -18.320824447910333
# Significant!
# For features ('x27', 'x50', 'x158') with neg_mean_absolute_error = -18.277659954821306
# Significant!
# For features ('x27', 'x50', 'x160') with neg_mean_absolute_error = -18.84356905708997
# Significant!
# For features ('x27', 'x50', 'x3') with neg_mean_absolute_error = -18.034228944846582
# Significant!
# For features ('x27', 'x50', 'x7') with neg_mean_absolute_error = -18.818174944540168
# Significant!
# For features ('x27', 'x188', 'x42') with neg_mean_absolute_error = -18.65947588752845
# Significant!
# For features ('x27', 'x188', 'x41') with neg_mean_absolute_error = -18.26242377995456
# Significant!
# For features ('x27', 'x188', 'x102') with neg_mean_absolute_error = -17.4658360586861
# Significant!
# For features ('x27', 'x188', 'x150') with neg_mean_absolute_error = -18.31473444669152
# Significant!
# For features ('x27', 'x188', 'x98') with neg_mean_absolute_error = -18.054264335345074
# Significant!
# For features ('x27', 'x188', 'x159') with neg_mean_absolute_error = -18.9367192011539
# Significant!
# For features ('x27', 'x188', 'x152') with neg_mean_absolute_error = -17.9593362179013
# Significant!
# For features ('x27', 'x188', 'x158') with neg_mean_absolute_error = -18.147751642342094
# Significant!
# For features ('x27', 'x188', 'x160') with neg_mean_absolute_error = -18.70303903113434
# Significant!
# For features ('x27', 'x188', 'x3') with neg_mean_absolute_error = -18.941311331436165
# Significant!
# For features ('x27', 'x45', 'x23') with neg_mean_absolute_error = -17.706594928381133
# Significant!
# For features ('x27', 'x45', 'x149') with neg_mean_absolute_error = -18.997901080866004
# Significant!
# For features ('x27', 'x45', 'x41') with neg_mean_absolute_error = -17.25945180566388
# Significant!
# For features ('x27', 'x45', 'x102') with neg_mean_absolute_error = -17.528152032715138
# Significant!
# For features ('x27', 'x45', 'x98') with neg_mean_absolute_error = -18.031990009764595
# Significant!
# For features ('x27', 'x45', 'x158') with neg_mean_absolute_error = -17.870202671623712
# Significant!
# For features ('x27', 'x45', 'x160') with neg_mean_absolute_error = -18.400523854258672
# Significant!
# For features ('x27', 'x42', 'x41') with neg_mean_absolute_error = -18.240569030112646
# Significant!
# For features ('x27', 'x42', 'x33') with neg_mean_absolute_error = -18.96341057446226
# Significant!
# For features ('x27', 'x42', 'x102') with neg_mean_absolute_error = -17.415325707269776
# Significant!
# For features ('x27', 'x42', 'x150') with neg_mean_absolute_error = -18.430424147626915
# Significant!
# For features ('x27', 'x42', 'x98') with neg_mean_absolute_error = -17.978603052451227
# Significant!
# For features ('x27', 'x42', 'x159') with neg_mean_absolute_error = -18.795730822795388
# Significant!
# For features ('x27', 'x42', 'x9') with neg_mean_absolute_error = -18.9509739297532
# Significant!
# For features ('x27', 'x42', 'x152') with neg_mean_absolute_error = -18.039169894837933
# Significant!
# For features ('x27', 'x42', 'x158') with neg_mean_absolute_error = -18.109917993386567
# Significant!
# For features ('x27', 'x42', 'x160') with neg_mean_absolute_error = -18.67162845794912
# Significant!
# For features ('x27', 'x42', 'x3') with neg_mean_absolute_error = -18.7310114715189
# Significant!
# For features ('x27', 'x193', 'x41') with neg_mean_absolute_error = -18.2937589220725
# Significant!
# For features ('x27', 'x193', 'x148') with neg_mean_absolute_error = -18.702389578649747
# Significant!
# For features ('x27', 'x193', 'x102') with neg_mean_absolute_error = -17.47285264268597
# Significant!
# For features ('x27', 'x193', 'x150') with neg_mean_absolute_error = -18.772494717484314
# Significant!
# For features ('x27', 'x193', 'x98') with neg_mean_absolute_error = -18.065296529870114
# Significant!
# For features ('x27', 'x193', 'x159') with neg_mean_absolute_error = -18.965273044669708
# Significant!
# For features ('x27', 'x193', 'x152') with neg_mean_absolute_error = -18.432222919965774
# Significant!
# For features ('x27', 'x193', 'x158') with neg_mean_absolute_error = -18.14998088382101
# Significant!
# For features ('x27', 'x193', 'x160') with neg_mean_absolute_error = -18.727729528421122
# Significant!
# For features ('x27', 'x193', 'x213') with neg_mean_absolute_error = -18.937215778491332
# Significant!
# For features ('x27', 'x193', 'x3') with neg_mean_absolute_error = -18.9729758526776
# Significant!
# For features ('x27', 'x71', 'x33') with neg_mean_absolute_error = -18.588098073134393
# Significant!
# For features ('x27', 'x71', 'x102') with neg_mean_absolute_error = -17.22345531706828
# Significant!
# For features ('x27', 'x71', 'x98') with neg_mean_absolute_error = -18.308768678772836
# Significant!
# For features ('x27', 'x71', 'x158') with neg_mean_absolute_error = -18.417845736484416
# Significant!
# For features ('x27', 'x23', 'x149') with neg_mean_absolute_error = -17.800829577568965
# Significant!
# For features ('x27', 'x23', 'x5') with neg_mean_absolute_error = -18.296021650915577
# Significant!
# For features ('x27', 'x23', 'x39') with neg_mean_absolute_error = -18.135680811942454
# Significant!
# For features ('x27', 'x23', 'x33') with neg_mean_absolute_error = -16.723591705154348
# Significant!
# For features ('x27', 'x23', 'x148') with neg_mean_absolute_error = -18.954734785540623
# Significant!
# For features ('x27', 'x23', 'x194') with neg_mean_absolute_error = -18.697356944349682
# Significant!
# For features ('x27', 'x23', 'x102') with neg_mean_absolute_error = -15.489421783433496
# Significant!
# For features ('x27', 'x23', 'x98') with neg_mean_absolute_error = -15.920150545768848
# Significant!
# For features ('x27', 'x23', 'x162') with neg_mean_absolute_error = -16.767967865813542
# Significant!
# For features ('x27', 'x23', 'x159') with neg_mean_absolute_error = -15.61533747961279
# Significant!
# For features ('x27', 'x23', 'x173') with neg_mean_absolute_error = -18.2831932533151
# Significant!
# For features ('x27', 'x23', 'x158') with neg_mean_absolute_error = -17.624768277560193
# Significant!
# For features ('x27', 'x23', 'x177') with neg_mean_absolute_error = -18.083622684845704
# Significant!
# For features ('x27', 'x23', 'x7') with neg_mean_absolute_error = -18.230472066761266
# Significant!
# For features ('x27', 'x149', 'x41') with neg_mean_absolute_error = -17.094049146999136
# Significant!
# For features ('x27', 'x149', 'x194') with neg_mean_absolute_error = -18.960120156921302
# Significant!
# For features ('x27', 'x149', 'x102') with neg_mean_absolute_error = -17.6127057615393
# Significant!
# For features ('x27', 'x149', 'x98') with neg_mean_absolute_error = -18.07440514505915
# Significant!
# For features ('x27', 'x149', 'x159') with neg_mean_absolute_error = -18.87766577699427
# Significant!
# For features ('x27', 'x149', 'x9') with neg_mean_absolute_error = -18.859852913593535
# Significant!
# For features ('x27', 'x149', 'x158') with neg_mean_absolute_error = -17.846675878684362
# Significant!
# For features ('x27', 'x149', 'x160') with neg_mean_absolute_error = -18.260977518729465
# Significant!
# For features ('x27', 'x149', 'x3') with neg_mean_absolute_error = -18.85663800927489
# Significant!
# For features ('x27', 'x6', 'x39') with neg_mean_absolute_error = -18.237949772164924
# Significant!
# For features ('x27', 'x6', 'x41') with neg_mean_absolute_error = -18.784341420299167
# Significant!
# ...
# Significant!
# For features ('x23', 'x148', 'x162') with neg_mean_absolute_error = -16.95067754406164
# Significant!
# For features ('x23', 'x148', 'x159') with neg_mean_absolute_error = -15.494810315689929
# Significant!
# For features ('x23', 'x148', 'x195') with neg_mean_absolute_error = -18.41365557582511
# Significant!
# For features ('x23', 'x148', 'x173') with neg_mean_absolute_error = -17.84087598846167
# Significant!
# For features ('x23', 'x148', 'x158') with neg_mean_absolute_error = -17.800231153864303
# Significant!
# For features ('x23', 'x148', 'x177') with neg_mean_absolute_error = -17.912771830586653
# Significant!
# For features ('x23', 'x148', 'x213') with neg_mean_absolute_error = -18.342707332590308
# Significant!
# For features ('x23', 'x148', 'x48') with neg_mean_absolute_error = -17.674324333226064
# Significant!
# For features ('x23', 'x194', 'x102') with neg_mean_absolute_error = -16.533242167194665
# Significant!
# For features ('x23', 'x194', 'x150') with neg_mean_absolute_error = -18.909835644183758
# Significant!
# For features ('x23', 'x194', 'x98') with neg_mean_absolute_error = -17.010642924801346
# Significant!
# For features ('x23', 'x194', 'x162') with neg_mean_absolute_error = -16.962477256069466
# Significant!
# For features ('x23', 'x194', 'x159') with neg_mean_absolute_error = -15.53539332923321
# Significant!
# For features ('x23', 'x194', 'x195') with neg_mean_absolute_error = -18.884949312745018
# Significant!
# For features ('x23', 'x194', 'x152') with neg_mean_absolute_error = -18.95185988009259
# Significant!
# For features ('x23', 'x194', 'x173') with neg_mean_absolute_error = -17.705186835353622
# Significant!
# For features ('x23', 'x194', 'x158') with neg_mean_absolute_error = -17.7365685967668
# Significant!
# For features ('x23', 'x194', 'x177') with neg_mean_absolute_error = -17.78540548248751
# Significant!
# For features ('x23', 'x194', 'x213') with neg_mean_absolute_error = -18.79588387463945
# Significant!
# For features ('x23', 'x194', 'x7') with neg_mean_absolute_error = -18.94055532946205
# Significant!
# For features ('x23', 'x194', 'x48') with neg_mean_absolute_error = -18.36688554536185
# Significant!
# For features ('x23', 'x102', 'x150') with neg_mean_absolute_error = -16.227933713521907
# Significant!
# For features ('x23', 'x102', 'x98') with neg_mean_absolute_error = -17.988726553828922
# Significant!
# For features ('x23', 'x102', 'x162') with neg_mean_absolute_error = -16.456305844092235
# Significant!
# For features ('x23', 'x102', 'x159') with neg_mean_absolute_error = -15.76744908490438
# Significant!
# For features ('x23', 'x102', 'x195') with neg_mean_absolute_error = -16.285173512412182
# Significant!
# For features ('x23', 'x102', 'x61') with neg_mean_absolute_error = -15.963032483213212
# Significant!
# For features ('x23', 'x102', 'x58') with neg_mean_absolute_error = -15.88074267001511
# Significant!
# For features ('x23', 'x102', 'x9') with neg_mean_absolute_error = -15.594241471234819
# Significant!
# For features ('x23', 'x102', 'x152') with neg_mean_absolute_error = -16.236873992206522
# Significant!
# For features ('x23', 'x102', 'x43') with neg_mean_absolute_error = -16.34341992238395
# Significant!
# For features ('x23', 'x102', 'x173') with neg_mean_absolute_error = -15.965156473989902
# Significant!
# For features ('x23', 'x102', 'x158') with neg_mean_absolute_error = -16.301179198745395
# Significant!
# For features ('x23', 'x102', 'x177') with neg_mean_absolute_error = -16.800783540975324
# Significant!
# For features ('x23', 'x102', 'x63') with neg_mean_absolute_error = -15.474182710783186
# Significant!
# For features ('x23', 'x102', 'x160') with neg_mean_absolute_error = -15.586389000235744
# Significant!
# For features ('x23', 'x102', 'x213') with neg_mean_absolute_error = -16.23954756254465
# Significant!
# For features ('x23', 'x102', 'x3') with neg_mean_absolute_error = -15.969493922161798
# Significant!
# For features ('x23', 'x102', 'x7') with neg_mean_absolute_error = -16.477186087400742
# Significant!
# For features ('x23', 'x102', 'x48') with neg_mean_absolute_error = -16.198255156125953
# Significant!
# For features ('x23', 'x150', 'x98') with neg_mean_absolute_error = -16.752903599269807
# Significant!
# For features ('x23', 'x150', 'x162') with neg_mean_absolute_error = -16.891033410558997
# Significant!
# For features ('x23', 'x150', 'x159') with neg_mean_absolute_error = -15.473247115707593
# Significant!
# For features ('x23', 'x150', 'x152') with neg_mean_absolute_error = -17.566273405645898
# Significant!
# For features ('x23', 'x150', 'x173') with neg_mean_absolute_error = -17.844015415167533
# Significant!
# For features ('x23', 'x150', 'x158') with neg_mean_absolute_error = -17.644465166816527
# Significant!
# For features ('x23', 'x150', 'x177') with neg_mean_absolute_error = -17.849784012055174
# Significant!
# For features ('x23', 'x150', 'x48') with neg_mean_absolute_error = -18.738424454733416
# Significant!
# For features ('x23', 'x98', 'x162') with neg_mean_absolute_error = -17.0843033030148
# Significant!
# For features ('x23', 'x98', 'x159') with neg_mean_absolute_error = -15.621503791572135
# Significant!
# For features ('x23', 'x98', 'x195') with neg_mean_absolute_error = -16.827670011856032
# Significant!
# For features ('x23', 'x98', 'x61') with neg_mean_absolute_error = -16.785741905800965
# Significant!
# For features ('x23', 'x98', 'x58') with neg_mean_absolute_error = -16.41478822660593
# Significant!
# For features ('x23', 'x98', 'x9') with neg_mean_absolute_error = -16.124545285615245
# Significant!
# For features ('x23', 'x98', 'x152') with neg_mean_absolute_error = -16.761067059247402
# Significant!
# For features ('x23', 'x98', 'x43') with neg_mean_absolute_error = -17.062797337839992
# Significant!
# For features ('x23', 'x98', 'x173') with neg_mean_absolute_error = -17.07128801258566
# Significant!
# For features ('x23', 'x98', 'x158') with neg_mean_absolute_error = -17.5517176319298
# Significant!
# For features ('x23', 'x98', 'x177') with neg_mean_absolute_error = -17.064231530250535
# Significant!
# For features ('x23', 'x98', 'x63') with neg_mean_absolute_error = -16.182729472501347
# Significant!
# For features ('x23', 'x98', 'x160') with neg_mean_absolute_error = -17.058291495788563
# Significant!
# For features ('x23', 'x98', 'x213') with neg_mean_absolute_error = -16.76576903659348
# Significant!
# For features ('x23', 'x98', 'x3') with neg_mean_absolute_error = -17.072127915510702
# Significant!
# For features ('x23', 'x98', 'x7') with neg_mean_absolute_error = -17.040736411735132
# Significant!
# For features ('x23', 'x98', 'x48') with neg_mean_absolute_error = -16.714006503684825
# Significant!
# For features ('x23', 'x162', 'x159') with neg_mean_absolute_error = -16.002179408877463
# Significant!
# For features ('x23', 'x162', 'x195') with neg_mean_absolute_error = -16.917126960026206
# Significant!
# For features ('x23', 'x162', 'x61') with neg_mean_absolute_error = -17.373853397566904
# Significant!
# For features ('x23', 'x162', 'x58') with neg_mean_absolute_error = -16.764389840227103
# Significant!
# For features ('x23', 'x162', 'x9') with neg_mean_absolute_error = -16.769820120257503
# Significant!
# For features ('x23', 'x162', 'x152') with neg_mean_absolute_error = -16.898429570382234
# Significant!
# For features ('x23', 'x162', 'x43') with neg_mean_absolute_error = -17.00516290616312
# Significant!
# For features ('x23', 'x162', 'x173') with neg_mean_absolute_error = -16.603337055035382
# Significant!
# For features ('x23', 'x162', 'x158') with neg_mean_absolute_error = -18.03428695097952
# Significant!
# For features ('x23', 'x162', 'x177') with neg_mean_absolute_error = -17.046296603430775
# Significant!
# For features ('x23', 'x162', 'x63') with neg_mean_absolute_error = -16.71755652173937
# Significant!
# For features ('x23', 'x162', 'x160') with neg_mean_absolute_error = -17.106014441404007
# Significant!
# For features ('x23', 'x162', 'x213') with neg_mean_absolute_error = -16.895429459675526
# Significant!
# For features ('x23', 'x162', 'x3') with neg_mean_absolute_error = -16.92604675031236
# Significant!
# For features ('x23', 'x162', 'x7') with neg_mean_absolute_error = -17.102742173456345
# Significant!
# For features ('x23', 'x162', 'x48') with neg_mean_absolute_error = -16.874976597727763
# Significant!
# For features ('x23', 'x159', 'x195') with neg_mean_absolute_error = -15.48003561154924
# Significant!
# For features ('x23', 'x159', 'x61') with neg_mean_absolute_error = -16.601731795929087
# Significant!
# For features ('x23', 'x159', 'x58') with neg_mean_absolute_error = -15.718710004832365
# Significant!
# For features ('x23', 'x159', 'x9') with neg_mean_absolute_error = -15.171017216306728
# Significant!
# For features ('x23', 'x159', 'x152') with neg_mean_absolute_error = -15.474177827875025
# Significant!
# For features ('x23', 'x159', 'x43') with neg_mean_absolute_error = -15.570720212195715
# Significant!
# For features ('x23', 'x159', 'x173') with neg_mean_absolute_error = -15.701091656913736
# Significant!
# For features ('x23', 'x159', 'x158') with neg_mean_absolute_error = -15.719383134884504
# Significant!
# For features ('x23', 'x159', 'x177') with neg_mean_absolute_error = -15.940906604084443
# Significant!
# For features ('x23', 'x159', 'x63') with neg_mean_absolute_error = -15.811446764967059
# Significant!
# For features ('x23', 'x159', 'x160') with neg_mean_absolute_error = -15.69747537590494
# Significant!
# For features ('x23', 'x159', 'x213') with neg_mean_absolute_error = -15.488577822388933
# Significant!
# For features ('x23', 'x159', 'x3') with neg_mean_absolute_error = -15.687515015129671
# Significant!
# For features ('x23', 'x159', 'x7') with neg_mean_absolute_error = -15.825818618716195
# Significant!
# For features ('x23', 'x159', 'x48') with neg_mean_absolute_error = -15.490130057752001
# Significant!
# For features ('x23', 'x195', 'x173') with neg_mean_absolute_error = -17.85846620493694
# Significant!
# For features ('x23', 'x195', 'x158') with neg_mean_absolute_error = -17.68266883206389
# Significant!
# For features ('x23', 'x195', 'x177') with neg_mean_absolute_error = -17.894084035346996
# Significant!
# For features ('x23', 'x61', 'x173') with neg_mean_absolute_error = -18.36134059196122
# Significant!
# For features ('x23', 'x61', 'x158') with neg_mean_absolute_error = -18.074518712900456
# Significant!
# For features ('x23', 'x61', 'x177') with neg_mean_absolute_error = -18.66693473137422
# Significant!
# For features ('x23', 'x58', 'x43') with neg_mean_absolute_error = -18.97325719429088
# Significant!
# For features ('x23', 'x58', 'x173') with neg_mean_absolute_error = -17.736264324149126
# Significant!
# For features ('x23', 'x58', 'x158') with neg_mean_absolute_error = -17.41199538700947
# Significant!
# For features ('x23', 'x58', 'x177') with neg_mean_absolute_error = -17.80064815402987
# Significant!
# For features ('x23', 'x9', 'x173') with neg_mean_absolute_error = -17.90753140228589
# Significant!
# For features ('x23', 'x9', 'x158') with neg_mean_absolute_error = -17.271612058477757
# Significant!
# For features ('x23', 'x9', 'x177') with neg_mean_absolute_error = -17.924860635666892
# Significant!
# For features ('x23', 'x9', 'x160') with neg_mean_absolute_error = -18.808574799994947
# Significant!
# For features ('x23', 'x9', 'x3') with neg_mean_absolute_error = -18.75738980484748
# Significant!
# For features ('x23', 'x9', 'x7') with neg_mean_absolute_error = -17.751085089873605
# Significant!
# For features ('x23', 'x152', 'x173') with neg_mean_absolute_error = -17.844180641391894
# Significant!
# For features ('x23', 'x152', 'x158') with neg_mean_absolute_error = -17.65687631462884
# Significant!
# For features ('x23', 'x152', 'x177') with neg_mean_absolute_error = -17.835658055813735
# Significant!
# For features ('x23', 'x152', 'x48') with neg_mean_absolute_error = -18.59061259755783
# Significant!
# For features ('x23', 'x43', 'x173') with neg_mean_absolute_error = -18.03790941335382
# Significant!
# For features ('x23', 'x43', 'x158') with neg_mean_absolute_error = -17.777140178528285
# Significant!
# For features ('x23', 'x43', 'x177') with neg_mean_absolute_error = -18.099748138957526
# Significant!
# For features ('x23', 'x43', 'x7') with neg_mean_absolute_error = -18.642201729701394
# Significant!
# For features ('x23', 'x173', 'x158') with neg_mean_absolute_error = -17.652609984421183
# Significant!
# For features ('x23', 'x173', 'x177') with neg_mean_absolute_error = -18.1310466560871
# Significant!
# For features ('x23', 'x173', 'x63') with neg_mean_absolute_error = -17.665780756672984
# Significant!
# For features ('x23', 'x173', 'x160') with neg_mean_absolute_error = -17.679928158554528
# Significant!
# For features ('x23', 'x173', 'x213') with neg_mean_absolute_error = -17.857391183043937
# Significant!
# For features ('x23', 'x173', 'x3') with neg_mean_absolute_error = -17.966910773219976
# Significant!
# For features ('x23', 'x173', 'x7') with neg_mean_absolute_error = -17.664119853771417
# Significant!
# For features ('x23', 'x173', 'x48') with neg_mean_absolute_error = -17.868533997787615
# Significant!
# For features ('x23', 'x158', 'x177') with neg_mean_absolute_error = -18.43293097921037
# Significant!
# For features ('x23', 'x158', 'x63') with neg_mean_absolute_error = -17.304637778028543
# Significant!
# For features ('x23', 'x158', 'x160') with neg_mean_absolute_error = -15.633154998252385
# Significant!
# For features ('x23', 'x158', 'x213') with neg_mean_absolute_error = -17.651388331508436
# Significant!
# For features ('x23', 'x158', 'x3') with neg_mean_absolute_error = -17.829982174631677
# Significant!
# For features ('x23', 'x158', 'x7') with neg_mean_absolute_error = -17.813540411944068
# Significant!
# For features ('x23', 'x158', 'x48') with neg_mean_absolute_error = -17.60551630382635
# Significant!
# For features ('x23', 'x177', 'x63') with neg_mean_absolute_error = -17.855045388923912
# Significant!
# For features ('x23', 'x177', 'x160') with neg_mean_absolute_error = -17.763508870125328
# Significant!
# For features ('x23', 'x177', 'x213') with neg_mean_absolute_error = -17.900554266156245
# Significant!
# For features ('x23', 'x177', 'x3') with neg_mean_absolute_error = -17.69431330507313
# Significant!
# For features ('x23', 'x177', 'x7') with neg_mean_absolute_error = -17.851566528395978
# Significant!
# For features ('x23', 'x177', 'x48') with neg_mean_absolute_error = -17.892866611199274
# Significant!
# For features ('x23', 'x213', 'x48') with neg_mean_absolute_error = -18.95711383908751
# Significant!
# For features ('x23', 'x3', 'x7') with neg_mean_absolute_error = -18.509025125904618
# Significant!
# For features ('x5', 'x41', 'x33') with neg_mean_absolute_error = -18.370459433147122
# Significant!
# For features ('x39', 'x41', 'x7') with neg_mean_absolute_error = -18.59776584658626
# Significant!
# For features ('x39', 'x33', 'x150') with neg_mean_absolute_error = -18.95269596644745
# Significant!
# For features ('x39', 'x33', 'x152') with neg_mean_absolute_error = -18.952217656170554
# Significant!
# For features ('x39', 'x33', 'x213') with neg_mean_absolute_error = -18.973462319444252
# Significant!
# For features ('x39', 'x33', 'x48') with neg_mean_absolute_error = -18.78851169934797
# Significant!
# For features ('x39', 'x102', 'x7') with neg_mean_absolute_error = -18.901149736609415
# Significant!
# For features ('x41', 'x33', 'x9') with neg_mean_absolute_error = -18.953478196526792
# Significant!
# For features ('x41', 'x33', 'x3') with neg_mean_absolute_error = -17.924445251120385
# Significant!
# For features ('x41', 'x33', 'x7') with neg_mean_absolute_error = -17.67374641587612
# Significant!
# For features ('x33', 'x148', 'x48') with neg_mean_absolute_error = -16.935705328248165
# Significant!
# For features ('x33', 'x150', 'x48') with neg_mean_absolute_error = -18.77949047423618
# Significant!
# For features ('x33', 'x195', 'x48') with neg_mean_absolute_error = -16.749139219106773
# Significant!
# For features ('x33', 'x152', 'x48') with neg_mean_absolute_error = -18.825585949484385
# Significant!
# For features ('x33', 'x158', 'x7') with neg_mean_absolute_error = -18.80238906411683
# Significant!
# For features ('x33', 'x160', 'x7') with neg_mean_absolute_error = -18.969437261993153
# Significant!
# For features ('x33', 'x213', 'x48') with neg_mean_absolute_error = -17.922355141658763

# %%
len(List2_2cvd_3_nmae)
# Out:
# 1085

# %%
List3_2cvd_3_nmae,List3_2cvd_2_nmae,List3_2cvd_0_nmae = combnfeats_MLR_evaby_crossval_metric(List2_2cvd_3_nmae,df_x,df_y,5,model,'neg_mean_absolute_error',-17)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x32', 'x23') with neg_mean_absolute_error = -16.429187344974576
# Significant!
# For features ('x186', 'x27', 'x102') with neg_mean_absolute_error = -16.636961315502397
# Significant!
# For features ('x186', 'x99', 'x23') with neg_mean_absolute_error = -15.861610728292339
# Significant!
# For features ('x186', 'x23', 'x33') with neg_mean_absolute_error = -16.194786669548293
# Significant!
# For features ('x186', 'x23', 'x102') with neg_mean_absolute_error = -14.275031233242993
# Significant!
# For features ('x186', 'x23', 'x98') with neg_mean_absolute_error = -15.097794482659799
# Significant!
# For features ('x186', 'x23', 'x162') with neg_mean_absolute_error = -15.768968531106363
# Significant!
# For features ('x186', 'x23', 'x159') with neg_mean_absolute_error = -15.596059579376282
# Significant!
# For features ('x186', 'x23', 'x173') with neg_mean_absolute_error = -16.933568928374218
# Significant!
# For features ('x186', 'x23', 'x158') with neg_mean_absolute_error = -16.157698580597575
# Significant!
# For features ('x49', 'x32', 'x23') with neg_mean_absolute_error = -16.83797102018011
# Significant!
# For features ('x49', 'x99', 'x23') with neg_mean_absolute_error = -16.34917261208103
# Significant!
# For features ('x49', 'x23', 'x33') with neg_mean_absolute_error = -16.190970330046685
# Significant!
# For features ('x49', 'x23', 'x102') with neg_mean_absolute_error = -16.156944729532746
# Significant!
# For features ('x49', 'x23', 'x98') with neg_mean_absolute_error = -16.743984125213995
# Significant!
# For features ('x49', 'x23', 'x162') with neg_mean_absolute_error = -16.876201080112256
# Significant!
# For features ('x49', 'x23', 'x159') with neg_mean_absolute_error = -15.491943647347302
# Significant!
# For features ('x32', 'x99', 'x23') with neg_mean_absolute_error = -14.190133608840819
# Significant!
# For features ('x32', 'x50', 'x23') with neg_mean_absolute_error = -15.729901432749301
# Significant!
# For features ('x32', 'x45', 'x23') with neg_mean_absolute_error = -16.40268403818997
# Significant!
# For features ('x32', 'x23', 'x149') with neg_mean_absolute_error = -16.531117748190074
# Significant!
# For features ('x32', 'x23', 'x175') with neg_mean_absolute_error = -16.75177217238049
# Significant!
# For features ('x32', 'x23', 'x33') with neg_mean_absolute_error = -16.083486805295507
# Significant!
# For features ('x32', 'x23', 'x194') with neg_mean_absolute_error = -16.973378785999387
# Significant!
# For features ('x32', 'x23', 'x102') with neg_mean_absolute_error = -13.62055399836952
# Significant!
# For features ('x32', 'x23', 'x98') with neg_mean_absolute_error = -14.609007824911018
# Significant!
# For features ('x32', 'x23', 'x162') with neg_mean_absolute_error = -15.787237701579745
# Significant!
# For features ('x32', 'x23', 'x159') with neg_mean_absolute_error = -14.285732776834356
# Significant!
# For features ('x32', 'x23', 'x173') with neg_mean_absolute_error = -15.567928487528556
# Significant!
# For features ('x32', 'x23', 'x158') with neg_mean_absolute_error = -14.197111475469635
# Significant!
# For features ('x32', 'x23', 'x177') with neg_mean_absolute_error = -16.959015125821264
# Significant!
# For features ('x32', 'x23', 'x160') with neg_mean_absolute_error = -15.066800409421253
# Significant!
# For features ('x8', 'x27', 'x41') with neg_mean_absolute_error = -16.72686767538757
# Significant!
# For features ('x8', 'x99', 'x23') with neg_mean_absolute_error = -16.03948499274228
# Significant!
# For features ('x8', 'x23', 'x102') with neg_mean_absolute_error = -15.629849252154518
# Significant!
# For features ('x8', 'x23', 'x98') with neg_mean_absolute_error = -16.125141121355295
# Significant!
# For features ('x8', 'x23', 'x162') with neg_mean_absolute_error = -16.47316320077438
# Significant!
# For features ('x8', 'x23', 'x159') with neg_mean_absolute_error = -15.758160218642796
# Significant!
# For features ('x8', 'x23', 'x158') with neg_mean_absolute_error = -16.987522312514262
# Significant!
# For features ('x8', 'x23', 'x177') with neg_mean_absolute_error = -16.9997921345193
# Significant!
# For features ('x2', 'x27', 'x102') with neg_mean_absolute_error = -16.51437868354696
# Significant!
# For features ('x2', 'x99', 'x23') with neg_mean_absolute_error = -15.980712109902734
# Significant!
# For features ('x2', 'x23', 'x33') with neg_mean_absolute_error = -16.417534904874472
# Significant!
# For features ('x2', 'x23', 'x102') with neg_mean_absolute_error = -15.902235582962584
# Significant!
# For features ('x2', 'x23', 'x98') with neg_mean_absolute_error = -16.70594542443324
# Significant!
# For features ('x2', 'x23', 'x162') with neg_mean_absolute_error = -16.702904682461668
# Significant!
# For features ('x2', 'x23', 'x159') with neg_mean_absolute_error = -15.501397482400042
# Significant!
# For features ('x4', 'x99', 'x23') with neg_mean_absolute_error = -15.887777910949586
# Significant!
# For features ('x4', 'x23', 'x33') with neg_mean_absolute_error = -16.803129127908377
# Significant!
# For features ('x4', 'x23', 'x102') with neg_mean_absolute_error = -15.235947112780746
# Significant!
# For features ('x4', 'x23', 'x98') with neg_mean_absolute_error = -15.910578227469381
# Significant!
# For features ('x4', 'x23', 'x162') with neg_mean_absolute_error = -16.35000072029059
# Significant!
# For features ('x4', 'x23', 'x159') with neg_mean_absolute_error = -15.540411444386049
# Significant!
# For features ('x4', 'x23', 'x173') with neg_mean_absolute_error = -16.95845432323296
# Significant!
# For features ('x4', 'x23', 'x158') with neg_mean_absolute_error = -16.72447112440681
# Significant!
# For features ('x27', 'x99', 'x23') with neg_mean_absolute_error = -15.777168848341947
# Significant!
# For features ('x27', 'x23', 'x33') with neg_mean_absolute_error = -16.723591705154348
# Significant!
# For features ('x27', 'x23', 'x102') with neg_mean_absolute_error = -15.489421783433496
# Significant!
# For features ('x27', 'x23', 'x98') with neg_mean_absolute_error = -15.920150545768848
# Significant!
# For features ('x27', 'x23', 'x162') with neg_mean_absolute_error = -16.767967865813542
# Significant!
# For features ('x27', 'x23', 'x159') with neg_mean_absolute_error = -15.61533747961279
# Significant!
# For features ('x27', 'x175', 'x102') with neg_mean_absolute_error = -15.926065325239454
# Significant!
# For features ('x27', 'x67', 'x102') with neg_mean_absolute_error = -16.845758666084173
# Significant!
# For features ('x27', 'x41', 'x102') with neg_mean_absolute_error = -15.600713107881683
# Significant!
# For features ('x27', 'x41', 'x98') with neg_mean_absolute_error = -16.4799766815409
# Significant!
# For features ('x27', 'x102', 'x162') with neg_mean_absolute_error = -16.480061201579495
# Significant!
# For features ('x27', 'x102', 'x173') with neg_mean_absolute_error = -16.34832272769325
# Significant!
# For features ('x27', 'x102', 'x177') with neg_mean_absolute_error = -16.38253129977428
# Significant!
# For features ('x27', 'x102', 'x3') with neg_mean_absolute_error = -16.768209323324875
# Significant!
# For features ('x27', 'x98', 'x177') with neg_mean_absolute_error = -16.598583970225214
# Significant!
# For features ('x99', 'x50', 'x23') with neg_mean_absolute_error = -16.19008700554513
# Significant!
# For features ('x99', 'x188', 'x23') with neg_mean_absolute_error = -16.324491148379018
# Significant!
# For features ('x99', 'x45', 'x23') with neg_mean_absolute_error = -16.197579819463844
# Significant!
# For features ('x99', 'x42', 'x23') with neg_mean_absolute_error = -16.327835495918617
# Significant!
# For features ('x99', 'x193', 'x23') with neg_mean_absolute_error = -16.35634758927431
# Significant!
# For features ('x99', 'x71', 'x23') with neg_mean_absolute_error = -16.196328187652554
# Significant!
# For features ('x99', 'x23', 'x149') with neg_mean_absolute_error = -16.320475682472356
# Significant!
# For features ('x99', 'x23', 'x6') with neg_mean_absolute_error = -15.500098013447609
# Significant!
# For features ('x99', 'x23', 'x5') with neg_mean_absolute_error = -16.502263100375384
# Significant!
# For features ('x99', 'x23', 'x39') with neg_mean_absolute_error = -15.854628791500238
# Significant!
# For features ('x99', 'x23', 'x175') with neg_mean_absolute_error = -16.340289069763628
# Significant!
# For features ('x99', 'x23', 'x67') with neg_mean_absolute_error = -16.226129476335696
# Significant!
# For features ('x99', 'x23', 'x41') with neg_mean_absolute_error = -16.490337743607576
# Significant!
# For features ('x99', 'x23', 'x33') with neg_mean_absolute_error = -14.68777438661096
# Significant!
# For features ('x99', 'x23', 'x148') with neg_mean_absolute_error = -16.363361338565937
# Significant!
# For features ('x99', 'x23', 'x194') with neg_mean_absolute_error = -16.414040731759833
# Significant!
# For features ('x99', 'x23', 'x102') with neg_mean_absolute_error = -16.5318888276439
# Significant!
# For features ('x99', 'x23', 'x150') with neg_mean_absolute_error = -16.33148976786148
# Significant!
# For features ('x99', 'x23', 'x98') with neg_mean_absolute_error = -16.26701346320662
# Significant!
# For features ('x99', 'x23', 'x162') with neg_mean_absolute_error = -16.285229448088167
# Significant!
# For features ('x99', 'x23', 'x159') with neg_mean_absolute_error = -15.671451611011193
# Significant!
# For features ('x99', 'x23', 'x195') with neg_mean_absolute_error = -16.342272908708235
# Significant!
# For features ('x99', 'x23', 'x61') with neg_mean_absolute_error = -16.523854096016144
# Significant!
# For features ('x99', 'x23', 'x58') with neg_mean_absolute_error = -15.78270202249403
# Significant!
# For features ('x99', 'x23', 'x9') with neg_mean_absolute_error = -15.598045213412087
# Significant!
# For features ('x99', 'x23', 'x152') with neg_mean_absolute_error = -16.334064377882875
# Significant!
# For features ('x99', 'x23', 'x43') with neg_mean_absolute_error = -16.224183554497344
# Significant!
# For features ('x99', 'x23', 'x173') with neg_mean_absolute_error = -16.27109162467331
# Significant!
# For features ('x99', 'x23', 'x158') with neg_mean_absolute_error = -16.34177098638544
# Significant!
# For features ('x99', 'x23', 'x177') with neg_mean_absolute_error = -16.39695720697949
# Significant!
# For features ('x99', 'x23', 'x63') with neg_mean_absolute_error = -15.712880124414596
# Significant!
# For features ('x99', 'x23', 'x160') with neg_mean_absolute_error = -16.44051495017785
# Significant!
# For features ('x99', 'x23', 'x213') with neg_mean_absolute_error = -16.3466634111715
# Significant!
# For features ('x99', 'x23', 'x3') with neg_mean_absolute_error = -16.40461041222851
# Significant!
# For features ('x99', 'x23', 'x7') with neg_mean_absolute_error = -16.52682458665568
# Significant!
# For features ('x99', 'x23', 'x48') with neg_mean_absolute_error = -16.36076636078374
# Significant!
# For features ('x50', 'x23', 'x33') with neg_mean_absolute_error = -16.077695128200908
# Significant!
# For features ('x50', 'x23', 'x102') with neg_mean_absolute_error = -16.130541715925382
# Significant!
# For features ('x50', 'x23', 'x98') with neg_mean_absolute_error = -16.97042834553657
# Significant!
# For features ('x50', 'x23', 'x162') with neg_mean_absolute_error = -16.954706303540913
# Significant!
# For features ('x50', 'x23', 'x159') with neg_mean_absolute_error = -15.512249767930081
# Significant!
# For features ('x188', 'x23', 'x33') with neg_mean_absolute_error = -16.33404164797371
# Significant!
# For features ('x188', 'x23', 'x102') with neg_mean_absolute_error = -16.2696052759165
# Significant!
# For features ('x188', 'x23', 'x98') with neg_mean_absolute_error = -16.797413212518855
# Significant!
# For features ('x188', 'x23', 'x162') with neg_mean_absolute_error = -16.89860207982779
# Significant!
# For features ('x188', 'x23', 'x159') with neg_mean_absolute_error = -15.464581964636059
# Significant!
# For features ('x188', 'x33', 'x48') with neg_mean_absolute_error = -14.683212230175604
# Significant!
# For features ('x45', 'x23', 'x33') with neg_mean_absolute_error = -16.146908200425376
# Significant!
# For features ('x45', 'x23', 'x102') with neg_mean_absolute_error = -16.532534452339604
# Significant!
# For features ('x45', 'x23', 'x98') with neg_mean_absolute_error = -16.915666690965026
# Significant!
# For features ('x45', 'x23', 'x162') with neg_mean_absolute_error = -16.94808478809896
# Significant!
# For features ('x45', 'x23', 'x159') with neg_mean_absolute_error = -15.40551597630485
# Significant!
# For features ('x42', 'x23', 'x33') with neg_mean_absolute_error = -16.291207356251466
# Significant!
# For features ('x42', 'x23', 'x102') with neg_mean_absolute_error = -16.222326970350622
# Significant!
# For features ('x42', 'x23', 'x98') with neg_mean_absolute_error = -16.75257037790049
# Significant!
# For features ('x42', 'x23', 'x162') with neg_mean_absolute_error = -16.8879087640498
# Significant!
# For features ('x42', 'x23', 'x159') with neg_mean_absolute_error = -15.469775233083965
# Significant!
# For features ('x193', 'x23', 'x33') with neg_mean_absolute_error = -16.380239047804277
# Significant!
# For features ('x193', 'x23', 'x102') with neg_mean_absolute_error = -16.299385210107868
# Significant!
# For features ('x193', 'x23', 'x98') with neg_mean_absolute_error = -16.82972568229133
# Significant!
# For features ('x193', 'x23', 'x162') with neg_mean_absolute_error = -16.913588619455954
# Significant!
# For features ('x193', 'x23', 'x159') with neg_mean_absolute_error = -15.495066046733237
# Significant!
# For features ('x193', 'x33', 'x48') with neg_mean_absolute_error = -15.74478667477337
# Significant!
# For features ('x71', 'x23', 'x33') with neg_mean_absolute_error = -15.90410856241724
# Significant!
# For features ('x71', 'x23', 'x102') with neg_mean_absolute_error = -15.75395699172753
# Significant!
# For features ('x71', 'x23', 'x98') with neg_mean_absolute_error = -16.574469910212958
# Significant!
# For features ('x71', 'x23', 'x162') with neg_mean_absolute_error = -16.989566281172543
# Significant!
# For features ('x71', 'x23', 'x159') with neg_mean_absolute_error = -15.959235928318781
# Significant!
# For features ('x23', 'x149', 'x33') with neg_mean_absolute_error = -16.060729908172
# Significant!
# For features ('x23', 'x149', 'x102') with neg_mean_absolute_error = -16.61141722413766
# Significant!
# For features ('x23', 'x149', 'x98') with neg_mean_absolute_error = -16.927509063904385
# Significant!
# For features ('x23', 'x149', 'x162') with neg_mean_absolute_error = -16.689810971576968
# Significant!
# For features ('x23', 'x149', 'x159') with neg_mean_absolute_error = -15.418868239985676
# Significant!
# For features ('x23', 'x6', 'x33') with neg_mean_absolute_error = -16.594357724771378
# Significant!
# For features ('x23', 'x6', 'x102') with neg_mean_absolute_error = -14.459124762922906
# Significant!
# For features ('x23', 'x6', 'x98') with neg_mean_absolute_error = -15.15152958821606
# Significant!
# For features ('x23', 'x6', 'x162') with neg_mean_absolute_error = -16.11555266959939
# Significant!
# For features ('x23', 'x6', 'x159') with neg_mean_absolute_error = -15.321344703176354
# Significant!
# For features ('x23', 'x6', 'x173') with neg_mean_absolute_error = -16.962925470000066
# Significant!
# For features ('x23', 'x6', 'x158') with neg_mean_absolute_error = -16.305259302046185
# Significant!
# For features ('x23', 'x5', 'x102') with neg_mean_absolute_error = -16.475018053312247
# Significant!
# For features ('x23', 'x5', 'x159') with neg_mean_absolute_error = -15.691741720037914
# Significant!
# For features ('x23', 'x39', 'x102') with neg_mean_absolute_error = -15.336222947451
# Significant!
# For features ('x23', 'x39', 'x98') with neg_mean_absolute_error = -15.92072658658238
# Significant!
# For features ('x23', 'x39', 'x162') with neg_mean_absolute_error = -16.34300924196541
# Significant!
# For features ('x23', 'x39', 'x159') with neg_mean_absolute_error = -15.610952629730065
# Significant!
# For features ('x23', 'x39', 'x173') with neg_mean_absolute_error = -16.970778573322075
# Significant!
# For features ('x23', 'x39', 'x158') with neg_mean_absolute_error = -16.762242097474378
# Significant!
# For features ('x23', 'x175', 'x33') with neg_mean_absolute_error = -16.327680084058038
# Significant!
# For features ('x23', 'x175', 'x102') with neg_mean_absolute_error = -14.379744520339937
# Significant!
# For features ('x23', 'x175', 'x98') with neg_mean_absolute_error = -15.896012510781725
# Significant!
# For features ('x23', 'x175', 'x162') with neg_mean_absolute_error = -15.417487428594262
# Significant!
# For features ('x23', 'x175', 'x159') with neg_mean_absolute_error = -15.977040285307172
# Significant!
# For features ('x23', 'x175', 'x173') with neg_mean_absolute_error = -16.125635891277756
# Significant!
# For features ('x23', 'x175', 'x158') with neg_mean_absolute_error = -16.895542588115365
# Significant!
# For features ('x23', 'x67', 'x33') with neg_mean_absolute_error = -16.175672640374053
# Significant!
# For features ('x23', 'x67', 'x102') with neg_mean_absolute_error = -15.795106638172783
# Significant!
# For features ('x23', 'x67', 'x98') with neg_mean_absolute_error = -16.703038604185515
# Significant!
# For features ('x23', 'x67', 'x162') with neg_mean_absolute_error = -16.759843129477336
# Significant!
# For features ('x23', 'x67', 'x159') with neg_mean_absolute_error = -15.817802630087712
# Significant!
# For features ('x23', 'x41', 'x33') with neg_mean_absolute_error = -16.520614342962084
# Significant!
# For features ('x23', 'x41', 'x102') with neg_mean_absolute_error = -16.20460915668598
# Significant!
# For features ('x23', 'x41', 'x98') with neg_mean_absolute_error = -16.99919648825591
# Significant!
# For features ('x23', 'x41', 'x159') with neg_mean_absolute_error = -15.923543500989888
# Significant!
# For features ('x23', 'x33', 'x148') with neg_mean_absolute_error = -16.31664036144233
# Significant!
# For features ('x23', 'x33', 'x194') with neg_mean_absolute_error = -16.34605297100863
# Significant!
# For features ('x23', 'x33', 'x102') with neg_mean_absolute_error = -14.39340056380853
# Significant!
# For features ('x23', 'x33', 'x150') with neg_mean_absolute_error = -16.282794189036245
# Significant!
# For features ('x23', 'x33', 'x98') with neg_mean_absolute_error = -14.945638014343155
# Significant!
# For features ('x23', 'x33', 'x162') with neg_mean_absolute_error = -16.041177163869683
# Significant!
# For features ('x23', 'x33', 'x159') with neg_mean_absolute_error = -14.998337512938548
# Significant!
# For features ('x23', 'x33', 'x195') with neg_mean_absolute_error = -16.34019152667782
# Significant!
# For features ('x23', 'x33', 'x61') with neg_mean_absolute_error = -16.265021956763274
# Significant!
# For features ('x23', 'x33', 'x58') with neg_mean_absolute_error = -16.152443777644983
# Significant!
# For features ('x23', 'x33', 'x9') with neg_mean_absolute_error = -16.686254843099306
# Significant!
# For features ('x23', 'x33', 'x152') with neg_mean_absolute_error = -16.277204849745907
# Significant!
# For features ('x23', 'x33', 'x43') with neg_mean_absolute_error = -16.730335992712128
# Significant!
# For features ('x23', 'x33', 'x173') with neg_mean_absolute_error = -16.10950233172954
# Significant!
# For features ('x23', 'x33', 'x158') with neg_mean_absolute_error = -14.710461740122241
# Significant!
# For features ('x23', 'x33', 'x177') with neg_mean_absolute_error = -16.537098196208785
# Significant!
# For features ('x23', 'x33', 'x63') with neg_mean_absolute_error = -16.16524715064689
# Significant!
# For features ('x23', 'x33', 'x160') with neg_mean_absolute_error = -15.497695770482997
# Significant!
# For features ('x23', 'x33', 'x213') with neg_mean_absolute_error = -16.329163279204128
# Significant!
# For features ('x23', 'x33', 'x3') with neg_mean_absolute_error = -16.772762660670598
# Significant!
# For features ('x23', 'x33', 'x48') with neg_mean_absolute_error = -16.23975028776315
# Significant!
# For features ('x23', 'x148', 'x102') with neg_mean_absolute_error = -16.424346614261463
# Significant!
# For features ('x23', 'x148', 'x98') with neg_mean_absolute_error = -16.858616176476254
# Significant!
# For features ('x23', 'x148', 'x162') with neg_mean_absolute_error = -16.95067754406164
# Significant!
# For features ('x23', 'x148', 'x159') with neg_mean_absolute_error = -15.494810315689929
# Significant!
# For features ('x23', 'x194', 'x102') with neg_mean_absolute_error = -16.533242167194665
# Significant!
# For features ('x23', 'x194', 'x162') with neg_mean_absolute_error = -16.962477256069466
# Significant!
# For features ('x23', 'x194', 'x159') with neg_mean_absolute_error = -15.53539332923321
# Significant!
# For features ('x23', 'x102', 'x150') with neg_mean_absolute_error = -16.227933713521907
# Significant!
# For features ('x23', 'x102', 'x162') with neg_mean_absolute_error = -16.456305844092235
# Significant!
# For features ('x23', 'x102', 'x159') with neg_mean_absolute_error = -15.76744908490438
# Significant!
# For features ('x23', 'x102', 'x195') with neg_mean_absolute_error = -16.285173512412182
# Significant!
# For features ('x23', 'x102', 'x61') with neg_mean_absolute_error = -15.963032483213212
# Significant!
# For features ('x23', 'x102', 'x58') with neg_mean_absolute_error = -15.88074267001511
# Significant!
# For features ('x23', 'x102', 'x9') with neg_mean_absolute_error = -15.594241471234819
# Significant!
# For features ('x23', 'x102', 'x152') with neg_mean_absolute_error = -16.236873992206522
# Significant!
# For features ('x23', 'x102', 'x43') with neg_mean_absolute_error = -16.34341992238395
# Significant!
# For features ('x23', 'x102', 'x173') with neg_mean_absolute_error = -15.965156473989902
# Significant!
# For features ('x23', 'x102', 'x158') with neg_mean_absolute_error = -16.301179198745395
# Significant!
# For features ('x23', 'x102', 'x177') with neg_mean_absolute_error = -16.800783540975324
# Significant!
# For features ('x23', 'x102', 'x63') with neg_mean_absolute_error = -15.474182710783186
# Significant!
# For features ('x23', 'x102', 'x160') with neg_mean_absolute_error = -15.586389000235744
# Significant!
# For features ('x23', 'x102', 'x213') with neg_mean_absolute_error = -16.23954756254465
# Significant!
# For features ('x23', 'x102', 'x3') with neg_mean_absolute_error = -15.969493922161798
# Significant!
# For features ('x23', 'x102', 'x7') with neg_mean_absolute_error = -16.477186087400742
# Significant!
# For features ('x23', 'x102', 'x48') with neg_mean_absolute_error = -16.198255156125953
# Significant!
# For features ('x23', 'x150', 'x98') with neg_mean_absolute_error = -16.752903599269807
# Significant!
# For features ('x23', 'x150', 'x162') with neg_mean_absolute_error = -16.891033410558997
# Significant!
# For features ('x23', 'x150', 'x159') with neg_mean_absolute_error = -15.473247115707593
# Significant!
# For features ('x23', 'x98', 'x159') with neg_mean_absolute_error = -15.621503791572135
# Significant!
# For features ('x23', 'x98', 'x195') with neg_mean_absolute_error = -16.827670011856032
# Significant!
# For features ('x23', 'x98', 'x61') with neg_mean_absolute_error = -16.785741905800965
# Significant!
# For features ('x23', 'x98', 'x58') with neg_mean_absolute_error = -16.41478822660593
# Significant!
# For features ('x23', 'x98', 'x9') with neg_mean_absolute_error = -16.124545285615245
# Significant!
# For features ('x23', 'x98', 'x152') with neg_mean_absolute_error = -16.761067059247402
# Significant!
# For features ('x23', 'x98', 'x63') with neg_mean_absolute_error = -16.182729472501347
# Significant!
# For features ('x23', 'x98', 'x213') with neg_mean_absolute_error = -16.76576903659348
# Significant!
# For features ('x23', 'x98', 'x48') with neg_mean_absolute_error = -16.714006503684825
# Significant!
# For features ('x23', 'x162', 'x159') with neg_mean_absolute_error = -16.002179408877463
# Significant!
# For features ('x23', 'x162', 'x195') with neg_mean_absolute_error = -16.917126960026206
# Significant!
# For features ('x23', 'x162', 'x58') with neg_mean_absolute_error = -16.764389840227103
# Significant!
# For features ('x23', 'x162', 'x9') with neg_mean_absolute_error = -16.769820120257503
# Significant!
# For features ('x23', 'x162', 'x152') with neg_mean_absolute_error = -16.898429570382234
# Significant!
# For features ('x23', 'x162', 'x173') with neg_mean_absolute_error = -16.603337055035382
# Significant!
# For features ('x23', 'x162', 'x63') with neg_mean_absolute_error = -16.71755652173937
# Significant!
# For features ('x23', 'x162', 'x213') with neg_mean_absolute_error = -16.895429459675526
# Significant!
# For features ('x23', 'x162', 'x3') with neg_mean_absolute_error = -16.92604675031236
# Significant!
# For features ('x23', 'x162', 'x48') with neg_mean_absolute_error = -16.874976597727763
# Significant!
# For features ('x23', 'x159', 'x195') with neg_mean_absolute_error = -15.48003561154924
# Significant!
# For features ('x23', 'x159', 'x61') with neg_mean_absolute_error = -16.601731795929087
# Significant!
# For features ('x23', 'x159', 'x58') with neg_mean_absolute_error = -15.718710004832365
# Significant!
# For features ('x23', 'x159', 'x9') with neg_mean_absolute_error = -15.171017216306728
# Significant!
# For features ('x23', 'x159', 'x152') with neg_mean_absolute_error = -15.474177827875025
# Significant!
# For features ('x23', 'x159', 'x43') with neg_mean_absolute_error = -15.570720212195715
# Significant!
# For features ('x23', 'x159', 'x173') with neg_mean_absolute_error = -15.701091656913736
# Significant!
# For features ('x23', 'x159', 'x158') with neg_mean_absolute_error = -15.719383134884504
# Significant!
# For features ('x23', 'x159', 'x177') with neg_mean_absolute_error = -15.940906604084443
# Significant!
# For features ('x23', 'x159', 'x63') with neg_mean_absolute_error = -15.811446764967059
# Significant!
# For features ('x23', 'x159', 'x160') with neg_mean_absolute_error = -15.69747537590494
# Significant!
# For features ('x23', 'x159', 'x213') with neg_mean_absolute_error = -15.488577822388933
# Significant!
# For features ('x23', 'x159', 'x3') with neg_mean_absolute_error = -15.687515015129671
# Significant!
# For features ('x23', 'x159', 'x7') with neg_mean_absolute_error = -15.825818618716195
# Significant!
# For features ('x23', 'x159', 'x48') with neg_mean_absolute_error = -15.490130057752001
# Significant!
# For features ('x23', 'x158', 'x160') with neg_mean_absolute_error = -15.633154998252385
# Significant!
# For features ('x33', 'x148', 'x48') with neg_mean_absolute_error = -16.935705328248165
# Significant!
# For features ('x33', 'x195', 'x48') with neg_mean_absolute_error = -16.749139219106773

# %%
len(List3_2cvd_3_nmae)
# Out:
# 260

# %%
List4_2cvd_3_nmae,List4_2cvd_2_nmae,List4_2cvd_0_nmae = combnfeats_MLR_evaby_crossval_metric(List3_2cvd_3_nmae,df_x,df_y,10,model,'neg_mean_absolute_error',-15)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x23', 'x102') with neg_mean_absolute_error = -14.370126499928272
# Significant!
# For features ('x32', 'x99', 'x23') with neg_mean_absolute_error = -14.13049066474737
# Significant!
# For features ('x32', 'x23', 'x102') with neg_mean_absolute_error = -13.762234389745874
# Significant!
# For features ('x32', 'x23', 'x98') with neg_mean_absolute_error = -14.529415963902412
# Significant!
# For features ('x32', 'x23', 'x159') with neg_mean_absolute_error = -14.4068165909628
# Significant!
# For features ('x32', 'x23', 'x158') with neg_mean_absolute_error = -14.567527483529862
# Significant!
# For features ('x99', 'x23', 'x33') with neg_mean_absolute_error = -14.849436999416998
# Significant!
# For features ('x188', 'x33', 'x48') with neg_mean_absolute_error = -14.721021521372387
# Significant!
# For features ('x23', 'x6', 'x102') with neg_mean_absolute_error = -14.329580630474634
# Significant!
# For features ('x23', 'x6', 'x98') with neg_mean_absolute_error = -14.967279127161115
# Significant!
# For features ('x23', 'x175', 'x102') with neg_mean_absolute_error = -14.613671013073965
# Significant!
# For features ('x23', 'x33', 'x102') with neg_mean_absolute_error = -14.562125767307887

# %%
a,b,c = combnfeats_MLR_evaby_crossval_metric(List4_2cvd_3_nmae,df_x,df_y,500,model,'neg_mean_absolute_error',-15)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x23', 'x102') with neg_mean_absolute_error = -14.144566636932714
# Significant!
# For features ('x32', 'x99', 'x23') with neg_mean_absolute_error = -14.135436225264135
# Significant!
# For features ('x32', 'x23', 'x102') with neg_mean_absolute_error = -13.699966990979012
# Significant!
# For features ('x32', 'x23', 'x98') with neg_mean_absolute_error = -14.503600690493798
# Significant!
# For features ('x32', 'x23', 'x159') with neg_mean_absolute_error = -14.169729080277424
# Significant!
# For features ('x32', 'x23', 'x158') with neg_mean_absolute_error = -14.608850729040185
# Significant!
# For features ('x99', 'x23', 'x33') with neg_mean_absolute_error = -14.69601302303316
# Significant!
# For features ('x188', 'x33', 'x48') with neg_mean_absolute_error = -14.370194418594874
# Significant!
# For features ('x23', 'x6', 'x102') with neg_mean_absolute_error = -13.878555361801821
# Significant!
# For features ('x23', 'x6', 'x98') with neg_mean_absolute_error = -14.783396717130316
# Significant!
# For features ('x23', 'x175', 'x102') with neg_mean_absolute_error = -14.480917138174757
# Significant!
# For features ('x23', 'x33', 'x102') with neg_mean_absolute_error = -14.331491486084252

# %% [markdown]
# 'x32', 'x23', 'x102'

# %% [markdown]
# Explained variance

# %%
List_2cvd_3_expv,List_2cvd_2_expv,List_2cvd_0_expv = combnfeats_MLR_evaby_crossval_metric(feats,df_x,df_y,5,model,'explained_variance',0.3)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x49', 'x27') with explained_variance = 0.3517260247290701
# Significant!
# For features ('x186', 'x49', 'x23') with explained_variance = 0.3868605117371822
# Significant!
# For features ('x186', 'x32', 'x23') with explained_variance = 0.4334291667090694
# Significant!
# For features ('x186', 'x8', 'x27') with explained_variance = 0.3561022361565488
# Significant!
# For features ('x186', 'x8', 'x23') with explained_variance = 0.40631121813232196
# Significant!
# For features ('x186', 'x2', 'x23') with explained_variance = 0.337155950794995
# Significant!
# For features ('x186', 'x2', 'x33') with explained_variance = 0.4067669012430139
# Significant!
# For features ('x186', 'x2', 'x102') with explained_variance = 0.3240137742465925
# Significant!
# For features ('x186', 'x2', 'x159') with explained_variance = 0.31823713781040197
# Significant!
# For features ('x186', 'x4', 'x23') with explained_variance = 0.34112508527888585
# Significant!
# For features ('x186', 'x4', 'x33') with explained_variance = 0.32955894044697503
# Significant!
# For features ('x186', 'x27', 'x99') with explained_variance = 0.38897179181852815
# Significant!
# For features ('x186', 'x27', 'x50') with explained_variance = 0.38095733864493864
# Significant!
# For features ('x186', 'x27', 'x188') with explained_variance = 0.337582553919613
# Significant!
# For features ('x186', 'x27', 'x45') with explained_variance = 0.3532942506460494
# Significant!
# For features ('x186', 'x27', 'x42') with explained_variance = 0.3427334407420913
# Significant!
# For features ('x186', 'x27', 'x193') with explained_variance = 0.3313544121876986
# Significant!
# For features ('x186', 'x27', 'x23') with explained_variance = 0.31519417874817846
# Significant!
# For features ('x186', 'x27', 'x149') with explained_variance = 0.3556457059373338
# Significant!
# For features ('x186', 'x27', 'x39') with explained_variance = 0.3089853850316382
# Significant!
# For features ('x186', 'x27', 'x33') with explained_variance = 0.35796283892853664
# Significant!
# For features ('x186', 'x27', 'x148') with explained_variance = 0.3383841648695791
# Significant!
# For features ('x186', 'x27', 'x194') with explained_variance = 0.3317863140318895
# Significant!
# For features ('x186', 'x27', 'x102') with explained_variance = 0.43318326473405044
# Significant!
# For features ('x186', 'x27', 'x150') with explained_variance = 0.3458164632637002
# Significant!
# For features ('x186', 'x27', 'x98') with explained_variance = 0.40072029041423934
# Significant!
# For features ('x186', 'x27', 'x162') with explained_variance = 0.3365276202362838
# Significant!
# For features ('x186', 'x27', 'x159') with explained_variance = 0.3738622928301624
# Significant!
# For features ('x186', 'x27', 'x195') with explained_variance = 0.3391116832157915
# Significant!
# For features ('x186', 'x27', 'x152') with explained_variance = 0.3493460636711799
# Significant!
# For features ('x186', 'x27', 'x43') with explained_variance = 0.30768690581440694
# Significant!
# For features ('x186', 'x27', 'x173') with explained_variance = 0.3122195188310583
# Significant!
# For features ('x186', 'x27', 'x158') with explained_variance = 0.36714719972339893
# Significant!
# For features ('x186', 'x27', 'x160') with explained_variance = 0.3482284488858985
# Significant!
# For features ('x186', 'x27', 'x213') with explained_variance = 0.33706319235039406
# Significant!
# For features ('x186', 'x27', 'x48') with explained_variance = 0.3353831520627092
# Significant!
# For features ('x186', 'x99', 'x23') with explained_variance = 0.512399412860655
# Significant!
# For features ('x186', 'x50', 'x23') with explained_variance = 0.43945569660387945
# Significant!
# For features ('x186', 'x188', 'x23') with explained_variance = 0.376041296755682
# Significant!
# For features ('x186', 'x45', 'x23') with explained_variance = 0.41796816272707193
# Significant!
# For features ('x186', 'x42', 'x23') with explained_variance = 0.3787698768866726
# Significant!
# For features ('x186', 'x193', 'x23') with explained_variance = 0.37076926481534683
# Significant!
# For features ('x186', 'x71', 'x23') with explained_variance = 0.30064138024690146
# Significant!
# For features ('x186', 'x23', 'x149') with explained_variance = 0.39673258335464123
# Significant!
# For features ('x186', 'x23', 'x6') with explained_variance = 0.3070624312345553
# Significant!
# For features ('x186', 'x23', 'x5') with explained_variance = 0.3520377137785065
# Significant!
# For features ('x186', 'x23', 'x39') with explained_variance = 0.3628221359712273
# Significant!
# For features ('x186', 'x23', 'x175') with explained_variance = 0.36409617622033313
# Significant!
# For features ('x186', 'x23', 'x67') with explained_variance = 0.3113772173899798
# Significant!
# For features ('x186', 'x23', 'x41') with explained_variance = 0.3112738639743923
# Significant!
# For features ('x186', 'x23', 'x33') with explained_variance = 0.5090477312300923
# Significant!
# For features ('x186', 'x23', 'x148') with explained_variance = 0.38191169895894367
# Significant!
# For features ('x186', 'x23', 'x194') with explained_variance = 0.3691641973460439
# Significant!
# For features ('x186', 'x23', 'x102') with explained_variance = 0.5546132292933643
# Significant!
# For features ('x186', 'x23', 'x150') with explained_variance = 0.3828047562580921
# Significant!
# For features ('x186', 'x23', 'x98') with explained_variance = 0.5177158478282917
# Significant!
# For features ('x186', 'x23', 'x162') with explained_variance = 0.4793884978990082
# Significant!
# For features ('x186', 'x23', 'x159') with explained_variance = 0.5276824209001674
# Significant!
# For features ('x186', 'x23', 'x195') with explained_variance = 0.37682390376789787
# Significant!
# For features ('x186', 'x23', 'x58') with explained_variance = 0.3217358271775631
# Significant!
# For features ('x186', 'x23', 'x9') with explained_variance = 0.3666443153133586
# Significant!
# For features ('x186', 'x23', 'x152') with explained_variance = 0.3865681406248707
# Significant!
# For features ('x186', 'x23', 'x43') with explained_variance = 0.4073186954223795
# Significant!
# For features ('x186', 'x23', 'x173') with explained_variance = 0.43547579300495426
# Significant!
# For features ('x186', 'x23', 'x158') with explained_variance = 0.4526400080717563
# Significant!
# For features ('x186', 'x23', 'x177') with explained_variance = 0.4211421042620616
# Significant!
# For features ('x186', 'x23', 'x63') with explained_variance = 0.322984008998324
# Significant!
# For features ('x186', 'x23', 'x160') with explained_variance = 0.4121989427622377
# Significant!
# For features ('x186', 'x23', 'x213') with explained_variance = 0.37376720859255086
# Significant!
# For features ('x186', 'x23', 'x3') with explained_variance = 0.3290568380170099
# Significant!
# For features ('x186', 'x23', 'x7') with explained_variance = 0.3601151519182338
# Significant!
# For features ('x186', 'x23', 'x48') with explained_variance = 0.3696288600585581
# Significant!
# For features ('x186', 'x33', 'x7') with explained_variance = 0.3217576175393817
# Significant!
# For features ('x49', 'x32', 'x27') with explained_variance = 0.3139843225792715
# Significant!
# For features ('x49', 'x32', 'x23') with explained_variance = 0.42073642500032465
# Significant!
# For features ('x49', 'x8', 'x27') with explained_variance = 0.356426143899339
# Significant!
# For features ('x49', 'x8', 'x23') with explained_variance = 0.32218877572462895
# Significant!
# For features ('x49', 'x8', 'x33') with explained_variance = 0.36450217321313483
# Significant!
# For features ('x49', 'x2', 'x27') with explained_variance = 0.31821264033042723
# Significant!
# For features ('x49', 'x2', 'x33') with explained_variance = 0.39009233535918525
# Significant!
# For features ('x49', 'x2', 'x159') with explained_variance = 0.3253071638521893
# Significant!
# For features ('x49', 'x4', 'x27') with explained_variance = 0.345958643727628
# Significant!
# For features ('x49', 'x4', 'x33') with explained_variance = 0.3536250397647144
# Significant!
# For features ('x49', 'x27', 'x99') with explained_variance = 0.4083217258655143
# Significant!
# For features ('x49', 'x27', 'x50') with explained_variance = 0.36494087858348495
# Significant!
# For features ('x49', 'x27', 'x45') with explained_variance = 0.34497217393343915
# Significant!
# For features ('x49', 'x27', 'x71') with explained_variance = 0.32688835565358304
# Significant!
# For features ('x49', 'x27', 'x23') with explained_variance = 0.3006307051171423
# Significant!
# For features ('x49', 'x27', 'x6') with explained_variance = 0.35453556935954883
# Significant!
# For features ('x49', 'x27', 'x5') with explained_variance = 0.35152223204940375
# Significant!
# For features ('x49', 'x27', 'x39') with explained_variance = 0.349982596089176
# Significant!
# For features ('x49', 'x27', 'x175') with explained_variance = 0.32056983293528746
# Significant!
# For features ('x49', 'x27', 'x67') with explained_variance = 0.3349686356037679
# Significant!
# For features ('x49', 'x27', 'x41') with explained_variance = 0.3437779008048928
# Significant!
# For features ('x49', 'x27', 'x33') with explained_variance = 0.3445972057419495
# Significant!
# For features ('x49', 'x27', 'x194') with explained_variance = 0.30403576401227783
# Significant!
# For features ('x49', 'x27', 'x102') with explained_variance = 0.4307847425357001
# Significant!
# For features ('x49', 'x27', 'x98') with explained_variance = 0.41308451471575347
# Significant!
# For features ('x49', 'x27', 'x162') with explained_variance = 0.35961726541319383
# Significant!
# For features ('x49', 'x27', 'x159') with explained_variance = 0.39075846530506814
# Significant!
# For features ('x49', 'x27', 'x58') with explained_variance = 0.32652006940976314
# Significant!
# For features ('x49', 'x27', 'x9') with explained_variance = 0.34698560980623594
# Significant!
# For features ('x49', 'x27', 'x152') with explained_variance = 0.33588824028219355
# Significant!
# For features ('x49', 'x27', 'x43') with explained_variance = 0.3104878089513329
# Significant!
# For features ('x49', 'x27', 'x173') with explained_variance = 0.3397943384522466
# Significant!
# For features ('x49', 'x27', 'x158') with explained_variance = 0.3984038599570469
# Significant!
# For features ('x49', 'x27', 'x177') with explained_variance = 0.32942683586234367
# Significant!
# For features ('x49', 'x27', 'x63') with explained_variance = 0.33061304113077405
# Significant!
# For features ('x49', 'x27', 'x160') with explained_variance = 0.37360477692845806
# Significant!
# For features ('x49', 'x27', 'x3') with explained_variance = 0.3529445277033235
# Significant!
# For features ('x49', 'x27', 'x7') with explained_variance = 0.3495004492138905
# Significant!
# For features ('x49', 'x27', 'x48') with explained_variance = 0.35296524567118437
# Significant!
# For features ('x49', 'x99', 'x23') with explained_variance = 0.48920865624129445
# Significant!
# For features ('x49', 'x45', 'x23') with explained_variance = 0.3364553697845264
# Significant!
# For features ('x49', 'x45', 'x33') with explained_variance = 0.38827601326430755
# Significant!
# For features ('x49', 'x23', 'x6') with explained_variance = 0.3290056440049168
# Significant!
# For features ('x49', 'x23', 'x39') with explained_variance = 0.3089048677041028
# Significant!
# For features ('x49', 'x23', 'x33') with explained_variance = 0.5180084282086094
# Significant!
# For features ('x49', 'x23', 'x102') with explained_variance = 0.4880320534250309
# Significant!
# For features ('x49', 'x23', 'x98') with explained_variance = 0.46074780298284057
# Significant!
# For features ('x49', 'x23', 'x162') with explained_variance = 0.4377540538467398
# Significant!
# For features ('x49', 'x23', 'x159') with explained_variance = 0.525398970824002
# Significant!
# For features ('x49', 'x23', 'x43') with explained_variance = 0.30158590819550185
# Significant!
# For features ('x49', 'x23', 'x173') with explained_variance = 0.36376733197075
# Significant!
# For features ('x49', 'x23', 'x158') with explained_variance = 0.35782489433917564
# Significant!
# For features ('x49', 'x23', 'x177') with explained_variance = 0.37871078469305397
# Significant!
# For features ('x49', 'x5', 'x33') with explained_variance = 0.3214846982469589
# Significant!
# For features ('x49', 'x39', 'x33') with explained_variance = 0.3693545479654693
# Significant!
# For features ('x49', 'x33', 'x7') with explained_variance = 0.35946375868298786
# Significant!
# For features ('x32', 'x8', 'x50') with explained_variance = 0.33357190897346045
# Significant!
# For features ('x32', 'x8', 'x23') with explained_variance = 0.41384645899855077
# Significant!
# For features ('x32', 'x8', 'x158') with explained_variance = 0.34556242748335725
# Significant!
# For features ('x32', 'x8', 'x160') with explained_variance = 0.32460219497793885
# Significant!
# For features ('x32', 'x2', 'x99') with explained_variance = 0.37330793497085263
# Significant!
# For features ('x32', 'x2', 'x50') with explained_variance = 0.33475082236779047
# Significant!
# For features ('x32', 'x2', 'x23') with explained_variance = 0.41679916628669567
# Significant!
# For features ('x32', 'x2', 'x33') with explained_variance = 0.40485285972006324
# Significant!
# For features ('x32', 'x2', 'x102') with explained_variance = 0.41455095437547607
# Significant!
# For features ('x32', 'x2', 'x98') with explained_variance = 0.3719554716052689
# Significant!
# For features ('x32', 'x2', 'x162') with explained_variance = 0.3460403716850552
# Significant!
# For features ('x32', 'x2', 'x159') with explained_variance = 0.37431479531241196
# Significant!
# For features ('x32', 'x2', 'x173') with explained_variance = 0.33414751785204144
# Significant!
# For features ('x32', 'x2', 'x158') with explained_variance = 0.38447613139810055
# Significant!
# For features ('x32', 'x2', 'x160') with explained_variance = 0.34438568678216996
# Significant!
# For features ('x32', 'x4', 'x23') with explained_variance = 0.37636447789376654
# Significant!
# For features ('x32', 'x4', 'x158') with explained_variance = 0.3064511895402339
# Significant!
# For features ('x32', 'x27', 'x50') with explained_variance = 0.35219171280397427
# Significant!
# For features ('x32', 'x27', 'x23') with explained_variance = 0.38741790038388746
# Significant!
# For features ('x32', 'x27', 'x41') with explained_variance = 0.358235450040548
# Significant!
# For features ('x32', 'x27', 'x102') with explained_variance = 0.37075267356717456
# Significant!
# For features ('x32', 'x27', 'x98') with explained_variance = 0.3046536388702042
# Significant!
# For features ('x32', 'x27', 'x152') with explained_variance = 0.30087197743677097
# Significant!
# For features ('x32', 'x27', 'x158') with explained_variance = 0.3661667877899307
# Significant!
# For features ('x32', 'x27', 'x160') with explained_variance = 0.3881975339601608
# Significant!
# For features ('x32', 'x99', 'x23') with explained_variance = 0.586256396999459
# Significant!
# For features ('x32', 'x50', 'x23') with explained_variance = 0.4979928188365541
# Significant!
# For features ('x32', 'x50', 'x39') with explained_variance = 0.3138646029176527
# Significant!
# For features ('x32', 'x50', 'x7') with explained_variance = 0.332424510220727
# Significant!
# For features ('x32', 'x188', 'x23') with explained_variance = 0.40235145006281936
# Significant!
# For features ('x32', 'x45', 'x23') with explained_variance = 0.4537909745956926
# Significant!
# For features ('x32', 'x42', 'x23') with explained_variance = 0.4065787360590363
# Significant!
# For features ('x32', 'x193', 'x23') with explained_variance = 0.40027199378368916
# Significant!
# For features ('x32', 'x71', 'x23') with explained_variance = 0.40093799385686835
# Significant!
# For features ('x32', 'x23', 'x149') with explained_variance = 0.42352655736979355
# Significant!
# For features ('x32', 'x23', 'x6') with explained_variance = 0.3890093006425508
# Significant!
# For features ('x32', 'x23', 'x5') with explained_variance = 0.39964795640172535
# Significant!
# For features ('x32', 'x23', 'x39') with explained_variance = 0.3787688056538845
# Significant!
# For features ('x32', 'x23', 'x175') with explained_variance = 0.4656960715907985
# Significant!
# For features ('x32', 'x23', 'x67') with explained_variance = 0.39855357172249495
# Significant!
# For features ('x32', 'x23', 'x41') with explained_variance = 0.41272957069814203
# Significant!
# For features ('x32', 'x23', 'x33') with explained_variance = 0.5175752580331872
# Significant!
# For features ('x32', 'x23', 'x148') with explained_variance = 0.4110449855906734
# Significant!
# For features ('x32', 'x23', 'x194') with explained_variance = 0.4001029000147991
# Significant!
# For features ('x32', 'x23', 'x102') with explained_variance = 0.6144733692071418
# Significant!
# For features ('x32', 'x23', 'x150') with explained_variance = 0.41040876303276985
# Significant!
# For features ('x32', 'x23', 'x98') with explained_variance = 0.5789274993604175
# Significant!
# For features ('x32', 'x23', 'x162') with explained_variance = 0.5383082192276298
# Significant!
# For features ('x32', 'x23', 'x159') with explained_variance = 0.5895757417912355
# Significant!
# For features ('x32', 'x23', 'x195') with explained_variance = 0.4019226412221551
# Significant!
# For features ('x32', 'x23', 'x61') with explained_variance = 0.392531311670106
# Significant!
# For features ('x32', 'x23', 'x58') with explained_variance = 0.40741712055265344
# Significant!
# For features ('x32', 'x23', 'x9') with explained_variance = 0.41360796620783746
# Significant!
# For features ('x32', 'x23', 'x152') with explained_variance = 0.4136798710670931
# Significant!
# For features ('x32', 'x23', 'x43') with explained_variance = 0.42191451621246356
# Significant!
# For features ('x32', 'x23', 'x173') with explained_variance = 0.5461730729557825
# Significant!
# For features ('x32', 'x23', 'x158') with explained_variance = 0.6113270941167871
# Significant!
# For features ('x32', 'x23', 'x177') with explained_variance = 0.47067487330417074
# Significant!
# For features ('x32', 'x23', 'x63') with explained_variance = 0.4067222918895294
# Significant!
# For features ('x32', 'x23', 'x160') with explained_variance = 0.5630864065748893
# Significant!
# For features ('x32', 'x23', 'x213') with explained_variance = 0.40451641964131557
# Significant!
# For features ('x32', 'x23', 'x3') with explained_variance = 0.40812323478904194
# Significant!
# For features ('x32', 'x23', 'x7') with explained_variance = 0.3826593407680003
# Significant!
# For features ('x32', 'x23', 'x48') with explained_variance = 0.40059178339661966
# Significant!
# For features ('x32', 'x39', 'x158') with explained_variance = 0.33878897029148447
# Significant!
# For features ('x32', 'x39', 'x160') with explained_variance = 0.3043524854668304
# Significant!
# For features ('x32', 'x102', 'x7') with explained_variance = 0.3557922559574666
# Significant!
# For features ('x32', 'x158', 'x7') with explained_variance = 0.38154528626184797
# Significant!
# For features ('x32', 'x160', 'x7') with explained_variance = 0.33372065216758917
# Significant!
# For features ('x8', 'x2', 'x27') with explained_variance = 0.36674735725827695
# Significant!
# For features ('x8', 'x2', 'x99') with explained_variance = 0.32577469242650253
# Significant!
# For features ('x8', 'x2', 'x23') with explained_variance = 0.3778945982645484
# Significant!
# For features ('x8', 'x2', 'x33') with explained_variance = 0.3604929458168789
# Significant!
# For features ('x8', 'x2', 'x102') with explained_variance = 0.32623695737179803
# Significant!
# For features ('x8', 'x2', 'x159') with explained_variance = 0.3282206213204099
# Significant!
# For features ('x8', 'x2', 'x7') with explained_variance = 0.32129116249224504
# Significant!
# For features ('x8', 'x4', 'x27') with explained_variance = 0.35781067330528826
# Significant!
# For features ('x8', 'x4', 'x23') with explained_variance = 0.3607542210666462
# Significant!
# For features ('x8', 'x27', 'x99') with explained_variance = 0.3558585289298907
# Significant!
# For features ('x8', 'x27', 'x50') with explained_variance = 0.3689924694029241
# Significant!
# For features ('x8', 'x27', 'x188') with explained_variance = 0.3447658619207233
# Significant!
# For features ('x8', 'x27', 'x45') with explained_variance = 0.3335260259645236
# Significant!
# For features ('x8', 'x27', 'x42') with explained_variance = 0.3481622980031597
# Significant!
# For features ('x8', 'x27', 'x193') with explained_variance = 0.3374313241813938
# Significant!
# For features ('x8', 'x27', 'x71') with explained_variance = 0.3164942644284817
# Significant!
# For features ('x8', 'x27', 'x23') with explained_variance = 0.4219231836859644
# Significant!
# For features ('x8', 'x27', 'x149') with explained_variance = 0.3490644233249033
# Significant!
# For features ('x8', 'x27', 'x6') with explained_variance = 0.38436701724453226
# Significant!
# For features ('x8', 'x27', 'x5') with explained_variance = 0.3107942206167565
# Significant!
# For features ('x8', 'x27', 'x39') with explained_variance = 0.3580240859360537
# Significant!
# For features ('x8', 'x27', 'x175') with explained_variance = 0.3185990685102963
# Significant!
# For features ('x8', 'x27', 'x67') with explained_variance = 0.32771913894763227
# Significant!
# For features ('x8', 'x27', 'x41') with explained_variance = 0.43261662445696897
# Significant!
# For features ('x8', 'x27', 'x148') with explained_variance = 0.33857368761905693
# Significant!
# For features ('x8', 'x27', 'x194') with explained_variance = 0.3330255840422461
# Significant!
# For features ('x8', 'x27', 'x102') with explained_variance = 0.40981059775224127
# Significant!
# For features ('x8', 'x27', 'x150') with explained_variance = 0.3490544117610447
# Significant!
# For features ('x8', 'x27', 'x98') with explained_variance = 0.37427154526169304
# Significant!
# For features ('x8', 'x27', 'x162') with explained_variance = 0.3320634317636203
# Significant!
# For features ('x8', 'x27', 'x159') with explained_variance = 0.3496589783027395
# Significant!
# For features ('x8', 'x27', 'x195') with explained_variance = 0.3451211597937417
# Significant!
# For features ('x8', 'x27', 'x58') with explained_variance = 0.31790854843537353
# Significant!
# For features ('x8', 'x27', 'x9') with explained_variance = 0.36414209371069706
# Significant!
# For features ('x8', 'x27', 'x152') with explained_variance = 0.35049287651181327
# Significant!
# For features ('x8', 'x27', 'x173') with explained_variance = 0.3221874004463179
# Significant!
# For features ('x8', 'x27', 'x158') with explained_variance = 0.3913987590285001
# Significant!
# For features ('x8', 'x27', 'x177') with explained_variance = 0.3107669906511436
# Significant!
# For features ('x8', 'x27', 'x63') with explained_variance = 0.30527789450037335
# Significant!
# For features ('x8', 'x27', 'x160') with explained_variance = 0.3906427406581217
# Significant!
# For features ('x8', 'x27', 'x213') with explained_variance = 0.342164759002077
# Significant!
# For features ('x8', 'x27', 'x3') with explained_variance = 0.354674254792947
# Significant!
# For features ('x8', 'x27', 'x7') with explained_variance = 0.3300006094990244
# Significant!
# For features ('x8', 'x27', 'x48') with explained_variance = 0.3488025120487098
# Significant!
# For features ('x8', 'x99', 'x23') with explained_variance = 0.49884192761659757
# Significant!
# For features ('x8', 'x50', 'x23') with explained_variance = 0.3409792102674443
# Significant!
# For features ('x8', 'x50', 'x33') with explained_variance = 0.4261174752848026
# Significant!
# For features ('x8', 'x188', 'x23') with explained_variance = 0.31526643770230023
# Significant!
# For features ('x8', 'x188', 'x33') with explained_variance = 0.30054701873510214
# Significant!
# For features ('x8', 'x45', 'x23') with explained_variance = 0.3310200026304094
# Significant!
# For features ('x8', 'x42', 'x23') with explained_variance = 0.31898883805607764
# Significant!
# For features ('x8', 'x42', 'x33') with explained_variance = 0.31625973009731856
# Significant!
# For features ('x8', 'x193', 'x23') with explained_variance = 0.3132759463918421
# Significant!
# For features ('x8', 'x71', 'x23') with explained_variance = 0.36112540880345784
# Significant!
# For features ('x8', 'x23', 'x149') with explained_variance = 0.3395058114931889
# Significant!
# For features ('x8', 'x23', 'x6') with explained_variance = 0.37391320028167313
# Significant!
# For features ('x8', 'x23', 'x5') with explained_variance = 0.4209942953756071
# Significant!
# For features ('x8', 'x23', 'x39') with explained_variance = 0.3603108141801489
# Significant!
# For features ('x8', 'x23', 'x175') with explained_variance = 0.3365956055058118
# Significant!
# For features ('x8', 'x23', 'x67') with explained_variance = 0.37275689549739577
# Significant!
# For features ('x8', 'x23', 'x41') with explained_variance = 0.37159185099777375
# Significant!
# For features ('x8', 'x23', 'x33') with explained_variance = 0.44270937591015513
# Significant!
# For features ('x8', 'x23', 'x148') with explained_variance = 0.31480543482610235
# Significant!
# For features ('x8', 'x23', 'x194') with explained_variance = 0.3111295272310781
# Significant!
# For features ('x8', 'x23', 'x102') with explained_variance = 0.48725698239724524
# Significant!
# For features ('x8', 'x23', 'x150') with explained_variance = 0.3198478167559876
# Significant!
# For features ('x8', 'x23', 'x98') with explained_variance = 0.46688024632421066
# Significant!
# For features ('x8', 'x23', 'x162') with explained_variance = 0.42226245189874784
# Significant!
# For features ('x8', 'x23', 'x159') with explained_variance = 0.5126576447491589
# Significant!
# For features ('x8', 'x23', 'x195') with explained_variance = 0.3172218956067666
# Significant!
# For features ('x8', 'x23', 'x61') with explained_variance = 0.362426217803572
# Significant!
# For features ('x8', 'x23', 'x58') with explained_variance = 0.3589187689236181
# Significant!
# For features ('x8', 'x23', 'x9') with explained_variance = 0.3924013050211799
# Significant!
# For features ('x8', 'x23', 'x152') with explained_variance = 0.3212980821305801
# Significant!
# For features ('x8', 'x23', 'x43') with explained_variance = 0.3302456449664315
# Significant!
# For features ('x8', 'x23', 'x173') with explained_variance = 0.38139245904315394
# Significant!
# For features ('x8', 'x23', 'x158') with explained_variance = 0.3758094588979525
# Significant!
# For features ('x8', 'x23', 'x177') with explained_variance = 0.3986461663997066
# Significant!
# For features ('x8', 'x23', 'x63') with explained_variance = 0.367196994215489
# Significant!
# For features ('x8', 'x23', 'x160') with explained_variance = 0.3479786113724939
# Significant!
# For features ('x8', 'x23', 'x213') with explained_variance = 0.31717017766104605
# Significant!
# For features ('x8', 'x23', 'x3') with explained_variance = 0.40918259119800204
# Significant!
# For features ('x8', 'x23', 'x7') with explained_variance = 0.42453832202744957
# Significant!
# For features ('x8', 'x23', 'x48') with explained_variance = 0.31759064625358385
# Significant!
# For features ('x8', 'x33', 'x150') with explained_variance = 0.3197219733484084
# Significant!
# For features ('x8', 'x33', 'x195') with explained_variance = 0.30847339572816057
# Significant!
# For features ('x8', 'x33', 'x152') with explained_variance = 0.32302081793398296
# Significant!
# For features ('x8', 'x33', 'x160') with explained_variance = 0.3266582881464296
# Significant!
# For features ('x8', 'x33', 'x213') with explained_variance = 0.3116673408418865
# Significant!
# For features ('x8', 'x33', 'x48') with explained_variance = 0.3265007292076813
# Significant!
# For features ('x2', 'x4', 'x99') with explained_variance = 0.30416003357200017
# Significant!
# For features ('x2', 'x4', 'x33') with explained_variance = 0.370590277597563
# Significant!
# For features ('x2', 'x4', 'x102') with explained_variance = 0.32576545874028773
# Significant!
# For features ('x2', 'x4', 'x159') with explained_variance = 0.304062298540335
# Significant!
# For features ('x2', 'x27', 'x99') with explained_variance = 0.3581794713431843
# Significant!
# For features ('x2', 'x27', 'x50') with explained_variance = 0.34246723990760575
# Significant!
# For features ('x2', 'x27', 'x188') with explained_variance = 0.3061194702459534
# Significant!
# For features ('x2', 'x27', 'x45') with explained_variance = 0.331749955811745
# Significant!
# For features ('x2', 'x27', 'x42') with explained_variance = 0.31132150000591036
# Significant!
# For features ('x2', 'x27', 'x149') with explained_variance = 0.33057723534137445
# Significant!
# For features ('x2', 'x27', 'x39') with explained_variance = 0.31474980184465035
# Significant!
# For features ('x2', 'x27', 'x33') with explained_variance = 0.38686324308484005
# Significant!
# For features ('x2', 'x27', 'x148') with explained_variance = 0.30753073385616814
# Significant!
# For features ('x2', 'x27', 'x194') with explained_variance = 0.30273563100714773
# Significant!
# For features ('x2', 'x27', 'x102') with explained_variance = 0.42148566234765594
# Significant!
# For features ('x2', 'x27', 'x150') with explained_variance = 0.3145971325727581
# Significant!
# For features ('x2', 'x27', 'x98') with explained_variance = 0.37619366728810555
# Significant!
# For features ('x2', 'x27', 'x162') with explained_variance = 0.31993242823109613
# Significant!
# For features ('x2', 'x27', 'x159') with explained_variance = 0.33172464582888306
# Significant!
# For features ('x2', 'x27', 'x195') with explained_variance = 0.30752349634760634
# Significant!
# For features ('x2', 'x27', 'x152') with explained_variance = 0.31850516420577335
# Significant!
# For features ('x2', 'x27', 'x158') with explained_variance = 0.32475549854056823
# Significant!
# For features ('x2', 'x27', 'x213') with explained_variance = 0.3050941237838475
# Significant!
# For features ('x2', 'x27', 'x48') with explained_variance = 0.30144420760733504
# Significant!
# For features ('x2', 'x99', 'x188') with explained_variance = 0.30560554880144747
# Significant!
# For features ('x2', 'x99', 'x42') with explained_variance = 0.3022937241737039
# Significant!
# For features ('x2', 'x99', 'x193') with explained_variance = 0.30486877212475616
# Significant!
# For features ('x2', 'x99', 'x71') with explained_variance = 0.3600491263615139
# Significant!
# For features ('x2', 'x99', 'x23') with explained_variance = 0.4984535110685866
# Significant!
# For features ('x2', 'x99', 'x149') with explained_variance = 0.30981329133207647
# Significant!
# For features ('x2', 'x99', 'x6') with explained_variance = 0.35588434139314745
# Significant!
# For features ('x2', 'x99', 'x39') with explained_variance = 0.3201373097827092
# Significant!
# For features ('x2', 'x99', 'x67') with explained_variance = 0.30996796217883216
# Significant!
# For features ('x2', 'x99', 'x33') with explained_variance = 0.4267930200142553
# Significant!
# For features ('x2', 'x99', 'x148') with explained_variance = 0.3018796824336703
# Significant!
# For features ('x2', 'x99', 'x194') with explained_variance = 0.30833551306579154
# Significant!
# For features ('x2', 'x99', 'x150') with explained_variance = 0.3018119455333585
# Significant!
# For features ('x2', 'x99', 'x195') with explained_variance = 0.30540851447014916
# Significant!
# For features ('x2', 'x99', 'x61') with explained_variance = 0.34925272484235625
# Significant!
# For features ('x2', 'x99', 'x58') with explained_variance = 0.36326177599652876
# Significant!
# For features ('x2', 'x99', 'x9') with explained_variance = 0.36496766179939033
# Significant!
# For features ('x2', 'x99', 'x152') with explained_variance = 0.3023522526658785
# Significant!
# For features ('x2', 'x99', 'x43') with explained_variance = 0.31638500064588265
# Significant!
# For features ('x2', 'x99', 'x63') with explained_variance = 0.37366738997097165
# Significant!
# For features ('x2', 'x99', 'x213') with explained_variance = 0.3014707358214894
# Significant!
# For features ('x2', 'x99', 'x48') with explained_variance = 0.30056004380654144
# Significant!
# For features ('x2', 'x50', 'x23') with explained_variance = 0.31498440460415655
# Significant!
# For features ('x2', 'x50', 'x33') with explained_variance = 0.4002579082788135
# Significant!
# For features ('x2', 'x188', 'x33') with explained_variance = 0.38383707190833816
# Significant!
# For features ('x2', 'x188', 'x159') with explained_variance = 0.3331170550844134
# Significant!
# For features ('x2', 'x45', 'x23') with explained_variance = 0.3430044043565742
# Significant!
# For features ('x2', 'x45', 'x33') with explained_variance = 0.39318825340496344
# Significant!
# For features ('x2', 'x45', 'x159') with explained_variance = 0.31866422192783145
# Significant!
# For features ('x2', 'x42', 'x33') with explained_variance = 0.3850416248468164
# Significant!
# For features ('x2', 'x42', 'x159') with explained_variance = 0.3297551737784431
# Significant!
# For features ('x2', 'x193', 'x33') with explained_variance = 0.38374409084170413
# Significant!
# For features ('x2', 'x193', 'x159') with explained_variance = 0.3336205819419626
# Significant!
# For features ('x2', 'x71', 'x33') with explained_variance = 0.39744260779762663
# Significant!
# For features ('x2', 'x71', 'x102') with explained_variance = 0.3883057804731683
# Significant!
# For features ('x2', 'x71', 'x98') with explained_variance = 0.3457869603577688
# Significant!
# For features ('x2', 'x71', 'x159') with explained_variance = 0.3509484906374469
# Significant!
# For features ('x2', 'x23', 'x149') with explained_variance = 0.3541893066374655
# Significant!
# For features ('x2', 'x23', 'x39') with explained_variance = 0.33291850617941277
# Significant!
# For features ('x2', 'x23', 'x33') with explained_variance = 0.5044080353770526
# Significant!
# For features ('x2', 'x23', 'x102') with explained_variance = 0.5007091273233458
# Significant!
# For features ('x2', 'x23', 'x98') with explained_variance = 0.4609440571776716
# Significant!
# For features ('x2', 'x23', 'x162') with explained_variance = 0.4435842701941201
# Significant!
# For features ('x2', 'x23', 'x159') with explained_variance = 0.5310813959573901
# Significant!
# For features ('x2', 'x23', 'x9') with explained_variance = 0.31472293358534664
# Significant!
# For features ('x2', 'x23', 'x43') with explained_variance = 0.34033525998350356
# Significant!
# For features ('x2', 'x23', 'x173') with explained_variance = 0.38875893902286557
# Significant!
# For features ('x2', 'x23', 'x158') with explained_variance = 0.3572983970392488
# Significant!
# For features ('x2', 'x23', 'x177') with explained_variance = 0.3979582283842117
# Significant!
# For features ('x2', 'x149', 'x33') with explained_variance = 0.3893289579804894
# Significant!
# For features ('x2', 'x149', 'x159') with explained_variance = 0.3450193305384027
# Significant!
# For features ('x2', 'x6', 'x33') with explained_variance = 0.31865826015787335
# Significant!
# For features ('x2', 'x6', 'x102') with explained_variance = 0.3900465710653039
# Significant!
# For features ('x2', 'x6', 'x98') with explained_variance = 0.33914771782314357
# Significant!
# For features ('x2', 'x6', 'x159') with explained_variance = 0.35568312016635784
# Significant!
# For features ('x2', 'x5', 'x33') with explained_variance = 0.3668713669010681
# Significant!
# For features ('x2', 'x39', 'x33') with explained_variance = 0.3600561667457211
# Significant!
# For features ('x2', 'x39', 'x102') with explained_variance = 0.33228700705280545
# Significant!
# For features ('x2', 'x39', 'x159') with explained_variance = 0.31812733007939265
# Significant!
# For features ('x2', 'x39', 'x7') with explained_variance = 0.3127888552445359
# Significant!
# For features ('x2', 'x175', 'x33') with explained_variance = 0.36382486447292106
# Significant!
# For features ('x2', 'x175', 'x102') with explained_variance = 0.357297925184911
# Significant!
# For features ('x2', 'x175', 'x162') with explained_variance = 0.31465796222808123
# Significant!
# For features ('x2', 'x67', 'x33') with explained_variance = 0.4023364181405024
# Significant!
# For features ('x2', 'x67', 'x102') with explained_variance = 0.3178412138984406
# Significant!
# For features ('x2', 'x67', 'x159') with explained_variance = 0.32212749470558344
# Significant!
# For features ('x2', 'x41', 'x33') with explained_variance = 0.38123486543393204
# Significant!
# For features ('x2', 'x33', 'x148') with explained_variance = 0.3858480919863445
# Significant!
# For features ('x2', 'x33', 'x194') with explained_variance = 0.38544649067580605
# Significant!
# For features ('x2', 'x33', 'x102') with explained_variance = 0.43176541602663787
# Significant!
# For features ('x2', 'x33', 'x150') with explained_variance = 0.38581410370449293
# Significant!
# For features ('x2', 'x33', 'x98') with explained_variance = 0.42775128518283134
# Significant!
# For features ('x2', 'x33', 'x162') with explained_variance = 0.3976100799712694
# Significant!
# For features ('x2', 'x33', 'x159') with explained_variance = 0.4124307198006809
# Significant!
# For features ('x2', 'x33', 'x195') with explained_variance = 0.3851049709649598
# Significant!
# For features ('x2', 'x33', 'x61') with explained_variance = 0.39625551528254166
# Significant!
# For features ('x2', 'x33', 'x58') with explained_variance = 0.3919012378185978
# Significant!
# For features ('x2', 'x33', 'x9') with explained_variance = 0.3455201262683006
# Significant!
# For features ('x2', 'x33', 'x152') with explained_variance = 0.38641487031535426
# Significant!
# For features ('x2', 'x33', 'x43') with explained_variance = 0.3352714074137981
# Significant!
# For features ('x2', 'x33', 'x173') with explained_variance = 0.36452335227294697
# Significant!
# For features ('x2', 'x33', 'x158') with explained_variance = 0.4340342831723524
# Significant!
# For features ('x2', 'x33', 'x177') with explained_variance = 0.4160845956673347
# Significant!
# For features ('x2', 'x33', 'x63') with explained_variance = 0.3935878020443938
# Significant!
# For features ('x2', 'x33', 'x160') with explained_variance = 0.42813603331697625
# Significant!
# For features ('x2', 'x33', 'x213') with explained_variance = 0.38503077492336335
# Significant!
# For features ('x2', 'x33', 'x3') with explained_variance = 0.35677125232756096
# Significant!
# For features ('x2', 'x33', 'x7') with explained_variance = 0.35355863503737994
# Significant!
# For features ('x2', 'x33', 'x48') with explained_variance = 0.38610454778651804
# Significant!
# For features ('x2', 'x148', 'x159') with explained_variance = 0.3324238094432417
# Significant!
# For features ('x2', 'x194', 'x159') with explained_variance = 0.3414538886000208
# Significant!
# For features ('x2', 'x102', 'x159') with explained_variance = 0.3011496031075636
# Significant!
# For features ('x2', 'x102', 'x61') with explained_variance = 0.3735211290450475
# Significant!
# For features ('x2', 'x102', 'x58') with explained_variance = 0.32024973812597957
# Significant!
# For features ('x2', 'x102', 'x9') with explained_variance = 0.3521369431150461
# Significant!
# For features ('x2', 'x102', 'x63') with explained_variance = 0.3529688466150367
# Significant!
# For features ('x2', 'x102', 'x3') with explained_variance = 0.30064030656939766
# Significant!
# For features ('x2', 'x150', 'x159') with explained_variance = 0.32975461700041986
# Significant!
# For features ('x2', 'x98', 'x159') with explained_variance = 0.316670082518986
# Significant!
# For features ('x2', 'x98', 'x61') with explained_variance = 0.3333132637775057
# Significant!
# For features ('x2', 'x98', 'x58') with explained_variance = 0.3159610950858794
# Significant!
# For features ('x2', 'x98', 'x9') with explained_variance = 0.31962341091556096
# Significant!
# For features ('x2', 'x98', 'x63') with explained_variance = 0.3392371765701562
# Significant!
# For features ('x2', 'x159', 'x195') with explained_variance = 0.3337990681601069
# Significant!
# For features ('x2', 'x159', 'x61') with explained_variance = 0.32111802831211583
# Significant!
# For features ('x2', 'x159', 'x58') with explained_variance = 0.35415603915561167
# Significant!
# For features ('x2', 'x159', 'x9') with explained_variance = 0.3784844303809701
# Significant!
# For features ('x2', 'x159', 'x152') with explained_variance = 0.3306342754954038
# Significant!
# For features ('x2', 'x159', 'x43') with explained_variance = 0.3386668364277386
# Significant!
# For features ('x2', 'x159', 'x173') with explained_variance = 0.312194868231836
# Significant!
# For features ('x2', 'x159', 'x63') with explained_variance = 0.35586204858751025
# Significant!
# For features ('x2', 'x159', 'x213') with explained_variance = 0.32966259825373934
# Significant!
# For features ('x2', 'x159', 'x48') with explained_variance = 0.3297296755146902
# Significant!
# For features ('x4', 'x27', 'x99') with explained_variance = 0.30831313939748906
# Significant!
# For features ('x4', 'x27', 'x50') with explained_variance = 0.3823938018985604
# Significant!
# For features ('x4', 'x27', 'x188') with explained_variance = 0.31999701312503476
# Significant!
# For features ('x4', 'x27', 'x45') with explained_variance = 0.30882140027616795
# Significant!
# For features ('x4', 'x27', 'x42') with explained_variance = 0.3279840922192843
# Significant!
# For features ('x4', 'x27', 'x193') with explained_variance = 0.3119041804313947
# Significant!
# For features ('x4', 'x27', 'x23') with explained_variance = 0.3349327284817355
# Significant!
# For features ('x4', 'x27', 'x149') with explained_variance = 0.3164437509252356
# Significant!
# For features ('x4', 'x27', 'x6') with explained_variance = 0.3097852766655621
# Significant!
# For features ('x4', 'x27', 'x5') with explained_variance = 0.309785286841901
# Significant!
# For features ('x4', 'x27', 'x39') with explained_variance = 0.356954689440166
# Significant!
# For features ('x4', 'x27', 'x41') with explained_variance = 0.34335747807294226
# Significant!
# For features ('x4', 'x27', 'x33') with explained_variance = 0.3148012002702957
# Significant!
# For features ('x4', 'x27', 'x148') with explained_variance = 0.3142928142144241
# Significant!
# For features ('x4', 'x27', 'x194') with explained_variance = 0.3045840708977183
# Significant!
# For features ('x4', 'x27', 'x102') with explained_variance = 0.40119635170966417
# Significant!
# For features ('x4', 'x27', 'x150') with explained_variance = 0.33061610595254115
# Significant!
# For features ('x4', 'x27', 'x98') with explained_variance = 0.3436112869449661
# Significant!
# For features ('x4', 'x27', 'x195') with explained_variance = 0.3221341548578435
# Significant!
# For features ('x4', 'x27', 'x152') with explained_variance = 0.333467852981874
# Significant!
# For features ('x4', 'x27', 'x158') with explained_variance = 0.38178648330683285
# Significant!
# For features ('x4', 'x27', 'x160') with explained_variance = 0.38586675726468733
# Significant!
# For features ('x4', 'x27', 'x213') with explained_variance = 0.32105142283564364
# Significant!
# For features ('x4', 'x27', 'x3') with explained_variance = 0.3097852805438309
# Significant!
# For features ('x4', 'x27', 'x7') with explained_variance = 0.30116119810980263
# Significant!
# For features ('x4', 'x27', 'x48') with explained_variance = 0.3271019202558301
# Significant!
# For features ('x4', 'x99', 'x23') with explained_variance = 0.49754949931830206
# Significant!
# For features ('x4', 'x50', 'x23') with explained_variance = 0.33237175242669786
# Significant!
# For features ('x4', 'x50', 'x33') with explained_variance = 0.3082718895200677
# Significant!
# For features ('x4', 'x188', 'x33') with explained_variance = 0.33307895085787953
# Significant!
# For features ('x4', 'x45', 'x23') with explained_variance = 0.32667407227961676
# Significant!
# For features ('x4', 'x45', 'x33') with explained_variance = 0.3096986947945846
# Significant!
# For features ('x4', 'x42', 'x33') with explained_variance = 0.33874081024924746
# Significant!
# For features ('x4', 'x193', 'x33') with explained_variance = 0.3282029536386766
# Significant!
# For features ('x4', 'x71', 'x23') with explained_variance = 0.3111460898423793
# Significant!
# For features ('x4', 'x23', 'x149') with explained_variance = 0.33912378881030963
# Significant!
# For features ('x4', 'x23', 'x6') with explained_variance = 0.3361464130886277
# Significant!
# For features ('x4', 'x23', 'x5') with explained_variance = 0.3361464135229134
# Significant!
# For features ('x4', 'x23', 'x39') with explained_variance = 0.36734791444479975
# Significant!
# For features ('x4', 'x23', 'x175') with explained_variance = 0.3047167319329406
# Significant!
# For features ('x4', 'x23', 'x67') with explained_variance = 0.3254678921777419
# Significant!
# For features ('x4', 'x23', 'x41') with explained_variance = 0.31384342253905523
# Significant!
# For features ('x4', 'x23', 'x33') with explained_variance = 0.4809057738644261
# Significant!
# For features ('x4', 'x23', 'x102') with explained_variance = 0.4949544317480621
# Significant!
# For features ('x4', 'x23', 'x98') with explained_variance = 0.4681075826623283
# Significant!
# For features ('x4', 'x23', 'x162') with explained_variance = 0.42814731964810476
# Significant!
# For features ('x4', 'x23', 'x159') with explained_variance = 0.5194891578484702
# Significant!
# For features ('x4', 'x23', 'x61') with explained_variance = 0.31086133416651285
# Significant!
# For features ('x4', 'x23', 'x58') with explained_variance = 0.3117758556899611
# Significant!
# For features ('x4', 'x23', 'x9') with explained_variance = 0.3700782819875189
# Significant!
# For features ('x4', 'x23', 'x43') with explained_variance = 0.3299073028368048
# Significant!
# For features ('x4', 'x23', 'x173') with explained_variance = 0.40154262853068906
# Significant!
# For features ('x4', 'x23', 'x158') with explained_variance = 0.3939300872440062
# Significant!
# For features ('x4', 'x23', 'x177') with explained_variance = 0.3914656495738471
# Significant!
# For features ('x4', 'x23', 'x63') with explained_variance = 0.3162146970638118
# Significant!
# For features ('x4', 'x23', 'x160') with explained_variance = 0.3228575482157684
# Significant!
# For features ('x4', 'x23', 'x3') with explained_variance = 0.33614641381054516
# Significant!
# For features ('x4', 'x149', 'x33') with explained_variance = 0.3288039740942844
# Significant!
# For features ('x4', 'x67', 'x33') with explained_variance = 0.3201194154783482
# Significant!
# For features ('x4', 'x33', 'x148') with explained_variance = 0.32484831944205034
# Significant!
# For features ('x4', 'x33', 'x194') with explained_variance = 0.3279197573206759
# Significant!
# For features ('x4', 'x33', 'x150') with explained_variance = 0.3386322090105386
# Significant!
# For features ('x4', 'x33', 'x159') with explained_variance = 0.3013448836985754
# Significant!
# For features ('x4', 'x33', 'x195') with explained_variance = 0.33597262757648805
# Significant!
# For features ('x4', 'x33', 'x61') with explained_variance = 0.31326354810228746
# Significant!
# For features ('x4', 'x33', 'x58') with explained_variance = 0.31341449761378265
# Significant!
# For features ('x4', 'x33', 'x152') with explained_variance = 0.33930792882787214
# Significant!
# For features ('x4', 'x33', 'x177') with explained_variance = 0.3336390206251683
# Significant!
# For features ('x4', 'x33', 'x63') with explained_variance = 0.3155920998175069
# Significant!
# For features ('x4', 'x33', 'x213') with explained_variance = 0.3350991887966904
# Significant!
# For features ('x4', 'x33', 'x48') with explained_variance = 0.3492713154105433
# Significant!
# For features ('x4', 'x102', 'x7') with explained_variance = 0.3230160249346946
# Significant!
# For features ('x27', 'x99', 'x50') with explained_variance = 0.4115188674516058
# Significant!
# For features ('x27', 'x99', 'x188') with explained_variance = 0.3976374794985101
# Significant!
# For features ('x27', 'x99', 'x45') with explained_variance = 0.3801127382965449
# Significant!
# For features ('x27', 'x99', 'x42') with explained_variance = 0.40056373509772125
# Significant!
# For features ('x27', 'x99', 'x193') with explained_variance = 0.39269308491884053
# Significant!
# For features ('x27', 'x99', 'x71') with explained_variance = 0.33080973802108044
# Significant!
# For features ('x27', 'x99', 'x23') with explained_variance = 0.5106206401945025
# Significant!
# For features ('x27', 'x99', 'x149') with explained_variance = 0.3861693760810615
# Significant!
# For features ('x27', 'x99', 'x6') with explained_variance = 0.3370481895656197
# Significant!
# For features ('x27', 'x99', 'x5') with explained_variance = 0.31544881335923514
# Significant!
# For features ('x27', 'x99', 'x39') with explained_variance = 0.3298239651448235
# Significant!
# For features ('x27', 'x99', 'x175') with explained_variance = 0.3657939247887831
# Significant!
# For features ('x27', 'x99', 'x67') with explained_variance = 0.36167381775920354
# Significant!
# For features ('x27', 'x99', 'x41') with explained_variance = 0.37938093117585486
# Significant!
# For features ('x27', 'x99', 'x148') with explained_variance = 0.3900726981451656
# Significant!
# For features ('x27', 'x99', 'x194') with explained_variance = 0.38533711853500613
# Significant!
# ...
# For features ('x23', 'x194', 'x61') with explained_variance = 0.30069463453252016
# Significant!
# For features ('x23', 'x194', 'x9') with explained_variance = 0.3003908496281187
# Significant!
# For features ('x23', 'x194', 'x173') with explained_variance = 0.35441721318317504
# Significant!
# For features ('x23', 'x194', 'x158') with explained_variance = 0.3265847816818709
# Significant!
# For features ('x23', 'x194', 'x177') with explained_variance = 0.36203373880011497
# Significant!
# For features ('x23', 'x194', 'x63') with explained_variance = 0.3115545204663701
# Significant!
# For features ('x23', 'x194', 'x213') with explained_variance = 0.33390235405149093
# Significant!
# For features ('x23', 'x194', 'x48') with explained_variance = 0.33830640086907393
# Significant!
# For features ('x23', 'x102', 'x150') with explained_variance = 0.4864931647059999
# Significant!
# For features ('x23', 'x102', 'x98') with explained_variance = 0.33164438777656147
# Significant!
# For features ('x23', 'x102', 'x162') with explained_variance = 0.45357889154301534
# Significant!
# For features ('x23', 'x102', 'x159') with explained_variance = 0.5147189779644427
# Significant!
# For features ('x23', 'x102', 'x195') with explained_variance = 0.4842641327160598
# Significant!
# For features ('x23', 'x102', 'x61') with explained_variance = 0.5326020899673604
# Significant!
# For features ('x23', 'x102', 'x58') with explained_variance = 0.49439302238552846
# Significant!
# For features ('x23', 'x102', 'x9') with explained_variance = 0.5347101878670559
# Significant!
# For features ('x23', 'x102', 'x152') with explained_variance = 0.4860114119412513
# Significant!
# For features ('x23', 'x102', 'x43') with explained_variance = 0.47602387658601203
# Significant!
# For features ('x23', 'x102', 'x173') with explained_variance = 0.471522986517698
# Significant!
# For features ('x23', 'x102', 'x158') with explained_variance = 0.386054949103904
# Significant!
# For features ('x23', 'x102', 'x177') with explained_variance = 0.4429332150446458
# Significant!
# For features ('x23', 'x102', 'x63') with explained_variance = 0.5203414039280998
# Significant!
# For features ('x23', 'x102', 'x160') with explained_variance = 0.4597122713402326
# Significant!
# For features ('x23', 'x102', 'x213') with explained_variance = 0.4863082793450591
# Significant!
# For features ('x23', 'x102', 'x3') with explained_variance = 0.5161824856362918
# Significant!
# For features ('x23', 'x102', 'x7') with explained_variance = 0.46446947069471767
# Significant!
# For features ('x23', 'x102', 'x48') with explained_variance = 0.4882029233855841
# Significant!
# For features ('x23', 'x150', 'x98') with explained_variance = 0.4602440102031603
# Significant!
# For features ('x23', 'x150', 'x162') with explained_variance = 0.4354937213272274
# Significant!
# For features ('x23', 'x150', 'x159') with explained_variance = 0.5257209904069572
# Significant!
# For features ('x23', 'x150', 'x152') with explained_variance = 0.4292153197044312
# Significant!
# For features ('x23', 'x150', 'x43') with explained_variance = 0.30817137296270014
# Significant!
# For features ('x23', 'x150', 'x173') with explained_variance = 0.36141258181850994
# Significant!
# For features ('x23', 'x150', 'x158') with explained_variance = 0.34340501747469787
# Significant!
# For features ('x23', 'x150', 'x177') with explained_variance = 0.3734077904632321
# Significant!
# For features ('x23', 'x150', 'x48') with explained_variance = 0.3166738156051968
# Significant!
# For features ('x23', 'x98', 'x162') with explained_variance = 0.4327058762284162
# Significant!
# For features ('x23', 'x98', 'x159') with explained_variance = 0.5174294396152049
# Significant!
# For features ('x23', 'x98', 'x195') with explained_variance = 0.45699753931287157
# Significant!
# For features ('x23', 'x98', 'x61') with explained_variance = 0.4893084509620789
# Significant!
# For features ('x23', 'x98', 'x58') with explained_variance = 0.4756855463549291
# Significant!
# For features ('x23', 'x98', 'x9') with explained_variance = 0.5011720709419303
# Significant!
# For features ('x23', 'x98', 'x152') with explained_variance = 0.46003627328086816
# Significant!
# For features ('x23', 'x98', 'x43') with explained_variance = 0.44405381743592204
# Significant!
# For features ('x23', 'x98', 'x173') with explained_variance = 0.42740555866913466
# Significant!
# For features ('x23', 'x98', 'x158') with explained_variance = 0.3589228104629432
# Significant!
# For features ('x23', 'x98', 'x177') with explained_variance = 0.44592653672409155
# Significant!
# For features ('x23', 'x98', 'x63') with explained_variance = 0.49792414422572556
# Significant!
# For features ('x23', 'x98', 'x160') with explained_variance = 0.36158348214299246
# Significant!
# For features ('x23', 'x98', 'x213') with explained_variance = 0.4602869410176117
# Significant!
# For features ('x23', 'x98', 'x3') with explained_variance = 0.4577616800565207
# Significant!
# For features ('x23', 'x98', 'x7') with explained_variance = 0.4343516910627677
# Significant!
# For features ('x23', 'x98', 'x48') with explained_variance = 0.4627419403712156
# Significant!
# For features ('x23', 'x162', 'x159') with explained_variance = 0.5256943993968612
# Significant!
# For features ('x23', 'x162', 'x195') with explained_variance = 0.4331851183585198
# Significant!
# For features ('x23', 'x162', 'x61') with explained_variance = 0.42930342323843124
# Significant!
# For features ('x23', 'x162', 'x58') with explained_variance = 0.43539805260941006
# Significant!
# For features ('x23', 'x162', 'x9') with explained_variance = 0.4683183007383077
# Significant!
# For features ('x23', 'x162', 'x152') with explained_variance = 0.435453094211106
# Significant!
# For features ('x23', 'x162', 'x43') with explained_variance = 0.4237336019250052
# Significant!
# For features ('x23', 'x162', 'x173') with explained_variance = 0.4391250834874742
# Significant!
# For features ('x23', 'x162', 'x177') with explained_variance = 0.4235062513839857
# Significant!
# For features ('x23', 'x162', 'x63') with explained_variance = 0.44763937483828
# Significant!
# For features ('x23', 'x162', 'x160') with explained_variance = 0.39151351659104494
# Significant!
# For features ('x23', 'x162', 'x213') with explained_variance = 0.4350460417462171
# Significant!
# For features ('x23', 'x162', 'x3') with explained_variance = 0.4547199035099557
# Significant!
# For features ('x23', 'x162', 'x7') with explained_variance = 0.408738618152948
# Significant!
# For features ('x23', 'x162', 'x48') with explained_variance = 0.4370590156280686
# Significant!
# For features ('x23', 'x159', 'x195') with explained_variance = 0.5256180631293088
# Significant!
# For features ('x23', 'x159', 'x61') with explained_variance = 0.49451621826888725
# Significant!
# For features ('x23', 'x159', 'x58') with explained_variance = 0.5256825024984408
# Significant!
# For features ('x23', 'x159', 'x9') with explained_variance = 0.5645275360282197
# Significant!
# For features ('x23', 'x159', 'x152') with explained_variance = 0.5260533876383479
# Significant!
# For features ('x23', 'x159', 'x43') with explained_variance = 0.5233294553830732
# Significant!
# For features ('x23', 'x159', 'x173') with explained_variance = 0.5188348203616728
# Significant!
# For features ('x23', 'x159', 'x158') with explained_variance = 0.49297248542617067
# Significant!
# For features ('x23', 'x159', 'x177') with explained_variance = 0.5240472930416271
# Significant!
# For features ('x23', 'x159', 'x63') with explained_variance = 0.529110827076638
# Significant!
# For features ('x23', 'x159', 'x160') with explained_variance = 0.5032669704632685
# Significant!
# For features ('x23', 'x159', 'x213') with explained_variance = 0.5252209795855173
# Significant!
# For features ('x23', 'x159', 'x3') with explained_variance = 0.5248781192642302
# Significant!
# For features ('x23', 'x159', 'x7') with explained_variance = 0.5036198421120257
# Significant!
# For features ('x23', 'x159', 'x48') with explained_variance = 0.5254364367024307
# Significant!
# For features ('x23', 'x195', 'x43') with explained_variance = 0.3137690872643092
# Significant!
# For features ('x23', 'x195', 'x173') with explained_variance = 0.35858950630271214
# Significant!
# For features ('x23', 'x195', 'x158') with explained_variance = 0.33855812714448313
# Significant!
# For features ('x23', 'x195', 'x177') with explained_variance = 0.36994975095724103
# Significant!
# For features ('x23', 'x61', 'x43') with explained_variance = 0.3190201519892315
# Significant!
# For features ('x23', 'x61', 'x173') with explained_variance = 0.38894757557105764
# Significant!
# For features ('x23', 'x61', 'x158') with explained_variance = 0.3775997736827151
# Significant!
# For features ('x23', 'x61', 'x177') with explained_variance = 0.3938775365342822
# Significant!
# For features ('x23', 'x58', 'x43') with explained_variance = 0.3199730851567419
# Significant!
# For features ('x23', 'x58', 'x173') with explained_variance = 0.3850094207274329
# Significant!
# For features ('x23', 'x58', 'x158') with explained_variance = 0.3639519556235241
# Significant!
# For features ('x23', 'x58', 'x177') with explained_variance = 0.40825474439014914
# Significant!
# For features ('x23', 'x9', 'x43') with explained_variance = 0.3160166918565912
# Significant!
# For features ('x23', 'x9', 'x173') with explained_variance = 0.40739454308570106
# Significant!
# For features ('x23', 'x9', 'x158') with explained_variance = 0.39969657152955473
# Significant!
# For features ('x23', 'x9', 'x177') with explained_variance = 0.4156425986404441
# Significant!
# For features ('x23', 'x9', 'x160') with explained_variance = 0.3006320520799405
# Significant!
# For features ('x23', 'x9', 'x3') with explained_variance = 0.34561196496575064
# Significant!
# For features ('x23', 'x9', 'x7') with explained_variance = 0.37395069369071327
# Significant!
# For features ('x23', 'x152', 'x43') with explained_variance = 0.30785027605626036
# Significant!
# For features ('x23', 'x152', 'x173') with explained_variance = 0.36134460889593556
# Significant!
# For features ('x23', 'x152', 'x158') with explained_variance = 0.34305553533136135
# Significant!
# For features ('x23', 'x152', 'x177') with explained_variance = 0.3743031132892035
# Significant!
# For features ('x23', 'x152', 'x213') with explained_variance = 0.33080830381921456
# Significant!
# For features ('x23', 'x152', 'x48') with explained_variance = 0.33565240382116385
# Significant!
# For features ('x23', 'x43', 'x173') with explained_variance = 0.3468407669681241
# Significant!
# For features ('x23', 'x43', 'x158') with explained_variance = 0.318517212510701
# Significant!
# For features ('x23', 'x43', 'x177') with explained_variance = 0.37599214662241154
# Significant!
# For features ('x23', 'x43', 'x63') with explained_variance = 0.3288010603309951
# Significant!
# For features ('x23', 'x43', 'x213') with explained_variance = 0.31074831369582145
# Significant!
# For features ('x23', 'x43', 'x3') with explained_variance = 0.3234765658339343
# Significant!
# For features ('x23', 'x43', 'x7') with explained_variance = 0.32286927242265334
# Significant!
# For features ('x23', 'x43', 'x48') with explained_variance = 0.31392849597326034
# Significant!
# For features ('x23', 'x173', 'x177') with explained_variance = 0.3603764970869661
# Significant!
# For features ('x23', 'x173', 'x63') with explained_variance = 0.40069311415265896
# Significant!
# For features ('x23', 'x173', 'x160') with explained_variance = 0.34913177348480706
# Significant!
# For features ('x23', 'x173', 'x213') with explained_variance = 0.36050078975673816
# Significant!
# For features ('x23', 'x173', 'x3') with explained_variance = 0.3846449313011483
# Significant!
# For features ('x23', 'x173', 'x7') with explained_variance = 0.3673433039722133
# Significant!
# For features ('x23', 'x173', 'x48') with explained_variance = 0.36278293936567535
# Significant!
# For features ('x23', 'x158', 'x63') with explained_variance = 0.3860816828552417
# Significant!
# For features ('x23', 'x158', 'x160') with explained_variance = 0.4857786691069818
# Significant!
# For features ('x23', 'x158', 'x213') with explained_variance = 0.34208455407435645
# Significant!
# For features ('x23', 'x158', 'x3') with explained_variance = 0.3586865621511651
# Significant!
# For features ('x23', 'x158', 'x7') with explained_variance = 0.3369839789530601
# Significant!
# For features ('x23', 'x158', 'x48') with explained_variance = 0.3503365804667941
# Significant!
# For features ('x23', 'x177', 'x63') with explained_variance = 0.41796002309086544
# Significant!
# For features ('x23', 'x177', 'x160') with explained_variance = 0.3752461099877493
# Significant!
# For features ('x23', 'x177', 'x213') with explained_variance = 0.3706331057117157
# Significant!
# For features ('x23', 'x177', 'x3') with explained_variance = 0.4057659890440405
# Significant!
# For features ('x23', 'x177', 'x7') with explained_variance = 0.3785157413762997
# Significant!
# For features ('x23', 'x177', 'x48') with explained_variance = 0.373845183882608
# Significant!
# For features ('x23', 'x3', 'x7') with explained_variance = 0.3205359914911038
# Significant!
# For features ('x149', 'x39', 'x33') with explained_variance = 0.3076451326535551
# Significant!
# For features ('x149', 'x33', 'x7') with explained_variance = 0.33306640987106517
# Significant!
# For features ('x5', 'x41', 'x33') with explained_variance = 0.34549213783364213
# Significant!
# For features ('x5', 'x33', 'x150') with explained_variance = 0.3032683064240668
# Significant!
# For features ('x5', 'x33', 'x152') with explained_variance = 0.3037519143396137
# Significant!
# For features ('x5', 'x33', 'x177') with explained_variance = 0.3021320645174343
# Significant!
# For features ('x5', 'x33', 'x48') with explained_variance = 0.316359157489543
# Significant!
# For features ('x39', 'x41', 'x7') with explained_variance = 0.38601523856067765
# Significant!
# For features ('x39', 'x33', 'x148') with explained_variance = 0.31958876612382375
# Significant!
# For features ('x39', 'x33', 'x194') with explained_variance = 0.31856379596516426
# Significant!
# For features ('x39', 'x33', 'x150') with explained_variance = 0.34171175427138983
# Significant!
# For features ('x39', 'x33', 'x195') with explained_variance = 0.3360881138568675
# Significant!
# For features ('x39', 'x33', 'x152') with explained_variance = 0.3434008082110129
# Significant!
# For features ('x39', 'x33', 'x213') with explained_variance = 0.33669357824235546
# Significant!
# For features ('x39', 'x33', 'x48') with explained_variance = 0.35048737981988837
# Significant!
# For features ('x39', 'x102', 'x7') with explained_variance = 0.3306302940826491
# Significant!
# For features ('x39', 'x98', 'x7') with explained_variance = 0.30017031900331553
# Significant!
# For features ('x39', 'x159', 'x7') with explained_variance = 0.3034060863410847
# Significant!
# For features ('x41', 'x33', 'x3') with explained_variance = 0.39081393400627346
# Significant!
# For features ('x41', 'x33', 'x7') with explained_variance = 0.3555604271136476
# Significant!
# For features ('x33', 'x148', 'x7') with explained_variance = 0.32732754675001857
# Significant!
# For features ('x33', 'x148', 'x48') with explained_variance = 0.3906121934044433
# Significant!
# For features ('x33', 'x194', 'x7') with explained_variance = 0.3250857199462442
# Significant!
# For features ('x33', 'x102', 'x7') with explained_variance = 0.30490934295000677
# Significant!
# For features ('x33', 'x150', 'x7') with explained_variance = 0.34254618327734143
# Significant!
# For features ('x33', 'x98', 'x7') with explained_variance = 0.3178705437559883
# Significant!
# For features ('x33', 'x195', 'x7') with explained_variance = 0.3339395680978368
# Significant!
# For features ('x33', 'x195', 'x48') with explained_variance = 0.4143596200872043
# Significant!
# For features ('x33', 'x152', 'x7') with explained_variance = 0.34384404153128556
# Significant!
# For features ('x33', 'x158', 'x7') with explained_variance = 0.3444812764842659
# Significant!
# For features ('x33', 'x160', 'x7') with explained_variance = 0.34319501154880305
# Significant!
# For features ('x33', 'x213', 'x7') with explained_variance = 0.33736369468732735
# Significant!
# For features ('x33', 'x213', 'x48') with explained_variance = 0.3810406780595348
# Significant!
# For features ('x33', 'x7', 'x48') with explained_variance = 0.34842585898002987

# %%
len(List_2cvd_3_expv)
# Out:
# 1506

# %%
List2_2cvd_3_expv,List2_2cvd_2_expv,List2_2cvd_0_expv = combnfeats_MLR_evaby_crossval_metric(List_2cvd_3_expv,df_x,df_y,5,model,'explained_variance',0.4)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x32', 'x23') with explained_variance = 0.4334291667090694
# Significant!
# For features ('x186', 'x8', 'x23') with explained_variance = 0.40631121813232196
# Significant!
# For features ('x186', 'x2', 'x33') with explained_variance = 0.4067669012430139
# Significant!
# For features ('x186', 'x27', 'x102') with explained_variance = 0.43318326473405044
# Significant!
# For features ('x186', 'x27', 'x98') with explained_variance = 0.40072029041423934
# Significant!
# For features ('x186', 'x99', 'x23') with explained_variance = 0.512399412860655
# Significant!
# For features ('x186', 'x50', 'x23') with explained_variance = 0.43945569660387945
# Significant!
# For features ('x186', 'x45', 'x23') with explained_variance = 0.41796816272707193
# Significant!
# For features ('x186', 'x23', 'x33') with explained_variance = 0.5090477312300923
# Significant!
# For features ('x186', 'x23', 'x102') with explained_variance = 0.5546132292933643
# Significant!
# For features ('x186', 'x23', 'x98') with explained_variance = 0.5177158478282917
# Significant!
# For features ('x186', 'x23', 'x162') with explained_variance = 0.4793884978990082
# Significant!
# For features ('x186', 'x23', 'x159') with explained_variance = 0.5276824209001674
# Significant!
# For features ('x186', 'x23', 'x43') with explained_variance = 0.4073186954223795
# Significant!
# For features ('x186', 'x23', 'x173') with explained_variance = 0.43547579300495426
# Significant!
# For features ('x186', 'x23', 'x158') with explained_variance = 0.4526400080717563
# Significant!
# For features ('x186', 'x23', 'x177') with explained_variance = 0.4211421042620616
# Significant!
# For features ('x186', 'x23', 'x160') with explained_variance = 0.4121989427622377
# Significant!
# For features ('x49', 'x32', 'x23') with explained_variance = 0.42073642500032465
# Significant!
# For features ('x49', 'x27', 'x99') with explained_variance = 0.4083217258655143
# Significant!
# For features ('x49', 'x27', 'x102') with explained_variance = 0.4307847425357001
# Significant!
# For features ('x49', 'x27', 'x98') with explained_variance = 0.41308451471575347
# Significant!
# For features ('x49', 'x99', 'x23') with explained_variance = 0.48920865624129445
# Significant!
# For features ('x49', 'x23', 'x33') with explained_variance = 0.5180084282086094
# Significant!
# For features ('x49', 'x23', 'x102') with explained_variance = 0.4880320534250309
# Significant!
# For features ('x49', 'x23', 'x98') with explained_variance = 0.46074780298284057
# Significant!
# For features ('x49', 'x23', 'x162') with explained_variance = 0.4377540538467398
# Significant!
# For features ('x49', 'x23', 'x159') with explained_variance = 0.525398970824002
# Significant!
# For features ('x32', 'x8', 'x23') with explained_variance = 0.41384645899855077
# Significant!
# For features ('x32', 'x2', 'x23') with explained_variance = 0.41679916628669567
# Significant!
# For features ('x32', 'x2', 'x33') with explained_variance = 0.40485285972006324
# Significant!
# For features ('x32', 'x2', 'x102') with explained_variance = 0.41455095437547607
# Significant!
# For features ('x32', 'x99', 'x23') with explained_variance = 0.586256396999459
# Significant!
# For features ('x32', 'x50', 'x23') with explained_variance = 0.4979928188365541
# Significant!
# For features ('x32', 'x188', 'x23') with explained_variance = 0.40235145006281936
# Significant!
# For features ('x32', 'x45', 'x23') with explained_variance = 0.4537909745956926
# Significant!
# For features ('x32', 'x42', 'x23') with explained_variance = 0.4065787360590363
# Significant!
# For features ('x32', 'x193', 'x23') with explained_variance = 0.40027199378368916
# Significant!
# For features ('x32', 'x71', 'x23') with explained_variance = 0.40093799385686835
# Significant!
# For features ('x32', 'x23', 'x149') with explained_variance = 0.42352655736979355
# Significant!
# For features ('x32', 'x23', 'x175') with explained_variance = 0.4656960715907985
# Significant!
# For features ('x32', 'x23', 'x41') with explained_variance = 0.41272957069814203
# Significant!
# For features ('x32', 'x23', 'x33') with explained_variance = 0.5175752580331872
# Significant!
# For features ('x32', 'x23', 'x148') with explained_variance = 0.4110449855906734
# Significant!
# For features ('x32', 'x23', 'x194') with explained_variance = 0.4001029000147991
# Significant!
# For features ('x32', 'x23', 'x102') with explained_variance = 0.6144733692071418
# Significant!
# For features ('x32', 'x23', 'x150') with explained_variance = 0.41040876303276985
# Significant!
# For features ('x32', 'x23', 'x98') with explained_variance = 0.5789274993604175
# Significant!
# For features ('x32', 'x23', 'x162') with explained_variance = 0.5383082192276298
# Significant!
# For features ('x32', 'x23', 'x159') with explained_variance = 0.5895757417912355
# Significant!
# For features ('x32', 'x23', 'x195') with explained_variance = 0.4019226412221551
# Significant!
# For features ('x32', 'x23', 'x58') with explained_variance = 0.40741712055265344
# Significant!
# For features ('x32', 'x23', 'x9') with explained_variance = 0.41360796620783746
# Significant!
# For features ('x32', 'x23', 'x152') with explained_variance = 0.4136798710670931
# Significant!
# For features ('x32', 'x23', 'x43') with explained_variance = 0.42191451621246356
# Significant!
# For features ('x32', 'x23', 'x173') with explained_variance = 0.5461730729557825
# Significant!
# For features ('x32', 'x23', 'x158') with explained_variance = 0.6113270941167871
# Significant!
# For features ('x32', 'x23', 'x177') with explained_variance = 0.47067487330417074
# Significant!
# For features ('x32', 'x23', 'x63') with explained_variance = 0.4067222918895294
# Significant!
# For features ('x32', 'x23', 'x160') with explained_variance = 0.5630864065748893
# Significant!
# For features ('x32', 'x23', 'x213') with explained_variance = 0.40451641964131557
# Significant!
# For features ('x32', 'x23', 'x3') with explained_variance = 0.40812323478904194
# Significant!
# For features ('x32', 'x23', 'x48') with explained_variance = 0.40059178339661966
# Significant!
# For features ('x8', 'x27', 'x23') with explained_variance = 0.4219231836859644
# Significant!
# For features ('x8', 'x27', 'x41') with explained_variance = 0.43261662445696897
# Significant!
# For features ('x8', 'x27', 'x102') with explained_variance = 0.40981059775224127
# Significant!
# For features ('x8', 'x99', 'x23') with explained_variance = 0.49884192761659757
# Significant!
# For features ('x8', 'x50', 'x33') with explained_variance = 0.4261174752848026
# Significant!
# For features ('x8', 'x23', 'x5') with explained_variance = 0.4209942953756071
# Significant!
# For features ('x8', 'x23', 'x33') with explained_variance = 0.44270937591015513
# Significant!
# For features ('x8', 'x23', 'x102') with explained_variance = 0.48725698239724524
# Significant!
# For features ('x8', 'x23', 'x98') with explained_variance = 0.46688024632421066
# Significant!
# For features ('x8', 'x23', 'x162') with explained_variance = 0.42226245189874784
# Significant!
# For features ('x8', 'x23', 'x159') with explained_variance = 0.5126576447491589
# Significant!
# For features ('x8', 'x23', 'x3') with explained_variance = 0.40918259119800204
# Significant!
# For features ('x8', 'x23', 'x7') with explained_variance = 0.42453832202744957
# Significant!
# For features ('x2', 'x27', 'x102') with explained_variance = 0.42148566234765594
# Significant!
# For features ('x2', 'x99', 'x23') with explained_variance = 0.4984535110685866
# Significant!
# For features ('x2', 'x99', 'x33') with explained_variance = 0.4267930200142553
# Significant!
# For features ('x2', 'x50', 'x33') with explained_variance = 0.4002579082788135
# Significant!
# For features ('x2', 'x23', 'x33') with explained_variance = 0.5044080353770526
# Significant!
# For features ('x2', 'x23', 'x102') with explained_variance = 0.5007091273233458
# Significant!
# For features ('x2', 'x23', 'x98') with explained_variance = 0.4609440571776716
# Significant!
# For features ('x2', 'x23', 'x162') with explained_variance = 0.4435842701941201
# Significant!
# For features ('x2', 'x23', 'x159') with explained_variance = 0.5310813959573901
# Significant!
# For features ('x2', 'x67', 'x33') with explained_variance = 0.4023364181405024
# Significant!
# For features ('x2', 'x33', 'x102') with explained_variance = 0.43176541602663787
# Significant!
# For features ('x2', 'x33', 'x98') with explained_variance = 0.42775128518283134
# Significant!
# For features ('x2', 'x33', 'x159') with explained_variance = 0.4124307198006809
# Significant!
# For features ('x2', 'x33', 'x158') with explained_variance = 0.4340342831723524
# Significant!
# For features ('x2', 'x33', 'x177') with explained_variance = 0.4160845956673347
# Significant!
# For features ('x2', 'x33', 'x160') with explained_variance = 0.42813603331697625
# Significant!
# For features ('x4', 'x27', 'x102') with explained_variance = 0.40119635170966417
# Significant!
# For features ('x4', 'x99', 'x23') with explained_variance = 0.49754949931830206
# Significant!
# For features ('x4', 'x23', 'x33') with explained_variance = 0.4809057738644261
# Significant!
# For features ('x4', 'x23', 'x102') with explained_variance = 0.4949544317480621
# Significant!
# For features ('x4', 'x23', 'x98') with explained_variance = 0.4681075826623283
# Significant!
# For features ('x4', 'x23', 'x162') with explained_variance = 0.42814731964810476
# Significant!
# For features ('x4', 'x23', 'x159') with explained_variance = 0.5194891578484702
# Significant!
# For features ('x4', 'x23', 'x173') with explained_variance = 0.40154262853068906
# Significant!
# For features ('x27', 'x99', 'x50') with explained_variance = 0.4115188674516058
# Significant!
# For features ('x27', 'x99', 'x42') with explained_variance = 0.40056373509772125
# Significant!
# For features ('x27', 'x99', 'x23') with explained_variance = 0.5106206401945025
# Significant!
# For features ('x27', 'x99', 'x150') with explained_variance = 0.40107926300353236
# Significant!
# For features ('x27', 'x99', 'x152') with explained_variance = 0.4022459492053529
# Significant!
# For features ('x27', 'x99', 'x48') with explained_variance = 0.40207650020099717
# Significant!
# For features ('x27', 'x50', 'x102') with explained_variance = 0.4305315339594905
# Significant!
# For features ('x27', 'x50', 'x98') with explained_variance = 0.4144831540911067
# Significant!
# For features ('x27', 'x188', 'x102') with explained_variance = 0.43081396623255663
# Significant!
# For features ('x27', 'x188', 'x98') with explained_variance = 0.40814179574868775
# Significant!
# For features ('x27', 'x188', 'x158') with explained_variance = 0.40099385100258633
# Significant!
# For features ('x27', 'x45', 'x102') with explained_variance = 0.4056781194736724
# Significant!
# For features ('x27', 'x45', 'x158') with explained_variance = 0.40140180532173925
# Significant!
# For features ('x27', 'x42', 'x102') with explained_variance = 0.43017145489692493
# Significant!
# For features ('x27', 'x42', 'x98') with explained_variance = 0.4098461068782024
# Significant!
# For features ('x27', 'x42', 'x152') with explained_variance = 0.4418576012707801
# Significant!
# For features ('x27', 'x42', 'x158') with explained_variance = 0.40155543344825606
# Significant!
# For features ('x27', 'x193', 'x102') with explained_variance = 0.42746209931027757
# Significant!
# For features ('x27', 'x193', 'x98') with explained_variance = 0.4047994585436451
# Significant!
# For features ('x27', 'x71', 'x102') with explained_variance = 0.4139883796638868
# Significant!
# For features ('x27', 'x23', 'x33') with explained_variance = 0.47713283212882074
# Significant!
# For features ('x27', 'x23', 'x102') with explained_variance = 0.5177433404050181
# Significant!
# For features ('x27', 'x23', 'x98') with explained_variance = 0.48682534168096836
# Significant!
# For features ('x27', 'x23', 'x162') with explained_variance = 0.4329123675999912
# Significant!
# For features ('x27', 'x23', 'x159') with explained_variance = 0.5180917629969554
# Significant!
# For features ('x27', 'x149', 'x102') with explained_variance = 0.4125277936213321
# Significant!
# For features ('x27', 'x149', 'x98') with explained_variance = 0.4054236456907616
# Significant!
# For features ('x27', 'x149', 'x158') with explained_variance = 0.41526748143336745
# Significant!
# For features ('x27', 'x149', 'x160') with explained_variance = 0.403546596034791
# Significant!
# For features ('x27', 'x6', 'x102') with explained_variance = 0.42471450098700225
# Significant!
# For features ('x27', 'x39', 'x102') with explained_variance = 0.40399363676573197
# Significant!
# For features ('x27', 'x175', 'x102') with explained_variance = 0.46431235117576986
# Significant!
# For features ('x27', 'x67', 'x102') with explained_variance = 0.4346257590556343
# Significant!
# For features ('x27', 'x41', 'x102') with explained_variance = 0.440537134925379
# Significant!
# For features ('x27', 'x148', 'x102') with explained_variance = 0.4217883864110791
# Significant!
# For features ('x27', 'x148', 'x98') with explained_variance = 0.40358359877150407
# Significant!
# For features ('x27', 'x148', 'x158') with explained_variance = 0.40062742332753115
# Significant!
# For features ('x27', 'x194', 'x102') with explained_variance = 0.41648237058591864
# Significant!
# For features ('x27', 'x194', 'x98') with explained_variance = 0.4022847182388648
# Significant!
# For features ('x27', 'x194', 'x158') with explained_variance = 0.4036459718011044
# Significant!
# For features ('x27', 'x102', 'x150') with explained_variance = 0.4298497086010987
# Significant!
# For features ('x27', 'x102', 'x162') with explained_variance = 0.43224070467019465
# Significant!
# For features ('x27', 'x102', 'x195') with explained_variance = 0.4306293219554947
# Significant!
# For features ('x27', 'x102', 'x58') with explained_variance = 0.4120771697934513
# Significant!
# For features ('x27', 'x102', 'x9') with explained_variance = 0.4396868461725806
# Significant!
# For features ('x27', 'x102', 'x152') with explained_variance = 0.43014273871443154
# Significant!
# For features ('x27', 'x102', 'x43') with explained_variance = 0.4082851829331394
# Significant!
# For features ('x27', 'x102', 'x173') with explained_variance = 0.4314695454239151
# Significant!
# For features ('x27', 'x102', 'x177') with explained_variance = 0.4300338417988584
# Significant!
# For features ('x27', 'x102', 'x63') with explained_variance = 0.4138293081726441
# Significant!
# For features ('x27', 'x102', 'x213') with explained_variance = 0.4274514711849129
# Significant!
# For features ('x27', 'x102', 'x3') with explained_variance = 0.42679401478435075
# Significant!
# For features ('x27', 'x102', 'x48') with explained_variance = 0.4309968840237525
# Significant!
# For features ('x27', 'x150', 'x98') with explained_variance = 0.4098087135025457
# Significant!
# For features ('x27', 'x150', 'x152') with explained_variance = 0.44115355595376854
# Significant!
# For features ('x27', 'x150', 'x158') with explained_variance = 0.40156181704398025
# Significant!
# For features ('x27', 'x98', 'x195') with explained_variance = 0.4081194874368734
# Significant!
# For features ('x27', 'x98', 'x152') with explained_variance = 0.4105381850926976
# Significant!
# For features ('x27', 'x98', 'x177') with explained_variance = 0.4438541514078088
# Significant!
# For features ('x27', 'x98', 'x213') with explained_variance = 0.40708109109566415
# Significant!
# For features ('x27', 'x98', 'x48') with explained_variance = 0.4095213472601257
# Significant!
# For features ('x27', 'x195', 'x158') with explained_variance = 0.40099108328349214
# Significant!
# For features ('x27', 'x152', 'x158') with explained_variance = 0.4023037724198636
# Significant!
# For features ('x99', 'x50', 'x23') with explained_variance = 0.49930118195865203
# Significant!
# For features ('x99', 'x188', 'x23') with explained_variance = 0.4886003938353758
# Significant!
# For features ('x99', 'x45', 'x23') with explained_variance = 0.48817823394783355
# Significant!
# For features ('x99', 'x42', 'x23') with explained_variance = 0.4890586229708359
# Significant!
# For features ('x99', 'x193', 'x23') with explained_variance = 0.48678445143187277
# Significant!
# For features ('x99', 'x71', 'x23') with explained_variance = 0.5091713784939731
# Significant!
# For features ('x99', 'x23', 'x149') with explained_variance = 0.4854005021422064
# Significant!
# For features ('x99', 'x23', 'x6') with explained_variance = 0.5240073776072804
# Significant!
# For features ('x99', 'x23', 'x5') with explained_variance = 0.47114668838339524
# Significant!
# For features ('x99', 'x23', 'x39') with explained_variance = 0.49578227893982063
# Significant!
# For features ('x99', 'x23', 'x175') with explained_variance = 0.49159269273581296
# Significant!
# For features ('x99', 'x23', 'x67') with explained_variance = 0.5059878282881517
# Significant!
# For features ('x99', 'x23', 'x41') with explained_variance = 0.4999789139378755
# Significant!
# For features ('x99', 'x23', 'x33') with explained_variance = 0.590663158376438
# Significant!
# For features ('x99', 'x23', 'x148') with explained_variance = 0.48540426539574255
# Significant!
# For features ('x99', 'x23', 'x194') with explained_variance = 0.4830519875567263
# Significant!
# For features ('x99', 'x23', 'x102') with explained_variance = 0.46523323273153727
# Significant!
# For features ('x99', 'x23', 'x150') with explained_variance = 0.4885278893332897
# Significant!
# For features ('x99', 'x23', 'x98') with explained_variance = 0.47520353046581204
# Significant!
# For features ('x99', 'x23', 'x162') with explained_variance = 0.4775227330234699
# Significant!
# For features ('x99', 'x23', 'x159') with explained_variance = 0.5182533459932533
# Significant!
# For features ('x99', 'x23', 'x195') with explained_variance = 0.48708687152155844
# Significant!
# For features ('x99', 'x23', 'x61') with explained_variance = 0.5105131709700496
# Significant!
# For features ('x99', 'x23', 'x58') with explained_variance = 0.5148504121209029
# Significant!
# For features ('x99', 'x23', 'x9') with explained_variance = 0.5397556157838227
# Significant!
# For features ('x99', 'x23', 'x152') with explained_variance = 0.4885937151552494
# Significant!
# For features ('x99', 'x23', 'x43') with explained_variance = 0.48994964689307324
# Significant!
# For features ('x99', 'x23', 'x173') with explained_variance = 0.47234977802998285
# Significant!
# For features ('x99', 'x23', 'x158') with explained_variance = 0.45461951625544667
# Significant!
# For features ('x99', 'x23', 'x177') with explained_variance = 0.486853933893766
# Significant!
# For features ('x99', 'x23', 'x63') with explained_variance = 0.5299813786255865
# Significant!
# For features ('x99', 'x23', 'x160') with explained_variance = 0.4561578766008553
# Significant!
# For features ('x99', 'x23', 'x213') with explained_variance = 0.4878345346926406
# Significant!
# For features ('x99', 'x23', 'x3') with explained_variance = 0.4932604071761581
# Significant!
# For features ('x99', 'x23', 'x7') with explained_variance = 0.47336218487498344
# Significant!
# For features ('x99', 'x23', 'x48') with explained_variance = 0.4882167517522859
# Significant!
# For features ('x50', 'x23', 'x33') with explained_variance = 0.524385037003223
# Significant!
# For features ('x50', 'x23', 'x102') with explained_variance = 0.4808869457164171
# Significant!
# For features ('x50', 'x23', 'x98') with explained_variance = 0.45348711707020933
# Significant!
# For features ('x50', 'x23', 'x162') with explained_variance = 0.4370942505832723
# Significant!
# For features ('x50', 'x23', 'x159') with explained_variance = 0.5273917253601376
# Significant!
# For features ('x188', 'x23', 'x33') with explained_variance = 0.5103647262108912
# Significant!
# For features ('x188', 'x23', 'x102') with explained_variance = 0.48563050201612984
# Significant!
# For features ('x188', 'x23', 'x98') with explained_variance = 0.45876956460391394
# Significant!
# For features ('x188', 'x23', 'x162') with explained_variance = 0.43474545251017904
# Significant!
# For features ('x188', 'x23', 'x159') with explained_variance = 0.5262203042089348
# Significant!
# For features ('x188', 'x33', 'x48') with explained_variance = 0.4967915300520464
# Significant!
# For features ('x45', 'x23', 'x33') with explained_variance = 0.5232356215465284
# Significant!
# For features ('x45', 'x23', 'x102') with explained_variance = 0.46624292853186927
# Significant!
# For features ('x45', 'x23', 'x98') with explained_variance = 0.453613347851013
# Significant!
# For features ('x45', 'x23', 'x162') with explained_variance = 0.422290893987317
# Significant!
# For features ('x45', 'x23', 'x159') with explained_variance = 0.5209031089101067
# Significant!
# For features ('x42', 'x23', 'x33') with explained_variance = 0.5116398221396903
# Significant!
# For features ('x42', 'x23', 'x102') with explained_variance = 0.4872767045224623
# Significant!
# For features ('x42', 'x23', 'x98') with explained_variance = 0.46082490321466707
# Significant!
# For features ('x42', 'x23', 'x162') with explained_variance = 0.435897419686157
# Significant!
# For features ('x42', 'x23', 'x159') with explained_variance = 0.5258544219585164
# Significant!
# For features ('x193', 'x23', 'x33') with explained_variance = 0.5071121566106721
# Significant!
# For features ('x193', 'x23', 'x102') with explained_variance = 0.48389997049386346
# Significant!
# For features ('x193', 'x23', 'x98') with explained_variance = 0.4574134680154499
# Significant!
# For features ('x193', 'x23', 'x162') with explained_variance = 0.43340233255548943
# Significant!
# For features ('x193', 'x23', 'x159') with explained_variance = 0.5255362393526758
# Significant!
# For features ('x193', 'x33', 'x48') with explained_variance = 0.4627651368168674
# Significant!
# For features ('x71', 'x23', 'x33') with explained_variance = 0.529877977829495
# Significant!
# For features ('x71', 'x23', 'x102') with explained_variance = 0.5325772223797254
# Significant!
# For features ('x71', 'x23', 'x98') with explained_variance = 0.48940963946113003
# Significant!
# For features ('x71', 'x23', 'x162') with explained_variance = 0.4424237160107654
# Significant!
# For features ('x71', 'x23', 'x159') with explained_variance = 0.5207715564337174
# Significant!
# For features ('x71', 'x23', 'x173') with explained_variance = 0.4087446653922231
# Significant!
# For features ('x71', 'x23', 'x158') with explained_variance = 0.40058858517689744
# Significant!
# For features ('x23', 'x149', 'x33') with explained_variance = 0.5159535941747088
# Significant!
# For features ('x23', 'x149', 'x102') with explained_variance = 0.4549825609717482
# Significant!
# For features ('x23', 'x149', 'x98') with explained_variance = 0.45894945460215836
# Significant!
# For features ('x23', 'x149', 'x162') with explained_variance = 0.428788603609689
# Significant!
# For features ('x23', 'x149', 'x159') with explained_variance = 0.5252638715115211
# Significant!
# For features ('x23', 'x6', 'x33') with explained_variance = 0.4918532218539772
# Significant!
# For features ('x23', 'x6', 'x102') with explained_variance = 0.5537731279010645
# Significant!
# For features ('x23', 'x6', 'x98') with explained_variance = 0.5060240022552901
# Significant!
# For features ('x23', 'x6', 'x162') with explained_variance = 0.4616700861819247
# Significant!
# For features ('x23', 'x6', 'x159') with explained_variance = 0.5407324593889585
# Significant!
# For features ('x23', 'x6', 'x173') with explained_variance = 0.4342830414662224
# Significant!
# For features ('x23', 'x6', 'x158') with explained_variance = 0.4549210883682068
# Significant!
# For features ('x23', 'x6', 'x177') with explained_variance = 0.4046118378858862
# Significant!
# For features ('x23', 'x5', 'x39') with explained_variance = 0.41160682154967054
# Significant!
# For features ('x23', 'x5', 'x33') with explained_variance = 0.4714408069099876
# Significant!
# For features ('x23', 'x5', 'x102') with explained_variance = 0.4610153388637275
# Significant!
# For features ('x23', 'x5', 'x98') with explained_variance = 0.4354524508155645
# Significant!
# For features ('x23', 'x5', 'x162') with explained_variance = 0.4052690352026609
# Significant!
# For features ('x23', 'x5', 'x159') with explained_variance = 0.5031334950573052
# Significant!
# For features ('x23', 'x39', 'x33') with explained_variance = 0.44589834763275205
# Significant!
# For features ('x23', 'x39', 'x102') with explained_variance = 0.49002544588138564
# Significant!
# For features ('x23', 'x39', 'x98') with explained_variance = 0.4662926097819883
# Significant!
# For features ('x23', 'x39', 'x162') with explained_variance = 0.4220210583827072
# Significant!
# For features ('x23', 'x39', 'x159') with explained_variance = 0.5126695180646281
# Significant!
# For features ('x23', 'x175', 'x33') with explained_variance = 0.5195450217931418
# Significant!
# For features ('x23', 'x175', 'x102') with explained_variance = 0.5555304582999072
# Significant!
# For features ('x23', 'x175', 'x98') with explained_variance = 0.48143621334356224
# Significant!
# For features ('x23', 'x175', 'x162') with explained_variance = 0.4985319615028952
# Significant!
# For features ('x23', 'x175', 'x159') with explained_variance = 0.5227417881336917
# Significant!
# For features ('x23', 'x175', 'x173') with explained_variance = 0.46883846357402204
# Significant!
# For features ('x23', 'x67', 'x33') with explained_variance = 0.531999123940107
# Significant!
# For features ('x23', 'x67', 'x102') with explained_variance = 0.5154131846185426
# Significant!
# For features ('x23', 'x67', 'x98') with explained_variance = 0.47328760763854527
# Significant!
# For features ('x23', 'x67', 'x162') with explained_variance = 0.45400929186636096
# Significant!
# For features ('x23', 'x67', 'x159') with explained_variance = 0.5210209738593731
# Significant!
# For features ('x23', 'x67', 'x177') with explained_variance = 0.4042868624726298
# Significant!
# For features ('x23', 'x41', 'x33') with explained_variance = 0.5131469584621456
# Significant!
# For features ('x23', 'x41', 'x102') with explained_variance = 0.5183332683687146
# Significant!
# For features ('x23', 'x41', 'x98') with explained_variance = 0.4664426220449876
# Significant!
# For features ('x23', 'x41', 'x162') with explained_variance = 0.4444635715720617
# Significant!
# For features ('x23', 'x41', 'x159') with explained_variance = 0.5274695666995081
# Significant!
# For features ('x23', 'x33', 'x148') with explained_variance = 0.510856634205737
# Significant!
# For features ('x23', 'x33', 'x194') with explained_variance = 0.5069158937169694
# Significant!
# For features ('x23', 'x33', 'x102') with explained_variance = 0.5983983133086632
# Significant!
# For features ('x23', 'x33', 'x150') with explained_variance = 0.5124474904952054
# Significant!
# For features ('x23', 'x33', 'x98') with explained_variance = 0.5815928374003982
# Significant!
# For features ('x23', 'x33', 'x162') with explained_variance = 0.5388391663754677
# Significant!
# For features ('x23', 'x33', 'x159') with explained_variance = 0.579798386561905
# Significant!
# For features ('x23', 'x33', 'x195') with explained_variance = 0.5092533585339614
# Significant!
# For features ('x23', 'x33', 'x61') with explained_variance = 0.5243327461320566
# Significant!
# For features ('x23', 'x33', 'x58') with explained_variance = 0.516336338971881
# Significant!
# For features ('x23', 'x33', 'x9') with explained_variance = 0.5065395933655789
# Significant!
# For features ('x23', 'x33', 'x152') with explained_variance = 0.513421222579119
# Significant!
# For features ('x23', 'x33', 'x43') with explained_variance = 0.47494478032842224
# Significant!
# For features ('x23', 'x33', 'x173') with explained_variance = 0.544997552065438
# Significant!
# For features ('x23', 'x33', 'x158') with explained_variance = 0.6092825061672656
# Significant!
# For features ('x23', 'x33', 'x177') with explained_variance = 0.5224822829192446
# Significant!
# For features ('x23', 'x33', 'x63') with explained_variance = 0.5253181949969179
# Significant!
# For features ('x23', 'x33', 'x160') with explained_variance = 0.5805224505138913
# Significant!
# For features ('x23', 'x33', 'x213') with explained_variance = 0.5090436956083825
# Significant!
# For features ('x23', 'x33', 'x3') with explained_variance = 0.4907609231719647
# Significant!
# For features ('x23', 'x33', 'x7') with explained_variance = 0.4420500183369958
# Significant!
# For features ('x23', 'x33', 'x48') with explained_variance = 0.5145138512753549
# Significant!
# For features ('x23', 'x148', 'x102') with explained_variance = 0.474774571164152
# Significant!
# For features ('x23', 'x148', 'x98') with explained_variance = 0.4572359941784244
# Significant!
# For features ('x23', 'x148', 'x162') with explained_variance = 0.4307025649641848
# Significant!
# For features ('x23', 'x148', 'x159') with explained_variance = 0.524766000243921
# Significant!
# For features ('x23', 'x194', 'x102') with explained_variance = 0.4637965244843265
# Significant!
# For features ('x23', 'x194', 'x98') with explained_variance = 0.4537356639247526
# Significant!
# For features ('x23', 'x194', 'x162') with explained_variance = 0.42286144174208473
# Significant!
# For features ('x23', 'x194', 'x159') with explained_variance = 0.5239716722477734
# Significant!
# For features ('x23', 'x102', 'x150') with explained_variance = 0.4864931647059999
# Significant!
# For features ('x23', 'x102', 'x162') with explained_variance = 0.45357889154301534
# Significant!
# For features ('x23', 'x102', 'x159') with explained_variance = 0.5147189779644427
# Significant!
# For features ('x23', 'x102', 'x195') with explained_variance = 0.4842641327160598
# Significant!
# For features ('x23', 'x102', 'x61') with explained_variance = 0.5326020899673604
# Significant!
# For features ('x23', 'x102', 'x58') with explained_variance = 0.49439302238552846
# Significant!
# For features ('x23', 'x102', 'x9') with explained_variance = 0.5347101878670559
# Significant!
# For features ('x23', 'x102', 'x152') with explained_variance = 0.4860114119412513
# Significant!
# For features ('x23', 'x102', 'x43') with explained_variance = 0.47602387658601203
# Significant!
# For features ('x23', 'x102', 'x173') with explained_variance = 0.471522986517698
# Significant!
# For features ('x23', 'x102', 'x177') with explained_variance = 0.4429332150446458
# Significant!
# For features ('x23', 'x102', 'x63') with explained_variance = 0.5203414039280998
# Significant!
# For features ('x23', 'x102', 'x160') with explained_variance = 0.4597122713402326
# Significant!
# For features ('x23', 'x102', 'x213') with explained_variance = 0.4863082793450591
# Significant!
# For features ('x23', 'x102', 'x3') with explained_variance = 0.5161824856362918
# Significant!
# For features ('x23', 'x102', 'x7') with explained_variance = 0.46446947069471767
# Significant!
# For features ('x23', 'x102', 'x48') with explained_variance = 0.4882029233855841
# Significant!
# For features ('x23', 'x150', 'x98') with explained_variance = 0.4602440102031603
# Significant!
# For features ('x23', 'x150', 'x162') with explained_variance = 0.4354937213272274
# Significant!
# For features ('x23', 'x150', 'x159') with explained_variance = 0.5257209904069572
# Significant!
# For features ('x23', 'x150', 'x152') with explained_variance = 0.4292153197044312
# Significant!
# For features ('x23', 'x98', 'x162') with explained_variance = 0.4327058762284162
# Significant!
# For features ('x23', 'x98', 'x159') with explained_variance = 0.5174294396152049
# Significant!
# For features ('x23', 'x98', 'x195') with explained_variance = 0.45699753931287157
# Significant!
# For features ('x23', 'x98', 'x61') with explained_variance = 0.4893084509620789
# Significant!
# For features ('x23', 'x98', 'x58') with explained_variance = 0.4756855463549291
# Significant!
# For features ('x23', 'x98', 'x9') with explained_variance = 0.5011720709419303
# Significant!
# For features ('x23', 'x98', 'x152') with explained_variance = 0.46003627328086816
# Significant!
# For features ('x23', 'x98', 'x43') with explained_variance = 0.44405381743592204
# Significant!
# For features ('x23', 'x98', 'x173') with explained_variance = 0.42740555866913466
# Significant!
# For features ('x23', 'x98', 'x177') with explained_variance = 0.44592653672409155
# Significant!
# For features ('x23', 'x98', 'x63') with explained_variance = 0.49792414422572556
# Significant!
# For features ('x23', 'x98', 'x213') with explained_variance = 0.4602869410176117
# Significant!
# For features ('x23', 'x98', 'x3') with explained_variance = 0.4577616800565207
# Significant!
# For features ('x23', 'x98', 'x7') with explained_variance = 0.4343516910627677
# Significant!
# For features ('x23', 'x98', 'x48') with explained_variance = 0.4627419403712156
# Significant!
# For features ('x23', 'x162', 'x159') with explained_variance = 0.5256943993968612
# Significant!
# For features ('x23', 'x162', 'x195') with explained_variance = 0.4331851183585198
# Significant!
# For features ('x23', 'x162', 'x61') with explained_variance = 0.42930342323843124
# Significant!
# For features ('x23', 'x162', 'x58') with explained_variance = 0.43539805260941006
# Significant!
# For features ('x23', 'x162', 'x9') with explained_variance = 0.4683183007383077
# Significant!
# For features ('x23', 'x162', 'x152') with explained_variance = 0.435453094211106
# Significant!
# For features ('x23', 'x162', 'x43') with explained_variance = 0.4237336019250052
# Significant!
# For features ('x23', 'x162', 'x173') with explained_variance = 0.4391250834874742
# Significant!
# For features ('x23', 'x162', 'x177') with explained_variance = 0.4235062513839857
# Significant!
# For features ('x23', 'x162', 'x63') with explained_variance = 0.44763937483828
# Significant!
# For features ('x23', 'x162', 'x213') with explained_variance = 0.4350460417462171
# Significant!
# For features ('x23', 'x162', 'x3') with explained_variance = 0.4547199035099557
# Significant!
# For features ('x23', 'x162', 'x7') with explained_variance = 0.408738618152948
# Significant!
# For features ('x23', 'x162', 'x48') with explained_variance = 0.4370590156280686
# Significant!
# For features ('x23', 'x159', 'x195') with explained_variance = 0.5256180631293088
# Significant!
# For features ('x23', 'x159', 'x61') with explained_variance = 0.49451621826888725
# Significant!
# For features ('x23', 'x159', 'x58') with explained_variance = 0.5256825024984408
# Significant!
# For features ('x23', 'x159', 'x9') with explained_variance = 0.5645275360282197
# Significant!
# For features ('x23', 'x159', 'x152') with explained_variance = 0.5260533876383479
# Significant!
# For features ('x23', 'x159', 'x43') with explained_variance = 0.5233294553830732
# Significant!
# For features ('x23', 'x159', 'x173') with explained_variance = 0.5188348203616728
# Significant!
# For features ('x23', 'x159', 'x158') with explained_variance = 0.49297248542617067
# Significant!
# For features ('x23', 'x159', 'x177') with explained_variance = 0.5240472930416271
# Significant!
# For features ('x23', 'x159', 'x63') with explained_variance = 0.529110827076638
# Significant!
# For features ('x23', 'x159', 'x160') with explained_variance = 0.5032669704632685
# Significant!
# For features ('x23', 'x159', 'x213') with explained_variance = 0.5252209795855173
# Significant!
# For features ('x23', 'x159', 'x3') with explained_variance = 0.5248781192642302
# Significant!
# For features ('x23', 'x159', 'x7') with explained_variance = 0.5036198421120257
# Significant!
# For features ('x23', 'x159', 'x48') with explained_variance = 0.5254364367024307
# Significant!
# For features ('x23', 'x58', 'x177') with explained_variance = 0.40825474439014914
# Significant!
# For features ('x23', 'x9', 'x173') with explained_variance = 0.40739454308570106
# Significant!
# For features ('x23', 'x9', 'x177') with explained_variance = 0.4156425986404441
# Significant!
# For features ('x23', 'x173', 'x63') with explained_variance = 0.40069311415265896
# Significant!
# For features ('x23', 'x158', 'x160') with explained_variance = 0.4857786691069818
# Significant!
# For features ('x23', 'x177', 'x63') with explained_variance = 0.41796002309086544
# Significant!
# For features ('x23', 'x177', 'x3') with explained_variance = 0.4057659890440405
# Significant!
# For features ('x33', 'x195', 'x48') with explained_variance = 0.4143596200872043

# %%
len(List2_2cvd_3_expv)
# Out:
# 377

# %%
List3_2cvd_3_expv,List3_2cvd_2_expv,List3_2cvd_0_expv = combnfeats_MLR_evaby_crossval_metric(List2_2cvd_3_expv,df_x,df_y,10,model,'explained_variance',0.5)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x99', 'x23') with explained_variance = 0.5222792458513423
# Significant!
# For features ('x186', 'x23', 'x102') with explained_variance = 0.5503288558183445
# Significant!
# For features ('x186', 'x23', 'x98') with explained_variance = 0.5298456038849868
# Significant!
# For features ('x186', 'x23', 'x159') with explained_variance = 0.5253211408615328
# Significant!
# For features ('x49', 'x23', 'x159') with explained_variance = 0.5214017172192204
# Significant!
# For features ('x32', 'x99', 'x23') with explained_variance = 0.5937428793778471
# Significant!
# For features ('x32', 'x23', 'x102') with explained_variance = 0.5949406713422736
# Significant!
# For features ('x32', 'x23', 'x98') with explained_variance = 0.5774066315322011
# Significant!
# For features ('x32', 'x23', 'x162') with explained_variance = 0.5017406618950422
# Significant!
# For features ('x32', 'x23', 'x159') with explained_variance = 0.5806367182587204
# Significant!
# For features ('x32', 'x23', 'x173') with explained_variance = 0.5142363852445475
# Significant!
# For features ('x32', 'x23', 'x158') with explained_variance = 0.5724806101295671
# Significant!
# For features ('x32', 'x23', 'x160') with explained_variance = 0.523319951565086
# Significant!
# For features ('x8', 'x99', 'x23') with explained_variance = 0.5203583113780147
# Significant!
# For features ('x8', 'x23', 'x159') with explained_variance = 0.5194843399406645
# Significant!
# For features ('x2', 'x99', 'x23') with explained_variance = 0.5084965210353308
# Significant!
# For features ('x2', 'x23', 'x159') with explained_variance = 0.5258515870463795
# Significant!
# For features ('x4', 'x99', 'x23') with explained_variance = 0.5054883931199684
# Significant!
# For features ('x4', 'x23', 'x159') with explained_variance = 0.5109998411104412
# Significant!
# For features ('x27', 'x99', 'x23') with explained_variance = 0.5138108066698043
# Significant!
# For features ('x27', 'x23', 'x102') with explained_variance = 0.5027525504386348
# Significant!
# For features ('x27', 'x23', 'x159') with explained_variance = 0.5127671040077291
# Significant!
# For features ('x99', 'x50', 'x23') with explained_variance = 0.5077634388940782
# Significant!
# For features ('x99', 'x71', 'x23') with explained_variance = 0.5117003068714226
# Significant!
# For features ('x99', 'x23', 'x6') with explained_variance = 0.5309536589603522
# Significant!
# For features ('x99', 'x23', 'x39') with explained_variance = 0.5148693129340168
# Significant!
# For features ('x99', 'x23', 'x175') with explained_variance = 0.5004739413933784
# Significant!
# For features ('x99', 'x23', 'x67') with explained_variance = 0.519693289571139
# Significant!
# For features ('x99', 'x23', 'x41') with explained_variance = 0.5054213624603577
# Significant!
# For features ('x99', 'x23', 'x33') with explained_variance = 0.5714296886181653
# Significant!
# For features ('x99', 'x23', 'x159') with explained_variance = 0.5133734803430234
# Significant!
# For features ('x99', 'x23', 'x61') with explained_variance = 0.5189739590895852
# Significant!
# For features ('x99', 'x23', 'x58') with explained_variance = 0.5131956935541842
# Significant!
# For features ('x99', 'x23', 'x9') with explained_variance = 0.5326194056077769
# Significant!
# For features ('x99', 'x23', 'x63') with explained_variance = 0.5283585409774882
# Significant!
# For features ('x99', 'x23', 'x3') with explained_variance = 0.5059018660542505
# Significant!
# For features ('x50', 'x23', 'x159') with explained_variance = 0.5257220599030618
# Significant!
# For features ('x188', 'x23', 'x159') with explained_variance = 0.5111898829673873
# Significant!
# For features ('x45', 'x23', 'x159') with explained_variance = 0.5089010446761242
# Significant!
# For features ('x42', 'x23', 'x159') with explained_variance = 0.514563806573119
# Significant!
# For features ('x193', 'x23', 'x159') with explained_variance = 0.5105430051983685
# Significant!
# For features ('x71', 'x23', 'x102') with explained_variance = 0.5009828584662588
# Significant!
# For features ('x71', 'x23', 'x159') with explained_variance = 0.5102710383382137
# Significant!
# For features ('x23', 'x6', 'x102') with explained_variance = 0.5273186347930765
# Significant!
# For features ('x23', 'x6', 'x98') with explained_variance = 0.5099366904915913
# Significant!
# For features ('x23', 'x6', 'x159') with explained_variance = 0.5246038690461364
# Significant!
# For features ('x23', 'x39', 'x159') with explained_variance = 0.5163711295800796
# Significant!
# For features ('x23', 'x175', 'x102') with explained_variance = 0.5371092073720973
# Significant!
# For features ('x23', 'x175', 'x159') with explained_variance = 0.5114196558131245
# Significant!
# For features ('x23', 'x67', 'x159') with explained_variance = 0.5199164077600784
# Significant!
# For features ('x23', 'x41', 'x159') with explained_variance = 0.5144137317853725
# Significant!
# For features ('x23', 'x33', 'x102') with explained_variance = 0.5693034406898081
# Significant!
# For features ('x23', 'x33', 'x98') with explained_variance = 0.5590296955350171
# Significant!
# For features ('x23', 'x33', 'x159') with explained_variance = 0.5540588766341781
# Significant!
# For features ('x23', 'x33', 'x158') with explained_variance = 0.5620477430528771
# Significant!
# For features ('x23', 'x33', 'x160') with explained_variance = 0.5331283627465575
# Significant!
# For features ('x23', 'x148', 'x159') with explained_variance = 0.5100542738286293
# Significant!
# For features ('x23', 'x102', 'x159') with explained_variance = 0.5141914218534347
# Significant!
# For features ('x23', 'x102', 'x61') with explained_variance = 0.5088401961719216
# Significant!
# For features ('x23', 'x150', 'x159') with explained_variance = 0.5158383450308544
# Significant!
# For features ('x23', 'x98', 'x159') with explained_variance = 0.5225189515019985
# Significant!
# For features ('x23', 'x162', 'x159') with explained_variance = 0.5186570582341148
# Significant!
# For features ('x23', 'x159', 'x195') with explained_variance = 0.5109820189457348
# Significant!
# For features ('x23', 'x159', 'x58') with explained_variance = 0.515002483438513
# Significant!
# For features ('x23', 'x159', 'x9') with explained_variance = 0.5387797701435729
# Significant!
# For features ('x23', 'x159', 'x152') with explained_variance = 0.5159556876652571
# Significant!
# For features ('x23', 'x159', 'x43') with explained_variance = 0.514831037479375
# Significant!
# For features ('x23', 'x159', 'x173') with explained_variance = 0.5142785193782201
# Significant!
# For features ('x23', 'x159', 'x177') with explained_variance = 0.518568219953137
# Significant!
# For features ('x23', 'x159', 'x63') with explained_variance = 0.5198336039135022
# Significant!
# For features ('x23', 'x159', 'x160') with explained_variance = 0.5136961438654407
# Significant!
# For features ('x23', 'x159', 'x213') with explained_variance = 0.5139146730465972
# Significant!
# For features ('x23', 'x159', 'x3') with explained_variance = 0.5203290538818485
# Significant!
# For features ('x23', 'x159', 'x7') with explained_variance = 0.5044746970532141
# Significant!
# For features ('x23', 'x159', 'x48') with explained_variance = 0.5173754956098764

# %%
len(List3_2cvd_3_expv)
# Out:
# 75

# %%
List4_2cvd_3_expv,List4_2cvd_2_expv,List4_2cvd_0_expv = combnfeats_MLR_evaby_crossval_metric(List3_2cvd_3_expv,df_x,df_y,20,model,'explained_variance',0.55)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x32', 'x99', 'x23') with explained_variance = 0.5816623466395823
# Significant!
# For features ('x32', 'x23', 'x102') with explained_variance = 0.5912772698620405
# Significant!
# For features ('x32', 'x23', 'x98') with explained_variance = 0.5663428728700451
# Significant!
# For features ('x32', 'x23', 'x159') with explained_variance = 0.5619162846003578
# Significant!
# For features ('x32', 'x23', 'x158') with explained_variance = 0.5534181162514866
# Significant!
# For features ('x99', 'x23', 'x33') with explained_variance = 0.5560352519743311
# Significant!
# For features ('x23', 'x33', 'x102') with explained_variance = 0.5582265193081213

# %%
a,b,c = combnfeats_MLR_evaby_crossval_metric(List4_2cvd_3_expv,df_x,df_y,500,model,'explained_variance',0.55)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x32', 'x99', 'x23') with explained_variance = 0.5678484407946495
# Significant!
# For features ('x32', 'x23', 'x102') with explained_variance = 0.584136948279881
# Significant!
# For features ('x32', 'x23', 'x98') with explained_variance = 0.5587627726194275
# Significant!
# For features ('x32', 'x23', 'x159') with explained_variance = 0.55668725228789
# Significant!
# For features ('x32', 'x23', 'x158') with explained_variance = 0.5514310933122439
# Significant!
# For features ('x23', 'x33', 'x102') with explained_variance = 0.5647944611966497

# %% [markdown]
# 'x32', 'x23', 'x102'

# %% [markdown]
# Negative MSE

# %%
List_2cvd_3_nrmse,List_2cvd_2_nrmse,List_2cvd_0_nrmse = combnfeats_MLR_evaby_crossval_metric(feats,df_x,df_y,5,model,'neg_root_mean_squared_error',-22)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x49', 'x23') with neg_root_mean_squared_error = -21.49641037860875
# Significant!
# For features ('x186', 'x32', 'x23') with neg_root_mean_squared_error = -20.083431386804826
# Significant!
# For features ('x186', 'x8', 'x23') with neg_root_mean_squared_error = -20.77001158854085
# Significant!
# For features ('x186', 'x2', 'x33') with neg_root_mean_squared_error = -21.101694181763914
# Significant!
# For features ('x186', 'x4', 'x23') with neg_root_mean_squared_error = -21.706545414298297
# Significant!
# For features ('x186', 'x99', 'x23') with neg_root_mean_squared_error = -19.494786643558733
# Significant!
# For features ('x186', 'x50', 'x23') with neg_root_mean_squared_error = -20.746343074166752
# Significant!
# For features ('x186', 'x188', 'x23') with neg_root_mean_squared_error = -21.693860709245875
# Significant!
# For features ('x186', 'x45', 'x23') with neg_root_mean_squared_error = -20.923011806913188
# Significant!
# For features ('x186', 'x42', 'x23') with neg_root_mean_squared_error = -21.617385484520135
# Significant!
# For features ('x186', 'x193', 'x23') with neg_root_mean_squared_error = -21.799933987292498
# Significant!
# For features ('x186', 'x23', 'x149') with neg_root_mean_squared_error = -21.170178096377974
# Significant!
# For features ('x186', 'x23', 'x5') with neg_root_mean_squared_error = -21.4670249253789
# Significant!
# For features ('x186', 'x23', 'x39') with neg_root_mean_squared_error = -21.27853786846616
# Significant!
# For features ('x186', 'x23', 'x175') with neg_root_mean_squared_error = -21.770167990935146
# Significant!
# For features ('x186', 'x23', 'x33') with neg_root_mean_squared_error = -18.909058909898953
# Significant!
# For features ('x186', 'x23', 'x148') with neg_root_mean_squared_error = -21.569524558637134
# Significant!
# For features ('x186', 'x23', 'x194') with neg_root_mean_squared_error = -21.784388990875897
# Significant!
# For features ('x186', 'x23', 'x102') with neg_root_mean_squared_error = -18.578672790121608
# Significant!
# For features ('x186', 'x23', 'x150') with neg_root_mean_squared_error = -21.558921787280887
# Significant!
# For features ('x186', 'x23', 'x98') with neg_root_mean_squared_error = -19.027677323630776
# Significant!
# For features ('x186', 'x23', 'x162') with neg_root_mean_squared_error = -20.07733709046115
# Significant!
# For features ('x186', 'x23', 'x159') with neg_root_mean_squared_error = -19.47934607033745
# Significant!
# For features ('x186', 'x23', 'x195') with neg_root_mean_squared_error = -21.681209710566616
# Significant!
# For features ('x186', 'x23', 'x152') with neg_root_mean_squared_error = -21.503941889451873
# Significant!
# For features ('x186', 'x23', 'x43') with neg_root_mean_squared_error = -21.58536594304497
# Significant!
# For features ('x186', 'x23', 'x173') with neg_root_mean_squared_error = -20.6313802750268
# Significant!
# For features ('x186', 'x23', 'x158') with neg_root_mean_squared_error = -20.074435318613094
# Significant!
# For features ('x186', 'x23', 'x177') with neg_root_mean_squared_error = -20.948619667206238
# Significant!
# For features ('x186', 'x23', 'x160') with neg_root_mean_squared_error = -20.84916924960154
# Significant!
# For features ('x186', 'x23', 'x213') with neg_root_mean_squared_error = -21.71245701658996
# Significant!
# For features ('x186', 'x23', 'x7') with neg_root_mean_squared_error = -21.443279082730534
# Significant!
# For features ('x186', 'x23', 'x48') with neg_root_mean_squared_error = -21.769258162344432
# Significant!
# For features ('x49', 'x32', 'x23') with neg_root_mean_squared_error = -20.392491485734837
# Significant!
# For features ('x49', 'x8', 'x23') with neg_root_mean_squared_error = -21.934464225160742
# Significant!
# For features ('x49', 'x8', 'x33') with neg_root_mean_squared_error = -21.847445435064486
# Significant!
# For features ('x49', 'x2', 'x33') with neg_root_mean_squared_error = -21.51557628717108
# Significant!
# For features ('x49', 'x99', 'x23') with neg_root_mean_squared_error = -20.441797592951207
# Significant!
# For features ('x49', 'x23', 'x39') with neg_root_mean_squared_error = -21.990601229096576
# Significant!
# For features ('x49', 'x23', 'x33') with neg_root_mean_squared_error = -18.980699294901708
# Significant!
# For features ('x49', 'x23', 'x102') with neg_root_mean_squared_error = -20.236013074103376
# Significant!
# For features ('x49', 'x23', 'x98') with neg_root_mean_squared_error = -20.725050836265932
# Significant!
# For features ('x49', 'x23', 'x162') with neg_root_mean_squared_error = -21.094320624948686
# Significant!
# For features ('x49', 'x23', 'x159') with neg_root_mean_squared_error = -19.68368509425745
# Significant!
# For features ('x49', 'x23', 'x158') with neg_root_mean_squared_error = -21.890656309561898
# Significant!
# For features ('x49', 'x23', 'x177') with neg_root_mean_squared_error = -21.9947940535643
# Significant!
# For features ('x32', 'x8', 'x23') with neg_root_mean_squared_error = -20.316533755574046
# Significant!
# For features ('x32', 'x8', 'x158') with neg_root_mean_squared_error = -21.75275196650269
# Significant!
# For features ('x32', 'x8', 'x160') with neg_root_mean_squared_error = -21.85389570133615
# Significant!
# For features ('x32', 'x2', 'x99') with neg_root_mean_squared_error = -21.70364276592128
# Significant!
# For features ('x32', 'x2', 'x23') with neg_root_mean_squared_error = -20.30741891817096
# Significant!
# For features ('x32', 'x2', 'x33') with neg_root_mean_squared_error = -21.673479939818762
# Significant!
# For features ('x32', 'x2', 'x102') with neg_root_mean_squared_error = -21.249462134937897
# Significant!
# For features ('x32', 'x2', 'x98') with neg_root_mean_squared_error = -21.848938915364396
# Significant!
# For features ('x32', 'x2', 'x159') with neg_root_mean_squared_error = -21.982408012619754
# Significant!
# For features ('x32', 'x2', 'x158') with neg_root_mean_squared_error = -21.361483425610427
# Significant!
# For features ('x32', 'x2', 'x160') with neg_root_mean_squared_error = -21.9483542295757
# Significant!
# For features ('x32', 'x4', 'x23') with neg_root_mean_squared_error = -20.970810717825216
# Significant!
# For features ('x32', 'x27', 'x23') with neg_root_mean_squared_error = -21.00247847472206
# Significant!
# For features ('x32', 'x27', 'x41') with neg_root_mean_squared_error = -21.07268561767443
# Significant!
# For features ('x32', 'x27', 'x160') with neg_root_mean_squared_error = -21.763355270872875
# Significant!
# For features ('x32', 'x99', 'x23') with neg_root_mean_squared_error = -16.98404900822988
# Significant!
# For features ('x32', 'x50', 'x23') with neg_root_mean_squared_error = -19.222460747967165
# Significant!
# For features ('x32', 'x188', 'x23') with neg_root_mean_squared_error = -20.727934677413746
# Significant!
# For features ('x32', 'x45', 'x23') with neg_root_mean_squared_error = -19.85155602899978
# Significant!
# For features ('x32', 'x42', 'x23') with neg_root_mean_squared_error = -20.631980392540346
# Significant!
# For features ('x32', 'x193', 'x23') with neg_root_mean_squared_error = -20.76996560012592
# Significant!
# For features ('x32', 'x71', 'x23') with neg_root_mean_squared_error = -20.70524661210331
# Significant!
# For features ('x32', 'x23', 'x149') with neg_root_mean_squared_error = -20.306625538900544
# Significant!
# For features ('x32', 'x23', 'x6') with neg_root_mean_squared_error = -21.009446988965614
# Significant!
# For features ('x32', 'x23', 'x5') with neg_root_mean_squared_error = -20.75893414236868
# Significant!
# For features ('x32', 'x23', 'x39') with neg_root_mean_squared_error = -20.73328085054928
# Significant!
# For features ('x32', 'x23', 'x175') with neg_root_mean_squared_error = -19.894498183716223
# Significant!
# For features ('x32', 'x23', 'x67') with neg_root_mean_squared_error = -20.764196607718496
# Significant!
# For features ('x32', 'x23', 'x41') with neg_root_mean_squared_error = -20.640234450703716
# Significant!
# For features ('x32', 'x23', 'x33') with neg_root_mean_squared_error = -18.84156223271319
# Significant!
# For features ('x32', 'x23', 'x148') with neg_root_mean_squared_error = -20.596534714820958
# Significant!
# For features ('x32', 'x23', 'x194') with neg_root_mean_squared_error = -20.74658350368837
# Significant!
# For features ('x32', 'x23', 'x102') with neg_root_mean_squared_error = -16.84572016971418
# Significant!
# For features ('x32', 'x23', 'x150') with neg_root_mean_squared_error = -20.57787186181673
# Significant!
# For features ('x32', 'x23', 'x98') with neg_root_mean_squared_error = -17.34677355111736
# Significant!
# For features ('x32', 'x23', 'x162') with neg_root_mean_squared_error = -18.65392285495862
# Significant!
# For features ('x32', 'x23', 'x159') with neg_root_mean_squared_error = -17.32985199738889
# Significant!
# For features ('x32', 'x23', 'x195') with neg_root_mean_squared_error = -20.726308031782416
# Significant!
# For features ('x32', 'x23', 'x61') with neg_root_mean_squared_error = -20.977108805489458
# Significant!
# For features ('x32', 'x23', 'x58') with neg_root_mean_squared_error = -20.697362523966582
# Significant!
# For features ('x32', 'x23', 'x9') with neg_root_mean_squared_error = -20.85544573687769
# Significant!
# For features ('x32', 'x23', 'x152') with neg_root_mean_squared_error = -20.53627321204283
# Significant!
# For features ('x32', 'x23', 'x43') with neg_root_mean_squared_error = -20.69087798513285
# Significant!
# For features ('x32', 'x23', 'x173') with neg_root_mean_squared_error = -18.493010665660442
# Significant!
# For features ('x32', 'x23', 'x158') with neg_root_mean_squared_error = -16.86157646769606
# Significant!
# For features ('x32', 'x23', 'x177') with neg_root_mean_squared_error = -19.86396323390351
# Significant!
# For features ('x32', 'x23', 'x63') with neg_root_mean_squared_error = -20.75193147008159
# Significant!
# For features ('x32', 'x23', 'x160') with neg_root_mean_squared_error = -17.85302721944897
# Significant!
# For features ('x32', 'x23', 'x213') with neg_root_mean_squared_error = -20.670699798724172
# Significant!
# For features ('x32', 'x23', 'x3') with neg_root_mean_squared_error = -20.845465327809034
# Significant!
# For features ('x32', 'x23', 'x7') with neg_root_mean_squared_error = -20.936090879792328
# Significant!
# For features ('x32', 'x23', 'x48') with neg_root_mean_squared_error = -20.703404054900048
# Significant!
# For features ('x32', 'x39', 'x158') with neg_root_mean_squared_error = -21.918886248574374
# Significant!
# For features ('x32', 'x158', 'x7') with neg_root_mean_squared_error = -21.29242553898012
# Significant!
# For features ('x32', 'x160', 'x7') with neg_root_mean_squared_error = -21.949866522560388
# Significant!
# For features ('x8', 'x2', 'x23') with neg_root_mean_squared_error = -21.186417315872184
# Significant!
# For features ('x8', 'x2', 'x33') with neg_root_mean_squared_error = -21.66943259394531
# Significant!
# For features ('x8', 'x4', 'x23') with neg_root_mean_squared_error = -21.486806270381514
# Significant!
# For features ('x8', 'x27', 'x23') with neg_root_mean_squared_error = -20.902229535485795
# Significant!
# For features ('x8', 'x27', 'x41') with neg_root_mean_squared_error = -20.44689066294166
# Significant!
# For features ('x8', 'x99', 'x23') with neg_root_mean_squared_error = -19.55324853601008
# Significant!
# For features ('x8', 'x50', 'x23') with neg_root_mean_squared_error = -21.64858096265385
# Significant!
# For features ('x8', 'x50', 'x33') with neg_root_mean_squared_error = -21.115242449089095
# Significant!
# For features ('x8', 'x45', 'x23') with neg_root_mean_squared_error = -21.972224413773468
# Significant!
# For features ('x8', 'x42', 'x23') with neg_root_mean_squared_error = -21.991700860825762
# Significant!
# For features ('x8', 'x71', 'x23') with neg_root_mean_squared_error = -21.553556571202503
# Significant!
# For features ('x8', 'x23', 'x149') with neg_root_mean_squared_error = -21.671429944544986
# Significant!
# For features ('x8', 'x23', 'x6') with neg_root_mean_squared_error = -21.32620698768169
# Significant!
# For features ('x8', 'x23', 'x5') with neg_root_mean_squared_error = -21.283717473464815
# Significant!
# For features ('x8', 'x23', 'x39') with neg_root_mean_squared_error = -21.455234527132696
# Significant!
# For features ('x8', 'x23', 'x175') with neg_root_mean_squared_error = -21.82682205652602
# Significant!
# For features ('x8', 'x23', 'x67') with neg_root_mean_squared_error = -21.21123993548246
# Significant!
# For features ('x8', 'x23', 'x41') with neg_root_mean_squared_error = -21.55728400703626
# Significant!
# For features ('x8', 'x23', 'x33') with neg_root_mean_squared_error = -19.84058300740715
# Significant!
# For features ('x8', 'x23', 'x102') with neg_root_mean_squared_error = -19.536195388825735
# Significant!
# For features ('x8', 'x23', 'x150') with neg_root_mean_squared_error = -21.992012456918367
# Significant!
# For features ('x8', 'x23', 'x98') with neg_root_mean_squared_error = -19.826231086101835
# Significant!
# For features ('x8', 'x23', 'x162') with neg_root_mean_squared_error = -20.68855311539659
# Significant!
# For features ('x8', 'x23', 'x159') with neg_root_mean_squared_error = -19.410034222772403
# Significant!
# For features ('x8', 'x23', 'x61') with neg_root_mean_squared_error = -21.70450765050886
# Significant!
# For features ('x8', 'x23', 'x58') with neg_root_mean_squared_error = -21.460635951678576
# Significant!
# For features ('x8', 'x23', 'x9') with neg_root_mean_squared_error = -21.254775565920006
# Significant!
# For features ('x8', 'x23', 'x152') with neg_root_mean_squared_error = -21.981805221126685
# Significant!
# For features ('x8', 'x23', 'x43') with neg_root_mean_squared_error = -21.874874678814095
# Significant!
# For features ('x8', 'x23', 'x173') with neg_root_mean_squared_error = -21.19186450584811
# Significant!
# For features ('x8', 'x23', 'x158') with neg_root_mean_squared_error = -21.06319759975233
# Significant!
# For features ('x8', 'x23', 'x177') with neg_root_mean_squared_error = -20.9420508985827
# Significant!
# For features ('x8', 'x23', 'x63') with neg_root_mean_squared_error = -21.37030923370991
# Significant!
# For features ('x8', 'x23', 'x160') with neg_root_mean_squared_error = -21.453074705556073
# Significant!
# For features ('x8', 'x23', 'x3') with neg_root_mean_squared_error = -21.354491035329097
# Significant!
# For features ('x8', 'x23', 'x7') with neg_root_mean_squared_error = -21.113928670861128
# Significant!
# For features ('x2', 'x4', 'x33') with neg_root_mean_squared_error = -21.92199443692025
# Significant!
# For features ('x2', 'x27', 'x33') with neg_root_mean_squared_error = -21.55699104633505
# Significant!
# For features ('x2', 'x99', 'x23') with neg_root_mean_squared_error = -20.21911090521193
# Significant!
# For features ('x2', 'x99', 'x33') with neg_root_mean_squared_error = -21.016033820718008
# Significant!
# For features ('x2', 'x50', 'x33') with neg_root_mean_squared_error = -21.372256313943513
# Significant!
# For features ('x2', 'x188', 'x33') with neg_root_mean_squared_error = -21.61206615594812
# Significant!
# For features ('x2', 'x45', 'x33') with neg_root_mean_squared_error = -21.498552812240888
# Significant!
# For features ('x2', 'x42', 'x33') with neg_root_mean_squared_error = -21.589310887434415
# Significant!
# For features ('x2', 'x193', 'x33') with neg_root_mean_squared_error = -21.633541470775025
# Significant!
# For features ('x2', 'x71', 'x33') with neg_root_mean_squared_error = -20.997803517631723
# Significant!
# For features ('x2', 'x23', 'x149') with neg_root_mean_squared_error = -21.790066202888188
# Significant!
# For features ('x2', 'x23', 'x39') with neg_root_mean_squared_error = -21.58930171265979
# Significant!
# For features ('x2', 'x23', 'x33') with neg_root_mean_squared_error = -19.047244611739334
# Significant!
# For features ('x2', 'x23', 'x102') with neg_root_mean_squared_error = -19.843521627380056
# Significant!
# For features ('x2', 'x23', 'x98') with neg_root_mean_squared_error = -20.527406879282534
# Significant!
# For features ('x2', 'x23', 'x162') with neg_root_mean_squared_error = -20.855839307148358
# Significant!
# For features ('x2', 'x23', 'x159') with neg_root_mean_squared_error = -19.634706330103707
# Significant!
# For features ('x2', 'x23', 'x173') with neg_root_mean_squared_error = -21.602256922462963
# Significant!
# For features ('x2', 'x23', 'x158') with neg_root_mean_squared_error = -21.593658491316653
# Significant!
# For features ('x2', 'x23', 'x177') with neg_root_mean_squared_error = -21.58512874564003
# Significant!
# For features ('x2', 'x149', 'x33') with neg_root_mean_squared_error = -21.610986745303954
# Significant!
# For features ('x2', 'x6', 'x33') with neg_root_mean_squared_error = -21.974132037735504
# Significant!
# For features ('x2', 'x39', 'x33') with neg_root_mean_squared_error = -21.791687356568282
# Significant!
# For features ('x2', 'x175', 'x33') with neg_root_mean_squared_error = -21.73221314682555
# Significant!
# For features ('x2', 'x67', 'x33') with neg_root_mean_squared_error = -20.976114828582148
# Significant!
# For features ('x2', 'x41', 'x33') with neg_root_mean_squared_error = -21.055979613708814
# Significant!
# For features ('x2', 'x33', 'x148') with neg_root_mean_squared_error = -21.63148502551497
# Significant!
# For features ('x2', 'x33', 'x194') with neg_root_mean_squared_error = -21.670991109878987
# Significant!
# For features ('x2', 'x33', 'x102') with neg_root_mean_squared_error = -20.840410704131507
# Significant!
# For features ('x2', 'x33', 'x150') with neg_root_mean_squared_error = -21.586366153189655
# Significant!
# For features ('x2', 'x33', 'x98') with neg_root_mean_squared_error = -20.998262498063824
# Significant!
# For features ('x2', 'x33', 'x162') with neg_root_mean_squared_error = -21.495227877209054
# Significant!
# For features ('x2', 'x33', 'x159') with neg_root_mean_squared_error = -21.355988188673273
# Significant!
# For features ('x2', 'x33', 'x195') with neg_root_mean_squared_error = -21.59711375660202
# Significant!
# For features ('x2', 'x33', 'x61') with neg_root_mean_squared_error = -21.23945644136048
# Significant!
# For features ('x2', 'x33', 'x58') with neg_root_mean_squared_error = -21.32521030393067
# Significant!
# For features ('x2', 'x33', 'x152') with neg_root_mean_squared_error = -21.586369097777492
# Significant!
# For features ('x2', 'x33', 'x173') with neg_root_mean_squared_error = -21.786431006942916
# Significant!
# For features ('x2', 'x33', 'x158') with neg_root_mean_squared_error = -20.95121620201192
# Significant!
# For features ('x2', 'x33', 'x177') with neg_root_mean_squared_error = -21.199047589587668
# Significant!
# For features ('x2', 'x33', 'x63') with neg_root_mean_squared_error = -21.28960682091544
# Significant!
# For features ('x2', 'x33', 'x160') with neg_root_mean_squared_error = -21.111074989000112
# Significant!
# For features ('x2', 'x33', 'x213') with neg_root_mean_squared_error = -21.604361258548987
# Significant!
# For features ('x2', 'x33', 'x3') with neg_root_mean_squared_error = -21.866285856982053
# Significant!
# For features ('x2', 'x33', 'x48') with neg_root_mean_squared_error = -21.567340403170274
# Significant!
# For features ('x4', 'x27', 'x41') with neg_root_mean_squared_error = -21.80139993695062
# Significant!
# For features ('x4', 'x99', 'x23') with neg_root_mean_squared_error = -19.32838860938596
# Significant!
# For features ('x4', 'x50', 'x23') with neg_root_mean_squared_error = -21.69772374354392
# Significant!
# For features ('x4', 'x45', 'x23') with neg_root_mean_squared_error = -21.934697043710237
# Significant!
# For features ('x4', 'x23', 'x149') with neg_root_mean_squared_error = -21.56647207990108
# Significant!
# For features ('x4', 'x23', 'x39') with neg_root_mean_squared_error = -21.41864970978548
# Significant!
# For features ('x4', 'x23', 'x67') with neg_root_mean_squared_error = -21.88295428893536
# Significant!
# For features ('x4', 'x23', 'x33') with neg_root_mean_squared_error = -19.59627836984775
# Significant!
# For features ('x4', 'x23', 'x102') with neg_root_mean_squared_error = -19.136220079468735
# Significant!
# For features ('x4', 'x23', 'x98') with neg_root_mean_squared_error = -19.599427743489887
# Significant!
# For features ('x4', 'x23', 'x162') with neg_root_mean_squared_error = -20.531947504804503
# Significant!
# For features ('x4', 'x23', 'x159') with neg_root_mean_squared_error = -19.164971365273665
# Significant!
# For features ('x4', 'x23', 'x9') with neg_root_mean_squared_error = -21.805031498662856
# Significant!
# For features ('x4', 'x23', 'x173') with neg_root_mean_squared_error = -20.77461126557981
# Significant!
# For features ('x4', 'x23', 'x158') with neg_root_mean_squared_error = -20.604141284056563
# Significant!
# For features ('x4', 'x23', 'x177') with neg_root_mean_squared_error = -21.09570137145056
# Significant!
# For features ('x4', 'x23', 'x160') with neg_root_mean_squared_error = -21.540162205867688
# Significant!
# For features ('x27', 'x99', 'x23') with neg_root_mean_squared_error = -19.900099391930826
# Significant!
# For features ('x27', 'x99', 'x41') with neg_root_mean_squared_error = -21.88753472910981
# Significant!
# For features ('x27', 'x50', 'x41') with neg_root_mean_squared_error = -21.859667643700497
# Significant!
# For features ('x27', 'x45', 'x23') with neg_root_mean_squared_error = -21.99990950251158
# Significant!
# For features ('x27', 'x45', 'x41') with neg_root_mean_squared_error = -21.556004814435042
# Significant!
# For features ('x27', 'x23', 'x5') with neg_root_mean_squared_error = -21.414292747893516
# Significant!
# For features ('x27', 'x23', 'x39') with neg_root_mean_squared_error = -21.392069088778317
# Significant!
# For features ('x27', 'x23', 'x33') with neg_root_mean_squared_error = -19.457358744453284
# Significant!
# For features ('x27', 'x23', 'x102') with neg_root_mean_squared_error = -20.0723028897541
# Significant!
# For features ('x27', 'x23', 'x98') with neg_root_mean_squared_error = -20.252567391417536
# Significant!
# For features ('x27', 'x23', 'x162') with neg_root_mean_squared_error = -21.375856195801436
# Significant!
# For features ('x27', 'x23', 'x159') with neg_root_mean_squared_error = -19.844010142226715
# Significant!
# For features ('x27', 'x23', 'x7') with neg_root_mean_squared_error = -21.224573431868528
# Significant!
# For features ('x27', 'x149', 'x41') with neg_root_mean_squared_error = -21.192138866464447
# Significant!
# For features ('x27', 'x39', 'x41') with neg_root_mean_squared_error = -20.89302315952164
# Significant!
# For features ('x27', 'x175', 'x102') with neg_root_mean_squared_error = -21.206194143465055
# Significant!
# For features ('x27', 'x41', 'x33') with neg_root_mean_squared_error = -20.711553344628435
# Significant!
# For features ('x27', 'x41', 'x194') with neg_root_mean_squared_error = -21.892285654536288
# Significant!
# For features ('x27', 'x41', 'x102') with neg_root_mean_squared_error = -21.141688991587056
# Significant!
# For features ('x27', 'x41', 'x98') with neg_root_mean_squared_error = -21.529065116508136
# Significant!
# For features ('x27', 'x41', 'x7') with neg_root_mean_squared_error = -21.98824593012269
# Significant!
# For features ('x27', 'x102', 'x162') with neg_root_mean_squared_error = -21.95338663061406
# Significant!
# For features ('x27', 'x102', 'x3') with neg_root_mean_squared_error = -21.893707135534427
# Significant!
# For features ('x27', 'x98', 'x177') with neg_root_mean_squared_error = -21.528911941359603
# Significant!
# For features ('x99', 'x50', 'x23') with neg_root_mean_squared_error = -20.29732054247648
# Significant!
# For features ('x99', 'x188', 'x23') with neg_root_mean_squared_error = -20.46285526616536
# Significant!
# For features ('x99', 'x45', 'x23') with neg_root_mean_squared_error = -20.391428113890168
# Significant!
# For features ('x99', 'x42', 'x23') with neg_root_mean_squared_error = -20.44079152894512
# Significant!
# For features ('x99', 'x193', 'x23') with neg_root_mean_squared_error = -20.51094790463586
# Significant!
# For features ('x99', 'x71', 'x23') with neg_root_mean_squared_error = -20.54677724566048
# Significant!
# For features ('x99', 'x23', 'x149') with neg_root_mean_squared_error = -20.43708093339483
# Significant!
# For features ('x99', 'x23', 'x6') with neg_root_mean_squared_error = -19.566968787513616
# Significant!
# For features ('x99', 'x23', 'x5') with neg_root_mean_squared_error = -19.921691669305037
# Significant!
# For features ('x99', 'x23', 'x39') with neg_root_mean_squared_error = -19.37158980735565
# Significant!
# For features ('x99', 'x23', 'x175') with neg_root_mean_squared_error = -20.22041732288307
# Significant!
# For features ('x99', 'x23', 'x67') with neg_root_mean_squared_error = -20.50805434795687
# Significant!
# For features ('x99', 'x23', 'x41') with neg_root_mean_squared_error = -20.695597690263902
# Significant!
# For features ('x99', 'x23', 'x33') with neg_root_mean_squared_error = -17.539852227820177
# Significant!
# For features ('x99', 'x23', 'x148') with neg_root_mean_squared_error = -20.532167472940227
# Significant!
# For features ('x99', 'x23', 'x194') with neg_root_mean_squared_error = -20.56844079581218
# Significant!
# For features ('x99', 'x23', 'x102') with neg_root_mean_squared_error = -21.00040799471386
# Significant!
# For features ('x99', 'x23', 'x150') with neg_root_mean_squared_error = -20.453519922748338
# Significant!
# For features ('x99', 'x23', 'x98') with neg_root_mean_squared_error = -20.605392582081418
# Significant!
# For features ('x99', 'x23', 'x162') with neg_root_mean_squared_error = -20.74771780644489
# Significant!
# For features ('x99', 'x23', 'x159') with neg_root_mean_squared_error = -19.915270826737324
# Significant!
# For features ('x99', 'x23', 'x195') with neg_root_mean_squared_error = -20.491994062110145
# Significant!
# For features ('x99', 'x23', 'x61') with neg_root_mean_squared_error = -20.78410652223804
# Significant!
# For features ('x99', 'x23', 'x58') with neg_root_mean_squared_error = -20.32281050358467
# Significant!
# For features ('x99', 'x23', 'x9') with neg_root_mean_squared_error = -20.02476062588819
# Significant!
# For features ('x99', 'x23', 'x152') with neg_root_mean_squared_error = -20.45380578738152
# Significant!
# For features ('x99', 'x23', 'x43') with neg_root_mean_squared_error = -20.62752444196482
# Significant!
# For features ('x99', 'x23', 'x173') with neg_root_mean_squared_error = -20.5891830015352
# Significant!
# For features ('x99', 'x23', 'x158') with neg_root_mean_squared_error = -20.706558082133757
# Significant!
# For features ('x99', 'x23', 'x177') with neg_root_mean_squared_error = -20.639833824084786
# Significant!
# For features ('x99', 'x23', 'x63') with neg_root_mean_squared_error = -20.134100770112745
# Significant!
# For features ('x99', 'x23', 'x160') with neg_root_mean_squared_error = -20.54694013231129
# Significant!
# For features ('x99', 'x23', 'x213') with neg_root_mean_squared_error = -20.47283332234602
# Significant!
# For features ('x99', 'x23', 'x3') with neg_root_mean_squared_error = -20.49430850897971
# Significant!
# For features ('x99', 'x23', 'x7') with neg_root_mean_squared_error = -20.052505646925077
# Significant!
# For features ('x99', 'x23', 'x48') with neg_root_mean_squared_error = -20.460422629134122
# Significant!
# For features ('x50', 'x23', 'x39') with neg_root_mean_squared_error = -21.595181212084807
# Significant!
# For features ('x50', 'x23', 'x33') with neg_root_mean_squared_error = -18.824104962649262
# Significant!
# For features ('x50', 'x23', 'x102') with neg_root_mean_squared_error = -20.294098320406412
# Significant!
# For features ('x50', 'x23', 'x98') with neg_root_mean_squared_error = -20.862267752979378
# Significant!
# For features ('x50', 'x23', 'x162') with neg_root_mean_squared_error = -21.12214526834204
# Significant!
# For features ('x50', 'x23', 'x159') with neg_root_mean_squared_error = -19.722193049904522
# Significant!
# For features ('x50', 'x23', 'x158') with neg_root_mean_squared_error = -21.96755071518275
# Significant!
# For features ('x50', 'x23', 'x177') with neg_root_mean_squared_error = -21.788903320382488
# Significant!
# For features ('x188', 'x45', 'x23') with neg_root_mean_squared_error = -21.987238890821544
# Significant!
# For features ('x188', 'x23', 'x149') with neg_root_mean_squared_error = -21.49668050208783
# Significant!
# For features ('x188', 'x23', 'x33') with neg_root_mean_squared_error = -19.104929422393376
# Significant!
# For features ('x188', 'x23', 'x102') with neg_root_mean_squared_error = -20.31237823104806
# Significant!
# For features ('x188', 'x23', 'x98') with neg_root_mean_squared_error = -20.78288214955547
# Significant!
# For features ('x188', 'x23', 'x162') with neg_root_mean_squared_error = -21.172662123541834
# Significant!
# For features ('x188', 'x23', 'x159') with neg_root_mean_squared_error = -19.697324979578816
# Significant!
# For features ('x188', 'x33', 'x48') with neg_root_mean_squared_error = -18.605544005987547
# Significant!
# For features ('x45', 'x42', 'x23') with neg_root_mean_squared_error = -21.955636959507643
# Significant!
# For features ('x45', 'x23', 'x6') with neg_root_mean_squared_error = -21.846161431188527
# Significant!
# For features ('x45', 'x23', 'x39') with neg_root_mean_squared_error = -21.92962532085666
# Significant!
# For features ('x45', 'x23', 'x33') with neg_root_mean_squared_error = -18.909884711161073
# Significant!
# For features ('x45', 'x23', 'x102') with neg_root_mean_squared_error = -20.547492650024985
# Significant!
# For features ('x45', 'x23', 'x98') with neg_root_mean_squared_error = -20.833662560688904
# Significant!
# For features ('x45', 'x23', 'x162') with neg_root_mean_squared_error = -21.23824656975791
# Significant!
# For features ('x45', 'x23', 'x159') with neg_root_mean_squared_error = -19.74602074705553
# Significant!
# For features ('x45', 'x23', 'x173') with neg_root_mean_squared_error = -21.954769253213513
# Significant!
# For features ('x45', 'x23', 'x177') with neg_root_mean_squared_error = -21.74058909843583
# Significant!
# For features ('x45', 'x23', 'x213') with neg_root_mean_squared_error = -21.946839568260835
# Significant!
# For features ('x45', 'x23', 'x48') with neg_root_mean_squared_error = -21.916673178369873
# Significant!
# For features ('x42', 'x23', 'x33') with neg_root_mean_squared_error = -19.08089427763744
# Significant!
# For features ('x42', 'x23', 'x102') with neg_root_mean_squared_error = -20.267092048086415
# Significant!
# For features ('x42', 'x23', 'x98') with neg_root_mean_squared_error = -20.732112617500835
# Significant!
# For features ('x42', 'x23', 'x162') with neg_root_mean_squared_error = -21.130246212373905
# Significant!
# For features ('x42', 'x23', 'x159') with neg_root_mean_squared_error = -19.68223223184809
# Significant!
# For features ('x193', 'x23', 'x149') with neg_root_mean_squared_error = -21.443118658952507
# Significant!
# For features ('x193', 'x23', 'x33') with neg_root_mean_squared_error = -19.16489769324141
# Significant!
# For features ('x193', 'x23', 'x148') with neg_root_mean_squared_error = -21.88162895639597
# Significant!
# For features ('x193', 'x23', 'x102') with neg_root_mean_squared_error = -20.359251532000194
# Significant!
# For features ('x193', 'x23', 'x98') with neg_root_mean_squared_error = -20.81985481675907
# Significant!
# For features ('x193', 'x23', 'x162') with neg_root_mean_squared_error = -21.21478460700267
# Significant!
# For features ('x193', 'x23', 'x159') with neg_root_mean_squared_error = -19.727405338355407
# Significant!
# For features ('x193', 'x33', 'x48') with neg_root_mean_squared_error = -19.330212225918835
# Significant!
# For features ('x71', 'x23', 'x39') with neg_root_mean_squared_error = -21.810598252848816
# Significant!
# For features ('x71', 'x23', 'x33') with neg_root_mean_squared_error = -18.63612541984908
# Significant!
# For features ('x71', 'x23', 'x102') with neg_root_mean_squared_error = -20.069266445644455
# Significant!
# For features ('x71', 'x23', 'x98') with neg_root_mean_squared_error = -20.709294880189987
# Significant!
# For features ('x71', 'x23', 'x162') with neg_root_mean_squared_error = -21.524268962573586
# Significant!
# For features ('x71', 'x23', 'x159') with neg_root_mean_squared_error = -20.29656215219145
# Significant!
# For features ('x23', 'x149', 'x6') with neg_root_mean_squared_error = -21.723287702424425
# Significant!
# For features ('x23', 'x149', 'x5') with neg_root_mean_squared_error = -21.962660699750177
# Significant!
# For features ('x23', 'x149', 'x39') with neg_root_mean_squared_error = -21.588784905587495
# Significant!
# For features ('x23', 'x149', 'x33') with neg_root_mean_squared_error = -19.00427078602581
# Significant!
# For features ('x23', 'x149', 'x148') with neg_root_mean_squared_error = -21.68446504009888
# Significant!
# For features ('x23', 'x149', 'x194') with neg_root_mean_squared_error = -21.192798379584104
# Significant!
# For features ('x23', 'x149', 'x102') with neg_root_mean_squared_error = -20.6376340127456
# Significant!
# For features ('x23', 'x149', 'x98') with neg_root_mean_squared_error = -20.668239706874896
# Significant!
# For features ('x23', 'x149', 'x162') with neg_root_mean_squared_error = -20.983674302017455
# Significant!
# For features ('x23', 'x149', 'x159') with neg_root_mean_squared_error = -19.632140406679405
# Significant!
# For features ('x23', 'x149', 'x195') with neg_root_mean_squared_error = -21.59592092266468
# Significant!
# For features ('x23', 'x149', 'x173') with neg_root_mean_squared_error = -21.62903674976682
# Significant!
# For features ('x23', 'x149', 'x158') with neg_root_mean_squared_error = -21.81830556281134
# Significant!
# For features ('x23', 'x149', 'x177') with neg_root_mean_squared_error = -21.803382206832094
# Significant!
# For features ('x23', 'x6', 'x39') with neg_root_mean_squared_error = -21.65474855950307
# Significant!
# For features ('x23', 'x6', 'x33') with neg_root_mean_squared_error = -19.321893763364262
# Significant!
# For features ('x23', 'x6', 'x102') with neg_root_mean_squared_error = -19.024738349454235
# Significant!
# For features ('x23', 'x6', 'x98') with neg_root_mean_squared_error = -19.67814445852132
# Significant!
# For features ('x23', 'x6', 'x162') with neg_root_mean_squared_error = -20.820860455141194
# Significant!
# For features ('x23', 'x6', 'x159') with neg_root_mean_squared_error = -19.49348826257772
# Significant!
# For features ('x23', 'x6', 'x173') with neg_root_mean_squared_error = -21.179341198007933
# Significant!
# For features ('x23', 'x6', 'x158') with neg_root_mean_squared_error = -20.492401070934783
# Significant!
# For features ('x23', 'x6', 'x177') with neg_root_mean_squared_error = -21.79405641322409
# Significant!
# For features ('x23', 'x6', 'x160') with neg_root_mean_squared_error = -21.688355774183265
# Significant!
# For features ('x23', 'x5', 'x39') with neg_root_mean_squared_error = -21.38154637154189
# Significant!
# For features ('x23', 'x5', 'x33') with neg_root_mean_squared_error = -19.749190590019236
# Significant!
# For features ('x23', 'x5', 'x102') with neg_root_mean_squared_error = -19.889513260636942
# Significant!
# For features ('x23', 'x5', 'x98') with neg_root_mean_squared_error = -20.329853227441937
# Significant!
# For features ('x23', 'x5', 'x162') with neg_root_mean_squared_error = -20.92328345113864
# Significant!
# For features ('x23', 'x5', 'x159') with neg_root_mean_squared_error = -19.456402396771765
# Significant!
# For features ('x23', 'x5', 'x9') with neg_root_mean_squared_error = -21.78780278775225
# Significant!
# For features ('x23', 'x5', 'x173') with neg_root_mean_squared_error = -21.34844287870631
# Significant!
# For features ('x23', 'x5', 'x158') with neg_root_mean_squared_error = -21.448782111039502
# Significant!
# For features ('x23', 'x5', 'x177') with neg_root_mean_squared_error = -21.270668835416295
# Significant!
# For features ('x23', 'x39', 'x175') with neg_root_mean_squared_error = -21.935202049574226
# Significant!
# For features ('x23', 'x39', 'x67') with neg_root_mean_squared_error = -21.40708782576748
# Significant!
# For features ('x23', 'x39', 'x41') with neg_root_mean_squared_error = -21.841791848416204
# Significant!
# For features ('x23', 'x39', 'x33') with neg_root_mean_squared_error = -19.852678316773865
# Significant!
# For features ('x23', 'x39', 'x102') with neg_root_mean_squared_error = -19.255810929575485
# Significant!
# For features ('x23', 'x39', 'x98') with neg_root_mean_squared_error = -19.630568596374292
# Significant!
# For features ('x23', 'x39', 'x162') with neg_root_mean_squared_error = -20.560794490660335
# Significant!
# For features ('x23', 'x39', 'x159') with neg_root_mean_squared_error = -19.25695381770837
# Significant!
# For features ('x23', 'x39', 'x61') with neg_root_mean_squared_error = -21.879113121065377
# Significant!
# For features ('x23', 'x39', 'x58') with neg_root_mean_squared_error = -21.6549879709016
# Significant!
# For features ('x23', 'x39', 'x9') with neg_root_mean_squared_error = -21.37597956906806
# Significant!
# For features ('x23', 'x39', 'x43') with neg_root_mean_squared_error = -21.937297964322042
# Significant!
# For features ('x23', 'x39', 'x173') with neg_root_mean_squared_error = -20.89544215153628
# Significant!
# For features ('x23', 'x39', 'x158') with neg_root_mean_squared_error = -20.71609340497431
# Significant!
# For features ('x23', 'x39', 'x177') with neg_root_mean_squared_error = -20.976009119492588
# Significant!
# For features ('x23', 'x39', 'x63') with neg_root_mean_squared_error = -21.627498423415513
# Significant!
# For features ('x23', 'x39', 'x160') with neg_root_mean_squared_error = -21.363031091888054
# Significant!
# For features ('x23', 'x39', 'x3') with neg_root_mean_squared_error = -21.6292907107404
# Significant!
# For features ('x23', 'x39', 'x7') with neg_root_mean_squared_error = -21.698190493316787
# Significant!
# For features ('x23', 'x175', 'x33') with neg_root_mean_squared_error = -18.95611209794985
# Significant!
# For features ('x23', 'x175', 'x102') with neg_root_mean_squared_error = -18.711833947509472
# Significant!
# For features ('x23', 'x175', 'x98') with neg_root_mean_squared_error = -20.22411729909721
# Significant!
# For features ('x23', 'x175', 'x162') with neg_root_mean_squared_error = -19.962884834394732
# Significant!
# For features ('x23', 'x175', 'x159') with neg_root_mean_squared_error = -19.746512534695036
# Significant!
# For features ('x23', 'x175', 'x173') with neg_root_mean_squared_error = -20.103834856808326
# Significant!
# For features ('x23', 'x175', 'x158') with neg_root_mean_squared_error = -21.44985869087866
# Significant!
# For features ('x23', 'x175', 'x177') with neg_root_mean_squared_error = -21.736381944001863
# Significant!
# For features ('x23', 'x67', 'x33') with neg_root_mean_squared_error = -18.657938883585373
# Significant!
# For features ('x23', 'x67', 'x102') with neg_root_mean_squared_error = -19.90595223763406
# Significant!
# For features ('x23', 'x67', 'x98') with neg_root_mean_squared_error = -20.741830816208697
# Significant!
# For features ('x23', 'x67', 'x162') with neg_root_mean_squared_error = -20.95717100504259
# Significant!
# For features ('x23', 'x67', 'x159') with neg_root_mean_squared_error = -20.06664186160404
# Significant!
# For features ('x23', 'x67', 'x173') with neg_root_mean_squared_error = -21.952909756478007
# Significant!
# For features ('x23', 'x67', 'x158') with neg_root_mean_squared_error = -21.73720291051599
# Significant!
# For features ('x23', 'x41', 'x33') with neg_root_mean_squared_error = -19.018473309548288
# Significant!
# For features ('x23', 'x41', 'x102') with neg_root_mean_squared_error = -20.429903219237968
# Significant!
# For features ('x23', 'x41', 'x98') with neg_root_mean_squared_error = -21.062014024893045
# Significant!
# For features ('x23', 'x41', 'x162') with neg_root_mean_squared_error = -21.54983378373594
# Significant!
# For features ('x23', 'x41', 'x159') with neg_root_mean_squared_error = -20.211434390914434
# Significant!
# For features ('x23', 'x33', 'x148') with neg_root_mean_squared_error = -19.13620695139884
# Significant!
# For features ('x23', 'x33', 'x194') with neg_root_mean_squared_error = -19.195834406549086
# Significant!
# For features ('x23', 'x33', 'x102') with neg_root_mean_squared_error = -17.550412590872433
# Significant!
# For features ('x23', 'x33', 'x150') with neg_root_mean_squared_error = -19.07217565112791
# Significant!
# For features ('x23', 'x33', 'x98') with neg_root_mean_squared_error = -17.72892227371715
# Significant!
# For features ('x23', 'x33', 'x162') with neg_root_mean_squared_error = -18.882990424784573
# Significant!
# For features ('x23', 'x33', 'x159') with neg_root_mean_squared_error = -17.974606798145594
# Significant!
# For features ('x23', 'x33', 'x195') with neg_root_mean_squared_error = -19.116913107193888
# Significant!
# For features ('x23', 'x33', 'x61') with neg_root_mean_squared_error = -18.92753898553287
# Significant!
# For features ('x23', 'x33', 'x58') with neg_root_mean_squared_error = -18.806641190269268
# Significant!
# For features ('x23', 'x33', 'x9') with neg_root_mean_squared_error = -19.337914253820422
# Significant!
# For features ('x23', 'x33', 'x152') with neg_root_mean_squared_error = -19.061318153261237
# Significant!
# For features ('x23', 'x33', 'x43') with neg_root_mean_squared_error = -19.596306741639136
# Significant!
# For features ('x23', 'x33', 'x173') with neg_root_mean_squared_error = -18.690924720127576
# Significant!
# For features ('x23', 'x33', 'x158') with neg_root_mean_squared_error = -17.421071494283513
# Significant!
# For features ('x23', 'x33', 'x177') with neg_root_mean_squared_error = -19.16839518077064
# Significant!
# For features ('x23', 'x33', 'x63') with neg_root_mean_squared_error = -18.72929689124396
# Significant!
# For features ('x23', 'x33', 'x160') with neg_root_mean_squared_error = -18.063059673771924
# Significant!
# For features ('x23', 'x33', 'x213') with neg_root_mean_squared_error = -19.12936676253358
# Significant!
# For features ('x23', 'x33', 'x3') with neg_root_mean_squared_error = -19.37002322201146
# Significant!
# For features ('x23', 'x33', 'x7') with neg_root_mean_squared_error = -20.13173244712035
# Significant!
# For features ('x23', 'x33', 'x48') with neg_root_mean_squared_error = -19.03943326246494
# Significant!
# For features ('x23', 'x148', 'x102') with neg_root_mean_squared_error = -20.50139167467928
# Significant!
# For features ('x23', 'x148', 'x98') with neg_root_mean_squared_error = -20.826446202244444
# Significant!
# For features ('x23', 'x148', 'x162') with neg_root_mean_squared_error = -21.237900688676433
# Significant!
# For features ('x23', 'x148', 'x159') with neg_root_mean_squared_error = -19.73985667938786
# Significant!
# For features ('x23', 'x148', 'x48') with neg_root_mean_squared_error = -21.897923973383975
# Significant!
# For features ('x23', 'x194', 'x102') with neg_root_mean_squared_error = -20.635387143584786
# Significant!
# For features ('x23', 'x194', 'x98') with neg_root_mean_squared_error = -20.856562161810537
# Significant!
# For features ('x23', 'x194', 'x162') with neg_root_mean_squared_error = -21.270962189652685
# Significant!
# For features ('x23', 'x194', 'x159') with neg_root_mean_squared_error = -19.73406107900142
# Significant!
# For features ('x23', 'x102', 'x150') with neg_root_mean_squared_error = -20.28323227577634
# Significant!
# For features ('x23', 'x102', 'x162') with neg_root_mean_squared_error = -20.77826734613359
# Significant!
# For features ('x23', 'x102', 'x159') with neg_root_mean_squared_error = -20.123909356188328
# Significant!
# For features ('x23', 'x102', 'x195') with neg_root_mean_squared_error = -20.339367986766383
# Significant!
# For features ('x23', 'x102', 'x61') with neg_root_mean_squared_error = -20.384309971836377
# Significant!
# For features ('x23', 'x102', 'x58') with neg_root_mean_squared_error = -20.242311185007832
# Significant!
# For features ('x23', 'x102', 'x9') with neg_root_mean_squared_error = -19.942666522698058
# Significant!
# For features ('x23', 'x102', 'x152') with neg_root_mean_squared_error = -20.289204858279554
# Significant!
# For features ('x23', 'x102', 'x43') with neg_root_mean_squared_error = -20.62010468874295
# Significant!
# For features ('x23', 'x102', 'x173') with neg_root_mean_squared_error = -20.315739107510574
# Significant!
# For features ('x23', 'x102', 'x158') with neg_root_mean_squared_error = -21.086399557654666
# Significant!
# For features ('x23', 'x102', 'x177') with neg_root_mean_squared_error = -21.03458213315033
# Significant!
# For features ('x23', 'x102', 'x63') with neg_root_mean_squared_error = -19.897876373949728
# Significant!
# For features ('x23', 'x102', 'x160') with neg_root_mean_squared_error = -20.158409113690034
# Significant!
# For features ('x23', 'x102', 'x213') with neg_root_mean_squared_error = -20.29705089132751
# Significant!
# For features ('x23', 'x102', 'x3') with neg_root_mean_squared_error = -20.137305850900912
# Significant!
# For features ('x23', 'x102', 'x7') with neg_root_mean_squared_error = -20.018652212061234
# Significant!
# For features ('x23', 'x102', 'x48') with neg_root_mean_squared_error = -20.24779016755673
# Significant!
# For features ('x23', 'x150', 'x98') with neg_root_mean_squared_error = -20.744093108737964
# Significant!
# For features ('x23', 'x150', 'x162') with neg_root_mean_squared_error = -21.14024533555784
# Significant!
# For features ('x23', 'x150', 'x159') with neg_root_mean_squared_error = -19.68992756271857
# Significant!
# For features ('x23', 'x150', 'x152') with neg_root_mean_squared_error = -21.72022369073362
# Significant!
# For features ('x23', 'x98', 'x162') with neg_root_mean_squared_error = -21.359327927915608
# Significant!
# For features ('x23', 'x98', 'x159') with neg_root_mean_squared_error = -19.854477974382434
# Significant!
# For features ('x23', 'x98', 'x195') with neg_root_mean_squared_error = -20.812675872993857
# Significant!
# For features ('x23', 'x98', 'x61') with neg_root_mean_squared_error = -21.004922760994578
# Significant!
# For features ('x23', 'x98', 'x58') with neg_root_mean_squared_error = -20.671474079924792
# Significant!
# For features ('x23', 'x98', 'x9') with neg_root_mean_squared_error = -20.392212063547305
# Significant!
# For features ('x23', 'x98', 'x152') with neg_root_mean_squared_error = -20.74625776458207
# Significant!
# For features ('x23', 'x98', 'x43') with neg_root_mean_squared_error = -21.1958636119706
# Significant!
# For features ('x23', 'x98', 'x173') with neg_root_mean_squared_error = -21.320507109233404
# Significant!
# For features ('x23', 'x98', 'x158') with neg_root_mean_squared_error = -21.874625310005946
# Significant!
# For features ('x23', 'x98', 'x177') with neg_root_mean_squared_error = -21.043685976791366
# Significant!
# For features ('x23', 'x98', 'x63') with neg_root_mean_squared_error = -20.394379932669313
# Significant!
# For features ('x23', 'x98', 'x160') with neg_root_mean_squared_error = -21.31871609451306
# Significant!
# For features ('x23', 'x98', 'x213') with neg_root_mean_squared_error = -20.75268352296178
# Significant!
# For features ('x23', 'x98', 'x3') with neg_root_mean_squared_error = -20.980879449599243
# Significant!
# For features ('x23', 'x98', 'x7') with neg_root_mean_squared_error = -20.500510030938464
# Significant!
# For features ('x23', 'x98', 'x48') with neg_root_mean_squared_error = -20.697227476262874
# Significant!
# For features ('x23', 'x162', 'x159') with neg_root_mean_squared_error = -19.97270369198499
# Significant!
# For features ('x23', 'x162', 'x195') with neg_root_mean_squared_error = -21.194186312455287
# Significant!
# For features ('x23', 'x162', 'x58') with neg_root_mean_squared_error = -21.247578414053656
# Significant!
# For features ('x23', 'x162', 'x9') with neg_root_mean_squared_error = -21.160278361933887
# Significant!
# For features ('x23', 'x162', 'x152') with neg_root_mean_squared_error = -21.13782140669553
# Significant!
# For features ('x23', 'x162', 'x43') with neg_root_mean_squared_error = -21.50866791306761
# Significant!
# For features ('x23', 'x162', 'x173') with neg_root_mean_squared_error = -20.965684873656045
# Significant!
# For features ('x23', 'x162', 'x177') with neg_root_mean_squared_error = -21.324589290889406
# Significant!
# For features ('x23', 'x162', 'x63') with neg_root_mean_squared_error = -21.2108516153746
# Significant!
# For features ('x23', 'x162', 'x160') with neg_root_mean_squared_error = -21.629078603288093
# Significant!
# For features ('x23', 'x162', 'x213') with neg_root_mean_squared_error = -21.160484778906348
# Significant!
# For features ('x23', 'x162', 'x3') with neg_root_mean_squared_error = -21.089662860311183
# Significant!
# For features ('x23', 'x162', 'x7') with neg_root_mean_squared_error = -21.045534031870066
# Significant!
# For features ('x23', 'x162', 'x48') with neg_root_mean_squared_error = -21.114985022702665
# Significant!
# For features ('x23', 'x159', 'x195') with neg_root_mean_squared_error = -19.708249553029
# Significant!
# For features ('x23', 'x159', 'x61') with neg_root_mean_squared_error = -20.96303789184545
# Significant!
# For features ('x23', 'x159', 'x58') with neg_root_mean_squared_error = -20.068513365895505
# Significant!
# For features ('x23', 'x159', 'x9') with neg_root_mean_squared_error = -19.612998656984782
# Significant!
# For features ('x23', 'x159', 'x152') with neg_root_mean_squared_error = -19.685509801382857
# Significant!
# For features ('x23', 'x159', 'x43') with neg_root_mean_squared_error = -19.954711160575677
# Significant!
# For features ('x23', 'x159', 'x173') with neg_root_mean_squared_error = -19.83079129559783
# Significant!
# For features ('x23', 'x159', 'x158') with neg_root_mean_squared_error = -20.102084819702032
# Significant!
# For features ('x23', 'x159', 'x177') with neg_root_mean_squared_error = -19.977480649920686
# Significant!
# For features ('x23', 'x159', 'x63') with neg_root_mean_squared_error = -20.080990312804072
# Significant!
# For features ('x23', 'x159', 'x160') with neg_root_mean_squared_error = -19.76314060273678
# Significant!
# For features ('x23', 'x159', 'x213') with neg_root_mean_squared_error = -19.705718758103338
# Significant!
# For features ('x23', 'x159', 'x3') with neg_root_mean_squared_error = -19.85719927631443
# Significant!
# For features ('x23', 'x159', 'x7') with neg_root_mean_squared_error = -19.63505159369824
# Significant!
# For features ('x23', 'x159', 'x48') with neg_root_mean_squared_error = -19.68226767219449
# Significant!
# For features ('x23', 'x58', 'x158') with neg_root_mean_squared_error = -21.94971294398637
# Significant!
# For features ('x23', 'x58', 'x177') with neg_root_mean_squared_error = -21.966945122536323
# Significant!
# For features ('x23', 'x9', 'x158') with neg_root_mean_squared_error = -21.79260047285397
# Significant!
# For features ('x23', 'x9', 'x7') with neg_root_mean_squared_error = -21.77870412465085
# Significant!
# For features ('x23', 'x173', 'x7') with neg_root_mean_squared_error = -21.52269556144076
# Significant!
# For features ('x23', 'x158', 'x63') with neg_root_mean_squared_error = -21.839286626442927
# Significant!
# For features ('x23', 'x158', 'x160') with neg_root_mean_squared_error = -18.973494346853187
# Significant!
# For features ('x23', 'x158', 'x7') with neg_root_mean_squared_error = -21.705878171277725
# Significant!
# For features ('x23', 'x158', 'x48') with neg_root_mean_squared_error = -21.966433706728623
# Significant!
# For features ('x23', 'x177', 'x63') with neg_root_mean_squared_error = -21.927939784300058
# Significant!
# For features ('x23', 'x177', 'x160') with neg_root_mean_squared_error = -21.97259562016479
# Significant!
# For features ('x23', 'x177', 'x3') with neg_root_mean_squared_error = -21.596306745162774
# Significant!
# For features ('x23', 'x177', 'x7') with neg_root_mean_squared_error = -21.3700556074322
# Significant!
# For features ('x41', 'x33', 'x3') with neg_root_mean_squared_error = -21.273439442250258
# Significant!
# For features ('x41', 'x33', 'x7') with neg_root_mean_squared_error = -21.60930144371242
# Significant!
# For features ('x33', 'x148', 'x48') with neg_root_mean_squared_error = -21.82060441586075
# Significant!
# For features ('x33', 'x195', 'x48') with neg_root_mean_squared_error = -20.28251424328723
# Significant!
# For features ('x33', 'x213', 'x48') with neg_root_mean_squared_error = -21.353434819139334

# %%
len(List_2cvd_3_nrmse)
# Out:
# 496

# %%
List2_2cvd_3_nrmse,List2_2cvd_2_nrmse,List2_2cvd_0_nrmse = combnfeats_MLR_evaby_crossval_metric(List_2cvd_3_nrmse,df_x,df_y,5,model,'neg_root_mean_squared_error',-20)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x99', 'x23') with neg_root_mean_squared_error = -19.494786643558733
# Significant!
# For features ('x186', 'x23', 'x33') with neg_root_mean_squared_error = -18.909058909898953
# Significant!
# For features ('x186', 'x23', 'x102') with neg_root_mean_squared_error = -18.578672790121608
# Significant!
# For features ('x186', 'x23', 'x98') with neg_root_mean_squared_error = -19.027677323630776
# Significant!
# For features ('x186', 'x23', 'x159') with neg_root_mean_squared_error = -19.47934607033745
# Significant!
# For features ('x49', 'x23', 'x33') with neg_root_mean_squared_error = -18.980699294901708
# Significant!
# For features ('x49', 'x23', 'x159') with neg_root_mean_squared_error = -19.68368509425745
# Significant!
# For features ('x32', 'x99', 'x23') with neg_root_mean_squared_error = -16.98404900822988
# Significant!
# For features ('x32', 'x50', 'x23') with neg_root_mean_squared_error = -19.222460747967165
# Significant!
# For features ('x32', 'x45', 'x23') with neg_root_mean_squared_error = -19.85155602899978
# Significant!
# For features ('x32', 'x23', 'x175') with neg_root_mean_squared_error = -19.894498183716223
# Significant!
# For features ('x32', 'x23', 'x33') with neg_root_mean_squared_error = -18.84156223271319
# Significant!
# For features ('x32', 'x23', 'x102') with neg_root_mean_squared_error = -16.84572016971418
# Significant!
# For features ('x32', 'x23', 'x98') with neg_root_mean_squared_error = -17.34677355111736
# Significant!
# For features ('x32', 'x23', 'x162') with neg_root_mean_squared_error = -18.65392285495862
# Significant!
# For features ('x32', 'x23', 'x159') with neg_root_mean_squared_error = -17.32985199738889
# Significant!
# For features ('x32', 'x23', 'x173') with neg_root_mean_squared_error = -18.493010665660442
# Significant!
# For features ('x32', 'x23', 'x158') with neg_root_mean_squared_error = -16.86157646769606
# Significant!
# For features ('x32', 'x23', 'x177') with neg_root_mean_squared_error = -19.86396323390351
# Significant!
# For features ('x32', 'x23', 'x160') with neg_root_mean_squared_error = -17.85302721944897
# Significant!
# For features ('x8', 'x99', 'x23') with neg_root_mean_squared_error = -19.55324853601008
# Significant!
# For features ('x8', 'x23', 'x33') with neg_root_mean_squared_error = -19.84058300740715
# Significant!
# For features ('x8', 'x23', 'x102') with neg_root_mean_squared_error = -19.536195388825735
# Significant!
# For features ('x8', 'x23', 'x98') with neg_root_mean_squared_error = -19.826231086101835
# Significant!
# For features ('x8', 'x23', 'x159') with neg_root_mean_squared_error = -19.410034222772403
# Significant!
# For features ('x2', 'x23', 'x33') with neg_root_mean_squared_error = -19.047244611739334
# Significant!
# For features ('x2', 'x23', 'x102') with neg_root_mean_squared_error = -19.843521627380056
# Significant!
# For features ('x2', 'x23', 'x159') with neg_root_mean_squared_error = -19.634706330103707
# Significant!
# For features ('x4', 'x99', 'x23') with neg_root_mean_squared_error = -19.32838860938596
# Significant!
# For features ('x4', 'x23', 'x33') with neg_root_mean_squared_error = -19.59627836984775
# Significant!
# For features ('x4', 'x23', 'x102') with neg_root_mean_squared_error = -19.136220079468735
# Significant!
# For features ('x4', 'x23', 'x98') with neg_root_mean_squared_error = -19.599427743489887
# Significant!
# For features ('x4', 'x23', 'x159') with neg_root_mean_squared_error = -19.164971365273665
# Significant!
# For features ('x27', 'x99', 'x23') with neg_root_mean_squared_error = -19.900099391930826
# Significant!
# For features ('x27', 'x23', 'x33') with neg_root_mean_squared_error = -19.457358744453284
# Significant!
# For features ('x27', 'x23', 'x159') with neg_root_mean_squared_error = -19.844010142226715
# Significant!
# For features ('x99', 'x23', 'x6') with neg_root_mean_squared_error = -19.566968787513616
# Significant!
# For features ('x99', 'x23', 'x5') with neg_root_mean_squared_error = -19.921691669305037
# Significant!
# For features ('x99', 'x23', 'x39') with neg_root_mean_squared_error = -19.37158980735565
# Significant!
# For features ('x99', 'x23', 'x33') with neg_root_mean_squared_error = -17.539852227820177
# Significant!
# For features ('x99', 'x23', 'x159') with neg_root_mean_squared_error = -19.915270826737324
# Significant!
# For features ('x50', 'x23', 'x33') with neg_root_mean_squared_error = -18.824104962649262
# Significant!
# For features ('x50', 'x23', 'x159') with neg_root_mean_squared_error = -19.722193049904522
# Significant!
# For features ('x188', 'x23', 'x33') with neg_root_mean_squared_error = -19.104929422393376
# Significant!
# For features ('x188', 'x23', 'x159') with neg_root_mean_squared_error = -19.697324979578816
# Significant!
# For features ('x188', 'x33', 'x48') with neg_root_mean_squared_error = -18.605544005987547
# Significant!
# For features ('x45', 'x23', 'x33') with neg_root_mean_squared_error = -18.909884711161073
# Significant!
# For features ('x45', 'x23', 'x159') with neg_root_mean_squared_error = -19.74602074705553
# Significant!
# For features ('x42', 'x23', 'x33') with neg_root_mean_squared_error = -19.08089427763744
# Significant!
# For features ('x42', 'x23', 'x159') with neg_root_mean_squared_error = -19.68223223184809
# Significant!
# For features ('x193', 'x23', 'x33') with neg_root_mean_squared_error = -19.16489769324141
# Significant!
# For features ('x193', 'x23', 'x159') with neg_root_mean_squared_error = -19.727405338355407
# Significant!
# For features ('x193', 'x33', 'x48') with neg_root_mean_squared_error = -19.330212225918835
# Significant!
# For features ('x71', 'x23', 'x33') with neg_root_mean_squared_error = -18.63612541984908
# Significant!
# For features ('x23', 'x149', 'x33') with neg_root_mean_squared_error = -19.00427078602581
# Significant!
# For features ('x23', 'x149', 'x159') with neg_root_mean_squared_error = -19.632140406679405
# Significant!
# For features ('x23', 'x6', 'x33') with neg_root_mean_squared_error = -19.321893763364262
# Significant!
# For features ('x23', 'x6', 'x102') with neg_root_mean_squared_error = -19.024738349454235
# Significant!
# For features ('x23', 'x6', 'x98') with neg_root_mean_squared_error = -19.67814445852132
# Significant!
# For features ('x23', 'x6', 'x159') with neg_root_mean_squared_error = -19.49348826257772
# Significant!
# For features ('x23', 'x5', 'x33') with neg_root_mean_squared_error = -19.749190590019236
# Significant!
# For features ('x23', 'x5', 'x102') with neg_root_mean_squared_error = -19.889513260636942
# Significant!
# For features ('x23', 'x5', 'x159') with neg_root_mean_squared_error = -19.456402396771765
# Significant!
# For features ('x23', 'x39', 'x33') with neg_root_mean_squared_error = -19.852678316773865
# Significant!
# For features ('x23', 'x39', 'x102') with neg_root_mean_squared_error = -19.255810929575485
# Significant!
# For features ('x23', 'x39', 'x98') with neg_root_mean_squared_error = -19.630568596374292
# Significant!
# For features ('x23', 'x39', 'x159') with neg_root_mean_squared_error = -19.25695381770837
# Significant!
# For features ('x23', 'x175', 'x33') with neg_root_mean_squared_error = -18.95611209794985
# Significant!
# For features ('x23', 'x175', 'x102') with neg_root_mean_squared_error = -18.711833947509472
# Significant!
# For features ('x23', 'x175', 'x162') with neg_root_mean_squared_error = -19.962884834394732
# Significant!
# For features ('x23', 'x175', 'x159') with neg_root_mean_squared_error = -19.746512534695036
# Significant!
# For features ('x23', 'x67', 'x33') with neg_root_mean_squared_error = -18.657938883585373
# Significant!
# For features ('x23', 'x67', 'x102') with neg_root_mean_squared_error = -19.90595223763406
# Significant!
# For features ('x23', 'x41', 'x33') with neg_root_mean_squared_error = -19.018473309548288
# Significant!
# For features ('x23', 'x33', 'x148') with neg_root_mean_squared_error = -19.13620695139884
# Significant!
# For features ('x23', 'x33', 'x194') with neg_root_mean_squared_error = -19.195834406549086
# Significant!
# For features ('x23', 'x33', 'x102') with neg_root_mean_squared_error = -17.550412590872433
# Significant!
# For features ('x23', 'x33', 'x150') with neg_root_mean_squared_error = -19.07217565112791
# Significant!
# For features ('x23', 'x33', 'x98') with neg_root_mean_squared_error = -17.72892227371715
# Significant!
# For features ('x23', 'x33', 'x162') with neg_root_mean_squared_error = -18.882990424784573
# Significant!
# For features ('x23', 'x33', 'x159') with neg_root_mean_squared_error = -17.974606798145594
# Significant!
# For features ('x23', 'x33', 'x195') with neg_root_mean_squared_error = -19.116913107193888
# Significant!
# For features ('x23', 'x33', 'x61') with neg_root_mean_squared_error = -18.92753898553287
# Significant!
# For features ('x23', 'x33', 'x58') with neg_root_mean_squared_error = -18.806641190269268
# Significant!
# For features ('x23', 'x33', 'x9') with neg_root_mean_squared_error = -19.337914253820422
# Significant!
# For features ('x23', 'x33', 'x152') with neg_root_mean_squared_error = -19.061318153261237
# Significant!
# For features ('x23', 'x33', 'x43') with neg_root_mean_squared_error = -19.596306741639136
# Significant!
# For features ('x23', 'x33', 'x173') with neg_root_mean_squared_error = -18.690924720127576
# Significant!
# For features ('x23', 'x33', 'x158') with neg_root_mean_squared_error = -17.421071494283513
# Significant!
# For features ('x23', 'x33', 'x177') with neg_root_mean_squared_error = -19.16839518077064
# Significant!
# For features ('x23', 'x33', 'x63') with neg_root_mean_squared_error = -18.72929689124396
# Significant!
# For features ('x23', 'x33', 'x160') with neg_root_mean_squared_error = -18.063059673771924
# Significant!
# For features ('x23', 'x33', 'x213') with neg_root_mean_squared_error = -19.12936676253358
# Significant!
# For features ('x23', 'x33', 'x3') with neg_root_mean_squared_error = -19.37002322201146
# Significant!
# For features ('x23', 'x33', 'x48') with neg_root_mean_squared_error = -19.03943326246494
# Significant!
# For features ('x23', 'x148', 'x159') with neg_root_mean_squared_error = -19.73985667938786
# Significant!
# For features ('x23', 'x194', 'x159') with neg_root_mean_squared_error = -19.73406107900142
# Significant!
# For features ('x23', 'x102', 'x9') with neg_root_mean_squared_error = -19.942666522698058
# Significant!
# For features ('x23', 'x102', 'x63') with neg_root_mean_squared_error = -19.897876373949728
# Significant!
# For features ('x23', 'x150', 'x159') with neg_root_mean_squared_error = -19.68992756271857
# Significant!
# For features ('x23', 'x98', 'x159') with neg_root_mean_squared_error = -19.854477974382434
# Significant!
# For features ('x23', 'x162', 'x159') with neg_root_mean_squared_error = -19.97270369198499
# Significant!
# For features ('x23', 'x159', 'x195') with neg_root_mean_squared_error = -19.708249553029
# Significant!
# For features ('x23', 'x159', 'x9') with neg_root_mean_squared_error = -19.612998656984782
# Significant!
# For features ('x23', 'x159', 'x152') with neg_root_mean_squared_error = -19.685509801382857
# Significant!
# For features ('x23', 'x159', 'x43') with neg_root_mean_squared_error = -19.954711160575677
# Significant!
# For features ('x23', 'x159', 'x173') with neg_root_mean_squared_error = -19.83079129559783
# Significant!
# For features ('x23', 'x159', 'x177') with neg_root_mean_squared_error = -19.977480649920686
# Significant!
# For features ('x23', 'x159', 'x160') with neg_root_mean_squared_error = -19.76314060273678
# Significant!
# For features ('x23', 'x159', 'x213') with neg_root_mean_squared_error = -19.705718758103338
# Significant!
# For features ('x23', 'x159', 'x3') with neg_root_mean_squared_error = -19.85719927631443
# Significant!
# For features ('x23', 'x159', 'x7') with neg_root_mean_squared_error = -19.63505159369824
# Significant!
# For features ('x23', 'x159', 'x48') with neg_root_mean_squared_error = -19.68226767219449
# Significant!
# For features ('x23', 'x158', 'x160') with neg_root_mean_squared_error = -18.973494346853187

# %%
len(List2_2cvd_3_nrmse)
# Out:
# 114

# %%
List3_2cvd_3_nrmse,List3_2cvd_2_nrmse,List3_2cvd_0_nrmse = combnfeats_MLR_evaby_crossval_metric(List2_2cvd_3_nrmse,df_x,df_y,10,model,'neg_root_mean_squared_error',-18)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x32', 'x99', 'x23') with neg_root_mean_squared_error = -16.86261104842348
# Significant!
# For features ('x32', 'x23', 'x102') with neg_root_mean_squared_error = -16.981337084268457
# Significant!
# For features ('x32', 'x23', 'x98') with neg_root_mean_squared_error = -17.186978944364938
# Significant!
# For features ('x32', 'x23', 'x159') with neg_root_mean_squared_error = -17.289543565684955
# Significant!
# For features ('x32', 'x23', 'x158') with neg_root_mean_squared_error = -17.15711083825868
# Significant!
# For features ('x99', 'x23', 'x33') with neg_root_mean_squared_error = -17.747758296968858
# Significant!
# For features ('x23', 'x33', 'x102') with neg_root_mean_squared_error = -17.826557352864402
# Significant!
# For features ('x23', 'x33', 'x98') with neg_root_mean_squared_error = -17.89928133950422
# Significant!
# For features ('x23', 'x33', 'x158') with neg_root_mean_squared_error = -17.860055838780234

# %%
a,b,c= combnfeats_MLR_evaby_crossval_metric(List3_2cvd_3_nrmse,df_x,df_y,500,model,'neg_root_mean_squared_error',-18)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x32', 'x99', 'x23') with neg_root_mean_squared_error = -16.830660157434497
# Significant!
# For features ('x32', 'x23', 'x102') with neg_root_mean_squared_error = -16.793635014345263
# Significant!
# For features ('x32', 'x23', 'x98') with neg_root_mean_squared_error = -17.06301570096567
# Significant!
# For features ('x32', 'x23', 'x159') with neg_root_mean_squared_error = -17.03779748224993
# Significant!
# For features ('x32', 'x23', 'x158') with neg_root_mean_squared_error = -17.172289222048907
# Significant!
# For features ('x99', 'x23', 'x33') with neg_root_mean_squared_error = -17.560090246670335
# Significant!
# For features ('x23', 'x33', 'x102') with neg_root_mean_squared_error = -17.54899133870348
# Significant!
# For features ('x23', 'x33', 'x98') with neg_root_mean_squared_error = -17.642704885256933
# Significant!
# For features ('x23', 'x33', 'x158') with neg_root_mean_squared_error = -17.695997282170747

# %% [markdown]
# 'x32', 'x23', 'x102'

# %% [markdown]
# max error

# %%
List_2cvd_3_me,List_2cvd_2_me,List_2cvd_0_me = combnfeats_MLR_evaby_crossval_metric(feats,df_x,df_y,5,model,'max_error',-20)
# Out:
# ----------Linear regression of n features evaby crossval starts----------

# %%
len(List_2cvd_0_me)
# Out:
# 668

# %%
List2_2cvd_3_me,List2_2cvd_2_me,List2_2cvd_0_me = combnfeats_MLR_evaby_crossval_metric(List_2cvd_0_me,df_x,df_y,5,model,'max_error',-37)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x32', 'x23') with max_error = -35.371683154204824
# Significant!
# For features ('x186', 'x8', 'x23') with max_error = -36.74492717947379
# Significant!
# For features ('x186', 'x2', 'x33') with max_error = -36.180444682488485
# Significant!
# For features ('x186', 'x99', 'x23') with max_error = -35.66572964117487
# Significant!
# For features ('x186', 'x23', 'x39') with max_error = -36.92126953156729
# Significant!
# For features ('x186', 'x23', 'x33') with max_error = -33.19930753155171
# Significant!
# For features ('x186', 'x23', 'x98') with max_error = -36.62495378781877
# Significant!
# For features ('x186', 'x23', 'x159') with max_error = -35.747285778603946
# Significant!
# For features ('x49', 'x2', 'x33') with max_error = -36.2416480201177
# Significant!
# For features ('x49', 'x23', 'x33') with max_error = -33.344874185315376
# Significant!
# For features ('x49', 'x23', 'x159') with max_error = -35.476199349780515
# Significant!
# For features ('x32', 'x8', 'x23') with max_error = -35.29642274301798
# Significant!
# For features ('x32', 'x8', 'x158') with max_error = -36.96067584398422
# Significant!
# For features ('x32', 'x2', 'x23') with max_error = -34.66194378960323
# Significant!
# For features ('x32', 'x2', 'x33') with max_error = -36.93705262182083
# Significant!
# For features ('x32', 'x4', 'x23') with max_error = -35.438632091447325
# Significant!
# For features ('x32', 'x27', 'x23') with max_error = -36.63099017528243
# Significant!
# For features ('x32', 'x27', 'x41') with max_error = -35.989807804911635
# Significant!
# For features ('x32', 'x99', 'x23') with max_error = -31.155108641030182
# Significant!
# For features ('x32', 'x50', 'x23') with max_error = -35.992852581107364
# Significant!
# For features ('x32', 'x45', 'x23') with max_error = -36.22234289544605
# Significant!
# For features ('x32', 'x71', 'x23') with max_error = -34.99690704255739
# Significant!
# For features ('x32', 'x23', 'x6') with max_error = -36.103396459876684
# Significant!
# For features ('x32', 'x23', 'x5') with max_error = -35.730125609544466
# Significant!
# For features ('x32', 'x23', 'x39') with max_error = -35.36990295439689
# Significant!
# For features ('x32', 'x23', 'x175') with max_error = -35.24669341810786
# Significant!
# For features ('x32', 'x23', 'x67') with max_error = -35.55595017136031
# Significant!
# For features ('x32', 'x23', 'x41') with max_error = -34.639601686674006
# Significant!
# For features ('x32', 'x23', 'x33') with max_error = -32.644257307763304
# Significant!
# For features ('x32', 'x23', 'x102') with max_error = -32.3921545382325
# Significant!
# For features ('x32', 'x23', 'x98') with max_error = -31.550452956969263
# Significant!
# For features ('x32', 'x23', 'x162') with max_error = -33.821391094303934
# Significant!
# For features ('x32', 'x23', 'x159') with max_error = -31.638197409924466
# Significant!
# For features ('x32', 'x23', 'x61') with max_error = -35.63847150777934
# Significant!
# For features ('x32', 'x23', 'x58') with max_error = -35.317012876136566
# Significant!
# For features ('x32', 'x23', 'x9') with max_error = -36.07777812006985
# Significant!
# For features ('x32', 'x23', 'x43') with max_error = -36.692467386318604
# Significant!
# For features ('x32', 'x23', 'x173') with max_error = -33.41233153652467
# Significant!
# For features ('x32', 'x23', 'x158') with max_error = -30.886087221987275
# Significant!
# For features ('x32', 'x23', 'x177') with max_error = -34.701302372590966
# Significant!
# For features ('x32', 'x23', 'x63') with max_error = -35.51341551284808
# Significant!
# For features ('x32', 'x23', 'x160') with max_error = -32.10814376285533
# Significant!
# For features ('x32', 'x23', 'x3') with max_error = -36.03152462521204
# Significant!
# For features ('x32', 'x23', 'x7') with max_error = -36.22436206725758
# Significant!
# For features ('x8', 'x2', 'x33') with max_error = -36.48845644604695
# Significant!
# For features ('x8', 'x99', 'x23') with max_error = -34.312280727972606
# Significant!
# For features ('x8', 'x23', 'x67') with max_error = -36.74531041606417
# Significant!
# For features ('x8', 'x23', 'x33') with max_error = -33.38520857452646
# Significant!
# For features ('x8', 'x23', 'x102') with max_error = -35.88371961395404
# Significant!
# For features ('x8', 'x23', 'x98') with max_error = -35.30342362977821
# Significant!
# For features ('x8', 'x23', 'x159') with max_error = -34.27857280720588
# Significant!
# For features ('x8', 'x23', 'x58') with max_error = -36.51832400556088
# Significant!
# For features ('x2', 'x4', 'x33') with max_error = -36.700651884739486
# Significant!
# For features ('x2', 'x27', 'x33') with max_error = -36.92736374661111
# Significant!
# For features ('x2', 'x99', 'x23') with max_error = -36.955233691997925
# Significant!
# For features ('x2', 'x99', 'x33') with max_error = -36.381523691750694
# Significant!
# For features ('x2', 'x50', 'x33') with max_error = -36.92986730954095
# Significant!
# For features ('x2', 'x188', 'x33') with max_error = -36.189944979674266
# Significant!
# For features ('x2', 'x45', 'x33') with max_error = -36.15968104020719
# Significant!
# For features ('x2', 'x42', 'x33') with max_error = -36.14482732722176
# Significant!
# For features ('x2', 'x193', 'x33') with max_error = -36.223182209042186
# Significant!
# For features ('x2', 'x71', 'x33') with max_error = -35.071420971672666
# Significant!
# For features ('x2', 'x23', 'x33') with max_error = -32.49835948716246
# Significant!
# For features ('x2', 'x23', 'x159') with max_error = -35.50318469778746
# Significant!
# For features ('x2', 'x149', 'x33') with max_error = -35.60307203336714
# Significant!
# For features ('x2', 'x39', 'x33') with max_error = -36.53927429243733
# Significant!
# For features ('x2', 'x175', 'x33') with max_error = -36.94308938164791
# Significant!
# For features ('x2', 'x67', 'x33') with max_error = -35.07694793512854
# Significant!
# For features ('x2', 'x41', 'x33') with max_error = -36.042605566956155
# Significant!
# For features ('x2', 'x33', 'x148') with max_error = -36.19428245261171
# Significant!
# For features ('x2', 'x33', 'x194') with max_error = -35.783690511128576
# Significant!
# For features ('x2', 'x33', 'x102') with max_error = -36.694621365847404
# Significant!
# For features ('x2', 'x33', 'x150') with max_error = -36.172751439196546
# Significant!
# For features ('x2', 'x33', 'x98') with max_error = -36.213031130457956
# Significant!
# For features ('x2', 'x33', 'x162') with max_error = -36.26263290667703
# Significant!
# For features ('x2', 'x33', 'x159') with max_error = -36.45629134679353
# Significant!
# For features ('x2', 'x33', 'x195') with max_error = -36.18471446025743
# Significant!
# For features ('x2', 'x33', 'x61') with max_error = -35.707717604763864
# Significant!
# For features ('x2', 'x33', 'x58') with max_error = -35.90070682943501
# Significant!
# For features ('x2', 'x33', 'x152') with max_error = -36.178071098657426
# Significant!
# For features ('x2', 'x33', 'x173') with max_error = -36.6444315161808
# Significant!
# For features ('x2', 'x33', 'x158') with max_error = -36.95606811478439
# Significant!
# For features ('x2', 'x33', 'x63') with max_error = -35.46677611409763
# Significant!
# For features ('x2', 'x33', 'x213') with max_error = -36.15521338168308
# Significant!
# For features ('x2', 'x33', 'x3') with max_error = -36.934138216210215
# Significant!
# For features ('x2', 'x33', 'x48') with max_error = -36.0975408592051
# Significant!
# For features ('x4', 'x99', 'x23') with max_error = -34.31191922051899
# Significant!
# For features ('x4', 'x23', 'x33') with max_error = -33.40960609626888
# Significant!
# For features ('x4', 'x23', 'x102') with max_error = -35.8698922939346
# Significant!
# For features ('x4', 'x23', 'x98') with max_error = -35.17767277146466
# Significant!
# For features ('x4', 'x23', 'x159') with max_error = -33.77410728612731
# Significant!
# For features ('x4', 'x23', 'x158') with max_error = -36.48941853482795
# Significant!
# For features ('x27', 'x99', 'x23') with max_error = -36.697427233800745
# Significant!
# For features ('x27', 'x23', 'x33') with max_error = -33.52363884664519
# Significant!
# For features ('x27', 'x23', 'x159') with max_error = -36.00460593384359
# Significant!
# For features ('x27', 'x23', 'x7') with max_error = -36.62111162000624
# Significant!
# For features ('x27', 'x41', 'x33') with max_error = -36.54955546783075
# Significant!
# For features ('x99', 'x50', 'x23') with max_error = -36.79289526367502
# Significant!
# For features ('x99', 'x45', 'x23') with max_error = -36.90446591401544
# Significant!
# For features ('x99', 'x23', 'x149') with max_error = -36.777896735232574
# Significant!
# For features ('x99', 'x23', 'x5') with max_error = -34.261487247509024
# Significant!
# For features ('x99', 'x23', 'x39') with max_error = -33.953012378172645
# Significant!
# For features ('x99', 'x23', 'x175') with max_error = -35.75170628353787
# Significant!
# For features ('x99', 'x23', 'x67') with max_error = -36.75057353995793
# Significant!
# For features ('x99', 'x23', 'x33') with max_error = -31.141804043324118
# Significant!
# For features ('x99', 'x23', 'x159') with max_error = -35.89822838065617
# Significant!
# For features ('x99', 'x23', 'x63') with max_error = -36.720698984201746
# Significant!
# For features ('x99', 'x23', 'x3') with max_error = -36.87341933842435
# Significant!
# For features ('x99', 'x23', 'x7') with max_error = -34.47515688064638
# Significant!
# For features ('x50', 'x23', 'x33') with max_error = -33.09189220118008
# Significant!
# For features ('x50', 'x23', 'x159') with max_error = -35.414388989580175
# Significant!
# For features ('x188', 'x23', 'x149') with max_error = -36.04340593027645
# Significant!
# For features ('x188', 'x23', 'x33') with max_error = -33.26715388248615
# Significant!
# For features ('x188', 'x23', 'x159') with max_error = -35.5110201761011
# Significant!
# For features ('x188', 'x33', 'x48') with max_error = -33.05015203995353
# Significant!
# For features ('x45', 'x23', 'x33') with max_error = -32.87882971723472
# Significant!
# For features ('x45', 'x23', 'x159') with max_error = -35.58342151405834
# Significant!
# For features ('x42', 'x23', 'x33') with max_error = -33.282987395803495
# Significant!
# For features ('x42', 'x23', 'x159') with max_error = -35.46096185627698
# Significant!
# For features ('x193', 'x23', 'x149') with max_error = -35.795159023848996
# Significant!
# For features ('x193', 'x23', 'x33') with max_error = -33.36499970817503
# Significant!
# For features ('x193', 'x23', 'x159') with max_error = -35.6215323270827
# Significant!
# For features ('x193', 'x33', 'x48') with max_error = -33.23950715249017
# Significant!
# For features ('x71', 'x23', 'x33') with max_error = -31.516348673196624
# Significant!
# For features ('x71', 'x23', 'x159') with max_error = -36.134350956499546
# Significant!
# For features ('x23', 'x149', 'x33') with max_error = -33.59222962943403
# Significant!
# For features ('x23', 'x149', 'x148') with max_error = -36.10774137398529
# Significant!
# For features ('x23', 'x149', 'x194') with max_error = -35.40303981296806
# Significant!
# For features ('x23', 'x149', 'x159') with max_error = -35.55256394048316
# Significant!
# For features ('x23', 'x149', 'x195') with max_error = -36.19532770285071
# Significant!
# For features ('x23', 'x6', 'x33') with max_error = -33.120566351394345
# Significant!
# For features ('x23', 'x6', 'x159') with max_error = -36.88507011526186
# Significant!
# For features ('x23', 'x5', 'x33') with max_error = -33.60624934948411
# Significant!
# For features ('x23', 'x5', 'x102') with max_error = -35.976593561655065
# Significant!
# For features ('x23', 'x5', 'x98') with max_error = -35.35968701081939
# Significant!
# For features ('x23', 'x5', 'x159') with max_error = -34.025236439169866
# Significant!
# For features ('x23', 'x5', 'x173') with max_error = -36.7562470327116
# Significant!
# For features ('x23', 'x5', 'x177') with max_error = -36.74237086762848
# Significant!
# For features ('x23', 'x39', 'x67') with max_error = -36.74527132998056
# Significant!
# For features ('x23', 'x39', 'x33') with max_error = -33.60324675409839
# Significant!
# For features ('x23', 'x39', 'x102') with max_error = -35.476354838904996
# Significant!
# For features ('x23', 'x39', 'x98') with max_error = -34.86802964980784
# Significant!
# For features ('x23', 'x39', 'x159') with max_error = -33.77880566598073
# Significant!
# For features ('x23', 'x39', 'x58') with max_error = -36.67302719410165
# Significant!
# For features ('x23', 'x39', 'x158') with max_error = -36.513574715362225
# Significant!
# For features ('x23', 'x175', 'x33') with max_error = -32.75932827667684
# Significant!
# For features ('x23', 'x175', 'x102') with max_error = -36.74725396086407
# Significant!
# For features ('x23', 'x175', 'x159') with max_error = -34.99016338814944
# Significant!
# For features ('x23', 'x175', 'x173') with max_error = -36.79467354515774
# Significant!
# For features ('x23', 'x67', 'x33') with max_error = -31.433338577940294
# Significant!
# For features ('x23', 'x67', 'x159') with max_error = -35.962381869569995
# Significant!
# For features ('x23', 'x41', 'x33') with max_error = -32.201255347091646
# Significant!
# For features ('x23', 'x41', 'x159') with max_error = -36.74679810690892
# Significant!
# For features ('x23', 'x33', 'x148') with max_error = -33.46027340323867
# Significant!
# For features ('x23', 'x33', 'x194') with max_error = -33.48459436656159
# Significant!
# For features ('x23', 'x33', 'x102') with max_error = -32.43840074999067
# Significant!
# For features ('x23', 'x33', 'x150') with max_error = -33.28054038557324
# Significant!
# For features ('x23', 'x33', 'x98') with max_error = -31.48961495082194
# Significant!
# For features ('x23', 'x33', 'x162') with max_error = -33.25545617728514
# Significant!
# For features ('x23', 'x33', 'x159') with max_error = -31.299204229720964
# Significant!
# For features ('x23', 'x33', 'x195') with max_error = -33.30121249395209
# Significant!
# For features ('x23', 'x33', 'x61') with max_error = -32.108526776670104
# Significant!
# For features ('x23', 'x33', 'x58') with max_error = -31.894755955282704
# Significant!
# For features ('x23', 'x33', 'x9') with max_error = -33.00545565694419
# Significant!
# For features ('x23', 'x33', 'x152') with max_error = -33.25951098314069
# Significant!
# For features ('x23', 'x33', 'x43') with max_error = -34.112795062415486
# Significant!
# For features ('x23', 'x33', 'x173') with max_error = -32.87704984596915
# Significant!
# For features ('x23', 'x33', 'x158') with max_error = -31.20987500120981
# Significant!
# For features ('x23', 'x33', 'x177') with max_error = -33.26129741930178
# Significant!
# For features ('x23', 'x33', 'x63') with max_error = -31.591755901634876
# Significant!
# For features ('x23', 'x33', 'x160') with max_error = -31.466380473859694
# Significant!
# For features ('x23', 'x33', 'x213') with max_error = -33.359375812894164
# Significant!
# For features ('x23', 'x33', 'x3') with max_error = -33.01229607245428
# Significant!
# For features ('x23', 'x33', 'x7') with max_error = -35.059145772504586
# Significant!
# For features ('x23', 'x33', 'x48') with max_error = -33.33353182106537
# Significant!
# For features ('x23', 'x148', 'x159') with max_error = -35.72177662280744
# Significant!
# For features ('x23', 'x194', 'x159') with max_error = -35.68021726974689
# Significant!
# For features ('x23', 'x102', 'x159') with max_error = -36.6701001658986
# Significant!
# For features ('x23', 'x102', 'x7') with max_error = -36.51433400736144
# Significant!
# For features ('x23', 'x150', 'x159') with max_error = -35.49263235721531
# Significant!
# For features ('x23', 'x98', 'x159') with max_error = -35.83200872707074
# Significant!
# For features ('x23', 'x98', 'x7') with max_error = -36.05287150659234
# Significant!
# For features ('x23', 'x162', 'x159') with max_error = -35.66232081605886
# Significant!
# For features ('x23', 'x159', 'x195') with max_error = -35.534251454330416
# Significant!
# For features ('x23', 'x159', 'x58') with max_error = -36.05469851347779
# Significant!
# For features ('x23', 'x159', 'x9') with max_error = -36.81441216899199
# Significant!
# For features ('x23', 'x159', 'x152') with max_error = -35.481451403203025
# Significant!
# For features ('x23', 'x159', 'x43') with max_error = -36.45117997571475
# Significant!
# For features ('x23', 'x159', 'x173') with max_error = -35.46394593247499
# Significant!
# For features ('x23', 'x159', 'x158') with max_error = -35.90572712601939
# Significant!
# For features ('x23', 'x159', 'x177') with max_error = -35.558411987599854
# Significant!
# For features ('x23', 'x159', 'x63') with max_error = -35.87287209059788
# Significant!
# For features ('x23', 'x159', 'x160') with max_error = -35.589511702573915
# Significant!
# For features ('x23', 'x159', 'x213') with max_error = -35.54765367698136
# Significant!
# For features ('x23', 'x159', 'x3') with max_error = -35.28419266895797
# Significant!
# For features ('x23', 'x159', 'x7') with max_error = -34.44124198168121
# Significant!
# For features ('x23', 'x159', 'x48') with max_error = -35.493532468441856
# Significant!
# For features ('x23', 'x158', 'x160') with max_error = -34.216589291943784
# Significant!
# For features ('x41', 'x33', 'x3') with max_error = -36.1140799425893
# Significant!
# For features ('x33', 'x195', 'x48') with max_error = -35.94510809925962
# Significant!
# For features ('x33', 'x213', 'x48') with max_error = -35.54681559551033

# %%
len(List2_2cvd_3_me)
# Out:
# 201

# %%
List3_2cvd_3_me,List3_2cvd_2_me,List3_2cvd_0_me = combnfeats_MLR_evaby_crossval_metric(List2_2cvd_3_me,df_x,df_y,10,model,'max_error',-36)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x32', 'x23') with max_error = -35.141455176083944
# Significant!
# For features ('x186', 'x23', 'x33') with max_error = -33.817030256876436
# Significant!
# For features ('x49', 'x23', 'x33') with max_error = -34.17644041871508
# Significant!
# For features ('x32', 'x8', 'x23') with max_error = -35.24328258577718
# Significant!
# For features ('x32', 'x2', 'x23') with max_error = -34.539313262758
# Significant!
# For features ('x32', 'x4', 'x23') with max_error = -35.04866418320002
# Significant!
# For features ('x32', 'x27', 'x23') with max_error = -35.701679513308214
# Significant!
# For features ('x32', 'x27', 'x41') with max_error = -35.85780553299511
# Significant!
# For features ('x32', 'x99', 'x23') with max_error = -30.50745226782563
# Significant!
# For features ('x32', 'x50', 'x23') with max_error = -35.81328959724969
# Significant!
# For features ('x32', 'x71', 'x23') with max_error = -35.38742348350519
# Significant!
# For features ('x32', 'x23', 'x6') with max_error = -35.75128912718356
# Significant!
# For features ('x32', 'x23', 'x5') with max_error = -35.127533550388605
# Significant!
# For features ('x32', 'x23', 'x39') with max_error = -35.14490200163461
# Significant!
# For features ('x32', 'x23', 'x175') with max_error = -35.47343038064076
# Significant!
# For features ('x32', 'x23', 'x67') with max_error = -35.31379154261025
# Significant!
# For features ('x32', 'x23', 'x41') with max_error = -34.81629765193803
# Significant!
# For features ('x32', 'x23', 'x33') with max_error = -33.41736369876861
# Significant!
# For features ('x32', 'x23', 'x102') with max_error = -32.81497421151206
# Significant!
# For features ('x32', 'x23', 'x98') with max_error = -30.987658106729736
# Significant!
# For features ('x32', 'x23', 'x162') with max_error = -34.160072710475205
# Significant!
# For features ('x32', 'x23', 'x159') with max_error = -31.07860011193775
# Significant!
# For features ('x32', 'x23', 'x61') with max_error = -35.309811060855296
# Significant!
# For features ('x32', 'x23', 'x58') with max_error = -35.715347359717896
# Significant!
# For features ('x32', 'x23', 'x9') with max_error = -35.80892938945677
# Significant!
# For features ('x32', 'x23', 'x173') with max_error = -33.748147448358836
# Significant!
# For features ('x32', 'x23', 'x158') with max_error = -31.111084492061842
# Significant!
# For features ('x32', 'x23', 'x177') with max_error = -35.00914996977191
# Significant!
# For features ('x32', 'x23', 'x63') with max_error = -35.63773713502337
# Significant!
# For features ('x32', 'x23', 'x160') with max_error = -32.19983399991553
# Significant!
# For features ('x32', 'x23', 'x3') with max_error = -35.407769420677255
# Significant!
# For features ('x32', 'x23', 'x7') with max_error = -35.39563241543444
# Significant!
# For features ('x8', 'x99', 'x23') with max_error = -34.92326399740774
# Significant!
# For features ('x8', 'x23', 'x33') with max_error = -34.061476046845236
# Significant!
# For features ('x8', 'x23', 'x159') with max_error = -35.08477181288028
# Significant!
# For features ('x2', 'x4', 'x33') with max_error = -35.56356994973318
# Significant!
# For features ('x2', 'x99', 'x33') with max_error = -35.89179646429064
# Significant!
# For features ('x2', 'x71', 'x33') with max_error = -35.141108178268354
# Significant!
# For features ('x2', 'x23', 'x33') with max_error = -32.57409312532511
# Significant!
# For features ('x2', 'x149', 'x33') with max_error = -35.92612123871893
# Significant!
# For features ('x2', 'x39', 'x33') with max_error = -35.652220118666555
# Significant!
# For features ('x2', 'x67', 'x33') with max_error = -35.103659568212414
# Significant!
# For features ('x2', 'x41', 'x33') with max_error = -35.49676935461433
# Significant!
# For features ('x2', 'x33', 'x98') with max_error = -35.777469670477934
# Significant!
# For features ('x2', 'x33', 'x61') with max_error = -35.65444456688201
# Significant!
# For features ('x2', 'x33', 'x63') with max_error = -35.70430679464081
# Significant!
# For features ('x4', 'x99', 'x23') with max_error = -35.113142011111584
# Significant!
# For features ('x4', 'x23', 'x33') with max_error = -33.621177033008934
# Significant!
# For features ('x4', 'x23', 'x159') with max_error = -34.53139657568272
# Significant!
# For features ('x27', 'x23', 'x33') with max_error = -33.92965820619678
# Significant!
# For features ('x99', 'x23', 'x5') with max_error = -35.44995279088325
# Significant!
# For features ('x99', 'x23', 'x39') with max_error = -34.76813480955417
# Significant!
# For features ('x99', 'x23', 'x33') with max_error = -31.7311248397398
# Significant!
# For features ('x99', 'x23', 'x7') with max_error = -35.478741295959026
# Significant!
# For features ('x50', 'x23', 'x33') with max_error = -33.741771025315174
# Significant!
# For features ('x188', 'x23', 'x33') with max_error = -34.34910451605166
# Significant!
# For features ('x188', 'x33', 'x48') with max_error = -33.55042574480436
# Significant!
# For features ('x45', 'x23', 'x33') with max_error = -33.86422084808028
# Significant!
# For features ('x42', 'x23', 'x33') with max_error = -34.30756799034117
# Significant!
# For features ('x193', 'x23', 'x33') with max_error = -34.45477657503542
# Significant!
# For features ('x193', 'x33', 'x48') with max_error = -33.666868597160075
# Significant!
# For features ('x71', 'x23', 'x33') with max_error = -32.571715536195164
# Significant!
# For features ('x23', 'x149', 'x33') with max_error = -34.43763804469806
# Significant!
# For features ('x23', 'x6', 'x33') with max_error = -33.60757944432029
# Significant!
# For features ('x23', 'x5', 'x33') with max_error = -33.85972726237206
# Significant!
# For features ('x23', 'x5', 'x159') with max_error = -35.01742806922232
# Significant!
# For features ('x23', 'x39', 'x33') with max_error = -33.7889829750455
# Significant!
# For features ('x23', 'x39', 'x159') with max_error = -34.57819716652852
# Significant!
# For features ('x23', 'x175', 'x33') with max_error = -33.62934712240057
# Significant!
# For features ('x23', 'x175', 'x159') with max_error = -35.261063681181724
# Significant!
# For features ('x23', 'x67', 'x33') with max_error = -32.148231347289254
# Significant!
# For features ('x23', 'x41', 'x33') with max_error = -33.07554057172092
# Significant!
# For features ('x23', 'x33', 'x148') with max_error = -34.53581622555532
# Significant!
# For features ('x23', 'x33', 'x194') with max_error = -34.67447961446676
# Significant!
# For features ('x23', 'x33', 'x102') with max_error = -33.39416926945373
# Significant!
# For features ('x23', 'x33', 'x150') with max_error = -34.281012108321576
# Significant!
# For features ('x23', 'x33', 'x98') with max_error = -32.22739322354728
# Significant!
# For features ('x23', 'x33', 'x162') with max_error = -34.25732546274658
# Significant!
# For features ('x23', 'x33', 'x159') with max_error = -31.910424817004547
# Significant!
# For features ('x23', 'x33', 'x195') with max_error = -34.36437092253094
# Significant!
# For features ('x23', 'x33', 'x61') with max_error = -32.89728842340349
# Significant!
# For features ('x23', 'x33', 'x58') with max_error = -32.76978748573974
# Significant!
# For features ('x23', 'x33', 'x9') with max_error = -33.75601439705159
# Significant!
# For features ('x23', 'x33', 'x152') with max_error = -34.23777636896379
# Significant!
# For features ('x23', 'x33', 'x43') with max_error = -34.701259734350344
# Significant!
# For features ('x23', 'x33', 'x173') with max_error = -33.66500304592304
# Significant!
# For features ('x23', 'x33', 'x158') with max_error = -32.264720200690306
# Significant!
# For features ('x23', 'x33', 'x177') with max_error = -34.36167812717773
# Significant!
# For features ('x23', 'x33', 'x63') with max_error = -32.45447041384696
# Significant!
# For features ('x23', 'x33', 'x160') with max_error = -32.51222662771355
# Significant!
# For features ('x23', 'x33', 'x213') with max_error = -34.39715424432027
# Significant!
# For features ('x23', 'x33', 'x3') with max_error = -33.83413880373716
# Significant!
# For features ('x23', 'x33', 'x7') with max_error = -34.55380655298573
# Significant!
# For features ('x23', 'x33', 'x48') with max_error = -34.33985166346874
# Significant!
# For features ('x23', 'x159', 'x173') with max_error = -35.95268025264505
# Significant!
# For features ('x23', 'x159', 'x177') with max_error = -35.98736613291848
# Significant!
# For features ('x23', 'x159', 'x160') with max_error = -35.94487090668687
# Significant!
# For features ('x23', 'x159', 'x3') with max_error = -35.92008089417286
# Significant!
# For features ('x23', 'x159', 'x7') with max_error = -35.208108263343505
# Significant!
# For features ('x23', 'x158', 'x160') with max_error = -35.25836125937282
# Significant!
# For features ('x33', 'x213', 'x48') with max_error = -34.530778866829635

# %%
len(List3_2cvd_3_me)
# Out:
# 101

# %%
List4_2cvd_3_me,List4_2cvd_2_me,List4_2cvd_0_me = combnfeats_MLR_evaby_crossval_metric(List3_2cvd_3_me,df_x,df_y,20,model,'max_error',-34)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x186', 'x23', 'x33') with max_error = -33.67384744102054
# Significant!
# For features ('x32', 'x2', 'x23') with max_error = -33.85163111918706
# Significant!
# For features ('x32', 'x99', 'x23') with max_error = -30.50871811819374
# Significant!
# For features ('x32', 'x23', 'x33') with max_error = -33.235722233067015
# Significant!
# For features ('x32', 'x23', 'x102') with max_error = -32.40546464667619
# Significant!
# For features ('x32', 'x23', 'x98') with max_error = -30.77212589906859
# Significant!
# For features ('x32', 'x23', 'x162') with max_error = -33.6604574523349
# Significant!
# For features ('x32', 'x23', 'x159') with max_error = -31.097548484318317
# Significant!
# For features ('x32', 'x23', 'x173') with max_error = -33.159160934502125
# Significant!
# For features ('x32', 'x23', 'x158') with max_error = -30.91490089740741
# Significant!
# For features ('x32', 'x23', 'x160') with max_error = -31.61382083032398
# Significant!
# For features ('x8', 'x23', 'x33') with max_error = -33.91208670862074
# Significant!
# For features ('x2', 'x23', 'x33') with max_error = -32.42159797819266
# Significant!
# For features ('x4', 'x23', 'x33') with max_error = -33.21373437494066
# Significant!
# For features ('x99', 'x23', 'x33') with max_error = -31.870108009684838
# Significant!
# For features ('x50', 'x23', 'x33') with max_error = -33.97675760917734
# Significant!
# For features ('x45', 'x23', 'x33') with max_error = -33.6600589798259
# Significant!
# For features ('x193', 'x33', 'x48') with max_error = -33.69240104853522
# Significant!
# For features ('x71', 'x23', 'x33') with max_error = -32.55362333731772
# Significant!
# For features ('x23', 'x6', 'x33') with max_error = -33.29773598068847
# Significant!
# For features ('x23', 'x5', 'x33') with max_error = -33.78949985862236
# Significant!
# For features ('x23', 'x39', 'x33') with max_error = -33.48012221049987
# Significant!
# For features ('x23', 'x175', 'x33') with max_error = -33.8207929913746
# Significant!
# For features ('x23', 'x67', 'x33') with max_error = -32.07144581348702
# Significant!
# For features ('x23', 'x41', 'x33') with max_error = -33.21091156254813
# Significant!
# For features ('x23', 'x33', 'x102') with max_error = -33.59216176390627
# Significant!
# For features ('x23', 'x33', 'x98') with max_error = -32.3393513420669
# Significant!
# For features ('x23', 'x33', 'x159') with max_error = -32.01317129121543
# Significant!
# For features ('x23', 'x33', 'x61') with max_error = -32.90707326973673
# Significant!
# For features ('x23', 'x33', 'x58') with max_error = -32.75526893185069
# Significant!
# For features ('x23', 'x33', 'x9') with max_error = -33.70078464198891
# Significant!
# For features ('x23', 'x33', 'x173') with max_error = -33.50185620820422
# Significant!
# For features ('x23', 'x33', 'x158') with max_error = -32.562174291448166
# Significant!
# For features ('x23', 'x33', 'x63') with max_error = -32.44750993068327
# Significant!
# For features ('x23', 'x33', 'x160') with max_error = -32.68681500738375

# %%
len(List4_2cvd_3_me)
# Out:
# 35

# %%
List5_2cvd_3_me,List5_2cvd_2_me,List5_2cvd_0_me = combnfeats_MLR_evaby_crossval_metric(List4_2cvd_3_me,df_x,df_y,30,model,'max_error',-32)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x32', 'x99', 'x23') with max_error = -29.738438709850566
# Significant!
# For features ('x32', 'x23', 'x102') with max_error = -31.94912585338481
# Significant!
# For features ('x32', 'x23', 'x98') with max_error = -29.987769915458365
# Significant!
# For features ('x32', 'x23', 'x159') with max_error = -30.167704677535205
# Significant!
# For features ('x32', 'x23', 'x158') with max_error = -30.156735394637998
# Significant!
# For features ('x32', 'x23', 'x160') with max_error = -31.158948382484436
# Significant!
# For features ('x99', 'x23', 'x33') with max_error = -31.315703083209325
# Significant!
# For features ('x23', 'x67', 'x33') with max_error = -31.95803811032669
# Significant!
# For features ('x23', 'x33', 'x98') with max_error = -31.773985246882933
# Significant!
# For features ('x23', 'x33', 'x159') with max_error = -31.511611898535772
# Significant!
# For features ('x23', 'x33', 'x158') with max_error = -31.95218989464478

# %%
a,b,c = combnfeats_MLR_evaby_crossval_metric(List5_2cvd_3_me,df_x,df_y,500,model,'max_error',-32)
# Out:
# ----------Linear regression of n features evaby crossval starts----------
# Significant!
# For features ('x32', 'x99', 'x23') with max_error = -29.972558580173747
# Significant!
# For features ('x32', 'x23', 'x102') with max_error = -31.92578618016166
# Significant!
# For features ('x32', 'x23', 'x98') with max_error = -30.151293511739464
# Significant!
# For features ('x32', 'x23', 'x159') with max_error = -30.27243660650324
# Significant!
# For features ('x32', 'x23', 'x158') with max_error = -30.374302951355084
# Significant!
# For features ('x32', 'x23', 'x160') with max_error = -31.489471878703586
# Significant!
# For features ('x99', 'x23', 'x33') with max_error = -31.413102187662805
# Significant!
# For features ('x23', 'x67', 'x33') with max_error = -31.82143260278473
# Significant!
# For features ('x23', 'x33', 'x98') with max_error = -31.93491727222382
# Significant!
# For features ('x23', 'x33', 'x159') with max_error = -31.668267331721534

# %%
highest_ranked_combination_feats = List5_2cvd_3_me + List3_2cvd_3_nrmse + List4_2cvd_3_expv + List4_2cvd_3_nmae + List4_cvd_3_r2

# %%
# get rid of duplicates
highest_ranked_combination_feats = list(set(highest_ranked_combination_feats))
print(len(highest_ranked_combination_feats))
# Out:
# 17

# %%
highest_ranked_combination_feats
# Out:
# [('x99', 'x23', 'x33'),
#  ('x23', 'x33', 'x102'),
#  ('x23', 'x33', 'x158'),
#  ('x23', 'x33', 'x98'),
#  ('x186', 'x23', 'x102'),
#  ('x32', 'x23', 'x98'),
#  ('x32', 'x23', 'x160'),
#  ('x32', 'x99', 'x23'),
#  ('x23', 'x6', 'x98'),
#  ('x23', 'x33', 'x159'),
#  ('x188', 'x33', 'x48'),
#  ('x32', 'x23', 'x102'),
#  ('x32', 'x23', 'x158'),
#  ('x23', 'x175', 'x102'),
#  ('x23', 'x6', 'x102'),
#  ('x32', 'x23', 'x159'),
#  ('x23', 'x67', 'x33')]
